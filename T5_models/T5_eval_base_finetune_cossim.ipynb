# %%
import re
import sacrebleu

import pandas as pd
from sklearn.model_selection import train_test_split

from transformers import T5ForConditionalGeneration, T5Config, T5Tokenizer
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AdamW

# %%
model_name = 'utrobinmv/t5_translate_en_ru_zh_base_200'
model = T5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = T5Tokenizer.from_pretrained(model_name)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# T5ForConditionalGeneration(
#   (shared): Embedding(65100, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(65100, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(65100, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=65100, bias=False)
# )

# %%
import os

# Path to your checkpoint
latest_checkpoint_path = '/Users/lauralee/Desktop/skoo/AY2324/sem 2/CS4248/project/latest_checkpoint_t5_base_consistency.pt'
model_name = "t5_base_finetune_cossim" # For naming of csv files (i.e. base, finetune, cosinesim, sbert)

# Load the checkpoint
checkpoint = torch.load(latest_checkpoint_path, map_location='cpu')

# Update the model's parameters
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
file_path_val = '/Users/lauralee/Desktop/skoo/AY2324/sem 2/CS4248/project/validation.csv'

val_df_unfiltered = pd.read_csv(file_path_val)
val_df_unfiltered
# Out:
#                                                     en  \
# 0    Last year I showed these two slides so that  d...
# 1    But this understates the seriousness of this p...
# 2    The arctic ice cap is, in a sense,  the beatin...
# 3        It expands in winter and contracts in summer.
# 4    The next slide I show you will be  a rapid fas...
# ..                                                 ...
# 874  You increase paralysis, and you decrease satis...
# 875                        Everybody needs a fishbowl.
# 876  This one is almost certainly too limited --  p...
# 877  But the absence of some metaphorical fishbowl ...
# 878                               Thank you very much.
#
#                                                     zh
# 0    去年我给各位展示了两个 关于北极冰帽的演示 在过去三百万年中 其面积由相当于美国南方48州面...
# 1                      但这些没能完全说明这个问题的严重性 因为这没有表示出冰帽的厚度
# 2                             感觉上，北极冰帽 就好象全球气候系统中跳动的心脏
# 3                                        冬天心脏舒张，夏天心脏收缩
# 4                                下面我要展示的是 在过去25年里的极剧变化
# ..                                                 ...
# 874                                  你增加了的是瘫痪，减少了的是满足。
# 875                                     每个人都需要这么个“鱼缸”。
# 876                至于这个（鱼缸）嘛，对这条鱼 可能是小了点，对于我们几乎肯定是太小了。
# 877                  但是，没有这么个象征性的鱼缸那就 意味着苦难将至， 也许是，灾难。
# 878                                              非常感谢。
#
# [879 rows x 2 columns]

# %%
val_df = []

for index, row in val_df_unfiltered.iterrows():
  src_text = row['zh']
  ref_text = row['en']
  input_tokens = tokenizer(src_text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids.to(device)
  reference_tokens = tokenizer(ref_text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids.to(device)
  if input_tokens.size(1) > 27 or reference_tokens.size(1) > 27: # Since we translating both ways, check both sides to align predictions and references array
    continue
  else:
    val_df.append(row)

val_df = pd.DataFrame(val_df)
val_df
# Out:
#                                                     en  \
# 1    But this understates the seriousness of this p...
# 2    The arctic ice cap is, in a sense,  the beatin...
# 3        It expands in winter and contracts in summer.
# 4    The next slide I show you will be  a rapid fas...
# 5                  The permanent ice is marked in red.
# ..                                                 ...
# 874  You increase paralysis, and you decrease satis...
# 875                        Everybody needs a fishbowl.
# 876  This one is almost certainly too limited --  p...
# 877  But the absence of some metaphorical fishbowl ...
# 878                               Thank you very much.
#
#                                       zh
# 1        但这些没能完全说明这个问题的严重性 因为这没有表示出冰帽的厚度
# 2               感觉上，北极冰帽 就好象全球气候系统中跳动的心脏
# 3                          冬天心脏舒张，夏天心脏收缩
# 4                  下面我要展示的是 在过去25年里的极剧变化
# 5                                红色的是永冻冰
# ..                                   ...
# 874                    你增加了的是瘫痪，减少了的是满足。
# 875                       每个人都需要这么个“鱼缸”。
# 876  至于这个（鱼缸）嘛，对这条鱼 可能是小了点，对于我们几乎肯定是太小了。
# 877    但是，没有这么个象征性的鱼缸那就 意味着苦难将至， 也许是，灾难。
# 878                                非常感谢。
#
# [508 rows x 2 columns]

# %% [markdown]
# backwards evaluation from chinese to english

# %%
prefix = 'translate to en: '

predictions, references = [], []

for index, row in val_df.iterrows(): 
  print("Row: ", str(index), ", translating: ", row["zh"])
  src_text = prefix + row['zh']
  input_ids = tokenizer(src_text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids.to(device)
  generated_tokens = model.generate(input_ids)
  translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
  print("translation: ", translation)
  predictions.append(translation)
  references.append(row['en'])

references = [[reference] for reference in references]
# Out:
# Row:  1 , translating:  但这些没能完全说明这个问题的严重性 因为这没有表示出冰帽的厚度
# translation:  But these do not fully explain the severity of the problem, because this does not indicate the thickness of the ice cap.
# Row:  2 , translating:  感觉上，北极冰帽 就好象全球气候系统中跳动的心脏
# translation:  The Arctic ice cap feels like a beating heart in the global climate system.
# Row:  3 , translating:  冬天心脏舒张，夏天心脏收缩
# translation:  The heart is swelled in winter and the heart contractes in summer.
# Row:  4 , translating:  下面我要展示的是 在过去25年里的极剧变化
# translation:  Below I want to show you the dramatic changes that have taken place over the past 25 years.
# Row:  5 , translating:  红色的是永冻冰
# translation:  The red is the permafrost ice.
# Row:  8 , translating:  在25年的时间里，它从这里，到了这里
# translation:  25 years later, it came from here to here.
# Row:  10 , translating:  如果突破顶点，温室气体排放量 将是现有大气层中的全球温室污染总量
# translation:  If it breaks through, the GHG emissions will be the total global greenhouse gas pollutant in the existing atmosphere.
# Row:  11 , translating:  在阿拉斯加的一些浅湖里 已经可以看到水中探头的沼气泡
# translation:  In some shallow lakes in Alaska, biobubbles can already be seen inside the water probe.
# Row:  12 , translating:  去年冬天，University of Alaska的Katey Walter教授 结队去了一个浅湖
# translation:  Last winter, Professor Katey Walter of the University of Alaska teamed up to a shallow lake.
# Row:  13 , translating:  哇（开心而又惊叹滴笑） 戈尔：她很好，我们怎么样呢？
# translation:  Wow (quickly laughing) Gore: She's fine, what about us?
# Row:  14 , translating:  有一个原因，北方沉积的大量热能 加热了格陵兰岛
# translation:  For one reason, the large amounts of thermal energy deposited in the north heated Greenland Island.
# Row:  15 , translating:  这是一条每年融化的河
# translation:  It is a river that melts every year.
# Row:  16 , translating:  但流量却比往年都要大
# translation:  But the flow is larger than in previous years.
# Row:  17 , translating:  这是格陵兰岛西南的Kangerlussuaq河
# translation:  This is the south-west of Greenland's Kangerlussuaq River.
# Row:  18 , translating:  如果你想了解陆地上的冰块融化 如何使得海平面上升 这里就是它的入海口
# translation:  If you want to understand how the ice on land melts and raises sea levels, this is its entry into the sea.
# Row:  19 , translating:  这里的流量正在急速上升
# translation:  Traffic is rising rapidly here.
# Row:  20 , translating:  南极，地球的另一端 这个行星上最大的冰块
# translation:  Antarctica, the planet's largest ice block.
# Row:  21 , translating:  上个月，科学家报告整个大洲 正处于冰量减少的阶段
# translation:  Last month, scientists reported that the continent was in a phase of decreasing ice.
# Row:  22 , translating:  在南极洲的西部突然发现 几个低于海平面的岛屿正在加速融化
# translation:  Suddenly several islands below sea level are being discovered in the western part of Antarctica, accelerating their melting.
# Row:  23 , translating:  这相当于海平面上20英尺，和格陵兰岛一样
# translation:  20英尺 above sea level, the same as Greenland.
# Row:  25 , translating:  全球40%从其融水中 获得一半的饮用水
# translation:  40% of the world gets half its drinking water from it.
# Row:  26 , translating:  在安第斯山脉,这条冰河 是这座城市的饮用水源
# translation:  In the Andes, this ice river is the city's drinking water source.
# Row:  27 , translating:  流量正在增加
# translation:  Traffic is increasing.
# Row:  28 , translating:  但当它们消失时，我们也将失去饮用水
# translation:  But when they disappear, we will also lose our drinking water.
# Row:  29 , translating:  在California, Sierra的积雪 每年减少40%
# translation:  In California, Sierra's snowfall is reduced by 40% per year.
# Row:  30 , translating:  对于蓄水而言，这是一个打击
# translation:  For water storage, this is a blow.
# Row:  31 , translating:  而且如你看到的，预计是非常严重的
# translation:  And as you can see, it's expected to be very serious.
# Row:  32 , translating:  全球的干燥化 正在导致火灾数量急剧增加
# translation:  Global drying is causing a sharp increase in the number of fires.
# Row:  33 , translating:  而全世界的灾害数量 也正以绝对显著的 空前的速度增加
# translation:  The number of disasters around the world is also increasing at an unprecedented rate.
# Row:  34 , translating:  在过去三十年内，灾害总数达到了 更早七十五年总数的四倍
# translation:  In the past 30 years, the total number of disasters has reached four times that of the previous 75 years.
# Row:  35 , translating:  这是一种完全不可持续的模式
# translation:  This is a completely unsustainable model.
# Row:  36 , translating:  如果看下历史 你可以看到发生了些什么
# translation:  If you look at history, you can see what happened.
# Row:  40 , translating:  石油很重要，煤炭最为紧要
# translation:  Oil is very important, coal is the most important.
# Row:  41 , translating:  美国 正成为全球最大的两个排放国之一，和中国一起
# translation:  The United States is becoming one of the world's two largest emitters, along with China.
# Row:  42 , translating:  解决方案曾经是建造一个使用更多煤碳的星球
# translation:  The solution was to build a planet with more coal-carbons.
# Row:  43 , translating:  但我们已经开始看到海洋的变化了
# translation:  但是, we are beginning to see the oceans change.
# Row:  44 , translating:  这里是近年已经取消的一些 以及一些新的绿色替代方案
# translation:  Here are some that have been canceled in recent years, as well as some new green alternatives.
# Row:  46 , translating:  那个画面让我想起了什么
# translation:  That picture reminded me of something.
# Row:  47 , translating:  圣诞前后，在我的家乡田纳西 挖出了几十亿升的煤淤泥
# translation:  Before and after Christmas, in my hometown of Tennessee, billions of litres of coal were mined.
# Row:  48 , translating:  可能你在新闻上看过
# translation:  You may have seen it in the news.
# Row:  49 , translating:  这里，是全美第二大的废水排放
# translation:  这是美国第二大 废水排放国。
# Row:  50 , translating:  这发生于圣诞前后
# translation:  This happened before and after Christmas.
# Row:  51 , translating:  有一则这样的煤碳行业广告
# translation:  There is one such coal-carbon industry advertisement.
# Row:  52 , translating:  录象：♪♫煤炭酷先生是高兴和快乐的化身
# translation:  Video: *** Mr. Coal is a joyful and happy incarnationist.
# Row:  53 , translating:  在美国你可以见到他富饶多产 他还帮助我们发展经济
# translation:  In the U.S., you can see that he's prolific and also helps us grow our economy.
# Row:  54 , translating:  煤炭酷先生每天都在变得更干净
# translation:  Mr. Coal is getting cleaner every day.
# Row:  55 , translating:  他可爱实惠，为工人们带来工作机会
# translation:  He's cute and affordable, bringing jobs to workers.
# Row:  56 , translating:  戈尔：这里是West Virginia，许多煤炭的原产地
# translation:  GOL: West Virginia, the birthplace of many coals.
# Row:  57 , translating:  最大的山顶采矿是head of Massey Coal
# translation:  The largest mountaintop mining is the head of Massey Coal.
# Row:  59 , translating:  戈尔：所以气候保护联盟 开展了两个项目
# translation:  Gore: So the Climate Protection Alliance launched two projects.
# Row:  60 , translating:  这是其中的一个，其中一个的一部分
# translation:  This is one of them, part of it.
# Row:  61 , translating:  演员：在COALergy，我们非常严肃地对待 气候变化对我们的事业威胁
# translation:  Actor: At COALergy, we take climate change very seriously as a threat to our cause.
# Row:  63 , translating:  事实上，煤炭并不肮脏
# translation:  In fact, coal is not dirty.
# Row:  64 , translating:  我们认为，它是干净的 好闻的
# translation:  我们认为,它是干净的, smelly.
# Row:  65 , translating:  因此，不必为全球变暖而担心
# translation:  Therefore, there is no need to worry about global warming.
# Row:  66 , translating:  让我们来搞定吧
# translation:  让我们来解决这个问题。
# Row:  67 , translating:  演员：清洁煤炭，你已经听过关于它的许多
# translation:  Actor: Clean coal, you've heard a lot about it.
# Row:  68 , translating:  所以，让我们去看看如同艺术一般的清洁煤炭工厂吧
# translation:  那么, let's look at the art-like clean coal plant.
# Row:  69 , translating:  壮观！机器有些喧哗
# translation:  Magnificent! the machine is rumbling.
# Row:  70 , translating:  但这是清洁煤炭技术的声音
# translation:  But that's the sound of clean coal technology.
# Row:  71 , translating:  虽然烧煤是导致全球变暖的主要原因之一 你在这里所见到的令人折服的清洁煤炭技术 改变了一切
# translation:  Although coal burning is one of the main causes of global warming, you can see that the complacent clean coal technology has changed everything.
# Row:  72 , translating:  好好看看吧！这就是如今的清洁煤炭技术
# translation:  OK, that's clean coal technology right now.
# Row:  73 , translating:  戈尔：最后是这个正面的方案 可以应对经济挑战 和国家安全挑战
# translation:  戈尔:最后, this positive program can address economic and national security challenges.
# Row:  74 , translating:  录象：旁白:美国正处于危机 经济的、国家安全的、气候的危机
# translation:  Video: The United States is in a crisis of economics, national security, and climate.
# Row:  76 , translating:  但现在，有一种全新的解决这些难题的方案 Repower America
# translation:  But now there's a whole new solution to these problems, RePower America.
# Row:  77 , translating:  用百分百清洁的电力 用十年的时间
# translation:  100% clean electricity in a decade.
# Row:  78 , translating:  让美国人全新获得工作 让我们生活得更安全，并且让地球不在变暖
# translation:  New jobs for Americans will make our lives safer, and the planet will not get warmer.
# Row:  79 , translating:  最终，一个足够庞大的方案来解决我们的问题
# translation:  Ultimately, a plan large enough to solve our problems.
# Row:  80 , translating:  Repower America ，了解更多
# translation:  Repower America, learn more.
# Row:  81 , translating:  戈尔：最后一个
# translation:  Gore: The last one.
# Row:  82 , translating:  旁白：这是关于Repower America的
# translation:  Thread: This is about Repower America.
# Row:  83 , translating:  陈旧的肮脏石油正在谋杀我们的星球 这是让我们减少对其依赖的最快方式
# translation:  Old dirty oil is killing our planet, which is the fastest way to reduce our dependence on it.
# Row:  84 , translating:  男A：未来就在这里。风力、太阳能、新的能源网络
# translation:  MAN: The future is here.Wind, solar, new energy networks.
# Row:  85 , translating:  男B：新的投资创造更的报酬丰厚的工作
# translation:  男B: New investment creates better-paid jobs.
# Row:  86 , translating:  旁白：Repower America 。是时候梦想成真了！
# translation:  旁白:Repower America, it's time to come true!
# Row:  87 , translating:  戈尔：有一条古老的非洲谚语 如果想要走得快，独立前行
# translation:  Gore: There's an old African proverb if you want to walk fast, go independent.
# Row:  88 , translating:  如果想要走得远，结伴前行
# translation:  If you want to go far, partner with them.
# Row:  89 , translating:  我们需要的是走得远，而且快
# translation:  What we need is to go far, and fast.
# Row:  90 , translating:  非常感谢
# translation:  非常感谢
# Row:  91 , translating:  在去年的TED发言上我介绍了LHC
# translation:  Last year I introduced LHC to my TED talk.
# Row:  92 , translating:  而且我说过一定回来给大家实况更新 说说机器的运转情况
# translation:  And I told you to come back with a factual update about how the machine works.
# Row:  95 , translating:  非常具有野心
# translation:  Very ambitious.
# Row:  96 , translating:  这就是在日内瓦地下的机械
# translation:  This is the Geneva-based machinery.
# Row:  97 , translating:  我们用这些探测器给迷你大爆炸照相
# translation:  We use these detectors to take mini-explosion photos.
# Row:  99 , translating:  这是ATLAS建造过程中的壮观景象 可以看出规模巨大
# translation:  This is the spectacular sight of ATLAS's construction process. It can be seen on a large scale.
# Row:  100 , translating:  去年9月10日我们第一次启动这一机器
# translation:  On September 10th last year, we launched the machine for the first time.
# Row:  101 , translating:  这是一张ATLAS照下的照片
# translation:  This is a picture taken by ATLAS.
# Row:  102 , translating:  当时控制室里欢呼雀跃
# translation:  In the control room there was a rejoicing jump.
# Row:  106 , translating:  这表明我们的工作造成了文化冲击 这与它的科研冲击同样意义重大
# translation:  This shows that our work has caused a cultural shock, which is just as significant as its scientific impact.
# Row:  108 , translating:  这些导线传导1万3千安培电流 当机器全部启动
# translation:  These wires conduct 13,000 amphibious currents when all the machines are started.
# Row:  109 , translating:  现在你们之中的一些工程师可能会说 “不可能，这些电线太细了”
# translation:  Now some of your engineers might say, "It's impossible, these wires are too thin."
# Row:  110 , translating:  它们能做到 因为当温度极低它们就成了超导导线
# translation:  They can do this because when the temperature is extremely low they become superconductive wires.
# Row:  112 , translating:  在LHC中九千多个电磁铁里的一个接点上 有一个安装技术失误
# translation:  At one of the more than 9000 connectors in the LHC, there is a technical installation error.
# Row:  114 , translating:  这就是结果
# translation:  这就是结果。
# Row:  115 , translating:  非常令人震惊 因为那些磁铁重达20吨 它们移动了大约一英尺
# translation:  Extremely shocking because the magnets weighed up to 20 tons, they moved about a foot.
# Row:  116 , translating:  一共大概有50个磁铁受损
# translation:  A total of 50 magnets were damaged.
# Row:  117 , translating:  必须得把它们卸下来，这些工作已经完成
# translation:  They have to be removed, the work has been completed.
# Row:  118 , translating:  我们给它们排除故障，修理好
# translation:  Fixing them, fixing them.
# Row:  119 , translating:  现在就等着它们重新回到地下了
# translation:  Now wait for them to come back underground.
# Row:  120 , translating:  在三月底左右LHC被重新接通
# translation:  LHC was re-connected around the end of March.
# Row:  125 , translating:  谢谢
# translation:  谢谢
# Row:  126 , translating:  首先，我想请大家回忆一下你们在孩提时代 玩过的积木。
# translation:  首先, I would like to remind you of the building blocks that you used to play in your childhood.
# Row:  128 , translating:  理解物体的空间结构非常有助于 我们对很多周围事物的学习。
# translation:  Knowing the spatial structure of an object helps us learn about a lot of things around it.
# Row:  130 , translating:  按我们的思路来组合信息--那样会如何呢？
# translation:  Combining information according to our thinking-- what would happen?
# Row:  132 , translating:  简单地说，Siftable是一款互动计算机， 体积如饼干般大小。
# translation:  Simple to say, the Siftable is an interactive computer that's as big as a biscuit.
# Row:  134 , translating:  最重要的是，每块Siftable都是独立的， 就像积木一样，可以随意搭配。
# translation:  The most important thing is that each Siftable is independent, like a building block, which can be matched at will.
# Row:  135 , translating:  而且Siftables代表了一种新的生态系统 --即数字化信息的操作工具。
# translation:  Siftables represent a new ecosystem-- the operational tool for digitalizing information.
# Row:  137 , translating:  现在，我就来演示一些简单的。
# translation:  现在, let me show you some simple things.
# Row:  139 , translating:  而且这些Siftables能互相感知。
# translation:  These siftables can sense each other.
# Row:  140 , translating:  如果把它们一个挨一个摆好，有趣的现象就会发生。
# translation:  If you put them one by one, an interesting phenomenon will occur.
# Row:  141 , translating:  如果把它们随意一堆，他们也会察觉到， 那就会有点儿混乱。
# translation:  If you put them all together, they'll notice a bit of confusion.
# Row:  142 , translating:  它们还能感知彼此的移动和倾斜。
# translation:  They can also sense each other's movement and tilt.
# Row:  145 , translating:  如果倒多了，可以再倒回去一些。
# translation:  If it's more, you can revert some.
# Row:  148 , translating:  Siftables还可以玩拼字游戏--一种Scrabble和Boggle混搭的拼字游戏。
# translation:  Siftables can also play a spelling game-- a type of ccrabble and boggle that mixes.
# Row:  151 , translating:  谢谢大家。
# translation:  谢谢大家。
# Row:  153 , translating:  孩子们非常喜欢Siftables。
# translation:  The kids loved the siftables.
# Row:  154 , translating:  而且有趣的是在玩这个拼字游戏的时候 我们并不需要向他们解释什么。
# translation:  有趣的 is that we don't need to explain anything to them when playing the spelling game.
# Row:  155 , translating:  只要跟他们说这是个“拼字”游戏时， 他们就知道该怎么做了。
# translation:  只要告诉 them it's a spelling game, they know what to do.
# Row:  156 , translating:  现在屏幕上显示的是另一些人在体验Siftables。
# translation:  Now the screen shows someone else experiencing Siftables.
# Row:  157 , translating:  右下角这位是年龄最小的体验者。
# translation:  In the lower right corner is the youngest person to experience it.
# Row:  158 , translating:  他只是想把Siftables堆在一起。
# translation:  He just wanted to stack the siftables together.
# Row:  159 , translating:  在他看来，Siftables只是积木。
# translation:  In his view, the siftables are just building blocks.
# Row:  160 , translating:  现在屏幕上显示的是一种动画功能的互动尝试。
# translation:  The screen now shows an interactive attempt to animate.
# Row:  161 , translating:  我们希望Siftables能成为学习语言的帮手。
# translation:  We want Siftables to be a language assistant.
# Row:  162 , translating:  画面上的这个孩子叫Felix。
# translation:  The child in the picture is Felix.
# Row:  164 , translating:  看，他把太阳加上去了。
# translation:  He added the sun.
# Row:  165 , translating:  视频：太阳升起来了。
# translation:  Video: The sun rises.
# Row:  166 , translating:  大卫·梅若：现在他把拖拉机加上去了。
# translation:  David Mayo: He added the tractor.
# Row:  167 , translating:  视频：橙色的拖拉机。
# translation:  Video: The orange tractor.
# Row:  168 , translating:  做的不错！
# translation:  OK!
# Row:  170 , translating:  梅若：他在编写属于他的动画故事。
# translation:  Mayo: He's writing his animated story.
# Row:  171 , translating:  视频：你好！
# translation:  Video: Hello!
# Row:  172 , translating:  梅若：这是个开放式结局的故事， 他在计划怎样展开故事情节。.
# translation:  Mayo: This is an open-ended story about how he plans to start the story.
# Row:  173 , translating:  视频：猫坐着热气球飞走了。
# translation:  Video: The cat was seated in a hot air balloon.
# Row:  175 , translating:  每个模块有四档可供调节， 任君选择。
# translation:  Each module has four patches to adjust for.
# Row:  177 , translating:  还有类似混响器、滤声器作用的Siftable模块。
# translation:  There are also Siftable modules that act like a mixer or filter.
# Row:  178 , translating:  把这类模块靠近声音模块就可以调整声音了。
# translation:  Putting these modules close to the sound module can adjust the sound.
# Row:  179 , translating:  接下来，可以用控制总体节奏和音量的Siftable模块
# translation:  Next, you can control the overall rhythm and volume of the Siftable module.
# Row:  180 , translating:  靠近编辑模块的Siftable来调整节奏和音量。 我们来看一下。
# translation:  Siftable near the editing module to adjust the rhythm and volume. Let's look at it.
# Row:  182 , translating:  现在加入贝斯音。
# translation:  Now join the bass.
# Row:  183 , translating:  视频： 梅若：现在加入一些打击乐器的声音。
# translation:  Video: Mayo: Now add some punching instruments.
# Row:  184 , translating:  视频： 梅若：现在把滤声模块靠近鼓声模块，这样可以调整声音。
# translation:  Video: Mayo: Put the filter module close to the drum module, so you can adjust the sound.
# Row:  185 , translating:  视频： 梅若：我来把节奏加快些 只需把节奏模块靠近编辑模块。
# translation:  Video: Mayo: I'm going to speed it up a little bit. Just put the rhythm module near the edit module.
# Row:  186 , translating:  视频： 梅若：现在再把滤声模块靠近贝斯模块滤声。
# translation:  Video: Mayo: Now bring the filter module closer to the Bass module.
# Row:  187 , translating:  视频： 梅若：在音乐演奏的过程中还可以重新编排。
# translation:  Video: Mayo: It can also be reorganized during the musical process.
# Row:  189 , translating:  最后，我来结束整个演奏， 用音量模块靠近编辑模块，用左边这个档。
# translation:  Finally, I'm going to end the whole play with a volume module near the editing module, using this file on the left.
# Row:  190 , translating:  谢谢大家。
# translation:  谢谢大家。
# Row:  194 , translating:  非常感谢大家。
# translation:  非常感谢大家。
# Row:  195 , translating:  我期待着和大家共同探讨。
# translation:  I look forward to discussing it with you.
# Row:  196 , translating:  我是个作家，写作不仅仅是我的职业，更是我一辈子的挚爱与迷恋
# translation:  I am a writer, not only my profession, but also the love and fascination of my life.
# Row:  197 , translating:  我是个作家，写作不仅仅是我的职业，更是我一辈子的挚爱与迷恋
# translation:  I am a writer, not only my profession, but also the love and fascination of my life.
# Row:  198 , translating:  我是个作家，写作不仅仅是我的职业，更是我一辈子的挚爱与迷恋
# translation:  I am a writer, not only my profession, but also the love and fascination of my life.
# Row:  199 , translating:  我认为这是永远不会改变的事情
# translation:  我认为, this is something that will never change.
# Row:  203 , translating:  真的，就这样了，彻底地，没救了，玩完了！
# translation:  真的, that's it, totally unsaved, overplayed!
# Row:  206 , translating:  他们可真是会安慰人呀
# translation:  They can really comfort people.
# Row:  208 , translating:  我当时遭遇到了同样的质疑，人们说：你不怕永远都不会成功吗？
# translation:  I was faced with the same question, and people said: "Are you not afraid of never succeeding?"
# Row:  211 , translating:  对于这些质疑，最简单的回答是：“怕”
# translation:  The simplest answer to these questions is 'fear'.
# Row:  212 , translating:  是的，这种种一切都让人害怕，直到今天也一样
# translation:  是的, everything is frightening to this day as well.
# Row:  213 , translating:  是的，这种种一切都让人害怕，直到今天也一样
# translation:  是的, everything is frightening to this day as well.
# Row:  216 , translating:  这难道是一种理性的想法吗？
# translation:  这是一个理性的想法吗?
# Row:  220 , translating:  没人说：“约翰，化学工作遇到瓶颈了吗？怎么样了？”
# translation:  Nobody said, "John, you've got a bottleneck?"
# Row:  221 , translating:  从来不曾发生过这种问话
# translation:  No such questioning has ever happened.
# Row:  226 , translating:  对于你毕生的作品，这是多么激进的说法啊
# translation:  对于 your life's work, this is a radical statement.
# Row:  229 , translating:  你们都觉得这一观点毫无问题吗?
# translation:  大家觉得这个观点没问题吗?
# Row:  231 , translating:  这个观点不但可憎，而且可怕，我不希望这样的想法一直延续到下个世纪
# translation:  This view is not only disgusting, but also horrifying, I don't want this idea to continue until the next century.
# Row:  233 , translating:  我觉得鼓励我们伟大的创作天才们继续活下去会更加好
# translation:  I think it would be better to encourage our great creative geniuses to continue living.
# Row:  236 , translating:  我今后还有大约四十年的创作生涯
# translation:  I still have about 40 years of creative career to go through.
# Row:  239 , translating:  天啊，这是何种的想法！
# translation:  天哪,这是什么主意!
# Row:  241 , translating:  我可不想变成那样 我希望继续从事我所热爱的写作事业，所以问题就变成：我应该怎么办呢？
# translation:  I don't want to be that way, so the question becomes: What should I do?
# Row:  242 , translating:  我希望继续从事我所热爱的写作事业，所以问题就变成：我应该怎么办呢？
# translation:  我想继续 my love of writing, so the question becomes: What should I do?
# Row:  246 , translating:  这一寻找最后把我带到了古希腊和古罗马
# translation:  This search finally took me to ancient Greece and Rome.
# Row:  247 , translating:  所以请耐心听我讲，因为最后会绕回到我们的问题
# translation:  So please listen to me, because at the end of the day it will come back to our problem.
# Row:  250 , translating:  希腊人普遍地称这种伴随着创造力的守护精灵为“守护神”
# translation:  The Greeks generally refer to this as the "guardian" of creativity.
# Row:  256 , translating:  我们都可以理解它的运作模式，不是吗？
# translation:  我们可以理解它的运作模式,不是吗?
# Row:  259 , translating:  如果你的作品很烂，同样也不全是你的错
# translation:  If your work is bad, it's not all your fault either.
# Row:  263 , translating:  而我要说的是，我认为那是一个巨大的错误
# translation:  我要说的是,我认为那是个大错误。
# Row:  265 , translating:  无异于要求他吞下太阳，这对于脆弱的个体而言，是太大的责任
# translation:  It's no different than asking him to swallow the sun, which is too much of a responsibility for vulnerable individuals.
# Row:  268 , translating:  如果真是这样 至少我认为是这样的 那么我们的问题就是：现在该怎么办？我们能够改变这种状况吗？
# translation:  如果这是真的,那么我们的问题是: 我们可以改变这种状况吗?
# Row:  269 , translating:  那么我们的问题就是：现在该怎么办？我们能够改变这种状况吗？
# translation:  那么我们的问题是:我们能不能改变这种状况?
# Row:  271 , translating:  也许不行
# translation:  Maybe not.
# Row:  274 , translating:  也许，我无法说服你们大家都同意我的看法
# translation:  也许我不能说服你们都同意我的观点。
# Row:  276 , translating:  但我想说的是：为何不呢？为什么不换个角度思考呢？
# translation:  我想说的是:为什么不换个角度?
# Row:  279 , translating:  实际上，创作过程有时简直就是超乎常理
# translation:  In fact, the process of creation is sometimes just beyond common sense.
# Row:  281 , translating:  像一股雷鸣般的气息，朝她倾泻而下
# translation:  It was like a thunderstorm, pouring down at her.
# Row:  282 , translating:  她可以感受到它的来临，因为这股力量会撼动她脚下的大地
# translation:  She could feel it coming, because that force would shake the ground beneath her feet.
# Row:  283 , translating:  她可以感受到它的来临，因为这股力量会撼动她脚下的大地
# translation:  She could feel it coming, because that force would shake the ground beneath her feet.
# Row:  294 , translating:  在坐很多人或许也有类似经历
# translation:  Many people may have similar experiences sitting there.
# Row:  296 , translating:  这到底是怎么回事呢？
# translation:  到底是怎么回事?
# Row:  302 , translating:  他急切地想要捕捉它，但是没有办法，他既没有纸笔，也没有录音机
# translation:  He desperately wanted to capture it, but he didn't have a pen or a recorder.
# Row:  305 , translating:  突然，他奇异般地停止了继续抓狂和焦躁情绪，然后做了一件不寻常的事情
# translation:  Suddenly, he stopped obsessive and anxious, and then did something unusual.
# Row:  306 , translating:  突然，他奇异般地停止了继续抓狂和焦躁情绪，然后做了一件不寻常的事情
# translation:  Suddenly, he stopped obsessive and anxious, and then did something unusual.
# Row:  308 , translating:  我看上去像是能立马记下一首曲子的样子吗？
# translation:  Do I look like I can remember the next song?
# Row:  310 , translating:  或者，你可以今天去骚扰别人，去找莱昂纳德·科恩去
# translation:  Or you can harass someone today, go to Leonard Cohen.
# Row:  311 , translating:  或者，你可以今天去骚扰别人，去找莱昂纳德·科恩去
# translation:  Or you can harass someone today, go to Leonard Cohen.
# Row:  312 , translating:  自从那件事以后，汤姆的整个创作过程改变了
# translation:  Since then, Tom's entire creative process has changed.
# Row:  313 , translating:  不是作品变了，他的作品仍是一如既往的黑暗
# translation:  His work hasn't changed, his work is still as dark as ever.
# Row:  318 , translating:  不仅是烂，而且是彻底的糟糕透顶，我开始觉得我应该放弃写这本书
# translation:  Not only was it bad, but I started to feel like I should give up writing this book.
# Row:  319 , translating:  这时我想起了汤姆对着天空喊话的事情，然后我试了试
# translation:  Then I thought about Tom shouting at the sky, and then I tried to do it.
# Row:  320 , translating:  这时我想起了汤姆对着天空喊话的事情，然后我试了试
# translation:  Then I thought about Tom shouting at the sky, and then I tried to do it.
# Row:  324 , translating:  “你若是想要这本书更好一些，现在轮到你出面，做你那部分工作了”
# translation:  "If you want a better book, it's your turn to come forward and do that part of your job."
# Row:  325 , translating:  “你要是不来帮忙，那就见你的鬼去吧”
# translation:  "If you don't want to help, go see your goddamn."
# Row:  333 , translating:  刹那间，他不再是个普通的凡人，他的生命从内部点燃，从心底发光
# translation:  At that moment he was no longer an ordinary human being, his life ignited from within, and lighted from the bottom of his heart.
# Row:  337 , translating:  人人都知道：那是神迹显现
# translation:  每个人都知道: it's a miracle that manifests itself.
# Row:  340 , translating:  这种方式很好，因为这正是我们需要的
# translation:  That's a good way to do it, because that's exactly what we need.
# Row:  344 , translating:  这是个很棘手的问题，也是创作生涯中最痛苦的自我认知之一
# translation:  It's a tricky problem, and one of the most painful self-cognitions in your creative career.
# Row:  348 , translating:  如果我们这样看待这一问题，一切就都改变了
# translation:  If we look at it this way, everything will change.
# Row:  351 , translating:  “不要害怕，不要气馁，只需做好你的那部分工作”
# translation:  "Don't be afraid, don't be discouraged, just do your part."
# Row:  352 , translating:  坚守在你的岗位上，无论你的岗位是什么：如果你是舞者，那就跳舞
# translation:  Hold on to your position, whatever your position is: If you're a dancer, then dance.
# Row:  353 , translating:  坚守在你的岗位上，无论你的岗位是什么：如果你是舞者，那就跳舞
# translation:  Hold on to your position, whatever your position is: If you're a dancer, then dance.
# Row:  355 , translating:  如果没有，那就请继续跳舞，坚守你的岗位，我依然为你喝彩：欧嘞！
# translation:  如果没有, please continue to dance and hold on to your position. I still cheer for you: Oasis!
# Row:  356 , translating:  如果没有，那就请继续跳舞，坚守你的岗位，我依然为你喝彩：欧嘞！
# translation:  如果没有, please continue to dance and hold on to your position. I still cheer for you: Oasis!
# Row:  357 , translating:  我坚信我们必须传授这一理念
# translation:  我坚信 that we must teach this concept.
# Row:  359 , translating:  谢谢
# translation:  谢谢
# Row:  360 , translating:  谢谢 谢谢
# translation:  谢谢
# Row:  361 , translating:  谢谢 主持人：欧嘞！
# translation:  谢谢!
# Row:  364 , translating:  我们经常试图提出一些较大的问题。
# translation:  We often try to ask bigger questions.
# Row:  365 , translating:  “生命是什么”我想是许多生物学家 不断地尝试在 在不同层面去理解的问题。
# translation:  "What is life?" I think many biologists are constantly trying to understand the problem at different levels.
# Row:  366 , translating:  我们尝试了许多方法， 把它分解到最小的组成部分。
# translation:  We tried many ways to break it down into the smallest part.
# Row:  373 , translating:  于是我们开始沿着这条路走下去 “我们能人工合成染色体吗？”
# translation:  于是我们开始沿着这条路走, "Can we artificially synthesize chromosomes?"
# Row:  374 , translating:  化学原则真的允许我们制造 这些我们从未实现过的 超大分子吗？
# translation:  Chemical principles really allow us to make these super-large molecules that we have never realized?
# Row:  375 , translating:  而且，就算我们可以，我们能激活它吗？
# translation:  而且,即使我们能激活它?
# Row:  376 , translating:  一对染色体，顺便说下，只是一些无活性的化学物质。
# translation:  A pair of chromosomes, by the way, are just some non-active chemicals.
# Row:  377 , translating:  我们数字化生命的速度不断地 以指数速度加快。
# translation:  Our digital life is accelerating exponentially.
# Row:  379 , translating:  我们于15年前开始这项工作。
# translation:  We started this work 15 years ago.
# Row:  380 , translating:  实际上它经过了好几个阶段。 在我们做最初的试验前，先进行了一次生物伦理学的评估。
# translation:  It actually went through several stages. Before we did the initial experiment, a bioethics assessment was carried out.
# Row:  381 , translating:  但结果是人工合成DNA 是非常困难的。
# translation:  But the result is that synthetic DNA is very difficult.
# Row:  383 , translating:  所以我们不得不创造一种新的方法 把这些小的片断排放在一起并纠正所有的错误。
# translation:  So we had to create a new way of ejected these small pieces together and correcting all the errors.
# Row:  384 , translating:  这是我们的第一次尝试，从Phi X 174基因组 的数字信息开始。
# translation:  This is our first attempt, starting with the digital information of the Phi X174 genome.
# Row:  385 , translating:  是一种能杀死细菌的小型病毒。
# translation:  A small virus that kills bacteria.
# Row:  388 , translating:  接着细胞释放出病毒粒子， 再返回来杀死了E.coli。
# translation:  The cell then releases the virus particles and returns to kill E. coli.
# Row:  389 , translating:  我最近与石油行业有一些交流， 我觉得他们对这个模式理解的非常透彻。
# translation:  I've had some conversations with the oil industry recently, and I think they understand this pattern very well.
# Row:  392 , translating:  设计是非常重要的， 并且如果你在计算机上开始使用数字信息。 那这些数字信息必须十分准确。
# translation:  设计 is very important, and if you start using digital information on a computer. These digital information must be accurate.
# Row:  396 , translating:  其中有我们设计过的独特部分。
# translation:  These are the unique parts that we designed.
# Row:  397 , translating:  你们可能听说过我们在其中加入了水印
# translation:  You may have heard that we added watermarks to it.
# Row:  398 , translating:  想想看 基因编码有四个字符：A,C,G和T。
# translation:  Think of the four characters that encode genes: A, C, G and T.
# Row:  400 , translating:  所以我们能使用基因编码来书写言语 句子，想法。
# translation:  所以我们可以用 genetic code to write sentences, ideas.
# Row:  401 , translating:  最初，我们所做的就是用它来签名。
# translation:  最初,我们用它来签名。
# Row:  402 , translating:  有些人有点失望我们没用它来做首诗。
# translation:  Some people are disappointed that we didn't use it to make a poem.
# Row:  406 , translating:  我们试着达到自动化的层面
# translation:  We try to reach the level of automation.
# Row:  407 , translating:  这看起来就像是一场篮球赛的对阵图
# translation:  It looks like a basketball match.
# Row:  409 , translating:  我们知道有个方法叫同源重组， 生物学上用来修复DNA， 它能把片断组合到一起
# translation:  We know that there is a method called co-source reorganisation, biologically used to repair DNA, it can combine fragments together.
# Row:  411 , translating:  你能看到在顶部的视图里，它的染色体四散在各个地方
# translation:  You can see in the top view, its chromosomes are scattered everywhere.
# Row:  412 , translating:  12到24小时以后，它将自己 又组合回之前的原状。
# translation:  12 to 24 hours later, it recombines itself back to its original form.
# Row:  413 , translating:  我们有数千种微生物有这种能耐
# translation:  数以千计的微生物 have this resilience.
# Row:  414 , translating:  这些微生物能够完全脱离水。 他们能存活在真空中
# translation:  These microbes are completely free from water. They can survive in a vacuum.
# Row:  415 , translating:  我完全确信外层空间存在着生命， 四处移动，遇到一个新的有水的环境
# translation:  I am fully convinced that there is life in outer space, moving around and encountering a new watery environment.
# Row:  416 , translating:  实际上，NASA已经展示过很多这样的例子。
# translation:  NASA has shown many such examples.
# Row:  418 , translating:  这并不是电子显微图像； 它仅仅是普通的光学显微镜。
# translation:  It's not an electronic micro-image; it's just a simple optical microscope.
# Row:  419 , translating:  这是如此之大的一个分子 我们能用一个光学显微镜观察它。
# translation:  这个分子 is so large that we can observe it with an optical microscope.
# Row:  420 , translating:  这些是时长约为六秒的图像。
# translation:  These are about six seconds long images.
# Row:  421 , translating:  这是我们所公开的最近的试验成果。
# translation:  These are the results of a recent trial that we have made public.
# Row:  423 , translating:  它超过了3亿分子重量。
# translation:  It weighs more than 300 million molecules.
# Row:  425 , translating:  那我们该如何来启动一段染色体，我们该如何激活它?
# translation:  那么,我们如何激活 a chromosome?
# Row:  426 , translating:  显然处理一个病毒非常简单 处理一个细菌就复杂多了
# translation:  Clearly, dealing with a virus is very simple. Dealing with a bacterium is much more complicated.
# Row:  430 , translating:  新的染色体进入细胞。
# translation:  新 chromosomes enter the cell.
# Row:  431 , translating:  实际上我们原以为这个过程就到此为止了。 但是我们试图将这个过程设计得更深入一些。
# translation:  实际上,我们以为这个过程已经结束。但我们试着把它设计得更深入一些。
# Row:  432 , translating:  这是一个重大的进化机制。
# translation:  This is a major evolutionary mechanism.
# Row:  434 , translating:  原本人们所持有的在进化的过程中 每次只会有一个基因发生变化 的观念忽略了生物的许多实际情况。
# translation:  The idea that only one gene can change in the course of evolution ignores many real-life situations.
# Row:  435 , translating:  有一种酶叫做限制酶 是能够消化DNA的
# translation:  There is an enzyme called a limitase that can digest DNA.
# Row:  436 , translating:  原先细胞中的染色体没有这种酶 没有这种酶 而当我们置入一段拥有这种酶的染色体
# translation:  The chromosomes in the original cells didn't have this enzyme, and when we put them into a section that had it, they weren't.
# Row:  438 , translating:  我们放入的基因导致它变成了蓝色。
# translation:  The genes we put in it turned blue.
# Row:  442 , translating:  现在，我要声明这不是创世纪 -- 这是建立在35亿年的进化上的
# translation:  Now, I would like to declare that this is not the Genesis century--it was built on three and a half billion years of evolution.
# Row:  444 , translating:  的新物种 为什么要这样做？
# translation:  为什么新物种会这样呢?
# Row:  445 , translating:  我认为出于一些需求我们这样做的原因是非常明显的。
# translation:  I think some of the reasons why we do this are very obvious.
# Row:  446 , translating:  我们的人口将在接下来的40年中从 65亿变成90亿
# translation:  未来40年,我们的人口将从6500万增长到900亿。
# Row:  447 , translating:  以我自己的例子来说 我出生于1946年
# translation:  For my own example, I was born in 1946.
# Row:  449 , translating:  我们在为65亿人提供食物，洁净的淡水， 医药，燃料上 都十分困难。
# translation:  We provide food, clean fresh water, medicine and fuel to 6500 million people.
# Row:  450 , translating:  换作90亿人那真是捉襟见肘了。
# translation:  换言之,900亿人 really do have elbows.
# Row:  452 , translating:  当我们尝试思考这个生物程序 或者任何能替代它的程序， 这会是一个巨大的挑战。
# translation:  当我们尝试 to think about this biological program, or anything that can replace it, would be a huge challenge.
# Row:  453 , translating:  接下来，当然，是这份材料 中所显示的被排放在大气层中 的二氧化碳。
# translation:  Next, of course, is the carbon dioxide emitted into the atmosphere.
# Row:  455 , translating:  电气行业只有十来种组件， 再看看从中能得到的多样性。
# translation:  There are only ten components in the electrical industry, look at the diversity that can be derived from it.
# Row:  456 , translating:  目前我们主要的限制来自于 生物学的现实情况 以及我们的想像力。
# translation:  Our main limitations come from the realities of biology and our imaginations.
# Row:  458 , translating:  我们现在所拥有的制造一个大型机器人的能力 能让我们每天制造一百万个染色体。
# translation:  我们现在拥有 the ability to make a large robot that allows us to make one million chromosomes every day.
# Row:  460 , translating:  并且这只是标准选择。 我们可以以生存能力来选择， 化学或燃料生产， 疫苗生产等等。
# translation:  And that's just a standard choice. We can choose from the ability to survive, chemical or fuel production, vaccine production, etc.
# Row:  462 , translating:  我们并不一定要知道它看起来是怎样。 我们确切地知道它们的基因编码究竟是什么样的。
# translation:  We don't necessarily know what it looks like.We know exactly what their genetic code is.
# Row:  463 , translating:  我们目前把注意力放在“第四代燃料”上。
# translation:  We are now focusing on the fourth generation of fuels.
# Row:  464 , translating:  你们最近看到了将谷物转化成乙醇 只是一个糟糕的试验。
# translation:  You've seen the transformation of grains into ethanol is just a bad trial.
# Row:  467 , translating:  并且我们认为在18个月里我们会取得 第一份第四代燃料。
# translation:  And we think in 18 months we'll get the first fourth-generation fuel.
# Row:  468 , translating:  阳光和二氧化碳是其中一个方法 --
# translation:  Sunshine and carbon dioxide are one way--
# Row:  469 , translating:  -- 但我们从全世界各地的发现中， 我们还有许多种其他方法。
# translation:  但我们从世界各地发现,我们还有很多其他方法。
# Row:  470 , translating:  这是一种微生物,1996年被记载
# translation:  This is a microbiome, recorded in 1996.
# Row:  471 , translating:  它生活在深海。 大约1.5英里深， 几乎是在沸腾的水温中。
# translation:  It lives in the deep sea. About 1.5 miles deep, almost at boiling water temperature.
# Row:  472 , translating:  它将二氧化碳转化成甲烷 使用氢分子最为它的能量来源。
# translation:  It converts carbon dioxide into methane using hydrogen molecules as its most important source of energy.
# Row:  476 , translating:  并且我们也在使用同样的工具 制造了几组即时疫苗。
# translation:  我们也 use the same tools to make several groups of instant vaccines.
# Row:  478 , translating:  我认为这情形是可以通过 预先制造混合疫苗来改变的。
# translation:  I think this can be changed by pre-creating a hybrid vaccine.
# Row:  487 , translating:  Seadragon同时也是一个非常灵活的架构。
# translation:  Seadragon is also a very flexible structure.
# Row:  488 , translating:  举个例子，这是一本完整的书，它的数据是非图像的。
# translation:  For example, this is a complete book, its data are non-images.
# Row:  489 , translating:  这是狄更斯所著的《荒凉山庄》，一列就是一章的内容。
# translation:  Dickens's "Desolate Mountains" is a chapter.
# Row:  491 , translating:  也许这会是一种阅读电子书的方式，
# translation:  Maybe it's a way to read e-books,
# Row:  492 , translating:  但是我可不推荐这么做。
# translation:  But I wouldn't recommend it.
# Row:  493 , translating:  接下来是一个更加实际的例子，这是一期《卫报》。
# translation:  The following is a more practical example, the Guardian.
# Row:  494 , translating:  每一张大图片是一版开篇，
# translation:  Each big picture is the opening page,
# Row:  496 , translating:  我们在这里做了小小的改动 在这一期《卫报》得角上。
# translation:  We made a small change in this issue of the Guardian.
# Row:  498 , translating:  如果你希望看到这辆车的特性，你可以看这里。
# translation:  如果你想要 to see the characteristics of this car, you can look here.
# Row:  499 , translating:  你还能看到其他的型号，甚至技术规格。
# translation:  You can also see other models, even technical specifications.
# Row:  500 , translating:  这种方式在一定程度上 避免了屏幕实际使用面积的限制。
# translation:  To a certain extent, this approach avoids the limitations of the screen's actual use area.
# Row:  501 , translating:  我们希望这个技术能够减少不必要的弹出窗口 以及类似的垃圾信息。
# translation:  We want this technology to reduce unnecessary pop-up windows and similar trash information.
# Row:  502 , translating:  显然，对于这项技术的应用， 数字地图也是显而易见的应用之一。
# translation:  Clearly, digital maps are one of the obvious applications for this technology.
# Row:  504 , translating:  这些只是在NASA的地理空间图片基础上
# translation:  These are based on NASA's geospatial images.
# Row:  505 , translating:  进行叠加处理而得到的美国的道路地图。
# translation:  A map of the U.S. road map is obtained by superimposed processing.
# Row:  506 , translating:  现在，我们先放下这些，看看其他的。
# translation:  让我们先放下这些,看看其他的。
# Row:  507 , translating:  实际上，这项技术已经放到网上了，大家可以自己去体验一下。
# translation:  实际上, this technology has been put on the Internet, so everyone can experience it for themselves.
# Row:  508 , translating:  这个项目叫Photosynth，
# translation:  This project is called Photosynth.
# Row:  510 , translating:  这项研究还得到了华盛顿大学Steve Seitz
# translation:  The study was also conducted by Steve Seitz of the University of Washington.
# Row:  511 , translating:  和微软研究院Rick Szeliski的协助。这是一个非常漂亮的合作成果。
# translation:  Assisted by Microsoft Research Institute Rick Szeliski. This is a very beautiful collaboration.
# Row:  512 , translating:  这个项目在互联网上已经得到应用了，它是基于Seadragon技术构建的。
# translation:  The project has already been implemented on the Internet, and it is based on Seadragon technology.
# Row:  514 , translating:  不过，这些图片在三维空间的排列事实上是非常有意义的。
# translation:  However, the arrangement of these images in three-dimensional space is actually very meaningful.
# Row:  516 , translating:  因此你可以看到这里的元素是稳定的幻灯放映或者全景成像， 而这些内容在空间上都是关联的。
# translation:  So you can see that the elements here are stable slide projections or panoramic imaging, and these contents are spatially related.
# Row:  517 , translating:  我不确定我们是否有时间来展示更多的环境全景。
# translation:  I'm not sure if we have time to show more panorama of the environment.
# Row:  518 , translating:  有很多例子比这个的空间感还要强。
# translation:  There are many more examples than this sense of space.
# Row:  520 , translating:  主要因为我们制作网站时，要顾及到很多法律问题。
# translation:  Primarily because we make websites, we have to take into account a lot of legal issues.
# Row:  521 , translating:  这里是利用Flickr网站上 的图像重建的巴黎圣母院。
# translation:  Here's an image of the Notre Dame on Flickr.
# Row:  523 , translating:  所有这些橘黄颜色的锥形都代表了一张 用来建立模型的图片。
# translation:  All these orange-colored cone shapes represent a picture used to build models.
# Row:  524 , translating:  这些全部是来自Flickr的图片， 被这样在空间里被串联起来。
# translation:  These are all images from Flickr, so they're chained up in space.
# Row:  525 , translating:  接着，我们便可如此自如的进行浏览。
# translation:  这样我们就可以自由地浏览了。
# Row:  526 , translating:  （鼓掌） 说实话，我从来没想过我会最后来为微软工作
# translation:  (Applause) To be honest, I never thought that I would end up working for Microsoft.
# Row:  527 , translating:  受到这样欢迎，真挺令人高兴的。
# translation:  It's a pleasure to be so welcome.
# Row:  530 , translating:  我记得这儿应该有 一个系列的照片 - 啊，在这儿。
# translation:  I remember there should have been a series of photos-- 啊, here.
# Row:  531 , translating:  这个是巴黎圣母院的海报。
# translation:  This is a poster of Notre Dame Paris.
# Row:  532 , translating:  我们可以钻到海报里 去看整个重建的环境。
# translation:  我们可以钻到海报里去看看整个重建的环境。
# Row:  533 , translating:  这里的重点呢便是我们可以 有效地利用网络社区。我们可以从每个人那里得到数据
# translation:  重点是我们能有效地利用网络社区。我们可以从每个人那里获取数据。
# Row:  535 , translating:  当所有这些图片交织在一起时， 所衍生出的 要远远超过单单收集起全部。
# translation:  When all these pictures are intertwined, the result is much more than a single collection.
# Row:  536 , translating:  这个模型所衍生出的，是整个地球。
# translation:  This model is derived from the entire Earth.
# Row:  537 , translating:  这如同是Stephen Lawler的《虚拟地球》的长尾市场。
# translation:  It's like Stephen Lawler's "Virtual Earth" long tail market.
# Row:  538 , translating:  这类模型，会随着人们的 使用而不断变的复杂， 变得更加有价值。
# translation:  These models, as people use them, become more complex and valuable.
# Row:  539 , translating:  用户的照片，会被大家 注上标签。
# translation:  The user's photos will be labeled.
# Row:  542 , translating:  非常感谢！
# translation:  非常感谢!
# Row:  545 , translating:  完全是基于图片的内容。
# translation:  完全 based on the content of the picture.
# Row:  546 , translating:  更令人兴奋的 在于图片所包含的大量文字语义信息。
# translation:  What's more exciting is the amount of semantic information contained in the pictures.
# Row:  548 , translating:  现在，假设这些图片全都与你的图片相连，那将会怎样？
# translation:  假设 all of these pictures are connected to yours, what would happen?
# Row:  549 , translating:  那时，所以这些语义信息的相互链接 以及内容量将是
# translation:  At that time, the interlinkages of these semantic messages and the amount of content will be.
# Row:  550 , translating:  巨大的。这将是非常典型的网络效应。
# translation:  Huge. This would be a very typical network effect.
# Row:  551 , translating:  CA:Blaise，太难以置信了。祝贺你们！ BAA:非常感谢各位！
# translation:  CA: That's unbelievable.BAA: Thank you very much!
# Row:  554 , translating:  只是一种适应性选择的结果 我们的祖先在很多世代以前就成功地做出了这种选择
# translation:  It's just an adaptive choice that our ancestors made many generations ago.
# Row:  555 , translating:  当然 我们所有都遵守同一种适应性规则
# translation:  Of course, we all follow the same rules of adaptability.
# Row:  556 , translating:  我们都出生于母腹 并且在这个世上生儿育女
# translation:  We are all born in the womb, and we have children in this world.
# Row:  557 , translating:  我们要经历成年礼的洗礼
# translation:  We have to go through adult baptism.
# Row:  559 , translating:  但是 你会发现 每种文化的歌曲韵律 和舞蹈节奏有着独一无二的特色
# translation:  但是, you will find that each culture's rhythm of song and dance has its own unique characteristics.
# Row:  561 , translating:  珠穆朗玛峰的山坡上
# translation:  Mount Everest on the slopes.
# Row:  563 , translating:  如果你认真思考 你发会现 这种不同的思维会让你看到希望
# translation:  If you think seriously, this different mindset will give you hope.
# Row:  566 , translating:  这个种族圈是人类的伟大遗产
# translation:  This racial circle is the great legacy of humanity.
# Row:  567 , translating:  它是我们的身份标志 也是我们作为具有很强的探究能力的物种的标志
# translation:  It is also a mark of our identity as a species with strong exploratory capabilities.
# Row:  570 , translating:  这其中的一个最重要的标志 就是语言的
# translation:  One of the most important signs is language.
# Row:  571 , translating:  在我们生活的这个星球上 原本有 6:00 种语言
# translation:  6:00的语言存在于我们生活的这个星球上。
# Row:  572 , translating:  语言不仅仅是发音 和语法规则
# translation:  Languages are not just about pronunciation and grammar rules.
# Row:  573 , translating:  语言是人类精神的闪光
# translation:  语言 is the flash of human spirit.
# Row:  574 , translating:  它是各个独特文化的精神实质 在这个物质世界上的承载体
# translation:  It is the spiritual substance of every unique culture in this material world.
# Row:  575 , translating:  每一种语言都是一种思想 一种意识和一种精神生态系统的长期沉淀和积累
# translation:  Every language is an idea, a consciousness and a mental ecosystem of long-term precipitation and accumulation.
# Row:  577 , translating:  这些语言已经没有传人 也就是说 除非采取有效的措施 它们将会彻底消失
# translation:  These languages are no longer permeable, i.e. unless effective measures are taken, they will disappear completely.
# Row:  581 , translating:  或者是科基语
# translation:  Or the coki language.
# Row:  582 , translating:  你就会发现 你不会说自己的母语了
# translation:  你会发现你不会说你的母语。
# Row:  588 , translating:  他们只要会听 就会说一种语言了
# translation:  只要他们能听,他们就能说出一门语言。
# Row:  590 , translating:  1957 年 五名传教士试图接近他们 但是这些人犯了一个致命的错误
# translation:  1957 Five missionaries tried to approach them, but they made a fatal mistake.
# Row:  593 , translating:  更恐怖的是 华拉尼不仅戮死外来人士
# translation:  What's more terrifying is that Wallani doesn't just kill outsiders.
# Row:  594 , translating:  他们还自相残杀
# translation:  They also kill each other.
# Row:  595 , translating:  54% 的死亡人口是被他们自己的族人戮死的
# translation:  54% of the dead were killed by their own people.
# Row:  600 , translating:  相反 这是一种复杂的形而上学的世界观
# translation:  Conversely, this is a complex metaphysical worldview.
# Row:  601 , translating:  这很有意思
# translation:  That's interesting.
# Row:  602 , translating:  如果我要你列举出世界上一些重要的宗教 你会举出哪些例子
# translation:  IF YOU want to list some of the world's most important religions, what examples would you give?
# Row:  603 , translating:  基督教 伊斯兰教 佛教 还有其他一些宗教
# translation:  基督教 Islam Buddhism There are other religions.
# Row:  606 , translating:  生者孕育了灵魂
# translation:  The living ones give birth to the soul.
# Row:  608 , translating:  因此 巫毒教徒喜欢说 你们去教堂做礼拜 言必称上帝
# translation:  So the witchlikes like to say that you go to church for worship, it is necessary to call God.
# Row:  609 , translating:  我们在圣殿起舞 成为神
# translation:  We danced in the temple to become God.
# Row:  610 , translating:  你已经被神灵附体 怎么还会受到伤害呢
# translation:  那么, how can you be harmed if you've been god-associated?
# Row:  614 , translating:  在这个血腥肆虐的大陆 这个种族从来没有被西班牙人征服过
# translation:  This bloody continent has never been conquered by the Spaniards.
# Row:  615 , translating:  至到今天 他们沿续着僧侣会统治制度 但是 他们的僧侣训诫非常的独特
# translation:  直到今天, they continue to rule the system of monks, but their teachings are very unique.
# Row:  619 , translating:  这里是多么的美丽 你要保护它
# translation:  多么美妙啊,你要保护它。
# Row:  621 , translating:  这种直觉的领会能力非常重要
# translation:  This intuitive comprehension is very important.
# Row:  623 , translating:  土著人并不会多愁善感 也不会承受思乡之苦
# translation:  土著人 don't have much sadness, they don't suffer from the pain of thinking about their country.
# Row:  625 , translating:  那么 这是什么意思呢
# translation:  那么,这是什么意思呢?
# Row:  627 , translating:  无论那座大山是神的住所 或者仅仅是一堆矿石 这都不重要
# translation:  Whether the mountain is God's dwelling place, or just a pile of minerals, it doesn't matter.
# Row:  628 , translating:  重要的是 这种象征意义 阐述了人与自然之间的关系
# translation:  Importantly, this symbolizes the relationship between man and nature.
# Row:  629 , translating:  我在英属哥伦比亚的丛林长大 受当地人思想的影响 我认为丛林是要被砍伐的
# translation:  I grew up in the jungles of British Columbia, influenced by local people's ideas. I think the jungle is to be cut down.
# Row:  632 , translating:  这张照片是我去年八月份在亚马逊西北地区拍摄的
# translation:  This photo was taken in the Amazon Northwest region last August.
# Row:  635 , translating:  混杂在一起
# translation:  Mixed together.
# Row:  640 , translating:  因为它们会被 人体器官中的一种名为单胺氧化酶的酶改变活性
# translation:  Because they can be altered by an enzyme in a human organ called monoamine oxidase.
# Row:  641 , translating:  要口服这些色胺物质 还有必须同时口服改变单胺氧化酶的活性的其他化学物质
# translation:  To do this, there are other chemicals that must simultaneously alter the activity of monoamine oxidase.
# Row:  644 , translating:  我们普通人会做各种各样的实验 不断地犯错误 结果却一无所获
# translation:  我们普通人 do a variety of experiments, and make mistakes all the time, but we don't get any results.
# Row:  645 , translating:  但是 如果你问印第安人 他们会说 植物会说话
# translation:  但是如果你问印第安人,他们会说植物会说话。
# Row:  646 , translating:  那是什么意思呢
# translation:  那是什么意思呢?
# Row:  648 , translating:  如果你问他们是如何给这些植物分门别类的 他们说 我想你对植物有一些研究
# translation:  If you ask them how to classify these plants, they say that you have some research on the plant.
# Row:  649 , translating:  你是不是对植物有一定的了解 我说 不是
# translation:  Do you know anything about plants? I don't think so.
# Row:  653 , translating:  所有的文化 一直受到新的生活方式 的强烈冲击
# translation:  All cultures have been strongly impacted by the new way of life.
# Row:  654 , translating:  这个问题并不在于技术本身
# translation:  The problem is not in the technology itself.
# Row:  659 , translating:  在那里 由于发现了金矿 人们蜂拥而至
# translation:  Because of the discovery of gold mines, people flocked there.
# Row:  664 , translating:  他立即被杀害了 他的叔叔和其他信徒
# translation:  He was immediately killed by his uncle and other believers.
# Row:  665 , translating:  一起逃亡到尼泊尔 他的母亲因为富农家庭成份
# translation:  His mother fled to Nepal because she was part of a wealthy farmer's family.
# Row:  667 , translating:  他的姐姐因为冒犯行为 而被送入学习班
# translation:  His sister was sent to the class for an offence.
# Row:  669 , translating:  西藏的痛楚让人难以承受 人类的救赎精神需要得到见证
# translation:  The pain in Tibet is unbearable, and the spirit of human redemption needs to be witnessed.
# Row:  674 , translating:  现代化的工业社会 只有将近三百年的历史
# translation:  现代化的工业社会 只有近300年的历史。
# Row:  680 , translating:  这位老人的祖父拒绝迁移
# translation:  The old man's grandfather refused to move.
# Row:  681 , translating:  他的家人担心他的安全 把他的所有武器和工具 都拿走了
# translation:  His family worried about his safety, taking all of his weapons and tools away.
# Row:  682 , translating:  你们都知道 因纽特人不怕冷 这是他们特天独厚的优势
# translation:  As you know, the Inuits are not afraid of cold. This is their unique advantage.
# Row:  683 , translating:  他们的雪橇的滑条最初是用 北美驯鹿皮包裹的冻鱼干做成的
# translation:  Their slippers were originally made of frozen fish wrapped in North American reindeer skin.
# Row:  690 , translating:  重新归还给因纽特人 我是我们的新家园 它的名字叫纽勒维特
# translation:  To the Inuit I am our new home. It's called Nyerwit.
# Row:  691 , translating:  这是一块独立的领土 他们控制那里所有的海洋资源
# translation:  It is an independent territory where they control all the marine resources.
# Row:  692 , translating:  这个例子很好地说明了 一个国家可以有所作为 想办法修复与它的人民之间的关系
# translation:  This example illustrates how a country can make a difference by trying to repair the relationship with its people.
# Row:  694 , translating:  因为那里是某个族类的家园
# translation:  Because it is the home of a certain ethnic group.
# Row:  698 , translating:  我们的电视频道在 156 个国家播放
# translation:  我们的电视频道在156个国家播放。
# Row:  699 , translating:  我们的杂志有上百万的读者
# translation:  Our magazine has millions of readers.
# Row:  701 , translating:  让所有种族的智慧 能够为全人类的福址做出贡献
# translation:  让所有种族的智慧 能够为整个人类做出贡献
# Row:  702 , translating:  谢谢
# translation:  谢谢
# Row:  704 , translating:  我想从一个公认的信条讲起。
# translation:  I want to start with an accepted creed.
# Row:  705 , translating:  什么样的公认的信条呢？
# translation:  What is the accepted creed?
# Row:  706 , translating:  就是整个西方工业社会所笃信不疑的 一个信条。
# translation:  That is the unquestionable precept of Western industrial society.
# Row:  708 , translating:  原因就是自由这东西在与本身就是美好的， 具有价值，为人们所必需。
# translation:  The reason is that freedom in itself is beautiful, valuable, and necessary.
# Row:  710 , translating:  使自由达到极大化的途径就是 最大限度的增加选择性。
# translation:  The way to maximise freedom is to maximize selectivity.
# Row:  713 , translating:  同样这个观念也深嵌于我们的日常生活之中。
# translation:  The same concept is embedded in our daily lives.
# Row:  714 , translating:  我来给你们举些例子看看当代社会的 进步发展让我们变得有可能做些什么事。
# translation:  Let me give you some examples of what the progressive development of modern society has made possible.
# Row:  715 , translating:  这是我家附近的一个超市。不算很大。
# translation:  This is a supermarket near my house. It's not very big.
# Row:  716 , translating:  我只想说说这里的色拉调料。
# translation:  I just want to talk about the coloring here.
# Row:  718 , translating:  你看，这就是超级市场的样子。
# translation:  看, that's what a supermarket looks like.
# Row:  721 , translating:  你没法不承认这可是不小的一堆选择吧。
# translation:  You can't deny that this is not a small set of choices.
# Row:  722 , translating:  换个行业，说说通讯。
# translation:  Change the industry, talk about communication.
# Row:  724 , translating:  你不用买，只需去租一架电话机回来。
# translation:  You don't have to buy, just rent a phone back.
# Row:  725 , translating:  通常情况是，那电话用到死都不会坏。
# translation:  通常情况下, the phone won't be bad to death.
# Row:  726 , translating:  那种日子早已一去不返了。
# translation:  Those days are long gone.
# Row:  727 , translating:  如今我们几乎有无穷无尽的电话品种， 尤其是手机。(显示漫画）
# translation:  Today we have almost endless phone varieties, especially mobile phones. (show comics)
# Row:  728 , translating:  这些都是未来的手机。
# translation:  These are the phones of the future.
# Row:  731 , translating:  这事的结果是， 人们跑到商店里问: 你们有没有一款不带这么多功能的?
# translation:  于是, people ran to the store and asked: "Are there any of these things that don't have so many functions?"
# Row:  732 , translating:  你想,回答会是什么？
# translation:  你们猜怎么回答?
# Row:  733 , translating:  回答是“没有”。
# translation:  The answer is no.
# Row:  734 , translating:  如今你已经不可能买到一款不干 那么多事的手机。
# translation:  现在 you can't buy a cell phone that doesn't do so much.
# Row:  735 , translating:  同样，在生活里的其它一些比购物更 对我们产生影响事情上， 这种选择的爆炸同样存在。
# translation:  Similarly, there are other things in life that affect us more than shopping, the explosion of choice is also present.
# Row:  738 , translating:  方案甲有如此这般疗效和风险。
# translation:  Programme A has such efficacy and risks.
# Row:  739 , translating:  方案乙有如此这般疗效和风险。 你想怎么治？
# translation:  Option B is so effective and risky. How do you treat it?
# Row:  740 , translating:  然后你说：“大夫，我该如何做？”
# translation:  Then you said, "Doctor, what should I do?"
# Row:  741 , translating:  医生又说一遍，甲有这些疗效和风险， 乙有那些疗效和风险。
# translation:  Physicians say again that A has these effects and risks, B has those effects and risks.
# Row:  742 , translating:  你想怎么治？
# translation:  What do you want to cure?
# Row:  743 , translating:  你再问医生：“大夫，你要是我，你选那种？”
# translation:  You ask the doctor, "If you were me, would you choose that?"
# Row:  744 , translating:  医生说：“但是我不是你。”
# translation:  The doctor said, "I'm not you."
# Row:  747 , translating:  他们为什么还要向我们做市场宣传？
# translation:  为什么他们还要向我们宣传市场?
# Row:  750 , translating:  现在我们的性别不是从父母那里继承下来， 而是由自己来发明。
# translation:  Our gender is not inherited from our parents, but invented by ourselves.
# Row:  751 , translating:  这样我们就可以随心所欲地的 重新塑造自己的性别身份。
# translation:  这样, we can re-create our gender identity as we please.
# Row:  754 , translating:  唯一你需要选择的就是和谁结婚， 而不是什么时候结，也不是结婚以后做什么。
# translation:  唯一的选择是和谁结婚,而不是什么时候结婚, 也不是做什么。
# Row:  755 , translating:  而如今呢，所有的事都可以拿来挑挑拣拣。
# translation:  现在, all things can be picked up.
# Row:  757 , translating:  这不是因为他们（比以前的学生）笨， 也不是因为他们不那么勤奋。
# translation:  Not because they're dumber than their former students, not because they're less diligent.
# Row:  759 , translating:  还是以后再说？我是该先要孩子， 还是先顾事业？
# translation:  还是以后再说?我需要孩子,还是先考虑事业?
# Row:  760 , translating:  这些都是费脑筋的问题。
# translation:  这些都是 brain-scrambling problems.
# Row:  762 , translating:  他们的确应该去想这些问题， 因为这都是些重要问题。
# translation:  They should really think about these issues, because they're all important ones.
# Row:  765 , translating:  不告诉你的理由是我也想用。
# translation:  不告诉你的理由是,我也想用它。
# Row:  769 , translating:  回还是不回这个Email？ 我该不该写这封信稿？
# translation:  回信还是不回信?我应该写这封信吗?
# Row:  771 , translating:  环顾四周， 不论大事还是小事， 物质的还是生活方式方面， 生活就是选择。
# translation:  环顾四周,不管 it's big or small, material or lifestyle, life is a choice.
# Row:  772 , translating:  我们过去生活的世界是这样的。
# translation:  我们过去的生活是这样的。
# Row:  773 , translating:  就是说，选择还是有的， 但不是事事都需要选择。
# translation:  就是说, there are choices, but not all things need to be chosen.
# Row:  774 , translating:  而今天我们生活的世界则是这样的。
# translation:  这就是我们今天所生活的世界。
# Row:  775 , translating:  问题是，这到底是好事还是坏事？
# translation:  问题是,这是好事还是坏事?
# Row:  776 , translating:  答案是肯定的。
# translation:  答案是肯定的。
# Row:  777 , translating:  我们都知道它的好处。 那么就让我来说说它的不好之处吧。
# translation:  我们都知道它的好处。那就让我来谈谈它的弊端吧。
# Row:  778 , translating:  所有这些选择对人们有两个影响， 而且是两个负面的影响。
# translation:  All these choices have two effects on people, and there are two negative ones.
# Row:  780 , translating:  面对这么许多的选择 人们发现要做出决定非常困难。
# translation:  Faced with so many choices, people find it very difficult to make a decision.
# Row:  783 , translating:  她的调查发现是 当这些客户 提供的互助基金种类每增加10个 参加的人数就减少2个百分点。
# translation:  Her survey found that when these clients provide mutual funds, the number of participants decreases by 2 percentage points.
# Row:  786 , translating:  明日复明日， 明日何其多， 当然，明天永远也不会到来。
# translation:  明天再也不会,当然。
# Row:  789 , translating:  所以，选择可能性过多的结果是麻痹僵化。
# translation:  So the result of over-selecting is paralysis.
# Row:  790 , translating:  它使得我们的世界变成这样样子
# translation:  It makes our world look like this.
# Row:  791 , translating:  当你进入极乐世界时， 你一定希望你做出的决定是正确的，是吗？
# translation:  When you enter the world of adoration, you must want your decision to be correct, right?
# Row:  792 , translating:  在那里你一定不想再选错互助基金， 或者是沙拉调料。
# translation:  You don't want to choose the wrong mutual fund, or salad dressing.
# Row:  794 , translating:  这里有几个原因。
# translation:  这里有几个原因。
# Row:  798 , translating:  其二，是经济学家称之为“机会成本”的东西。
# translation:  Second, economists call it "opportunity cost."
# Row:  802 , translating:  但这是你此时此刻应该想的事。
# translation:  但这是你现在应该想到的。
# Row:  803 , translating:  看看汉普顿的这两口子，
# translation:  Look at these two Hampton mouths,
# Row:  804 , translating:  昂贵的富人区，
# translation:  昂贵的富人区,
# Row:  805 , translating:  华丽的海滩，阳光明媚，他们拥有这一切。
# translation:  Beautiful beaches, sunny ones, they have it all.
# Row:  807 , translating:  “我要是回去就能把车停到我自己的门前了。”
# translation:  "I can stop the car in front of my own door."
# Row:  811 , translating:  这又是一个例子。 这幅漫画说明了好几个问题。
# translation:  Here's another example. This cartoon illustrates a number of issues.
# Row:  812 , translating:  它也说出了“活在当下”这个道理。 也许还包括做事情要一步一步来。
# translation:  It also says 'live in the present'. Perhaps it includes doing things step by step.
# Row:  814 , translating:  第三点，期望值增高。
# translation:  第三, expectations increase.
# Row:  815 , translating:  这点在有一次我去买一条 新牛仔裤时对我触动很大。
# translation:  It touched me a lot when I went to buy a new jeans.
# Row:  816 , translating:  我差不多总是穿牛仔裤。
# translation:  I almost always wear jeans.
# Row:  819 , translating:  店员说： 你要紧身型的，舒适型的，还是宽松型的？
# translation:  The clerk said: "You want to be tight, comfortable, or loose?"
# Row:  820 , translating:  前面要扣子的还是拉锁的？石磨的还是酸洗的？
# translation:  Should I pull the buttons in front of me? mellowed or acid washed?
# Row:  821 , translating:  要那种快磨破的么？
# translation:  Do you want to grind that fast?
# Row:  822 , translating:  直口的，还是缩口的？他喋喋不休地问着。
# translation:  Directly, or narrowly? he asked unceasingly.
# Row:  825 , translating:  我做得的确不错。这些选择 使得我有机会做的更好。
# translation:  I did really well. These choices gave me a chance to do better.
# Row:  826 , translating:  但是心里感觉却更糟。
# translation:  But my heart feels worse.
# Row:  827 , translating:  为什么？为这我还专门写了一本书 来为我自己找借口。
# translation:  Why? I also wrote a book for myself to justify it.
# Row:  829 , translating:  我以前期望值很低。 当牛仔裤就那么一种时，我没有过多指望。
# translation:  I had very low expectations. When jeans were like that, I didn't expect much.
# Row:  830 , translating:  当它们有一百种规格时，哼， 最好至少有一条是极致完美的。
# translation:  When they have a hundred specifications, at least one is perfect.
# Row:  831 , translating:  我那条的确不错，但是它还是不够完美。
# translation:  I did, but it wasn't perfect.
# Row:  834 , translating:  带来的只是使人们对结果不那么满意了， 即使那是好结果。
# translation:  It just makes people less happy with the results, even if it's a good result.
# Row:  835 , translating:  搞市场的人没有人懂得这个道理。
# translation:  No one in the market understands this.
# Row:  836 , translating:  因为如果他们里面有人懂的话， 你也就不会有机会知道这是什么意思了
# translation:  因为如果有人知道,你也不会有机会知道这是什么意思。
# Row:  839 , translating:  你再也不会被什么所惊喜， 因为你我的期望值比天还高。
# translation:  You won't be surprised anymore, because your expectations are higher than the sky.
# Row:  842 , translating:  这件事上我没有凑合，我尽力了。
# translation:  I didn't do anything about it, I did my best.
# Row:  843 , translating:  但是能凑合并不一定是坏事。
# translation:  But being able to merge isn't necessarily a bad thing.
# Row:  845 , translating:  这个世界该为此负责。 你有什么能做的么？
# translation:  这个世界应该对此负责。你能做些什么?
# Row:  847 , translating:  现在这个问题的答案显然就是：你。
# translation:  The answer to this question is: you.
# Row:  848 , translating:  你完全可以做得更好。
# translation:  You can do better.
# Row:  849 , translating:  那里摆着上百种牛仔裤， 你没有借口把事情搞砸。
# translation:  There are hundreds of jeans out there, and you have no excuse to mess around.
# Row:  851 , translating:  在我们过去的这一代人里， 工业化世界中临床压抑症爆炸性增长。
# translation:  In our past generation, clinical depression has exploded in the industrialized world.
# Row:  853 , translating:  最后的净效果就是，尽管客观上 我们做得比以往好了， 但是感觉上却不如从前。
# translation:  The net effect is that while we are doing better than ever, it doesn't feel the same.
# Row:  854 , translating:  我再提醒大家，
# translation:  再提醒大家,
# Row:  857 , translating:  这里有一个关键值，我不知道是多少。
# translation:  Here's a key value, I don't know how much.
# Row:  858 , translating:  但是我可以肯定我们早就远远超出了 ‘选择令我们富有’ 所需要的这个关键值了。
# translation:  但是, I can be sure that we have far exceeded the critical value of 'choice to make us rich'.
# Row:  861 , translating:  而是几乎没有。
# translation:  It's almost impossible.
# Row:  862 , translating:  所以我在这里谈的这个话题是现代富裕的西方社会的
# translation:  所以我今天要讲的这个话题 是关于富裕的西方社会。
# Row:  864 , translating:  而我今天要说的就是这些昂贵的，复杂的选择 不仅仅是于事无补，
# translation:  今天, I want to talk about these expensive, complex choices that aren't just inconvenient.
# Row:  865 , translating:  它们其实在给我们带来伤害。
# translation:  实际上, they're hurting us.
# Row:  866 , translating:  它们其实让我们变得不如从前。
# translation:  实际上,它们让我们变得不如以前。
# Row:  869 , translating:  告诉你，在这个鱼缸里一切都是不可能的。”
# translation:  To tell you, everything in this fish tank is impossible."
# Row:  870 , translating:  毫无想象力，目光短浅- 我第一次看到这幅画时是这么解读的。
# translation:  Unimagined, short-sighted - I read this picture for the first time.
# Row:  871 , translating:  可是，我越想越明显地感到 这鱼肯定知道些什么。
# translation:  But the more I wanted to feel that this fish must know something.
# Row:  873 , translating:  如果你想让一切都变得有可能而把鱼缸打破， 你反而降低了满意度。
# translation:  If you want to make everything possible and break the fish tank, you reduce satisfaction.
# Row:  874 , translating:  你增加了的是瘫痪，减少了的是满足。
# translation:  You increase paralysis, you decrease satisfaction.
# Row:  875 , translating:  每个人都需要这么个“鱼缸”。
# translation:  Everyone needs a fish tank.
# Row:  876 , translating:  至于这个（鱼缸）嘛，对这条鱼 可能是小了点，对于我们几乎肯定是太小了。
# translation:  As for this (fish tank), it might be a little bit small, almost certainly too small for us.
# Row:  877 , translating:  但是，没有这么个象征性的鱼缸那就 意味着苦难将至， 也许是，灾难。
# translation:  But the absence of such a symbolic tank means that suffering will come, perhaps, disaster.
# Row:  878 , translating:  非常感谢。
# translation:  非常感谢。

# %%
def process_string(text):
    return replace_punctuation_with_en(text)

'''def remove_spaces(text):
    return ''.join(text.split())'''

# Replacing en punctuation with the zh counterparts
def replace_punctuation_with_en(text):
    # Define a mapping of English punctuation to Chinese punctuation
    punctuation_mapping = {
        '，': ',',
        '。': '.',
        '？': '?',
        '！': '!',
        '：': ':',
        '；': ';',
        '”': '"',
        '’': "'",
        '（': '(',
        '）': ')',
        '【': '[',
        '】': ']',
        '｛': '{',
        '｝': '}'
    }

    # Replace each English punctuation with its Chinese counterpart
    for chi_punc, eng_punc in punctuation_mapping.items():
        text = text.replace(chi_punc, eng_punc)

    return text

processed_predictions_backward = [process_string(sent) for sent in predictions]
processed_references_backward = [process_string(sent[0]) for sent in references]

df = pd.DataFrame({'Prediction': processed_predictions_backward, 'Reference': processed_references_backward})
df.to_csv(f'zh_to_en_t5_{model_name}_backwards_translations.csv', index=False)

processed_references_backward = [[reference] for reference in processed_references_backward]

bleu_score_no_smoothing = sacrebleu.corpus_bleu(processed_predictions_backward, processed_references_backward)
bleu_score_add_1 = sacrebleu.corpus_bleu(processed_predictions_backward, processed_references_backward, smooth_method="add-k", smooth_value=1)

print(f"BLEU Score without smoothing: BLEU = {bleu_score_no_smoothing}")
print(f"BLEU Score with smoothing: BLEU = {bleu_score_add_1}")
# Out:
# BLEU Score without smoothing: BLEU = BLEU = 26.51 87.5/43.5/13.6/9.5 (BP = 1.000 ratio = 1.000 hyp_len = 24 ref_len = 24)
# BLEU Score with smoothing: BLEU = BLEU = 31.23 87.5/45.8/17.4/13.6 (BP = 1.000 ratio = 1.000 hyp_len = 24 ref_len = 24)

# %% [markdown]
# forward evaluation from english to chinese

# %%
prefix = 'translate to zh: '

predictions, references = [], []

for index, row in val_df.iterrows():
  print("Row: ", str(index), ", translating: ", row["en"])
  src_text = prefix + row['en']
  input_ids = tokenizer(src_text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids.to(device)
  generated_tokens = model.generate(input_ids)
  translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
  print("translation: ", translation)
  predictions.append(translation)
  references.append(row['zh'])

references = [[reference] for reference in references]
# Out:
# Row:  1 , translating:  But this understates the seriousness of this particular problem  because it doesn't show the thickness of the ice.
# translation:  但是这低估了这个问题的严重性, 因为它没有显示冰的厚度。
# Row:  2 , translating:  The arctic ice cap is, in a sense,  the beating heart of the global climate system.
# translation:  从某种意义上说,北极冰盖是全球气候系统的跳动中心。
# Row:  3 , translating:  It expands in winter and contracts in summer.
# translation:  它在冬天扩张,在夏天收缩。
# Row:  4 , translating:  The next slide I show you will be  a rapid fast-forward of what's happened over the last 25 years.
# translation:  下一张幻灯片将展示过去25年里发生的事情。
# Row:  5 , translating:  The permanent ice is marked in red.
# translation:  永久性冰被标记为红色。
# Row:  8 , translating:  In 25 years it's gone from this, to this.
# translation:  25年过去了。
# Row:  10 , translating:  Compared to the total amount of global warming pollution in the atmosphere,  that amount could double if we cross this tipping point.
# translation:  与全球变暖的污染总量相比, 如果跨过这个转折点,这一数量可以翻一番。
# Row:  11 , translating:  Already in some shallow lakes in Alaska,  methane is actively bubbling up out of the water.
# translation:  在阿拉斯加的一些浅湖里, 甲烷正积极地从水中涌出。
# Row:  12 , translating:  Professor Katey Walter from the University of Alaska  went out with another team to another shallow lake last winter.
# translation:  阿拉斯加大学的凯蒂·沃尔特教授去年冬天去了另一个浅湖。
# Row:  13 , translating:  Video: Whoa!   Al Gore: She's okay. The question is whether we will be.
# translation:  视频:哇!戈尔:没问题。
# Row:  14 , translating:  And one reason is, this enormous heat sink  heats up Greenland from the north.
# translation:  其中一个原因是,这个巨大的热汇从北边向格陵兰岛升温。
# Row:  15 , translating:  This is an annual melting river.
# translation:  这是一年一度的河水融化。
# Row:  16 , translating:  But the volumes are much larger than ever.
# translation:  但它的数量比以往任何时候都要大。
# Row:  17 , translating:  This is the Kangerlussuaq River in southwest Greenland.
# translation:  这是格陵兰西南部的Kangerlussuaq河。
# Row:  18 , translating:  If you want to know how sea level rises  from land-base ice melting  this is where it reaches the sea.
# translation:  如果你想知道海平面是如何从陆地冰层融化而上升的, 那就是它到达海洋的地方。
# Row:  19 , translating:  These flows are increasing very rapidly.
# translation:  这些流动正在迅速增加。
# Row:  20 , translating:  At the other end of the planet, Antarctica  the largest mass of ice on the planet.
# translation:  在地球的另一端,南极是地球上最大的冰块。
# Row:  21 , translating:  Last month scientists reported the entire continent  is now in negative ice balance.
# translation:  上个月,科学家报告了整个大陆的负冰平衡。
# Row:  22 , translating:  And west Antarctica cropped up on top some under-sea islands,  is particularly rapid in its melting.
# translation:  西南极洲在一些海底岛屿上生长, 它的融化速度特别快。
# Row:  23 , translating:  That's equal to 20 feet of sea level, as is Greenland.
# translation:  相当于20英尺的海平面,就像格陵兰岛一样。
# Row:  25 , translating:  40 percent of all the people in the world  get half of their drinking water from that melting flow.
# translation:  世界上40%的人从这种融化中得到一半的饮用水。
# Row:  26 , translating:  In the Andes, this glacier is the  source of drinking water for this city.
# translation:  在安第斯山脉,冰川是这个城市饮用水的来源。
# Row:  27 , translating:  The flows have increased.
# translation:  流量增加。
# Row:  28 , translating:  But when they go away, so does much of the drinking water.
# translation:  但是当它们消失时,大部分的饮用水也随之消失。
# Row:  29 , translating:  In California there has been a 40 percent  decline in the Sierra snowpack.
# translation:  在加州,雪囊的数量下降了40%。
# Row:  30 , translating:  This is hitting the reservoirs.
# translation:  这会撞到水库。
# Row:  31 , translating:  And the predictions, as you've read, are serious.
# translation:  正如你所读到的,这些预测是严肃的。
# Row:  32 , translating:  This drying around the world has lead to  a dramatic increase in fires.
# translation:  全世界的干旱导致火灾急剧增加。
# Row:  33 , translating:  And the disasters around the world  have been increasing at an absolutely extraordinary  and unprecedented rate.
# translation:  全世界的灾难都在以前所未有的速度增加。
# Row:  34 , translating:  Four times as many in the last 30 years  as in the previous 75.
# translation:  在过去的30年里,这个数字是前75年的4倍。
# Row:  35 , translating:  This is a completely unsustainable pattern.
# translation:  这是一种完全不可持续的模式。
# Row:  36 , translating:  If you look at in the context of history  you can see what this is doing.
# translation:  如果你从历史的角度来看,你可以看到这是怎么回事。
# Row:  40 , translating:  Oil is a problem, and coal is the most serious problem.
# translation:  石油是个问题,而煤炭则是最严重的问题。
# Row:  41 , translating:  The United States is one of the two  largest emitters, along with China.
# translation:  美国是最大的两个排放国之一。
# Row:  42 , translating:  And the proposal has been to build a lot more coal plants.
# translation:  建议建造更多的燃煤电厂。
# Row:  43 , translating:  But we're beginning to see a sea change.
# translation:  但我们开始看到大海的变化。
# Row:  44 , translating:  Here are the ones that have been cancelled in the last few years  with some green alternatives proposed.
# translation:  这些是在过去几年里被取消的, 有一些绿色的替代品。
# Row:  46 , translating:  That image reminded me of something.
# translation:  这张照片让我想起了一些事情。
# Row:  47 , translating:  Around Christmas, in my home in Tennessee,  a billion gallons of coal sludge was spilled.
# translation:  在田纳西州的圣诞节前夕, 10亿加仑的煤污被泄漏了。
# Row:  48 , translating:  You probably saw it on the news.
# translation:  你可能在新闻上看到过。
# Row:  49 , translating:  This, all over the country, is the second largest waste stream in America.
# translation:  在美国,这是第二大的废物流。
# Row:  50 , translating:  This happened around Christmas.
# translation:  那是在圣诞节的时候。
# Row:  51 , translating:  One of the coal industry's ads around Christmas was this one.
# translation:  一个关于圣诞节的广告是这个。
# Row:  52 , translating:  Video: ♪♫ Frosty the coal man is a jolly, happy soul.
# translation:  视频:♪冻煤人是一个快乐的灵魂。
# Row:  53 , translating:  He's abundant here in America,  and he helps our economy grow.
# translation:  他在美国很丰富,他帮助我们的经济成长。
# Row:  54 , translating:  Frosty the coal man is getting cleaner everyday.
# translation:  煤矿工人每天都在变的更清洁。
# Row:  55 , translating:  He's affordable and adorable, and workers keep their pay.
# translation:  他负担得起,很可爱,而且工人可以拿到工资。
# Row:  56 , translating:  Al Gore: This is the source of much of the coal in West Virginia.
# translation:  戈尔:这是西弗吉尼亚州大部分煤炭的来源。
# Row:  57 , translating:  The largest mountaintop miner is the head of Massey Coal.
# translation:  最大的矿工是马西煤矿。
# Row:  59 , translating:  Al Gore: So the Alliance for Climate Protection  has launched two campaigns.
# translation:  戈尔:气候保护联盟发起了两项运动。
# Row:  60 , translating:  This is one of them, part of one of them.
# translation:  这是其中之一,也是其中的一部分。
# Row:  61 , translating:  Video: Actor: At COALergy we view climate change as a very serious  threat to our business.
# translation:  视频:在COALgy,我们把气候变化看作是对我们业务的一个非常严重的威胁。
# Row:  63 , translating:  The fact is, coal isn't dirty.
# translation:  事实是,煤并不脏。
# Row:  64 , translating:  We think it's clean --  smells good, too.
# translation:  我们认为它很干净,味道也很好。
# Row:  65 , translating:  So don't worry about climate change.
# translation:  所以不要担心气候变化。
# Row:  66 , translating:  Leave that up to us.
# translation:  留给我们吧。
# Row:  67 , translating:  Video: Actor: Clean coal -- you've heard a lot about it.
# translation:  视频:清洁煤——你听过很多。
# Row:  68 , translating:  So let's take a tour of this state-of-the-art clean coal facility.
# translation:  让我们来看看这个最先进的清洁煤矿设施。
# Row:  69 , translating:  Amazing! The machinery is kind of loud.
# translation:  太棒了!机器有点响。
# Row:  70 , translating:  But that's the sound of clean coal technology.
# translation:  这就是清洁煤技术的声音。
# Row:  71 , translating:  And while burning coal is one of the leading causes of global warming,  the remarkable clean coal technology you see here  changes everything.
# translation:  虽然燃烧煤炭是导致全球变暖的主要原因之一, 但清洁煤技术可以改变一切。
# Row:  72 , translating:  Take a good long look: this is today's clean coal technology.
# translation:  长话短说:这是今天的清洁煤技术。
# Row:  73 , translating:  Al Gore: Finally, the positive alternative  meshes with our economic challenge  and our national security challenge.
# translation:  Al Gore:最后,积极的选择 与我们的经济挑战和国家安全挑战交汇在一起。
# Row:  74 , translating:  Video: Narrator: America is in crisis -- the economy,  national security, the climate crisis.
# translation:  视频:美国正处在危机中--经济,国家安全,气候危机。
# Row:  76 , translating:  But now there is a bold new solution to get us out of this mess.
# translation:  但是现在有一个大胆的新方案 来让我们摆脱这种混乱。
# Row:  77 , translating:  Repower America with 100 percent clean electricity  within 10 years.
# translation:  用100%的清洁电力来重振美国。
# Row:  78 , translating:  A plan to put America back to work,  make us more secure, and help stop global warming.
# translation:  让美国恢复工作,让我们更加安全, 并帮助阻止全球变暖。
# Row:  79 , translating:  Finally, a solution that's big enough to solve our problems.
# translation:  最后,一个足够大的解决方案 来解决我们的问题。
# Row:  80 , translating:  Repower America. Find out more.
# translation:  重振美国。了解更多
# Row:  81 , translating:  Al Gore: This is the last one.
# translation:  戈尔:这是最后一个。
# Row:  82 , translating:  Video: Narrator: It's about repowering America.
# translation:  视频:是关于重振美国。
# Row:  83 , translating:  One of the fastest ways to cut our dependence  on old dirty fuels that are killing our planet.
# translation:  减少我们对旧燃料的依赖的最快方法之一, 它正在扼杀我们的星球。
# Row:  84 , translating:  Man: Future's over here. Wind, sun, a new energy grid.
# translation:  男人:未来来了。风,太阳,新能源网。
# Row:  85 , translating:  Man #2: New investments to create high-paying jobs.
# translation:  男人2:创造高薪工作的新投资。
# Row:  86 , translating:  Narrator: Repower America. It's time to get real.
# translation:  讲述者:重振美国。是时候让它变成现实了。
# Row:  87 , translating:  Al Gore: There is an old African proverb that says,  "If you want to go quickly, go alone.
# translation:  阿尔·戈尔:有句古老的非洲谚语说, “如果你想快点去,就一个人去。”
# Row:  88 , translating:  If you want to go far, go together."
# translation:  如果你想走得更远,一起去。”
# Row:  89 , translating:  We need to go far, quickly.
# translation:  我们需要走得更远,更快。
# Row:  90 , translating:  Thank you very much.
# translation:  非常感谢。
# Row:  91 , translating:  Last year at TED I gave an introduction to the LHC.
# translation:  去年我在TED做了一个LHC的介绍。
# Row:  92 , translating:  And I promised to come back and give you an update  on how that machine worked.
# translation:  我答应再给你一个关于那台机器如何工作的更新。
# Row:  95 , translating:  It's nothing if not ambitious.
# translation:  如果不是雄心勃勃的话,那就什么都没有了。
# Row:  96 , translating:  This is the machine below Geneva.
# translation:  这是日内瓦下方的机器。
# Row:  97 , translating:  We take the pictures of those mini-Big Bangs inside detectors.
# translation:  我们拍下这些小爆炸探测器里面的照片。
# Row:  99 , translating:  Spectacular picture here of ATLAS under construction  so you can see the scale.
# translation:  这里是正在建设中的ATLAS的壮观图片,所以你可以看到它的规模。
# Row:  100 , translating:  On the 10th of September last year we turned the machine on for the first time.
# translation:  去年9月10日,我们第一次打开机器。
# Row:  101 , translating:  And this picture was taken by ATLAS.
# translation:  这张照片是ATLAS拍摄的。
# Row:  102 , translating:  It caused immense celebration in the control room.
# translation:  它在控制室里引起了极大的欢庆。
# Row:  106 , translating:  It means we made cultural impact  as well as scientific impact.
# translation:  这意味着我们不仅对文化产生了影响, 也对科学产生了影响。
# Row:  108 , translating:  Those wires carry 13 thousand amps  when the machine is working in full power.
# translation:  这些电线携带13000个安培器 当机器全功率工作时。
# Row:  109 , translating:  Now the engineers amongst you will look at them and say,  "No they don't. They're small wires."
# translation:  你们中的工程师会看着他们,说:“不是。它们是小电线。”
# Row:  110 , translating:  They can do that because  when they are very cold they are what's called superconducting wire.
# translation:  因为当它们很冷的时候,就被称为超导线。
# Row:  112 , translating:  In one of the joints between over 9,000 magnets in LHC,  there was a manufacturing defect.
# translation:  在LHC中超过9000个磁体之间的一个关节里, 有一个制造缺陷。
# Row:  114 , translating:  This was the result.
# translation:  这就是结果。
# Row:  115 , translating:  Now that's more impressive  when you consider those magnets weigh over 20 tons,  and they moved about a foot.
# translation:  更让人印象深刻的是,这些磁铁重达20吨, 然后它们移动了大约一英尺。
# Row:  116 , translating:  So we damaged about 50 of the magnets.
# translation:  所以我们损坏了大约50个磁铁。
# Row:  117 , translating:  We had to take them out, which we did.
# translation:  我们必须把它们拿出来,我们做到了。
# Row:  118 , translating:  We reconditioned them all, fixed them.
# translation:  我们重新调整了它们,修复了它们。
# Row:  119 , translating:  They're all on their way back underground now.
# translation:  他们正准备回到地下。
# Row:  120 , translating:  By the end of March the LHC will be intact again.
# translation:  到3月底,LHC将再次完好无损。
# Row:  125 , translating:  Thank you.
# translation:  谢谢。
# Row:  126 , translating:  I want to start out by asking you to think back to when you were a kid,  playing with blocks.
# translation:  我想先让大家回想一下 你还是个孩子的时候,玩砖块。
# Row:  128 , translating:  Spatial reasoning is deeply connected  to how we understand a lot of the world around us.
# translation:  空间推理与我们如何理解周围世界息息相关。
# Row:  130 , translating:  arranging it the way we wanted?
# translation:  按照我们想要的方式来安排?
# Row:  132 , translating:  In a nutshell, a Siftable is an interactive computer  the size of a cookie.
# translation:  简而言之,Siftable是一个像饼干一样的交互式计算机。
# Row:  134 , translating:  Most importantly, they're physical,  so like the blocks, you can move them just by reaching out and grasping.
# translation:  最重要的是,它们是有形的,你可以通过伸展和抓取来移动它们。
# Row:  135 , translating:  And Siftables are an example of a new ecosystem  of tools for manipulating digital information.
# translation:  Siftables是一种新的生态系统, 用来操纵数字信息。
# Row:  137 , translating:  So, I'm going to start with some simple examples.
# translation:  那么,我将以一些简单的例子开始。
# Row:  139 , translating:  And these interactive portraits are aware of each other.
# translation:  这些互动的肖像是相互了解的。
# Row:  140 , translating:  So if I put them next to each other, they get interested.
# translation:  如果我把它们放在一起,它们就会变得很感兴趣。
# Row:  141 , translating:  If they get surrounded, they notice that too,  they might get a little flustered.
# translation:  如果他们被包围了,他们也可能会有点晕眩。
# Row:  142 , translating:  And they can also sense their motion and tilt.
# translation:  它们也能感知它们的运动和倾斜。
# Row:  145 , translating:  If we overshoot, we can pour a little bit back.
# translation:  如果我们超额,我们可以倒退一点。
# Row:  148 , translating:  Here we have a word game that's kind of like a mash-up between Scrabble and Boggle.
# translation:  这里有个单词游戏,有点像在Scrabble和Boggle之间。
# Row:  151 , translating:  Thank you.
# translation:  谢谢。
# Row:  153 , translating:  They really loved it.
# translation:  他们真的很喜欢它。
# Row:  154 , translating:  And, one of the interesting things about this kind of application  is that you don't have to give people many instructions.
# translation:  而且,这种应用的有趣之处在于 你不需要给人们很多指令。
# Row:  155 , translating:  All you have to say is, "Make words,"  and they know exactly what to do.
# translation:  你要说的就是“写字”,他们知道该怎么做。
# Row:  156 , translating:  So here's another few people trying it out.
# translation:  还有几个人试着去做。
# Row:  157 , translating:  That's our youngest beta tester, down there on the right.
# translation:  这是我们最年轻的测试者,在右边。
# Row:  158 , translating:  Turns out, all he wanted to do was to stack the Siftables up.
# translation:  结果是,他想做的就是把Siftables堆起来。
# Row:  159 , translating:  So to him, they were just blocks.
# translation:  对他来说,他们只是个街区。
# Row:  160 , translating:  Now, this is an interactive cartoon application.
# translation:  现在,这是一个交互式卡通应用程序。
# Row:  161 , translating:  And we wanted to build a learning tool for language learners.
# translation:  我们想为语言学习者建立一个学习工具。
# Row:  162 , translating:  And this is Felix, actually.
# translation:  这是费利克斯,事实上。
# Row:  164 , translating:  Here, he's bringing the sun out.
# translation:  在这里,他把太阳拿出来。
# Row:  165 , translating:  Video: The sun is rising.
# translation:  视频:太阳在升起。
# Row:  166 , translating:  David Merrill: Now he's brought a tractor into the scene.
# translation:  大卫·梅里尔:他把拖拉机带到了现场。
# Row:  167 , translating:  Video: The orange tractor.
# translation:  视频:橙色拖拉机
# Row:  168 , translating:  Good job! Yeah!
# translation:  干得好!
# Row:  170 , translating:  DM: inventing his own narrative.
# translation:  DM:发明他自己的叙事。
# Row:  171 , translating:  Video: Hello!
# translation:  视频:你好!
# Row:  172 , translating:  DM: It's an open-ended story,  and he gets to decide how it unfolds.
# translation:  DM:这是一个开放的故事,他可以决定如何展开。
# Row:  173 , translating:  Video: Fly away, cat.
# translation:  视频:飞开,猫。
# Row:  175 , translating:  Each of these has four different variations,  you get to choose which one you want to use.
# translation:  每一个都有四个不同的变化,你可以选择你想要用哪一个。
# Row:  177 , translating:  And you inject it by just bumping up the sound Siftable against a sequence Siftable.
# translation:  只需将声波与音波对撞即可注射。
# Row:  178 , translating:  There are effects that you can control live, like reverb and filter.
# translation:  你可以实时控制这些影响,比如说声波和滤波器。
# Row:  179 , translating:  You attach it to a particular sound and then tilt to adjust it.
# translation:  你把它附在一个特定的声音上 然后倾斜来调节它。
# Row:  180 , translating:  And then, overall effects like tempo and volume  So let's have a look.
# translation:  总的来说,比如速度和音量。
# Row:  182 , translating:  Now I put a bass line in.
# translation:  现在我把一条低音线放进去。
# Row:  183 , translating:  Video:   DM: Now I'll put some percussion in.
# translation:  视频:DM:现在我要放一些冲击。
# Row:  184 , translating:  Video:   DM: And now I'll attach the filter to the drums, so I can control the effect live.
# translation:  视频:DM:现在我把过滤器附在鼓上,这样我可以实时控制效果。
# Row:  185 , translating:  Video:   DM: I can speed up the whole sequence  by tilting the tempo one way or the other.
# translation:  视频:DM:我可以通过倾斜速度来加快整个过程。
# Row:  186 , translating:  Video:   DM: And now I'll attach the filter to the bass for some more expression.
# translation:  视频:DM:现在我将过滤器附加到低音上,以获得更多的表情。
# Row:  187 , translating:  Video:   DM: I can rearrange the sequence while it plays.
# translation:  视频:DM:我可以重新排列顺序。
# Row:  189 , translating:  And now, finally, I can fade the whole sequence out  using the volume Siftable, tilted to the left.
# translation:  现在,我可以用左边的音量 将整个序列褪色。
# Row:  190 , translating:  Thank you.
# translation:  谢谢。
# Row:  194 , translating:  Thank you very much.
# translation:  非常感谢。
# Row:  195 , translating:  I look forward to talking with all of you.
# translation:  我很期待与大家交流。
# Row:  196 , translating:  I am a writer.
# translation:  我是作家。
# Row:  197 , translating:  Writing books is my profession but it's more than that, of course.
# translation:  写书是我的职业,当然不止如此。
# Row:  198 , translating:  It is also my great lifelong love and fascination.
# translation:  这也是我一生的爱和魅力。
# Row:  199 , translating:  And I don't expect that that's ever going to change.
# translation:  我不认为这会改变。
# Row:  203 , translating:  Seriously -- doomed, doomed!
# translation:  真的——注定,注定!
# Row:  206 , translating:  So that's reassuring, you know.
# translation:  那令人放心,你知道的。
# Row:  208 , translating:  And people would say, "Aren't you afraid you're never going to have any success?
# translation:  人们会说:“你不怕什么成功吗?”
# Row:  211 , translating:  The answer -- the short answer to all those questions is, "Yes."
# translation:  答案--对所有这些问题的简短回答是, “是的。”
# Row:  212 , translating:  Yes, I'm afraid of all those things.
# translation:  是的,我害怕所有这些事情。
# Row:  213 , translating:  And I always have been.
# translation:  我一直都是。
# Row:  216 , translating:  You know, is it rational?
# translation:  你知道吗?
# Row:  220 , translating:  "That chemical-engineering block, John, how's it going?"
# translation:  “化学工程学块,约翰,怎么回事?”
# Row:  221 , translating:  It just didn't come up like that, you know?
# translation:  它不是这样出现的,你知道吗?
# Row:  226 , translating:  An extraordinary statement to make about your life's work.
# translation:  一个关于你一生工作的非凡声明。
# Row:  229 , translating:  Are you comfortable with that?
# translation:  你觉得舒服吗?
# Row:  231 , translating:  I think it's odious.
# translation:  我觉得很可怕。
# Row:  233 , translating:  I think it's better if we encourage our great creative minds to live.
# translation:  我认为如果我们鼓励我们伟大的创造力,那就更好了。
# Row:  236 , translating:  I still have maybe another four decades of work left in me.
# translation:  也许我还有四十年的工作。
# Row:  239 , translating:  So Jesus, what a thought!
# translation:  天啊,真是个想法!
# Row:  241 , translating:  I would prefer to keep doing this work that I love.
# translation:  我宁愿继续做我热爱的工作。
# Row:  242 , translating:  And so, the question becomes, how?
# translation:  那么问题就变成了,如何?
# Row:  246 , translating:  And that search has led me to ancient Greece and ancient Rome.
# translation:  那次搜索带我到了古希腊和古罗马。
# Row:  247 , translating:  So stay with me, because it does circle around and back.
# translation:  那就跟我一起吧,因为它会四处游荡。
# Row:  250 , translating:  The Greeks famously called these divine attendant spirits of creativity "daemons."
# translation:  古希腊人称这些神灵为“达蒙”。
# Row:  256 , translating:  And everyone knew that this is how it functioned, right?
# translation:  每个人都知道这是怎么运作的,对吧?
# Row:  259 , translating:  If your work bombed, not entirely your fault, you know?
# translation:  如果你的工作被轰炸了,不是完全是你的错。
# Row:  263 , translating:  And I got to tell you, I think that was a huge error.
# translation:  我想说,这是一个很大的错误。
# Row:  265 , translating:  It's like asking somebody to swallow the sun.
# translation:  就像要人吞下太阳一样。
# Row:  268 , translating:  And, if this is true,  and I think it is true,  the question becomes, what now?
# translation:  如果这是真的,那么问题就变成了,现在呢?
# Row:  269 , translating:  Can we do this differently?
# translation:  我们能做点别的吗?
# Row:  271 , translating:  Maybe not.
# translation:  也许不是。
# Row:  274 , translating:  I'm not, probably, going to bring you all along with me on this.
# translation:  我可能不会把你们都带到这里来。
# Row:  276 , translating:  Why not think about it this way?
# translation:  为什么不这样想呢?
# Row:  279 , translating:  And, in fact, can sometimes feel downright paranormal.
# translation:  事实上,有时会感觉很不正常。
# Row:  281 , translating:  And she said it was like a thunderous train of air.
# translation:  她说那就像一列巨大的空中列车。
# Row:  282 , translating:  And it would come barreling down at her over the landscape.
# translation:  它会向她伸出手来。
# Row:  283 , translating:  And she felt it coming, because it would shake the earth under her feet.
# translation:  她感觉到它来了,因为它会震动她脚下的地球。
# Row:  294 , translating:  And I would imagine that a lot of you have too.
# translation:  我想你们很多人也一样。
# Row:  296 , translating:  And what is that thing?
# translation:  那是什么呢?
# Row:  302 , translating:  He doesn't have a piece of paper, or a pencil, or a tape recorder.
# translation:  他没有一张纸,或者铅笔,或录音机。
# Row:  305 , translating:  And instead of panicking, he just stopped.
# translation:  而不是惊慌失措,他停了下来。
# Row:  306 , translating:  He just stopped that whole mental process and he did something completely novel.
# translation:  他停止了整个心理过程, 做了一些完全新颖的事情。
# Row:  308 , translating:  "Do I look like I can write down a song right now?
# translation:  “我现在能写一首歌吗?”
# Row:  310 , translating:  Otherwise, go bother somebody else today.
# translation:  否则,今天就去麻烦别人了。
# Row:  311 , translating:  Go bother Leonard Cohen."
# translation:  麻烦伦纳德·科恩。”
# Row:  312 , translating:  And his whole work process changed after that.
# translation:  之后他的整个工作流程都发生了变化。
# Row:  313 , translating:  Not the work, the work was still oftentimes as dark as ever.
# translation:  不是工作,还是像以前一样黑暗。
# Row:  318 , translating:  Not just bad, but the worst book ever written.
# translation:  不光是坏书,更是有史以来最差的书。
# Row:  319 , translating:  And I started to think I should just dump this project.
# translation:  我开始想,我应该把这个项目扔掉。
# Row:  320 , translating:  But then I remembered Tom talking to the open air and I tried it.
# translation:  但我记得汤姆在开阔的空气中说话,然后我试了一下。
# Row:  324 , translating:  If you want it to be better, you've got to show up and do your part of the deal.
# translation:  如果你想做得更好,你就必须参与其中。
# Row:  325 , translating:  But if you don't do that, you know what, the hell with it.
# translation:  但是如果你不这样做,你知道吗?
# Row:  333 , translating:  And all of a sudden, he would no longer appear to be merely human.
# translation:  突然间,他不再是人类了。
# Row:  337 , translating:  That's God, you know.
# translation:  那是上帝,你知道的。
# Row:  340 , translating:  Which is great, because we need that.
# translation:  那太棒了,因为我们需要它。
# Row:  344 , translating:  This is hard.
# translation:  这是很难的。
# Row:  348 , translating:  And, you know, if we think about it this way, it starts to change everything.
# translation:  如果我们这样想,它就会改变一切。
# Row:  351 , translating:  Don't be daunted. Just do your job.
# translation:  不要害怕。做你的工作。
# Row:  352 , translating:  Continue to show up for your piece of it, whatever that might be.
# translation:  继续展示你的作品,不管它是什么。
# Row:  353 , translating:  If your job is to dance, do your dance.
# translation:  如果你的工作是跳舞,那就跳吧。
# Row:  355 , translating:  And if not, do your dance anyhow.
# translation:  如果不是,那就跳舞吧。
# Row:  356 , translating:  And "Olé!" to you, nonetheless.
# translation:  还有“Olé”
# Row:  357 , translating:  I believe this and I feel that we must teach it.
# translation:  我相信这一点,我觉得我们必须教它。
# Row:  359 , translating:  Thank you.
# translation:  谢谢。
# Row:  360 , translating:  Thank you.
# translation:  谢谢。
# Row:  361 , translating:  June Cohen: Olé!
# translation:  朱恩·科恩:奥莱!
# Row:  364 , translating:  So, we've always been trying to ask big questions.
# translation:  所以,我们一直试图问一些大问题。
# Row:  365 , translating:  "What is life?" is something that I think many biologists  have been trying to understand  at various levels.
# translation:  “生命是什么?” 是许多生物学家在不同层面上试图理解的。
# Row:  366 , translating:  We've tried various approaches,  paring it down to minimal components.
# translation:  我们尝试了各种方法, 把它归结为最小的组件。
# Row:  373 , translating:  And so we started down the road of:  can we synthesize a chromosome?
# translation:  于是我们开始了: 我们能不能合成一个染色体?
# Row:  374 , translating:  Can chemistry permit making  these really large molecules  where we've never been before?
# translation:  化学能不能创造出我们从未有过的巨大分子呢?
# Row:  375 , translating:  And if we do, can we boot up a chromosome?
# translation:  如果我们这样做,我们能启动染色体吗?
# Row:  376 , translating:  A chromosome, by the way, is just a piece of inert chemical material.
# translation:  顺便说一下,染色体只是一小块惰性化学材料。
# Row:  377 , translating:  So, our pace of digitizing life has been increasing  at an exponential pace.
# translation:  因此,我们把生命数字化的速度 以指数速度增长。
# Row:  379 , translating:  We started this over 15 years ago.
# translation:  我们是在15年前开始的。
# Row:  380 , translating:  It took several stages, in fact,  starting with a bioethical review before we did the first experiments.
# translation:  实际上,在进行第一次实验之前,它经历了几个阶段。
# Row:  381 , translating:  But it turns out synthesizing DNA  is very difficult.
# translation:  但是合成DNA是非常困难的。
# Row:  383 , translating:  So we had to create a new method  for putting these little pieces together and correct all the errors.
# translation:  所以我们必须创造一种新的方法 把这些小片段放在一起,并纠正所有的错误。
# Row:  384 , translating:  And this was our first attempt, starting with the digital information  of the genome of phi X174.
# translation:  这是我们第一次尝试,从数码信息开始。
# Row:  385 , translating:  It's a small virus that kills bacteria.
# translation:  一种能杀死细菌的小病毒。
# Row:  388 , translating:  The viral particles then were released from the cells  and came back and killed the E. coli.
# translation:  病毒颗粒从细胞中释放出来,杀死了大肠杆菌。
# Row:  389 , translating:  I was talking to the oil industry recently  and I said they clearly understood that model.
# translation:  我最近和石油行业谈过,他们说他们很清楚这个模型。
# Row:  392 , translating:  Design is critical,  and if you're starting with digital information in the computer,  that digital information has to be really accurate.
# translation:  设计是至关重要的,如果你从计算机里的数字信息开始, 这个数字信息必须非常准确。
# Row:  396 , translating:  We design unique elements into this.
# translation:  我们设计了独特的元素。
# Row:  397 , translating:  You may have read that we put watermarks in.
# translation:  你可能读过我们把水印进去。
# Row:  398 , translating:  Think of this:  we have a four-letter genetic code -- A, C, G and T.
# translation:  想一想:我们有四字母的基因密码--A,C,G和T。
# Row:  400 , translating:  So we can use the genetic code to write out words,  sentences, thoughts.
# translation:  我们可以用基因编码来写出单词,句子,想法。
# Row:  401 , translating:  Initially, all we did was autograph it.
# translation:  最初,我们所做的只是自画像。
# Row:  402 , translating:  Some people were disappointed there was not poetry.
# translation:  有些人失望的是,那不是诗。
# Row:  406 , translating:  We're trying to get to the point of automation.
# translation:  我们正在努力实现自动化。
# Row:  407 , translating:  So, this looks like a basketball playoff.
# translation:  看起来就像一个篮球季后赛。
# Row:  409 , translating:  We knew there's a mechanism called homologous recombination  that biology uses to repair DNA  that can put pieces together.
# translation:  我们知道有一种叫做同质重组的机制, 生物学用它来修复DNA。
# Row:  411 , translating:  You can see in the top panel, its chromosome just gets blown apart.
# translation:  你可以在上面看到,它的染色体被撕裂了。
# Row:  412 , translating:  Twelve to 24 hours later, it put it  back together exactly as it was before.
# translation:  12到24小时后,它又回到了原来的样子。
# Row:  413 , translating:  We have thousands of organisms that can do this.
# translation:  我们有数以千计的生物可以做到这点。
# Row:  414 , translating:  These organisms can be totally desiccated;  they can live in a vacuum.
# translation:  这些生物可以完全枯竭; 它们可以在真空中生存。
# Row:  415 , translating:  I am absolutely certain that life can exist in outer space,  move around, find a new aqueous environment.
# translation:  我绝对确信生命可以在外太空存在, 可以四处移动,找到新的水生环境。
# Row:  416 , translating:  In fact, NASA has shown a lot of this is out there.
# translation:  事实上,美国宇航局已经展示了很多这样的例子。
# Row:  418 , translating:  This is not an electron micrograph;  this is just a regular photomicrograph.
# translation:  这不是电子图;这只是一个普通的微图像。
# Row:  419 , translating:  It's such a large molecule  we can see it with a light microscope.
# translation:  这是一个很大的分子,我们可以用光显微镜来观察它。
# Row:  420 , translating:  These are pictures over about a six-second period.
# translation:  这些照片大约是六秒钟。
# Row:  421 , translating:  So, this is the publication we had just a short while ago.
# translation:  这就是我们不久前发表的文章。
# Row:  423 , translating:  It's over 300 million molecular weight.
# translation:  超过3亿分子重。
# Row:  425 , translating:  Well, how do we boot up a chromosome? How do we activate this?
# translation:  那么,我们如何启动一个染色体? 我们如何激活它呢?
# Row:  426 , translating:  Obviously, with a virus it's pretty simple;  it's much more complicated dealing with bacteria.
# translation:  很显然,对付病毒要简单得多。
# Row:  430 , translating:  The new chromosome went into the cell.
# translation:  新的染色体进入细胞。
# Row:  431 , translating:  In fact, we thought this might be as far as it went,  but we tried to design the process a little bit further.
# translation:  实际上,我们认为这个过程可能更远一些。
# Row:  432 , translating:  This is a major mechanism of evolution right here.
# translation:  这是进化的一个主要机制。
# Row:  434 , translating:  So, people who think of evolution  as just one gene changing at a time  have missed much of biology.
# translation:  所以,那些认为进化只是一个基因一次的改变的人 忽略了很多生物学。
# Row:  435 , translating:  There are enzymes called restriction enzymes  that actually digest DNA.
# translation:  有限制性酶,它们能消化DNA。
# Row:  436 , translating:  The chromosome that was in the cell  doesn't have one;  the chromosome we put in does.
# translation:  细胞里没有染色体;我们放的染色体有。
# Row:  438 , translating:  It turned blue because of the genes we put in it.
# translation:  它变成了蓝色,因为我们放进去的基因。
# Row:  442 , translating:  Now I've argued, this is not genesis;  this is building on three and a half billion years of evolution.
# translation:  我一直认为,这不是创世纪; 而是建立在35亿年的进化之上。
# Row:  444 , translating:  Why do this?
# translation:  为什么要这么做?
# Row:  445 , translating:  I think this is pretty obvious in terms of some of the needs.
# translation:  我认为这在一定程度上是显而易见的。
# Row:  446 , translating:  We're about to go from six and a half  to nine billion people over the next 40 years.
# translation:  未来40年,我们将会从65亿人发展到90亿人。
# Row:  447 , translating:  To put it in context for myself:  I was born in 1946.
# translation:  用我自己的话来说: 我生于1946年。
# Row:  449 , translating:  We have trouble feeding, providing fresh, clean water,  medicines, fuel  for the six and a half billion.
# translation:  我们很难为这65亿人提供新鲜、清洁的水,药品和燃料。
# Row:  450 , translating:  It's going to be a stretch to do it for nine.
# translation:  这将是一个9小时的拉伸。
# Row:  452 , translating:  When we try to think of biological processes  or any process to replace that,  it's going to be a huge challenge.
# translation:  当我们试着去思考生物过程,或者任何可以取代它的过程时, 这将会是一个巨大的挑战。
# Row:  453 , translating:  Then of course, there's all that  CO2 from this material  that ends up in the atmosphere.
# translation:  当然,所有来自这种物质的二氧化碳 最终都会进入大气层。
# Row:  455 , translating:  The electronics industry only had a dozen or so components,  and look at the diversity that came out of that.
# translation:  电子工业只有几十个部件,看看其中的多样性。
# Row:  456 , translating:  We're limited here primarily  by a biological reality  and our imagination.
# translation:  我们主要受到生物现实和想象力的限制。
# Row:  458 , translating:  We have the ability now to build a large robot  that can make a million chromosomes a day.
# translation:  现在我们有能力制造一个大型的机器人, 每天可以产生100万个染色体。
# Row:  460 , translating:  And it's just standard selection:  we can select for viability,  chemical or fuel production,  vaccine production, etc.
# translation:  这只是标准的选择:我们可以选择可行性, 化学或燃料生产,疫苗生产等等。
# Row:  462 , translating:  You know, we don't know necessarily what it'll look like:  we know exactly what their genetic code looks like.
# translation:  我们不一定知道它们会是什么样子: 我们知道它们的基因密码是什么样的。
# Row:  463 , translating:  We're focusing on now fourth-generation fuels.
# translation:  我们现在关注的是第四代燃料。
# Row:  464 , translating:  You've seen recently, corn to ethanol  is just a bad experiment.
# translation:  你最近看到的,玉米到乙醇只是个坏实验。
# Row:  467 , translating:  And we think we'll have the first fourth-generation fuels  in about 18 months.
# translation:  我们将有第四代燃料在18个月左右。
# Row:  468 , translating:  Sunlight and CO2 is one method ...
# translation:  阳光和二氧化碳是一种方法。
# Row:  469 , translating:  but in our discovery around the world,  we have all kinds of other methods.
# translation:  但在全世界的发现中,我们还有其他各种方法。
# Row:  470 , translating:  This is an organism we described in 1996.
# translation:  这是我们在1996年描述的有机体。
# Row:  471 , translating:  It lives in the deep ocean,  about a mile and a half deep,  almost at boiling-water temperatures.
# translation:  它生活在深海中,大约有1.5英里深, 几乎处于沸腾的温度下。
# Row:  472 , translating:  It takes CO2 to methane  using molecular hydrogen as its energy source.
# translation:  它使用分子氢气作为其能源。
# Row:  476 , translating:  But also, we're now working on using these same tools  to come up with instant sets of vaccines.
# translation:  但是,我们也在用同样的工具 来设计一整套疫苗。
# Row:  478 , translating:  I think that can be changed  by building combinatorial vaccines in advance.
# translation:  我认为这可以通过预先建立组合疫苗来改变。
# Row:  487 , translating:  It's also very flexible architecture.
# translation:  它也是一个非常灵活的建筑。
# Row:  488 , translating:  This is an entire book, so this is an example of non-image data.
# translation:  这是整本书,这是一个非图像数据的例子。
# Row:  489 , translating:  This is "Bleak House" by Dickens. Every column is a chapter.
# translation:  这是狄更斯的《白屋》。每一列都是一章。
# Row:  491 , translating:  Maybe this is an artificial way to read an e-book.
# translation:  也许这是一种人工阅读电子书的方法。
# Row:  492 , translating:  I wouldn't recommend it.
# translation:  我不会推荐它。
# Row:  493 , translating:  This is a more realistic case, an issue of The Guardian.
# translation:  这是一个更现实的例子,《卫报》的问题。
# Row:  494 , translating:  Every large image is the beginning of a section.
# translation:  每个大图像都是一个部分的开始。
# Row:  496 , translating:  We've done something  with the corner of this particular issue of The Guardian.
# translation:  我们在“卫报”这个特别的议题上做了些什么。
# Row:  498 , translating:  If you want to see the features of this car, you can see it here.
# translation:  如果你想看看这辆车的特点,你可以在这里看到。
# Row:  499 , translating:  Or other models, or even technical specifications.
# translation:  或者其他模型,甚至技术规格。
# Row:  500 , translating:  And this really gets at some of these ideas  about really doing away with those limits on screen real estate.
# translation:  这些想法真的可以消除 屏幕房地产的限制。
# Row:  501 , translating:  We hope that this means no more pop-ups  and other rubbish like that -- shouldn't be necessary.
# translation:  我们希望这不会再有弹出和其他的垃圾了-- 这不应该是必要的。
# Row:  502 , translating:  Of course, mapping is one of those obvious applications  for a technology like this.
# translation:  当然,地图是这类技术的明显应用之一。
# Row:  504 , translating:  But those are all the roads in the U.S.
# translation:  但在美国,这些都是道路。
# Row:  505 , translating:  superimposed on top of a NASA geospatial image.
# translation:  置于NASA的地理空间图像之上。
# Row:  506 , translating:  So let's pull up, now, something else.
# translation:  那么,让我们拉上去,别的什么东西。
# Row:  507 , translating:  This is actually live on the Web now; you can go check it out.
# translation:  实际上这是在网络上,你可以去看看。
# Row:  508 , translating:  This is a project called Photosynth, which marries two different technologies.
# translation:  这是一个叫做Photosynth的项目, 它结合了两种不同的技术。
# Row:  510 , translating:  and Rick Szeliski at Microsoft Research.
# translation:  还有微软的Rick Szeliski。
# Row:  511 , translating:  A very nice collaboration.
# translation:  非常好的合作。
# Row:  512 , translating:  And so this is live on the Web. It's powered by Seadragon.
# translation:  这是在网络上直播的,由Seadragon提供动力。
# Row:  514 , translating:  But the spatial arrangement of the images here is actually meaningful.
# translation:  但是这些图像的空间排列其实是有意义的。
# Row:  516 , translating:  So you see elements here of stabilized slide-show or panoramic imaging,  and these things have all been related spatially.
# translation:  这里你可以看到稳定的幻灯片或全景成像, 这些东西都和空间有关。
# Row:  517 , translating:  I'm not sure if I have time to show you any other environments.
# translation:  我不确定我是否有时间给你们展示其他环境。
# Row:  518 , translating:  Some are much more spatial.
# translation:  有些更具有空间性。
# Row:  520 , translating:  We had to worry about the lawyers and so on.
# translation:  我们不得不担心律师,等等。
# Row:  521 , translating:  This is a reconstruction of Notre Dame Cathedral  that was done entirely computationally from images scraped from Flickr.
# translation:  这是圣母大教堂的重建, 完全是用Flickr上的图像完成的。
# Row:  523 , translating:  And each of these orange cones represents an image  that was discovered to belong to this model.
# translation:  这些橙色的圆柱代表了 一个被发现属于这个模型的图像。
# Row:  524 , translating:  And so these are all Flickr images,  and they've all been related spatially in this way.
# translation:  这些都是Flickr的图片, 它们都以这种方式在空间上相关联。
# Row:  525 , translating:  We can just navigate in this very simple way.
# translation:  我们可以用这种简单的方式导航。
# Row:  526 , translating:  You know, I never thought that I'd end up working at Microsoft.
# translation:  我从没想过我会在微软工作。
# Row:  527 , translating:  It's very gratifying to have this kind of reception here.
# translation:  很高兴能有这样的接待。
# Row:  530 , translating:  Somewhere in here there is actually a series of photographs -- here we go.
# translation:  这里有一系列的照片。
# Row:  531 , translating:  This is actually a poster of Notre Dame that registered correctly.
# translation:  这是一张圣母院的海报,注册正确。
# Row:  532 , translating:  We can dive in from the poster  to a physical view of this environment.
# translation:  我们可以从海报到这个环境的物理视图。
# Row:  533 , translating:  What the point here really is  is that we can do things with the social environment.
# translation:  这里的重点是,我们能用社会环境做些什么。
# Row:  535 , translating:  Those photos become linked, and they make something emergent  that's greater than the sum of the parts.
# translation:  这些照片变得关联起来, 它们产生的比部分的总和还要大。
# Row:  536 , translating:  You have a model that emerges of the entire Earth.
# translation:  整个地球都有一个模型。
# Row:  537 , translating:  Think of this as the long tail to Stephen Lawler's Virtual Earth work.
# translation:  把这看作是史蒂芬·劳勒的虚拟地球作品。
# Row:  538 , translating:  And this is something that grows in complexity as people use it,  and whose benefits become greater to the users as they use it.
# translation:  当人们使用它时,它的好处会越来越大。
# Row:  539 , translating:  Their own photos are getting tagged with meta-data that somebody else entered.
# translation:  他们自己的照片被别人输入的元数据标记。
# Row:  542 , translating:  Thank you so much.
# translation:  非常感谢。
# Row:  545 , translating:  It's doing that based on the content inside the images.
# translation:  它基于图像中的内容。
# Row:  546 , translating:  And that gets really exciting when you think about the richness  of the semantic information a lot of images have.
# translation:  当你想到语义信息的丰富性时,你会感到非常兴奋。
# Row:  548 , translating:  What if that picture links to all of your pictures?
# translation:  如果这张照片链接到你所有的图片呢?
# Row:  549 , translating:  The amount of semantic interconnection and richness  that comes out of that is really huge.
# translation:  语义上的联系和丰富性是巨大的。
# Row:  550 , translating:  It's a classic network effect.
# translation:  这是一个经典的网络效应。
# Row:  551 , translating:  CA: Truly incredible. Congratulations.
# translation:  克里斯·安德森:真是太不可思议了。
# Row:  554 , translating:  the consequence of one particular set of adaptive choices  that our lineage made, albeit successfully, many generations ago.
# translation:  一个特定的适应性选择的后果, 虽然是成功的,许多代以前。
# Row:  555 , translating:  And of course, we all share the same adaptive imperatives.
# translation:  当然,我们都有同样的适应性。
# Row:  556 , translating:  We're all born. We all bring our children into the world.
# translation:  我们都是天生的。我们把孩子带进了这个世界。
# Row:  557 , translating:  We go through initiation rites.
# translation:  我们通过启蒙仪式。
# Row:  559 , translating:  But what's interesting is the unique cadence of the song,  the rhythm of the dance in every culture.
# translation:  但有趣的是这首歌的独特节奏, 每一种文化中舞蹈的节奏。
# Row:  561 , translating:  Everest, the goddess mother of the world.
# translation:  珠穆朗玛,世界之母。
# Row:  563 , translating:  And this is an idea, if you think about it,  can only fill you with hope.
# translation:  如果你仔细想想,这个想法只能充满希望。
# Row:  566 , translating:  The ethnosphere is humanity's great legacy.
# translation:  种族是人类的伟大遗产。
# Row:  567 , translating:  It's the symbol of all that we are  and all that we can be as an astonishingly inquisitive species.
# translation:  它象征着我们, 也象征着我们作为一个令人惊叹的物种。
# Row:  570 , translating:  And the great indicator of that, of course, is language loss.
# translation:  当然,最大的指标是语言流失。
# Row:  571 , translating:  When each of you in this room were born,  there were 6,000 languages spoken on the planet.
# translation:  当你们每一个人出生时,地球上有6000种语言。
# Row:  572 , translating:  Now, a language is not just a body of vocabulary  or a set of grammatical rules.
# translation:  现在,语言不仅仅是一个词汇体 或者一套语法规则。
# Row:  573 , translating:  A language is a flash of the human spirit.
# translation:  语言是人类精神的闪光。
# Row:  574 , translating:  It's a vehicle through which the soul of each particular culture  comes into the material world.
# translation:  它是每个特定文化的灵魂进入物质世界的载体。
# Row:  575 , translating:  Every language is an old-growth forest of the mind,  a watershed, a thought, an ecosystem of spiritual possibilities.
# translation:  每一种语言都是心灵的古老森林, 一个分水岭,一个充满灵性可能性的生态系统。
# Row:  577 , translating:  They're no longer being taught to babies,  which means, effectively, unless something changes,  they're already dead.
# translation:  他们不再被教导, 也就是说,除非有什么改变,他们已经死了。
# Row:  581 , translating:  Let's make it Kogi."
# translation:  让它Kogi。”
# Row:  582 , translating:  And you'll suddenly discover what it would be like  to be unable to speak your own language.
# translation:  你就会突然发现 不能说你自己的语言。
# Row:  588 , translating:  They simply listen and then begin to speak.
# translation:  他们只是听着然后开始说话。
# Row:  590 , translating:  In 1957, five missionaries attempted contact  and made a critical mistake.
# translation:  1957年,五位传教士试图联系并犯了一个重大错误。
# Row:  593 , translating:  But the Waorani didn't just spear outsiders.
# translation:  但瓦拉尼人不仅仅只是局外人。
# Row:  594 , translating:  They speared each other.
# translation:  他们互相推搡。
# Row:  595 , translating:  54 percent of their mortality was due to them spearing each other.
# translation:  54%的死亡是因为他们互相鞭打。
# Row:  600 , translating:  On the contrary, it's a complex metaphysical worldview.
# translation:  相反,这是一个复杂的形而上学的世界观。
# Row:  601 , translating:  It's interesting.
# translation:  很有趣。
# Row:  602 , translating:  If I asked you to name the great religions of the world,  what would you say?
# translation:  如果我请你给世界各大宗教起名字,你会怎么说?
# Row:  603 , translating:  Christianity, Islam, Buddhism, Judaism, whatever.
# translation:  基督教,伊斯兰教,犹太教,等等。
# Row:  606 , translating:  So, the living give birth to the spirits.
# translation:  于是,活人就生了灵魂。
# Row:  608 , translating:  That's why the Voodooists like to say  that "You white people go to church and speak about God.
# translation:  这就是为什么伏地魔喜欢说 “你们白人去教堂谈论上帝。
# Row:  609 , translating:  We dance in the temple and become God."
# translation:  我们在寺庙里跳舞,成为上帝。”
# Row:  610 , translating:  And because you are possessed, you are taken by the spirit --  how can you be harmed?
# translation:  因为你被精神所占据, 你怎么会受到伤害呢?
# Row:  614 , translating:  In a bloodstained continent,  these people alone were never conquered by the Spanish.
# translation:  在一片鲜血的大陆上, 只有这些人从未被西班牙人征服过。
# Row:  615 , translating:  To this day, they remain ruled by a ritual priesthood  but the training for the priesthood is rather extraordinary.
# translation:  直到今天,他们仍然被一个仪式的祭司统治着 但牧师的训练是相当了不起的。
# Row:  619 , translating:  It is that beautiful. It is yours to protect."
# translation:  太美了,是你们的保护。”
# Row:  621 , translating:  Now, this level of intuition becomes very important.
# translation:  现在,直觉变得非常重要。
# Row:  623 , translating:  Well, indigenous people are neither sentimental  nor weakened by nostalgia.
# translation:  土著人既没有感情,也没有怀旧。
# Row:  625 , translating:  Now, what does that mean?
# translation:  这意味着什么?
# Row:  627 , translating:  Whether it's the abode of a spirit or a pile of ore is irrelevant.
# translation:  不管是精神还是一堆矿石,都无关紧要。
# Row:  628 , translating:  What's interesting is the metaphor that defines the relationship  between the individual and the natural world.
# translation:  有趣的是,这个比喻定义了个人和自然界之间的关系。
# Row:  629 , translating:  I was raised in the forests of British Columbia  to believe those forests existed to be cut.
# translation:  我是在不列颠哥伦比亚省的森林里长大的, 相信这些森林是可以被砍伐的。
# Row:  632 , translating:  It's a photograph I took in the Northwest Amazon just last April.
# translation:  这是我去年四月在亚马逊西北部拍摄的照片。
# Row:  635 , translating:  called Psychotria viridis.
# translation:  叫做Psychotria viridis。
# Row:  640 , translating:  because they're denatured by an enzyme  found naturally in the human gut called monoamine oxidase.
# translation:  因为它们被一种叫做一氧化二氮的酶破坏了。
# Row:  641 , translating:  They can only be taken orally if taken in conjunction  with some other chemical that denatures the MAO.
# translation:  它们只能被口服, 如果与一些其他化学物质结合使用的话。
# Row:  644 , translating:  Well, we use that great euphemism, "trial and error,"  which is exposed to be meaningless.
# translation:  嗯,我们用“试错”这句话来形容它毫无意义。
# Row:  645 , translating:  But you ask the Indians, and they say, "The plants talk to us."
# translation:  但是你问印第安人,他们说,“植物会跟我们说话。”
# Row:  646 , translating:  Well, what does that mean?
# translation:  那是什么意思呢?
# Row:  648 , translating:  And then you ask them how they establish their taxonomy  and they say, "I thought you knew something about plants.
# translation:  然后你问他们如何建立他们的分类法,他们说,“我以为你知道一些关于植物的东西。
# Row:  649 , translating:  I mean, don't you know anything?" And I said, "No."
# translation:  你知道吗?”我说,“不。”
# Row:  653 , translating:  All cultures through all time  have constantly been engaged in a dance  with new possibilities of life.
# translation:  所有的文化都不断地参与到舞蹈中, 带着新的生命可能性。
# Row:  654 , translating:  And the problem is not technology itself.
# translation:  问题不在于技术本身。
# Row:  659 , translating:  it's the disease entities that have come in,  in the wake of the discovery of gold.
# translation:  是那些在发现黄金之后出现的病菌。
# Row:  664 , translating:  That meant he was instantly killed  at the time of the Chinese invasion.
# translation:  这意味着他在中国入侵时被立即杀死。
# Row:  665 , translating:  His uncle fled with His Holiness in the Diaspora  that took the people to Nepal.
# translation:  他的叔叔逃到了尼泊尔的散居地。
# Row:  667 , translating:  The sister who had done that brave deed  was put into an education camp.
# translation:  做了那件勇敢的事的姐姐被送进了教育营。
# Row:  669 , translating:  The pain of Tibet can be impossible to bear,  but the redemptive spirit of the people is something to behold.
# translation:  西藏的痛苦是无法忍受的, 但人民的救赎精神却是值得注意的。
# Row:  674 , translating:  The modern industrial world as we know it  is barely 300 years old.
# translation:  我们所知的现代工业世界 只有300年的历史。
# Row:  680 , translating:  This old man's grandfather refused to go.
# translation:  这位老人的爷爷拒绝了。
# Row:  681 , translating:  The family, fearful for his life, took away all of his weapons,  all of his tools.
# translation:  他的家人,害怕他的生活,拿走了所有的武器,所有的工具。
# Row:  682 , translating:  Now, you must understand that the Inuit did not fear the cold;  they took advantage of it.
# translation:  现在,你必须明白因纽特人并不害怕寒冷;他们利用了它。
# Row:  683 , translating:  The runners of their sleds were originally made of fish  wrapped in caribou hide.
# translation:  他们的雪橇最初是用鱼包装成的。
# Row:  690 , translating:  It's our new homeland. It's called Nunavut.
# translation:  这就是我们的新家园。它叫做Nunavut。
# Row:  691 , translating:  It's an independent territory. They control all mineral resources.
# translation:  这是一个独立的领土。他们控制着所有的矿产资源。
# Row:  692 , translating:  An amazing example of how a nation-state  can seek restitution with its people.
# translation:  一个民族国家如何与人民一起寻求恢复。
# Row:  694 , translating:  They're homelands of somebody.
# translation:  他们是某人的故乡。
# Row:  698 , translating:  156 nations carry our television channel.
# translation:  156个国家拥有我们的电视频道。
# Row:  699 , translating:  Our magazines are read by millions.
# translation:  我们的杂志被数以百万计的人阅读。
# Row:  701 , translating:  where all of the wisdom of all peoples  can contribute to our collective well-being.
# translation:  所有人民的智慧 都能为我们的集体幸福做出贡献。
# Row:  702 , translating:  Thank you very much.
# translation:  非常感谢。
# Row:  704 , translating:  But I want to start with what I call the "official dogma."
# translation:  我想从“官方的教条”开始。
# Row:  705 , translating:  The official dogma of what?
# translation:  官方的教条是什么?
# Row:  706 , translating:  The official dogma of all Western industrial societies.
# translation:  西方工业社会的官方教条。
# Row:  708 , translating:  The reason for this is both that freedom is in and of itself good,  valuable, worthwhile, essential to being human.
# translation:  因为自由本身就是好的,有价值的,对人类来说是必不可少的。
# Row:  710 , translating:  The way to maximize freedom is to maximize choice.
# translation:  最大化自由的方法就是最大限度地选择。
# Row:  713 , translating:  And it's also deeply embedded in our lives.
# translation:  它也深深地植根于我们的生活中。
# Row:  714 , translating:  I'll give you some examples of what modern progress has made possible for us.
# translation:  我给你们举几个例子, 说明现代进步给我们带来了什么。
# Row:  715 , translating:  This is my supermarket. Not such a big one.
# translation:  这是我的超市。不是那么大。
# Row:  716 , translating:  I want to say just a word about salad dressing.
# translation:  我想说一个关于沙拉打扮的词。
# Row:  718 , translating:  So this is what the supermarket is like.
# translation:  这就是超市的样子。
# Row:  721 , translating:  You've got to admit that's a lot of choice.
# translation:  你必须承认这有很多选择。
# Row:  722 , translating:  In other domains -- the world of communications.
# translation:  在其他领域——通讯的世界。
# Row:  724 , translating:  You rented your phone. You didn't buy it.
# translation:  你租了你的手机,你没有买。
# Row:  725 , translating:  One consequence of that, by the way, is that the phone never broke.
# translation:  顺便说一下,其中一个后果是电话从未断过。
# Row:  726 , translating:  And those days are gone.
# translation:  那些日子过去了。
# Row:  727 , translating:  We now have an almost unlimited variety of phones,  especially in the world of cell phones.
# translation:  现在我们有几乎无限的手机, 尤其是在手机的世界里。
# Row:  728 , translating:  These are cell phones of the future.
# translation:  这些是未来的手机。
# Row:  731 , translating:  And what this does  is it leads people to walk into their stores asking this question.
# translation:  这会让人们走进商店 问这个问题。
# Row:  732 , translating:  And do you know what the answer to this question now is?
# translation:  你知道这个问题的答案是什么吗?
# Row:  733 , translating:  The answer is "no."
# translation:  答案是“不”。
# Row:  734 , translating:  It is not possible to buy a cell phone that doesn't do too much.
# translation:  买一个没有太多功效的手机是不可能的。
# Row:  735 , translating:  So, in other aspects of life that are much more significant than buying things,  the same explosion of choice is true.
# translation:  所以,在生活中的其他方面 比购买东西更重要,同样的选择爆炸性是真的。
# Row:  738 , translating:  A has these benefits, and these risks.
# translation:  A有这些好处,还有这些风险。
# Row:  739 , translating:  B has these benefits, and these risks. What do you want to do?"
# translation:  B有这些好处和风险。你想做什么?”
# Row:  740 , translating:  And you say, "Doc, what should I do?"
# translation:  你说:“医生,我该怎么办?”
# Row:  741 , translating:  And the doc says, "A has these benefits and risks, and B has these benefits and risks.
# translation:  医生说,“A有这些好处和风险,B也有这些好处和风险。”
# Row:  742 , translating:  What do you want to do?"
# translation:  你想怎么做?”
# Row:  743 , translating:  And you say, "If you were me, Doc, what would you do?"
# translation:  你会说,“如果你是我,博士,你会怎么做?”
# Row:  744 , translating:  And the doc says, "But I'm not you."
# translation:  医生说:“我不是你。”
# Row:  747 , translating:  Why do they market to us if we can't buy them?
# translation:  如果我们买不到它们,为什么要向我们推销呢?
# Row:  750 , translating:  We don't inherit an identity; we get to invent it.
# translation:  我们不能继承一个身份,我们可以发明它。
# Row:  751 , translating:  And we get to re-invent ourselves as often as we like.
# translation:  我们会尽可能的重塑自己。
# Row:  754 , translating:  The only real choice was who,  not when, and not what you did after.
# translation:  唯一的选择是谁,而不是你之后做了什么。
# Row:  755 , translating:  Nowadays, everything is very much up for grabs.
# translation:  如今,一切都是可以抓取的。
# Row:  757 , translating:  And it's not because they're less smart,  and it's not because they're less diligent.
# translation:  不是因为他们不够聪明,也不是因为他们不那么勤奋。
# Row:  759 , translating:  Should I get married later? Should I have kids first, or a career first?"
# translation:  我应该结婚吗?我应该先生孩子,还是先有事业?”
# Row:  760 , translating:  All of these are consuming questions.
# translation:  这些都是消耗性的问题。
# Row:  762 , translating:  And indeed they should. These are important questions to answer.
# translation:  的确,他们应该回答这些重要的问题。
# Row:  765 , translating:  I'm not telling you about it because I want to use it.
# translation:  我不是在跟你们说这个,因为我想用它。
# Row:  769 , translating:  Should I respond to this email? Should I draft this letter?"
# translation:  我应该回复这封邮件吗?我应该起草这封信吗?”
# Row:  771 , translating:  So everywhere we look,  big things and small things, material things and lifestyle things,  life is a matter of choice.
# translation:  无论我们看到什么,大事小事,物质和生活方式的事物, 生活都是一个选择。
# Row:  772 , translating:  And the world we used to live in looked like this.
# translation:  我们曾经生活的世界是这样的。
# Row:  773 , translating:  That is to say, there were some choices,  but not everything was a matter of choice.
# translation:  也就是说,有一些选择, 但不是所有事情都是有选择的。
# Row:  774 , translating:  And the world we now live in looks like this.
# translation:  我们现在生活的世界是这样的。
# Row:  775 , translating:  And the question is, is this good news, or bad news?
# translation:  问题是,这是好消息还是坏消息?
# Row:  776 , translating:  And the answer is, "yes."
# translation:  答案是肯定的。
# Row:  777 , translating:  We all know what's good about it,  so I'm going to talk about what's bad about it.
# translation:  我们都知道什么是好的,所以我将要谈论什么是坏的。
# Row:  778 , translating:  All of this choice has two effects,  two negative effects on people.
# translation:  所有这些选择都对人们有两种负面影响。
# Row:  780 , translating:  With so many options to choose from,  people find it very difficult to choose at all.
# translation:  有如此多的选择,人们觉得很难去选择。
# Row:  783 , translating:  And what she found  is that for every 10 mutual funds the employer offered,  rate of participation went down two percent.
# translation:  她发现每提供10个共同基金, 参与率就下降了2%。
# Row:  786 , translating:  And then tomorrow,  and tomorrow, and tomorrow,  and of course tomorrow never comes.
# translation:  明天,明天,当然也永远不会到来。
# Row:  789 , translating:  So paralysis is a consequence of having too many choices.
# translation:  所以瘫痪是有太多选择的后果。
# Row:  790 , translating:  And I think it makes the world look like this.
# translation:  我认为这个世界是这样的。
# Row:  791 , translating:  You really want to get the decision right if it's for all eternity, right?
# translation:  你真的想做出正确的决定,如果它是永恒的,对吧?
# Row:  792 , translating:  You don't want to pick the wrong mutual fund, or the wrong salad dressing.
# translation:  你不会选择错误的互助基金, 或者不正确的沙拉打扮。
# Row:  794 , translating:  And there are several reasons for this.
# translation:  原因有几个。
# Row:  798 , translating:  Second, what economists call "opportunity costs."
# translation:  第二,经济学家称之为“机会成本”。
# Row:  802 , translating:  Here's what you're supposed to be thinking.
# translation:  这就是你要想的。
# Row:  803 , translating:  Here's this couple on the Hamptons.
# translation:  这是一对汉普顿夫妇。
# Row:  804 , translating:  Very expensive real estate.
# translation:  非常昂贵的房地产。
# Row:  805 , translating:  Gorgeous beach. Beautiful day. They have it all to themselves.
# translation:  美妙的海滩,美好的一天。他们自己拥有这一切。
# Row:  807 , translating:  I could be parking right in front of my building."
# translation:  我可以停在我大楼前面。”
# Row:  811 , translating:  Here's another example.   Now this cartoon makes a lot of points.
# translation:  这里是另一个例子。这幅漫画有很多要点。
# Row:  812 , translating:  It makes points about living in the moment as well,  and probably about doing things slowly.
# translation:  它也意味着活在当下,并且可能慢慢地做一些事情。
# Row:  814 , translating:  Third: escalation of expectations.
# translation:  第三,期望的升级。
# Row:  815 , translating:  This hit me when I went to replace my jeans.
# translation:  当我去换牛仔裤的时候,我被吓坏了。
# Row:  816 , translating:  I wear jeans almost all the time.
# translation:  我几乎总是穿牛仔裤。
# Row:  819 , translating:  And the shopkeeper said,  "Do you want slim fit, easy fit, relaxed fit?
# translation:  店主说:“你想要柔软的,容易的,放松的吗?”
# Row:  820 , translating:  You want button fly or zipper fly? You want stonewashed or acid-washed?
# translation:  你要按钮飞,还是起重机飞?要洗石头或酸奶吗?
# Row:  821 , translating:  Do you want them distressed?
# translation:  你想让他们痛苦吗?
# Row:  822 , translating:  You want boot cut, tapered, blah blah." On and on he went.
# translation:  你要剪靴子,带上磁带。”他继续说道。
# Row:  825 , translating:  I did better. All this choice made it possible for me to do better.
# translation:  我做得更好。这些选择使我能做得更好。
# Row:  826 , translating:  But -- I felt worse.
# translation:  但我感觉更糟。
# Row:  827 , translating:  Why? I wrote a whole book to try to explain this to myself.
# translation:  为什么?我写了整本书来向自己解释。
# Row:  829 , translating:  I had very low, no particular expectations when they only came in one flavor.
# translation:  我的期望值很低,只有一种味道。
# Row:  830 , translating:  When they came in 100 flavors, damn it, one of them should've been perfect.
# translation:  当它们有100种味道,该死的,其中一个应该是完美的。
# Row:  831 , translating:  And what I got was good, but it wasn't perfect.
# translation:  我得到的很好,但并不完美。
# Row:  834 , translating:  And what that's going to produce is less satisfaction with results,  even when they're good results.
# translation:  结果的满意度会降低, 即使效果好。
# Row:  835 , translating:  Nobody in the world of marketing knows this.
# translation:  营销界没有人知道这个。
# Row:  836 , translating:  Because if they did, you wouldn't all know what this was about.
# translation:  因为如果他们这么做了,你们可能不知道这是什么。
# Row:  839 , translating:  You will never be pleasantly surprised  because your expectations, my expectations, have gone through the roof.
# translation:  你永远不会感到惊讶, 因为你的期望,我的期待,已经过时了。
# Row:  842 , translating:  I couldn't have done better. I didn't settle.
# translation:  我不能做得更好。我没有安定下来。
# Row:  843 , translating:  But settling isn't always such a bad thing.
# translation:  但安定并不总是一件坏事。
# Row:  845 , translating:  What could you do?
# translation:  你能做什么?
# Row:  847 , translating:  It is equally clear that the answer to the question is "you."
# translation:  很明显,这个问题的答案是“你”。
# Row:  848 , translating:  You could have done better.
# translation:  你可以做得更好。
# Row:  849 , translating:  With a hundred different kinds of jeans on display,  there is no excuse for failure.
# translation:  有上百种不同的牛仔裤,没有理由失败。
# Row:  851 , translating:  Clinical depression has exploded in the industrial world in the last generation.
# translation:  临床抑郁症在上一代人中爆发了。
# Row:  853 , translating:  And so the net result is that we do better in general, objectively,  and we feel worse.
# translation:  总的来说,我们做得更好, 我们感觉更糟。
# Row:  854 , translating:  So let me remind you.
# translation:  让我提醒你们。
# Row:  857 , translating:  There's some magical amount. I don't know what it is.
# translation:  有些神奇的量。我不知道它是什么。
# Row:  858 , translating:  I'm pretty confident that we have long since passed the point  where options improve our welfare.
# translation:  我非常有信心,我们早就通过 选择来改善我们的福利。
# Row:  861 , translating:  Their problem is that they have too little.
# translation:  问题是他们太少了。
# Row:  862 , translating:  So the stuff I'm talking about is the peculiar problem of modern, affluent, Western societies.
# translation:  我所谈论的是 现代的,富裕的,西方社会的特殊问题。
# Row:  864 , translating:  What I'm telling you is that these expensive, complicated choices --  it's not simply that they don't help.
# translation:  我要告诉你们的是,这些昂贵而复杂的选择-- 不仅仅是它们无济于事。
# Row:  865 , translating:  They actually hurt.
# translation:  他们真的很伤人。
# Row:  866 , translating:  They actually make us worse off.
# translation:  实际上,他们让我们更糟。
# Row:  869 , translating:  You know, nothing is possible in this fishbowl."
# translation:  你知道,在这个鱼碗里什么都不可能。”
# Row:  870 , translating:  Impoverished imagination, a myopic view of the world --  and that's the way I read it at first.
# translation:  贫穷的想象力,我最初读的方式。
# Row:  871 , translating:  The more I thought about it, however,  the more I came to the view that this fish knows something.
# translation:  然而,我越是想到 这条鱼就知道些什么。
# Row:  873 , translating:  If you shatter this fishbowl so that everything is possible,  you decrease satisfaction.
# translation:  如果你打破了这个鱼碗,所有事情都有可能发生, 你就会降低满意度。
# Row:  874 , translating:  You increase paralysis, and you decrease satisfaction.
# translation:  会增加麻痹,降低满意度。
# Row:  875 , translating:  Everybody needs a fishbowl.
# translation:  每个人都需要一碗鱼。
# Row:  876 , translating:  This one is almost certainly too limited --  perhaps even for the fish, certainly for us.
# translation:  这几乎肯定是太有限了-- 甚至鱼,对我们来说也是。
# Row:  877 , translating:  But the absence of some metaphorical fishbowl is a recipe for misery,  and, I suspect, disaster.
# translation:  但是缺乏一些隐喻的鱼碗 是痛苦的秘诀,我怀疑,灾难。
# Row:  878 , translating:  Thank you very much.
# translation:  非常感谢。

# %%
def process_string(text):
    return replace_punctuation_with_zh(remove_spaces(text))

def remove_spaces(text):
    return ''.join(text.split())

# Replacing en punctuation with the zh counterparts
def replace_punctuation_with_zh(text):
    # Define a mapping of English punctuation to Chinese punctuation
    punctuation_mapping = {
        ',': '，',
        '.': '。',
        '?': '？',
        '!': '！',
        ':': '：',
        ';': '；',
        '"': '”',
        "'": '’',
        '(': '（',
        ')': '）',
        '[': '【',
        ']': '】',
        '{': '｛',
        '}': '｝'
    }

    # Replace each English punctuation with its Chinese counterpart
    for eng_punc, chi_punc in punctuation_mapping.items():
        text = text.replace(eng_punc, chi_punc)

    return text

processed_predictions_forward = [process_string(sent) for sent in predictions]
processed_references_forward = [process_string(sent[0]) for sent in references]

df = pd.DataFrame({'Prediction': processed_predictions_forward, 'Reference': processed_references_forward})
df.to_csv(f'zh_to_en_t5_{model_name}_forwards_translations.csv', index=False)

processed_references_forward = [[reference] for reference in processed_references_forward]

bleu_score_no_smoothing = sacrebleu.corpus_bleu(processed_predictions_forward, processed_references_forward, tokenize='zh')
bleu_score_add_1 = sacrebleu.corpus_bleu(processed_predictions_forward, processed_references_forward, tokenize='zh', smooth_method="add-k", smooth_value=1)

print(f"BLEU Score without smoothing: BLEU = {bleu_score_no_smoothing}")
print(f"BLEU Score with smoothing: BLEU = {bleu_score_add_1}")
# Out:
# BLEU Score without smoothing: BLEU = BLEU = 49.68 100.0/73.1/40.0/20.8 (BP = 1.000 ratio = 1.000 hyp_len = 27 ref_len = 27)
# BLEU Score with smoothing: BLEU = BLEU = 52.37 100.0/74.1/42.3/24.0 (BP = 1.000 ratio = 1.000 hyp_len = 27 ref_len = 27)

# %% [markdown]
# 2 way evaluation from chinese to english back to chinese

# %%
prefix = 'translate to en: '

first_predictions, references = [], []

for index, row in val_df.iterrows():
  print("Row: ", str(index), ", translating: ", row['zh'])
  src_text = prefix + row['zh']
  input_ids = tokenizer(src_text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids.to(device)
  generated_tokens = model.generate(input_ids)
  translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
  print("translation: ", translation)
  first_predictions.append(translation)
  references.append(row['zh'])

references = [[reference] for reference in references]
# Out:
# Row:  1 , translating:  但这些没能完全说明这个问题的严重性 因为这没有表示出冰帽的厚度
# translation:  But these do not fully explain the severity of the problem, because this does not indicate the thickness of the ice cap.
# Row:  2 , translating:  感觉上，北极冰帽 就好象全球气候系统中跳动的心脏
# translation:  The Arctic ice cap feels like a beating heart in the global climate system.
# Row:  3 , translating:  冬天心脏舒张，夏天心脏收缩
# translation:  The heart is swelled in winter and the heart contractes in summer.
# Row:  4 , translating:  下面我要展示的是 在过去25年里的极剧变化
# translation:  Below I want to show you the dramatic changes that have taken place over the past 25 years.
# Row:  5 , translating:  红色的是永冻冰
# translation:  The red is the permafrost ice.
# Row:  8 , translating:  在25年的时间里，它从这里，到了这里
# translation:  25 years later, it came from here to here.
# Row:  10 , translating:  如果突破顶点，温室气体排放量 将是现有大气层中的全球温室污染总量
# translation:  If it breaks through, the GHG emissions will be the total global greenhouse gas pollutant in the existing atmosphere.
# Row:  11 , translating:  在阿拉斯加的一些浅湖里 已经可以看到水中探头的沼气泡
# translation:  In some shallow lakes in Alaska, biobubbles can already be seen inside the water probe.
# Row:  12 , translating:  去年冬天，University of Alaska的Katey Walter教授 结队去了一个浅湖
# translation:  Last winter, Professor Katey Walter of the University of Alaska teamed up to a shallow lake.
# Row:  13 , translating:  哇（开心而又惊叹滴笑） 戈尔：她很好，我们怎么样呢？
# translation:  Wow (quickly laughing) Gore: She's fine, what about us?
# Row:  14 , translating:  有一个原因，北方沉积的大量热能 加热了格陵兰岛
# translation:  For one reason, the large amounts of thermal energy deposited in the north heated Greenland Island.
# Row:  15 , translating:  这是一条每年融化的河
# translation:  It is a river that melts every year.
# Row:  16 , translating:  但流量却比往年都要大
# translation:  But the flow is larger than in previous years.
# Row:  17 , translating:  这是格陵兰岛西南的Kangerlussuaq河
# translation:  This is the south-west of Greenland's Kangerlussuaq River.
# Row:  18 , translating:  如果你想了解陆地上的冰块融化 如何使得海平面上升 这里就是它的入海口
# translation:  If you want to understand how the ice on land melts and raises sea levels, this is its entry into the sea.
# Row:  19 , translating:  这里的流量正在急速上升
# translation:  Traffic is rising rapidly here.
# Row:  20 , translating:  南极，地球的另一端 这个行星上最大的冰块
# translation:  Antarctica, the planet's largest ice block.
# Row:  21 , translating:  上个月，科学家报告整个大洲 正处于冰量减少的阶段
# translation:  Last month, scientists reported that the continent was in a phase of decreasing ice.
# Row:  22 , translating:  在南极洲的西部突然发现 几个低于海平面的岛屿正在加速融化
# translation:  Suddenly several islands below sea level are being discovered in the western part of Antarctica, accelerating their melting.
# Row:  23 , translating:  这相当于海平面上20英尺，和格陵兰岛一样
# translation:  20英尺 above sea level, the same as Greenland.
# Row:  25 , translating:  全球40%从其融水中 获得一半的饮用水
# translation:  40% of the world gets half its drinking water from it.
# Row:  26 , translating:  在安第斯山脉,这条冰河 是这座城市的饮用水源
# translation:  In the Andes, this ice river is the city's drinking water source.
# Row:  27 , translating:  流量正在增加
# translation:  Traffic is increasing.
# Row:  28 , translating:  但当它们消失时，我们也将失去饮用水
# translation:  But when they disappear, we will also lose our drinking water.
# Row:  29 , translating:  在California, Sierra的积雪 每年减少40%
# translation:  In California, Sierra's snowfall is reduced by 40% per year.
# Row:  30 , translating:  对于蓄水而言，这是一个打击
# translation:  For water storage, this is a blow.
# Row:  31 , translating:  而且如你看到的，预计是非常严重的
# translation:  And as you can see, it's expected to be very serious.
# Row:  32 , translating:  全球的干燥化 正在导致火灾数量急剧增加
# translation:  Global drying is causing a sharp increase in the number of fires.
# Row:  33 , translating:  而全世界的灾害数量 也正以绝对显著的 空前的速度增加
# translation:  The number of disasters around the world is also increasing at an unprecedented rate.
# Row:  34 , translating:  在过去三十年内，灾害总数达到了 更早七十五年总数的四倍
# translation:  In the past 30 years, the total number of disasters has reached four times that of the previous 75 years.
# Row:  35 , translating:  这是一种完全不可持续的模式
# translation:  This is a completely unsustainable model.
# Row:  36 , translating:  如果看下历史 你可以看到发生了些什么
# translation:  If you look at history, you can see what happened.
# Row:  40 , translating:  石油很重要，煤炭最为紧要
# translation:  Oil is very important, coal is the most important.
# Row:  41 , translating:  美国 正成为全球最大的两个排放国之一，和中国一起
# translation:  The United States is becoming one of the world's two largest emitters, along with China.
# Row:  42 , translating:  解决方案曾经是建造一个使用更多煤碳的星球
# translation:  The solution was to build a planet with more coal-carbons.
# Row:  43 , translating:  但我们已经开始看到海洋的变化了
# translation:  但是, we are beginning to see the oceans change.
# Row:  44 , translating:  这里是近年已经取消的一些 以及一些新的绿色替代方案
# translation:  Here are some that have been canceled in recent years, as well as some new green alternatives.
# Row:  46 , translating:  那个画面让我想起了什么
# translation:  That picture reminded me of something.
# Row:  47 , translating:  圣诞前后，在我的家乡田纳西 挖出了几十亿升的煤淤泥
# translation:  Before and after Christmas, in my hometown of Tennessee, billions of litres of coal were mined.
# Row:  48 , translating:  可能你在新闻上看过
# translation:  You may have seen it in the news.
# Row:  49 , translating:  这里，是全美第二大的废水排放
# translation:  这是美国第二大 废水排放国。
# Row:  50 , translating:  这发生于圣诞前后
# translation:  This happened before and after Christmas.
# Row:  51 , translating:  有一则这样的煤碳行业广告
# translation:  There is one such coal-carbon industry advertisement.
# Row:  52 , translating:  录象：♪♫煤炭酷先生是高兴和快乐的化身
# translation:  Video: *** Mr. Coal is a joyful and happy incarnationist.
# Row:  53 , translating:  在美国你可以见到他富饶多产 他还帮助我们发展经济
# translation:  In the U.S., you can see that he's prolific and also helps us grow our economy.
# Row:  54 , translating:  煤炭酷先生每天都在变得更干净
# translation:  Mr. Coal is getting cleaner every day.
# Row:  55 , translating:  他可爱实惠，为工人们带来工作机会
# translation:  He's cute and affordable, bringing jobs to workers.
# Row:  56 , translating:  戈尔：这里是West Virginia，许多煤炭的原产地
# translation:  GOL: West Virginia, the birthplace of many coals.
# Row:  57 , translating:  最大的山顶采矿是head of Massey Coal
# translation:  The largest mountaintop mining is the head of Massey Coal.
# Row:  59 , translating:  戈尔：所以气候保护联盟 开展了两个项目
# translation:  Gore: So the Climate Protection Alliance launched two projects.
# Row:  60 , translating:  这是其中的一个，其中一个的一部分
# translation:  This is one of them, part of it.
# Row:  61 , translating:  演员：在COALergy，我们非常严肃地对待 气候变化对我们的事业威胁
# translation:  Actor: At COALergy, we take climate change very seriously as a threat to our cause.
# Row:  63 , translating:  事实上，煤炭并不肮脏
# translation:  In fact, coal is not dirty.
# Row:  64 , translating:  我们认为，它是干净的 好闻的
# translation:  我们认为,它是干净的, smelly.
# Row:  65 , translating:  因此，不必为全球变暖而担心
# translation:  Therefore, there is no need to worry about global warming.
# Row:  66 , translating:  让我们来搞定吧
# translation:  让我们来解决这个问题。
# Row:  67 , translating:  演员：清洁煤炭，你已经听过关于它的许多
# translation:  Actor: Clean coal, you've heard a lot about it.
# Row:  68 , translating:  所以，让我们去看看如同艺术一般的清洁煤炭工厂吧
# translation:  那么, let's look at the art-like clean coal plant.
# Row:  69 , translating:  壮观！机器有些喧哗
# translation:  Magnificent! the machine is rumbling.
# Row:  70 , translating:  但这是清洁煤炭技术的声音
# translation:  But that's the sound of clean coal technology.
# Row:  71 , translating:  虽然烧煤是导致全球变暖的主要原因之一 你在这里所见到的令人折服的清洁煤炭技术 改变了一切
# translation:  Although coal burning is one of the main causes of global warming, you can see that the complacent clean coal technology has changed everything.
# Row:  72 , translating:  好好看看吧！这就是如今的清洁煤炭技术
# translation:  OK, that's clean coal technology right now.
# Row:  73 , translating:  戈尔：最后是这个正面的方案 可以应对经济挑战 和国家安全挑战
# translation:  戈尔:最后, this positive program can address economic and national security challenges.
# Row:  74 , translating:  录象：旁白:美国正处于危机 经济的、国家安全的、气候的危机
# translation:  Video: The United States is in a crisis of economics, national security, and climate.
# Row:  76 , translating:  但现在，有一种全新的解决这些难题的方案 Repower America
# translation:  But now there's a whole new solution to these problems, RePower America.
# Row:  77 , translating:  用百分百清洁的电力 用十年的时间
# translation:  100% clean electricity in a decade.
# Row:  78 , translating:  让美国人全新获得工作 让我们生活得更安全，并且让地球不在变暖
# translation:  New jobs for Americans will make our lives safer, and the planet will not get warmer.
# Row:  79 , translating:  最终，一个足够庞大的方案来解决我们的问题
# translation:  Ultimately, a plan large enough to solve our problems.
# Row:  80 , translating:  Repower America ，了解更多
# translation:  Repower America, learn more.
# Row:  81 , translating:  戈尔：最后一个
# translation:  Gore: The last one.
# Row:  82 , translating:  旁白：这是关于Repower America的
# translation:  Thread: This is about Repower America.
# Row:  83 , translating:  陈旧的肮脏石油正在谋杀我们的星球 这是让我们减少对其依赖的最快方式
# translation:  Old dirty oil is killing our planet, which is the fastest way to reduce our dependence on it.
# Row:  84 , translating:  男A：未来就在这里。风力、太阳能、新的能源网络
# translation:  MAN: The future is here.Wind, solar, new energy networks.
# Row:  85 , translating:  男B：新的投资创造更的报酬丰厚的工作
# translation:  男B: New investment creates better-paid jobs.
# Row:  86 , translating:  旁白：Repower America 。是时候梦想成真了！
# translation:  旁白:Repower America, it's time to come true!
# Row:  87 , translating:  戈尔：有一条古老的非洲谚语 如果想要走得快，独立前行
# translation:  Gore: There's an old African proverb if you want to walk fast, go independent.
# Row:  88 , translating:  如果想要走得远，结伴前行
# translation:  If you want to go far, partner with them.
# Row:  89 , translating:  我们需要的是走得远，而且快
# translation:  What we need is to go far, and fast.
# Row:  90 , translating:  非常感谢
# translation:  非常感谢
# Row:  91 , translating:  在去年的TED发言上我介绍了LHC
# translation:  Last year I introduced LHC to my TED talk.
# Row:  92 , translating:  而且我说过一定回来给大家实况更新 说说机器的运转情况
# translation:  And I told you to come back with a factual update about how the machine works.
# Row:  95 , translating:  非常具有野心
# translation:  Very ambitious.
# Row:  96 , translating:  这就是在日内瓦地下的机械
# translation:  This is the Geneva-based machinery.
# Row:  97 , translating:  我们用这些探测器给迷你大爆炸照相
# translation:  We use these detectors to take mini-explosion photos.
# Row:  99 , translating:  这是ATLAS建造过程中的壮观景象 可以看出规模巨大
# translation:  This is the spectacular sight of ATLAS's construction process. It can be seen on a large scale.
# Row:  100 , translating:  去年9月10日我们第一次启动这一机器
# translation:  On September 10th last year, we launched the machine for the first time.
# Row:  101 , translating:  这是一张ATLAS照下的照片
# translation:  This is a picture taken by ATLAS.
# Row:  102 , translating:  当时控制室里欢呼雀跃
# translation:  In the control room there was a rejoicing jump.
# Row:  106 , translating:  这表明我们的工作造成了文化冲击 这与它的科研冲击同样意义重大
# translation:  This shows that our work has caused a cultural shock, which is just as significant as its scientific impact.
# Row:  108 , translating:  这些导线传导1万3千安培电流 当机器全部启动
# translation:  These wires conduct 13,000 amphibious currents when all the machines are started.
# Row:  109 , translating:  现在你们之中的一些工程师可能会说 “不可能，这些电线太细了”
# translation:  Now some of your engineers might say, "It's impossible, these wires are too thin."
# Row:  110 , translating:  它们能做到 因为当温度极低它们就成了超导导线
# translation:  They can do this because when the temperature is extremely low they become superconductive wires.
# Row:  112 , translating:  在LHC中九千多个电磁铁里的一个接点上 有一个安装技术失误
# translation:  At one of the more than 9000 connectors in the LHC, there is a technical installation error.
# Row:  114 , translating:  这就是结果
# translation:  这就是结果。
# Row:  115 , translating:  非常令人震惊 因为那些磁铁重达20吨 它们移动了大约一英尺
# translation:  Extremely shocking because the magnets weighed up to 20 tons, they moved about a foot.
# Row:  116 , translating:  一共大概有50个磁铁受损
# translation:  A total of 50 magnets were damaged.
# Row:  117 , translating:  必须得把它们卸下来，这些工作已经完成
# translation:  They have to be removed, the work has been completed.
# Row:  118 , translating:  我们给它们排除故障，修理好
# translation:  Fixing them, fixing them.
# Row:  119 , translating:  现在就等着它们重新回到地下了
# translation:  Now wait for them to come back underground.
# Row:  120 , translating:  在三月底左右LHC被重新接通
# translation:  LHC was re-connected around the end of March.
# Row:  125 , translating:  谢谢
# translation:  谢谢
# Row:  126 , translating:  首先，我想请大家回忆一下你们在孩提时代 玩过的积木。
# translation:  首先, I would like to remind you of the building blocks that you used to play in your childhood.
# Row:  128 , translating:  理解物体的空间结构非常有助于 我们对很多周围事物的学习。
# translation:  Knowing the spatial structure of an object helps us learn about a lot of things around it.
# Row:  130 , translating:  按我们的思路来组合信息--那样会如何呢？
# translation:  Combining information according to our thinking-- what would happen?
# Row:  132 , translating:  简单地说，Siftable是一款互动计算机， 体积如饼干般大小。
# translation:  Simple to say, the Siftable is an interactive computer that's as big as a biscuit.
# Row:  134 , translating:  最重要的是，每块Siftable都是独立的， 就像积木一样，可以随意搭配。
# translation:  The most important thing is that each Siftable is independent, like a building block, which can be matched at will.
# Row:  135 , translating:  而且Siftables代表了一种新的生态系统 --即数字化信息的操作工具。
# translation:  Siftables represent a new ecosystem-- the operational tool for digitalizing information.
# Row:  137 , translating:  现在，我就来演示一些简单的。
# translation:  现在, let me show you some simple things.
# Row:  139 , translating:  而且这些Siftables能互相感知。
# translation:  These siftables can sense each other.
# Row:  140 , translating:  如果把它们一个挨一个摆好，有趣的现象就会发生。
# translation:  If you put them one by one, an interesting phenomenon will occur.
# Row:  141 , translating:  如果把它们随意一堆，他们也会察觉到， 那就会有点儿混乱。
# translation:  If you put them all together, they'll notice a bit of confusion.
# Row:  142 , translating:  它们还能感知彼此的移动和倾斜。
# translation:  They can also sense each other's movement and tilt.
# Row:  145 , translating:  如果倒多了，可以再倒回去一些。
# translation:  If it's more, you can revert some.
# Row:  148 , translating:  Siftables还可以玩拼字游戏--一种Scrabble和Boggle混搭的拼字游戏。
# translation:  Siftables can also play a spelling game-- a type of ccrabble and boggle that mixes.
# Row:  151 , translating:  谢谢大家。
# translation:  谢谢大家。
# Row:  153 , translating:  孩子们非常喜欢Siftables。
# translation:  The kids loved the siftables.
# Row:  154 , translating:  而且有趣的是在玩这个拼字游戏的时候 我们并不需要向他们解释什么。
# translation:  有趣的 is that we don't need to explain anything to them when playing the spelling game.
# Row:  155 , translating:  只要跟他们说这是个“拼字”游戏时， 他们就知道该怎么做了。
# translation:  只要告诉 them it's a spelling game, they know what to do.
# Row:  156 , translating:  现在屏幕上显示的是另一些人在体验Siftables。
# translation:  Now the screen shows someone else experiencing Siftables.
# Row:  157 , translating:  右下角这位是年龄最小的体验者。
# translation:  In the lower right corner is the youngest person to experience it.
# Row:  158 , translating:  他只是想把Siftables堆在一起。
# translation:  He just wanted to stack the siftables together.
# Row:  159 , translating:  在他看来，Siftables只是积木。
# translation:  In his view, the siftables are just building blocks.
# Row:  160 , translating:  现在屏幕上显示的是一种动画功能的互动尝试。
# translation:  The screen now shows an interactive attempt to animate.
# Row:  161 , translating:  我们希望Siftables能成为学习语言的帮手。
# translation:  We want Siftables to be a language assistant.
# Row:  162 , translating:  画面上的这个孩子叫Felix。
# translation:  The child in the picture is Felix.
# Row:  164 , translating:  看，他把太阳加上去了。
# translation:  He added the sun.
# Row:  165 , translating:  视频：太阳升起来了。
# translation:  Video: The sun rises.
# Row:  166 , translating:  大卫·梅若：现在他把拖拉机加上去了。
# translation:  David Mayo: He added the tractor.
# Row:  167 , translating:  视频：橙色的拖拉机。
# translation:  Video: The orange tractor.
# Row:  168 , translating:  做的不错！
# translation:  OK!
# Row:  170 , translating:  梅若：他在编写属于他的动画故事。
# translation:  Mayo: He's writing his animated story.
# Row:  171 , translating:  视频：你好！
# translation:  Video: Hello!
# Row:  172 , translating:  梅若：这是个开放式结局的故事， 他在计划怎样展开故事情节。.
# translation:  Mayo: This is an open-ended story about how he plans to start the story.
# Row:  173 , translating:  视频：猫坐着热气球飞走了。
# translation:  Video: The cat was seated in a hot air balloon.
# Row:  175 , translating:  每个模块有四档可供调节， 任君选择。
# translation:  Each module has four patches to adjust for.
# Row:  177 , translating:  还有类似混响器、滤声器作用的Siftable模块。
# translation:  There are also Siftable modules that act like a mixer or filter.
# Row:  178 , translating:  把这类模块靠近声音模块就可以调整声音了。
# translation:  Putting these modules close to the sound module can adjust the sound.
# Row:  179 , translating:  接下来，可以用控制总体节奏和音量的Siftable模块
# translation:  Next, you can control the overall rhythm and volume of the Siftable module.
# Row:  180 , translating:  靠近编辑模块的Siftable来调整节奏和音量。 我们来看一下。
# translation:  Siftable near the editing module to adjust the rhythm and volume. Let's look at it.
# Row:  182 , translating:  现在加入贝斯音。
# translation:  Now join the bass.
# Row:  183 , translating:  视频： 梅若：现在加入一些打击乐器的声音。
# translation:  Video: Mayo: Now add some punching instruments.
# Row:  184 , translating:  视频： 梅若：现在把滤声模块靠近鼓声模块，这样可以调整声音。
# translation:  Video: Mayo: Put the filter module close to the drum module, so you can adjust the sound.
# Row:  185 , translating:  视频： 梅若：我来把节奏加快些 只需把节奏模块靠近编辑模块。
# translation:  Video: Mayo: I'm going to speed it up a little bit. Just put the rhythm module near the edit module.
# Row:  186 , translating:  视频： 梅若：现在再把滤声模块靠近贝斯模块滤声。
# translation:  Video: Mayo: Now bring the filter module closer to the Bass module.
# Row:  187 , translating:  视频： 梅若：在音乐演奏的过程中还可以重新编排。
# translation:  Video: Mayo: It can also be reorganized during the musical process.
# Row:  189 , translating:  最后，我来结束整个演奏， 用音量模块靠近编辑模块，用左边这个档。
# translation:  Finally, I'm going to end the whole play with a volume module near the editing module, using this file on the left.
# Row:  190 , translating:  谢谢大家。
# translation:  谢谢大家。
# Row:  194 , translating:  非常感谢大家。
# translation:  非常感谢大家。
# Row:  195 , translating:  我期待着和大家共同探讨。
# translation:  I look forward to discussing it with you.
# Row:  196 , translating:  我是个作家，写作不仅仅是我的职业，更是我一辈子的挚爱与迷恋
# translation:  I am a writer, not only my profession, but also the love and fascination of my life.
# Row:  197 , translating:  我是个作家，写作不仅仅是我的职业，更是我一辈子的挚爱与迷恋
# translation:  I am a writer, not only my profession, but also the love and fascination of my life.
# Row:  198 , translating:  我是个作家，写作不仅仅是我的职业，更是我一辈子的挚爱与迷恋
# translation:  I am a writer, not only my profession, but also the love and fascination of my life.
# Row:  199 , translating:  我认为这是永远不会改变的事情
# translation:  我认为, this is something that will never change.
# Row:  203 , translating:  真的，就这样了，彻底地，没救了，玩完了！
# translation:  真的, that's it, totally unsaved, overplayed!
# Row:  206 , translating:  他们可真是会安慰人呀
# translation:  They can really comfort people.
# Row:  208 , translating:  我当时遭遇到了同样的质疑，人们说：你不怕永远都不会成功吗？
# translation:  I was faced with the same question, and people said: "Are you not afraid of never succeeding?"
# Row:  211 , translating:  对于这些质疑，最简单的回答是：“怕”
# translation:  The simplest answer to these questions is 'fear'.
# Row:  212 , translating:  是的，这种种一切都让人害怕，直到今天也一样
# translation:  是的, everything is frightening to this day as well.
# Row:  213 , translating:  是的，这种种一切都让人害怕，直到今天也一样
# translation:  是的, everything is frightening to this day as well.
# Row:  216 , translating:  这难道是一种理性的想法吗？
# translation:  这是一个理性的想法吗?
# Row:  220 , translating:  没人说：“约翰，化学工作遇到瓶颈了吗？怎么样了？”
# translation:  Nobody said, "John, you've got a bottleneck?"
# Row:  221 , translating:  从来不曾发生过这种问话
# translation:  No such questioning has ever happened.
# Row:  226 , translating:  对于你毕生的作品，这是多么激进的说法啊
# translation:  对于 your life's work, this is a radical statement.
# Row:  229 , translating:  你们都觉得这一观点毫无问题吗?
# translation:  大家觉得这个观点没问题吗?
# Row:  231 , translating:  这个观点不但可憎，而且可怕，我不希望这样的想法一直延续到下个世纪
# translation:  This view is not only disgusting, but also horrifying, I don't want this idea to continue until the next century.
# Row:  233 , translating:  我觉得鼓励我们伟大的创作天才们继续活下去会更加好
# translation:  I think it would be better to encourage our great creative geniuses to continue living.
# Row:  236 , translating:  我今后还有大约四十年的创作生涯
# translation:  I still have about 40 years of creative career to go through.
# Row:  239 , translating:  天啊，这是何种的想法！
# translation:  天哪,这是什么主意!
# Row:  241 , translating:  我可不想变成那样 我希望继续从事我所热爱的写作事业，所以问题就变成：我应该怎么办呢？
# translation:  I don't want to be that way, so the question becomes: What should I do?
# Row:  242 , translating:  我希望继续从事我所热爱的写作事业，所以问题就变成：我应该怎么办呢？
# translation:  我想继续 my love of writing, so the question becomes: What should I do?
# Row:  246 , translating:  这一寻找最后把我带到了古希腊和古罗马
# translation:  This search finally took me to ancient Greece and Rome.
# Row:  247 , translating:  所以请耐心听我讲，因为最后会绕回到我们的问题
# translation:  So please listen to me, because at the end of the day it will come back to our problem.
# Row:  250 , translating:  希腊人普遍地称这种伴随着创造力的守护精灵为“守护神”
# translation:  The Greeks generally refer to this as the "guardian" of creativity.
# Row:  256 , translating:  我们都可以理解它的运作模式，不是吗？
# translation:  我们可以理解它的运作模式,不是吗?
# Row:  259 , translating:  如果你的作品很烂，同样也不全是你的错
# translation:  If your work is bad, it's not all your fault either.
# Row:  263 , translating:  而我要说的是，我认为那是一个巨大的错误
# translation:  我要说的是,我认为那是个大错误。
# Row:  265 , translating:  无异于要求他吞下太阳，这对于脆弱的个体而言，是太大的责任
# translation:  It's no different than asking him to swallow the sun, which is too much of a responsibility for vulnerable individuals.
# Row:  268 , translating:  如果真是这样 至少我认为是这样的 那么我们的问题就是：现在该怎么办？我们能够改变这种状况吗？
# translation:  如果这是真的,那么我们的问题是: 我们可以改变这种状况吗?
# Row:  269 , translating:  那么我们的问题就是：现在该怎么办？我们能够改变这种状况吗？
# translation:  那么我们的问题是:我们能不能改变这种状况?
# Row:  271 , translating:  也许不行
# translation:  Maybe not.
# Row:  274 , translating:  也许，我无法说服你们大家都同意我的看法
# translation:  也许我不能说服你们都同意我的观点。
# Row:  276 , translating:  但我想说的是：为何不呢？为什么不换个角度思考呢？
# translation:  我想说的是:为什么不换个角度?
# Row:  279 , translating:  实际上，创作过程有时简直就是超乎常理
# translation:  In fact, the process of creation is sometimes just beyond common sense.
# Row:  281 , translating:  像一股雷鸣般的气息，朝她倾泻而下
# translation:  It was like a thunderstorm, pouring down at her.
# Row:  282 , translating:  她可以感受到它的来临，因为这股力量会撼动她脚下的大地
# translation:  She could feel it coming, because that force would shake the ground beneath her feet.
# Row:  283 , translating:  她可以感受到它的来临，因为这股力量会撼动她脚下的大地
# translation:  She could feel it coming, because that force would shake the ground beneath her feet.
# Row:  294 , translating:  在坐很多人或许也有类似经历
# translation:  Many people may have similar experiences sitting there.
# Row:  296 , translating:  这到底是怎么回事呢？
# translation:  到底是怎么回事?
# Row:  302 , translating:  他急切地想要捕捉它，但是没有办法，他既没有纸笔，也没有录音机
# translation:  He desperately wanted to capture it, but he didn't have a pen or a recorder.
# Row:  305 , translating:  突然，他奇异般地停止了继续抓狂和焦躁情绪，然后做了一件不寻常的事情
# translation:  Suddenly, he stopped obsessive and anxious, and then did something unusual.
# Row:  306 , translating:  突然，他奇异般地停止了继续抓狂和焦躁情绪，然后做了一件不寻常的事情
# translation:  Suddenly, he stopped obsessive and anxious, and then did something unusual.
# Row:  308 , translating:  我看上去像是能立马记下一首曲子的样子吗？
# translation:  Do I look like I can remember the next song?
# Row:  310 , translating:  或者，你可以今天去骚扰别人，去找莱昂纳德·科恩去
# translation:  Or you can harass someone today, go to Leonard Cohen.
# Row:  311 , translating:  或者，你可以今天去骚扰别人，去找莱昂纳德·科恩去
# translation:  Or you can harass someone today, go to Leonard Cohen.
# Row:  312 , translating:  自从那件事以后，汤姆的整个创作过程改变了
# translation:  Since then, Tom's entire creative process has changed.
# Row:  313 , translating:  不是作品变了，他的作品仍是一如既往的黑暗
# translation:  His work hasn't changed, his work is still as dark as ever.
# Row:  318 , translating:  不仅是烂，而且是彻底的糟糕透顶，我开始觉得我应该放弃写这本书
# translation:  Not only was it bad, but I started to feel like I should give up writing this book.
# Row:  319 , translating:  这时我想起了汤姆对着天空喊话的事情，然后我试了试
# translation:  Then I thought about Tom shouting at the sky, and then I tried to do it.
# Row:  320 , translating:  这时我想起了汤姆对着天空喊话的事情，然后我试了试
# translation:  Then I thought about Tom shouting at the sky, and then I tried to do it.
# Row:  324 , translating:  “你若是想要这本书更好一些，现在轮到你出面，做你那部分工作了”
# translation:  "If you want a better book, it's your turn to come forward and do that part of your job."
# Row:  325 , translating:  “你要是不来帮忙，那就见你的鬼去吧”
# translation:  "If you don't want to help, go see your goddamn."
# Row:  333 , translating:  刹那间，他不再是个普通的凡人，他的生命从内部点燃，从心底发光
# translation:  At that moment he was no longer an ordinary human being, his life ignited from within, and lighted from the bottom of his heart.
# Row:  337 , translating:  人人都知道：那是神迹显现
# translation:  每个人都知道: it's a miracle that manifests itself.
# Row:  340 , translating:  这种方式很好，因为这正是我们需要的
# translation:  That's a good way to do it, because that's exactly what we need.
# Row:  344 , translating:  这是个很棘手的问题，也是创作生涯中最痛苦的自我认知之一
# translation:  It's a tricky problem, and one of the most painful self-cognitions in your creative career.
# Row:  348 , translating:  如果我们这样看待这一问题，一切就都改变了
# translation:  If we look at it this way, everything will change.
# Row:  351 , translating:  “不要害怕，不要气馁，只需做好你的那部分工作”
# translation:  "Don't be afraid, don't be discouraged, just do your part."
# Row:  352 , translating:  坚守在你的岗位上，无论你的岗位是什么：如果你是舞者，那就跳舞
# translation:  Hold on to your position, whatever your position is: If you're a dancer, then dance.
# Row:  353 , translating:  坚守在你的岗位上，无论你的岗位是什么：如果你是舞者，那就跳舞
# translation:  Hold on to your position, whatever your position is: If you're a dancer, then dance.
# Row:  355 , translating:  如果没有，那就请继续跳舞，坚守你的岗位，我依然为你喝彩：欧嘞！
# translation:  如果没有, please continue to dance and hold on to your position. I still cheer for you: Oasis!
# Row:  356 , translating:  如果没有，那就请继续跳舞，坚守你的岗位，我依然为你喝彩：欧嘞！
# translation:  如果没有, please continue to dance and hold on to your position. I still cheer for you: Oasis!
# Row:  357 , translating:  我坚信我们必须传授这一理念
# translation:  我坚信 that we must teach this concept.
# Row:  359 , translating:  谢谢
# translation:  谢谢
# Row:  360 , translating:  谢谢 谢谢
# translation:  谢谢
# Row:  361 , translating:  谢谢 主持人：欧嘞！
# translation:  谢谢!
# Row:  364 , translating:  我们经常试图提出一些较大的问题。
# translation:  We often try to ask bigger questions.
# Row:  365 , translating:  “生命是什么”我想是许多生物学家 不断地尝试在 在不同层面去理解的问题。
# translation:  "What is life?" I think many biologists are constantly trying to understand the problem at different levels.
# Row:  366 , translating:  我们尝试了许多方法， 把它分解到最小的组成部分。
# translation:  We tried many ways to break it down into the smallest part.
# Row:  373 , translating:  于是我们开始沿着这条路走下去 “我们能人工合成染色体吗？”
# translation:  于是我们开始沿着这条路走, "Can we artificially synthesize chromosomes?"
# Row:  374 , translating:  化学原则真的允许我们制造 这些我们从未实现过的 超大分子吗？
# translation:  Chemical principles really allow us to make these super-large molecules that we have never realized?
# Row:  375 , translating:  而且，就算我们可以，我们能激活它吗？
# translation:  而且,即使我们能激活它?
# Row:  376 , translating:  一对染色体，顺便说下，只是一些无活性的化学物质。
# translation:  A pair of chromosomes, by the way, are just some non-active chemicals.
# Row:  377 , translating:  我们数字化生命的速度不断地 以指数速度加快。
# translation:  Our digital life is accelerating exponentially.
# Row:  379 , translating:  我们于15年前开始这项工作。
# translation:  We started this work 15 years ago.
# Row:  380 , translating:  实际上它经过了好几个阶段。 在我们做最初的试验前，先进行了一次生物伦理学的评估。
# translation:  It actually went through several stages. Before we did the initial experiment, a bioethics assessment was carried out.
# Row:  381 , translating:  但结果是人工合成DNA 是非常困难的。
# translation:  But the result is that synthetic DNA is very difficult.
# Row:  383 , translating:  所以我们不得不创造一种新的方法 把这些小的片断排放在一起并纠正所有的错误。
# translation:  So we had to create a new way of ejected these small pieces together and correcting all the errors.
# Row:  384 , translating:  这是我们的第一次尝试，从Phi X 174基因组 的数字信息开始。
# translation:  This is our first attempt, starting with the digital information of the Phi X174 genome.
# Row:  385 , translating:  是一种能杀死细菌的小型病毒。
# translation:  A small virus that kills bacteria.
# Row:  388 , translating:  接着细胞释放出病毒粒子， 再返回来杀死了E.coli。
# translation:  The cell then releases the virus particles and returns to kill E. coli.
# Row:  389 , translating:  我最近与石油行业有一些交流， 我觉得他们对这个模式理解的非常透彻。
# translation:  I've had some conversations with the oil industry recently, and I think they understand this pattern very well.
# Row:  392 , translating:  设计是非常重要的， 并且如果你在计算机上开始使用数字信息。 那这些数字信息必须十分准确。
# translation:  设计 is very important, and if you start using digital information on a computer. These digital information must be accurate.
# Row:  396 , translating:  其中有我们设计过的独特部分。
# translation:  These are the unique parts that we designed.
# Row:  397 , translating:  你们可能听说过我们在其中加入了水印
# translation:  You may have heard that we added watermarks to it.
# Row:  398 , translating:  想想看 基因编码有四个字符：A,C,G和T。
# translation:  Think of the four characters that encode genes: A, C, G and T.
# Row:  400 , translating:  所以我们能使用基因编码来书写言语 句子，想法。
# translation:  所以我们可以用 genetic code to write sentences, ideas.
# Row:  401 , translating:  最初，我们所做的就是用它来签名。
# translation:  最初,我们用它来签名。
# Row:  402 , translating:  有些人有点失望我们没用它来做首诗。
# translation:  Some people are disappointed that we didn't use it to make a poem.
# Row:  406 , translating:  我们试着达到自动化的层面
# translation:  We try to reach the level of automation.
# Row:  407 , translating:  这看起来就像是一场篮球赛的对阵图
# translation:  It looks like a basketball match.
# Row:  409 , translating:  我们知道有个方法叫同源重组， 生物学上用来修复DNA， 它能把片断组合到一起
# translation:  We know that there is a method called co-source reorganisation, biologically used to repair DNA, it can combine fragments together.
# Row:  411 , translating:  你能看到在顶部的视图里，它的染色体四散在各个地方
# translation:  You can see in the top view, its chromosomes are scattered everywhere.
# Row:  412 , translating:  12到24小时以后，它将自己 又组合回之前的原状。
# translation:  12 to 24 hours later, it recombines itself back to its original form.
# Row:  413 , translating:  我们有数千种微生物有这种能耐
# translation:  数以千计的微生物 have this resilience.
# Row:  414 , translating:  这些微生物能够完全脱离水。 他们能存活在真空中
# translation:  These microbes are completely free from water. They can survive in a vacuum.
# Row:  415 , translating:  我完全确信外层空间存在着生命， 四处移动，遇到一个新的有水的环境
# translation:  I am fully convinced that there is life in outer space, moving around and encountering a new watery environment.
# Row:  416 , translating:  实际上，NASA已经展示过很多这样的例子。
# translation:  NASA has shown many such examples.
# Row:  418 , translating:  这并不是电子显微图像； 它仅仅是普通的光学显微镜。
# translation:  It's not an electronic micro-image; it's just a simple optical microscope.
# Row:  419 , translating:  这是如此之大的一个分子 我们能用一个光学显微镜观察它。
# translation:  这个分子 is so large that we can observe it with an optical microscope.
# Row:  420 , translating:  这些是时长约为六秒的图像。
# translation:  These are about six seconds long images.
# Row:  421 , translating:  这是我们所公开的最近的试验成果。
# translation:  These are the results of a recent trial that we have made public.
# Row:  423 , translating:  它超过了3亿分子重量。
# translation:  It weighs more than 300 million molecules.
# Row:  425 , translating:  那我们该如何来启动一段染色体，我们该如何激活它?
# translation:  那么,我们如何激活 a chromosome?
# Row:  426 , translating:  显然处理一个病毒非常简单 处理一个细菌就复杂多了
# translation:  Clearly, dealing with a virus is very simple. Dealing with a bacterium is much more complicated.
# Row:  430 , translating:  新的染色体进入细胞。
# translation:  新 chromosomes enter the cell.
# Row:  431 , translating:  实际上我们原以为这个过程就到此为止了。 但是我们试图将这个过程设计得更深入一些。
# translation:  实际上,我们以为这个过程已经结束。但我们试着把它设计得更深入一些。
# Row:  432 , translating:  这是一个重大的进化机制。
# translation:  This is a major evolutionary mechanism.
# Row:  434 , translating:  原本人们所持有的在进化的过程中 每次只会有一个基因发生变化 的观念忽略了生物的许多实际情况。
# translation:  The idea that only one gene can change in the course of evolution ignores many real-life situations.
# Row:  435 , translating:  有一种酶叫做限制酶 是能够消化DNA的
# translation:  There is an enzyme called a limitase that can digest DNA.
# Row:  436 , translating:  原先细胞中的染色体没有这种酶 没有这种酶 而当我们置入一段拥有这种酶的染色体
# translation:  The chromosomes in the original cells didn't have this enzyme, and when we put them into a section that had it, they weren't.
# Row:  438 , translating:  我们放入的基因导致它变成了蓝色。
# translation:  The genes we put in it turned blue.
# Row:  442 , translating:  现在，我要声明这不是创世纪 -- 这是建立在35亿年的进化上的
# translation:  Now, I would like to declare that this is not the Genesis century--it was built on three and a half billion years of evolution.
# Row:  444 , translating:  的新物种 为什么要这样做？
# translation:  为什么新物种会这样呢?
# Row:  445 , translating:  我认为出于一些需求我们这样做的原因是非常明显的。
# translation:  I think some of the reasons why we do this are very obvious.
# Row:  446 , translating:  我们的人口将在接下来的40年中从 65亿变成90亿
# translation:  未来40年,我们的人口将从6500万增长到900亿。
# Row:  447 , translating:  以我自己的例子来说 我出生于1946年
# translation:  For my own example, I was born in 1946.
# Row:  449 , translating:  我们在为65亿人提供食物，洁净的淡水， 医药，燃料上 都十分困难。
# translation:  We provide food, clean fresh water, medicine and fuel to 6500 million people.
# Row:  450 , translating:  换作90亿人那真是捉襟见肘了。
# translation:  换言之,900亿人 really do have elbows.
# Row:  452 , translating:  当我们尝试思考这个生物程序 或者任何能替代它的程序， 这会是一个巨大的挑战。
# translation:  当我们尝试 to think about this biological program, or anything that can replace it, would be a huge challenge.
# Row:  453 , translating:  接下来，当然，是这份材料 中所显示的被排放在大气层中 的二氧化碳。
# translation:  Next, of course, is the carbon dioxide emitted into the atmosphere.
# Row:  455 , translating:  电气行业只有十来种组件， 再看看从中能得到的多样性。
# translation:  There are only ten components in the electrical industry, look at the diversity that can be derived from it.
# Row:  456 , translating:  目前我们主要的限制来自于 生物学的现实情况 以及我们的想像力。
# translation:  Our main limitations come from the realities of biology and our imaginations.
# Row:  458 , translating:  我们现在所拥有的制造一个大型机器人的能力 能让我们每天制造一百万个染色体。
# translation:  我们现在拥有 the ability to make a large robot that allows us to make one million chromosomes every day.
# Row:  460 , translating:  并且这只是标准选择。 我们可以以生存能力来选择， 化学或燃料生产， 疫苗生产等等。
# translation:  And that's just a standard choice. We can choose from the ability to survive, chemical or fuel production, vaccine production, etc.
# Row:  462 , translating:  我们并不一定要知道它看起来是怎样。 我们确切地知道它们的基因编码究竟是什么样的。
# translation:  We don't necessarily know what it looks like.We know exactly what their genetic code is.
# Row:  463 , translating:  我们目前把注意力放在“第四代燃料”上。
# translation:  We are now focusing on the fourth generation of fuels.
# Row:  464 , translating:  你们最近看到了将谷物转化成乙醇 只是一个糟糕的试验。
# translation:  You've seen the transformation of grains into ethanol is just a bad trial.
# Row:  467 , translating:  并且我们认为在18个月里我们会取得 第一份第四代燃料。
# translation:  And we think in 18 months we'll get the first fourth-generation fuel.
# Row:  468 , translating:  阳光和二氧化碳是其中一个方法 --
# translation:  Sunshine and carbon dioxide are one way--
# Row:  469 , translating:  -- 但我们从全世界各地的发现中， 我们还有许多种其他方法。
# translation:  但我们从世界各地发现,我们还有很多其他方法。
# Row:  470 , translating:  这是一种微生物,1996年被记载
# translation:  This is a microbiome, recorded in 1996.
# Row:  471 , translating:  它生活在深海。 大约1.5英里深， 几乎是在沸腾的水温中。
# translation:  It lives in the deep sea. About 1.5 miles deep, almost at boiling water temperature.
# Row:  472 , translating:  它将二氧化碳转化成甲烷 使用氢分子最为它的能量来源。
# translation:  It converts carbon dioxide into methane using hydrogen molecules as its most important source of energy.
# Row:  476 , translating:  并且我们也在使用同样的工具 制造了几组即时疫苗。
# translation:  我们也 use the same tools to make several groups of instant vaccines.
# Row:  478 , translating:  我认为这情形是可以通过 预先制造混合疫苗来改变的。
# translation:  I think this can be changed by pre-creating a hybrid vaccine.
# Row:  487 , translating:  Seadragon同时也是一个非常灵活的架构。
# translation:  Seadragon is also a very flexible structure.
# Row:  488 , translating:  举个例子，这是一本完整的书，它的数据是非图像的。
# translation:  For example, this is a complete book, its data are non-images.
# Row:  489 , translating:  这是狄更斯所著的《荒凉山庄》，一列就是一章的内容。
# translation:  Dickens's "Desolate Mountains" is a chapter.
# Row:  491 , translating:  也许这会是一种阅读电子书的方式，
# translation:  Maybe it's a way to read e-books,
# Row:  492 , translating:  但是我可不推荐这么做。
# translation:  But I wouldn't recommend it.
# Row:  493 , translating:  接下来是一个更加实际的例子，这是一期《卫报》。
# translation:  The following is a more practical example, the Guardian.
# Row:  494 , translating:  每一张大图片是一版开篇，
# translation:  Each big picture is the opening page,
# Row:  496 , translating:  我们在这里做了小小的改动 在这一期《卫报》得角上。
# translation:  We made a small change in this issue of the Guardian.
# Row:  498 , translating:  如果你希望看到这辆车的特性，你可以看这里。
# translation:  如果你想要 to see the characteristics of this car, you can look here.
# Row:  499 , translating:  你还能看到其他的型号，甚至技术规格。
# translation:  You can also see other models, even technical specifications.
# Row:  500 , translating:  这种方式在一定程度上 避免了屏幕实际使用面积的限制。
# translation:  To a certain extent, this approach avoids the limitations of the screen's actual use area.
# Row:  501 , translating:  我们希望这个技术能够减少不必要的弹出窗口 以及类似的垃圾信息。
# translation:  We want this technology to reduce unnecessary pop-up windows and similar trash information.
# Row:  502 , translating:  显然，对于这项技术的应用， 数字地图也是显而易见的应用之一。
# translation:  Clearly, digital maps are one of the obvious applications for this technology.
# Row:  504 , translating:  这些只是在NASA的地理空间图片基础上
# translation:  These are based on NASA's geospatial images.
# Row:  505 , translating:  进行叠加处理而得到的美国的道路地图。
# translation:  A map of the U.S. road map is obtained by superimposed processing.
# Row:  506 , translating:  现在，我们先放下这些，看看其他的。
# translation:  让我们先放下这些,看看其他的。
# Row:  507 , translating:  实际上，这项技术已经放到网上了，大家可以自己去体验一下。
# translation:  实际上, this technology has been put on the Internet, so everyone can experience it for themselves.
# Row:  508 , translating:  这个项目叫Photosynth，
# translation:  This project is called Photosynth.
# Row:  510 , translating:  这项研究还得到了华盛顿大学Steve Seitz
# translation:  The study was also conducted by Steve Seitz of the University of Washington.
# Row:  511 , translating:  和微软研究院Rick Szeliski的协助。这是一个非常漂亮的合作成果。
# translation:  Assisted by Microsoft Research Institute Rick Szeliski. This is a very beautiful collaboration.
# Row:  512 , translating:  这个项目在互联网上已经得到应用了，它是基于Seadragon技术构建的。
# translation:  The project has already been implemented on the Internet, and it is based on Seadragon technology.
# Row:  514 , translating:  不过，这些图片在三维空间的排列事实上是非常有意义的。
# translation:  However, the arrangement of these images in three-dimensional space is actually very meaningful.
# Row:  516 , translating:  因此你可以看到这里的元素是稳定的幻灯放映或者全景成像， 而这些内容在空间上都是关联的。
# translation:  So you can see that the elements here are stable slide projections or panoramic imaging, and these contents are spatially related.
# Row:  517 , translating:  我不确定我们是否有时间来展示更多的环境全景。
# translation:  I'm not sure if we have time to show more panorama of the environment.
# Row:  518 , translating:  有很多例子比这个的空间感还要强。
# translation:  There are many more examples than this sense of space.
# Row:  520 , translating:  主要因为我们制作网站时，要顾及到很多法律问题。
# translation:  Primarily because we make websites, we have to take into account a lot of legal issues.
# Row:  521 , translating:  这里是利用Flickr网站上 的图像重建的巴黎圣母院。
# translation:  Here's an image of the Notre Dame on Flickr.
# Row:  523 , translating:  所有这些橘黄颜色的锥形都代表了一张 用来建立模型的图片。
# translation:  All these orange-colored cone shapes represent a picture used to build models.
# Row:  524 , translating:  这些全部是来自Flickr的图片， 被这样在空间里被串联起来。
# translation:  These are all images from Flickr, so they're chained up in space.
# Row:  525 , translating:  接着，我们便可如此自如的进行浏览。
# translation:  这样我们就可以自由地浏览了。
# Row:  526 , translating:  （鼓掌） 说实话，我从来没想过我会最后来为微软工作
# translation:  (Applause) To be honest, I never thought that I would end up working for Microsoft.
# Row:  527 , translating:  受到这样欢迎，真挺令人高兴的。
# translation:  It's a pleasure to be so welcome.
# Row:  530 , translating:  我记得这儿应该有 一个系列的照片 - 啊，在这儿。
# translation:  I remember there should have been a series of photos-- 啊, here.
# Row:  531 , translating:  这个是巴黎圣母院的海报。
# translation:  This is a poster of Notre Dame Paris.
# Row:  532 , translating:  我们可以钻到海报里 去看整个重建的环境。
# translation:  我们可以钻到海报里去看看整个重建的环境。
# Row:  533 , translating:  这里的重点呢便是我们可以 有效地利用网络社区。我们可以从每个人那里得到数据
# translation:  重点是我们能有效地利用网络社区。我们可以从每个人那里获取数据。
# Row:  535 , translating:  当所有这些图片交织在一起时， 所衍生出的 要远远超过单单收集起全部。
# translation:  When all these pictures are intertwined, the result is much more than a single collection.
# Row:  536 , translating:  这个模型所衍生出的，是整个地球。
# translation:  This model is derived from the entire Earth.
# Row:  537 , translating:  这如同是Stephen Lawler的《虚拟地球》的长尾市场。
# translation:  It's like Stephen Lawler's "Virtual Earth" long tail market.
# Row:  538 , translating:  这类模型，会随着人们的 使用而不断变的复杂， 变得更加有价值。
# translation:  These models, as people use them, become more complex and valuable.
# Row:  539 , translating:  用户的照片，会被大家 注上标签。
# translation:  The user's photos will be labeled.
# Row:  542 , translating:  非常感谢！
# translation:  非常感谢!
# Row:  545 , translating:  完全是基于图片的内容。
# translation:  完全 based on the content of the picture.
# Row:  546 , translating:  更令人兴奋的 在于图片所包含的大量文字语义信息。
# translation:  What's more exciting is the amount of semantic information contained in the pictures.
# Row:  548 , translating:  现在，假设这些图片全都与你的图片相连，那将会怎样？
# translation:  假设 all of these pictures are connected to yours, what would happen?
# Row:  549 , translating:  那时，所以这些语义信息的相互链接 以及内容量将是
# translation:  At that time, the interlinkages of these semantic messages and the amount of content will be.
# Row:  550 , translating:  巨大的。这将是非常典型的网络效应。
# translation:  Huge. This would be a very typical network effect.
# Row:  551 , translating:  CA:Blaise，太难以置信了。祝贺你们！ BAA:非常感谢各位！
# translation:  CA: That's unbelievable.BAA: Thank you very much!
# Row:  554 , translating:  只是一种适应性选择的结果 我们的祖先在很多世代以前就成功地做出了这种选择
# translation:  It's just an adaptive choice that our ancestors made many generations ago.
# Row:  555 , translating:  当然 我们所有都遵守同一种适应性规则
# translation:  Of course, we all follow the same rules of adaptability.
# Row:  556 , translating:  我们都出生于母腹 并且在这个世上生儿育女
# translation:  We are all born in the womb, and we have children in this world.
# Row:  557 , translating:  我们要经历成年礼的洗礼
# translation:  We have to go through adult baptism.
# Row:  559 , translating:  但是 你会发现 每种文化的歌曲韵律 和舞蹈节奏有着独一无二的特色
# translation:  但是, you will find that each culture's rhythm of song and dance has its own unique characteristics.
# Row:  561 , translating:  珠穆朗玛峰的山坡上
# translation:  Mount Everest on the slopes.
# Row:  563 , translating:  如果你认真思考 你发会现 这种不同的思维会让你看到希望
# translation:  If you think seriously, this different mindset will give you hope.
# Row:  566 , translating:  这个种族圈是人类的伟大遗产
# translation:  This racial circle is the great legacy of humanity.
# Row:  567 , translating:  它是我们的身份标志 也是我们作为具有很强的探究能力的物种的标志
# translation:  It is also a mark of our identity as a species with strong exploratory capabilities.
# Row:  570 , translating:  这其中的一个最重要的标志 就是语言的
# translation:  One of the most important signs is language.
# Row:  571 , translating:  在我们生活的这个星球上 原本有 6:00 种语言
# translation:  6:00的语言存在于我们生活的这个星球上。
# Row:  572 , translating:  语言不仅仅是发音 和语法规则
# translation:  Languages are not just about pronunciation and grammar rules.
# Row:  573 , translating:  语言是人类精神的闪光
# translation:  语言 is the flash of human spirit.
# Row:  574 , translating:  它是各个独特文化的精神实质 在这个物质世界上的承载体
# translation:  It is the spiritual substance of every unique culture in this material world.
# Row:  575 , translating:  每一种语言都是一种思想 一种意识和一种精神生态系统的长期沉淀和积累
# translation:  Every language is an idea, a consciousness and a mental ecosystem of long-term precipitation and accumulation.
# Row:  577 , translating:  这些语言已经没有传人 也就是说 除非采取有效的措施 它们将会彻底消失
# translation:  These languages are no longer permeable, i.e. unless effective measures are taken, they will disappear completely.
# Row:  581 , translating:  或者是科基语
# translation:  Or the coki language.
# Row:  582 , translating:  你就会发现 你不会说自己的母语了
# translation:  你会发现你不会说你的母语。
# Row:  588 , translating:  他们只要会听 就会说一种语言了
# translation:  只要他们能听,他们就能说出一门语言。
# Row:  590 , translating:  1957 年 五名传教士试图接近他们 但是这些人犯了一个致命的错误
# translation:  1957 Five missionaries tried to approach them, but they made a fatal mistake.
# Row:  593 , translating:  更恐怖的是 华拉尼不仅戮死外来人士
# translation:  What's more terrifying is that Wallani doesn't just kill outsiders.
# Row:  594 , translating:  他们还自相残杀
# translation:  They also kill each other.
# Row:  595 , translating:  54% 的死亡人口是被他们自己的族人戮死的
# translation:  54% of the dead were killed by their own people.
# Row:  600 , translating:  相反 这是一种复杂的形而上学的世界观
# translation:  Conversely, this is a complex metaphysical worldview.
# Row:  601 , translating:  这很有意思
# translation:  That's interesting.
# Row:  602 , translating:  如果我要你列举出世界上一些重要的宗教 你会举出哪些例子
# translation:  IF YOU want to list some of the world's most important religions, what examples would you give?
# Row:  603 , translating:  基督教 伊斯兰教 佛教 还有其他一些宗教
# translation:  基督教 Islam Buddhism There are other religions.
# Row:  606 , translating:  生者孕育了灵魂
# translation:  The living ones give birth to the soul.
# Row:  608 , translating:  因此 巫毒教徒喜欢说 你们去教堂做礼拜 言必称上帝
# translation:  So the witchlikes like to say that you go to church for worship, it is necessary to call God.
# Row:  609 , translating:  我们在圣殿起舞 成为神
# translation:  We danced in the temple to become God.
# Row:  610 , translating:  你已经被神灵附体 怎么还会受到伤害呢
# translation:  那么, how can you be harmed if you've been god-associated?
# Row:  614 , translating:  在这个血腥肆虐的大陆 这个种族从来没有被西班牙人征服过
# translation:  This bloody continent has never been conquered by the Spaniards.
# Row:  615 , translating:  至到今天 他们沿续着僧侣会统治制度 但是 他们的僧侣训诫非常的独特
# translation:  直到今天, they continue to rule the system of monks, but their teachings are very unique.
# Row:  619 , translating:  这里是多么的美丽 你要保护它
# translation:  多么美妙啊,你要保护它。
# Row:  621 , translating:  这种直觉的领会能力非常重要
# translation:  This intuitive comprehension is very important.
# Row:  623 , translating:  土著人并不会多愁善感 也不会承受思乡之苦
# translation:  土著人 don't have much sadness, they don't suffer from the pain of thinking about their country.
# Row:  625 , translating:  那么 这是什么意思呢
# translation:  那么,这是什么意思呢?
# Row:  627 , translating:  无论那座大山是神的住所 或者仅仅是一堆矿石 这都不重要
# translation:  Whether the mountain is God's dwelling place, or just a pile of minerals, it doesn't matter.
# Row:  628 , translating:  重要的是 这种象征意义 阐述了人与自然之间的关系
# translation:  Importantly, this symbolizes the relationship between man and nature.
# Row:  629 , translating:  我在英属哥伦比亚的丛林长大 受当地人思想的影响 我认为丛林是要被砍伐的
# translation:  I grew up in the jungles of British Columbia, influenced by local people's ideas. I think the jungle is to be cut down.
# Row:  632 , translating:  这张照片是我去年八月份在亚马逊西北地区拍摄的
# translation:  This photo was taken in the Amazon Northwest region last August.
# Row:  635 , translating:  混杂在一起
# translation:  Mixed together.
# Row:  640 , translating:  因为它们会被 人体器官中的一种名为单胺氧化酶的酶改变活性
# translation:  Because they can be altered by an enzyme in a human organ called monoamine oxidase.
# Row:  641 , translating:  要口服这些色胺物质 还有必须同时口服改变单胺氧化酶的活性的其他化学物质
# translation:  To do this, there are other chemicals that must simultaneously alter the activity of monoamine oxidase.
# Row:  644 , translating:  我们普通人会做各种各样的实验 不断地犯错误 结果却一无所获
# translation:  我们普通人 do a variety of experiments, and make mistakes all the time, but we don't get any results.
# Row:  645 , translating:  但是 如果你问印第安人 他们会说 植物会说话
# translation:  但是如果你问印第安人,他们会说植物会说话。
# Row:  646 , translating:  那是什么意思呢
# translation:  那是什么意思呢?
# Row:  648 , translating:  如果你问他们是如何给这些植物分门别类的 他们说 我想你对植物有一些研究
# translation:  If you ask them how to classify these plants, they say that you have some research on the plant.
# Row:  649 , translating:  你是不是对植物有一定的了解 我说 不是
# translation:  Do you know anything about plants? I don't think so.
# Row:  653 , translating:  所有的文化 一直受到新的生活方式 的强烈冲击
# translation:  All cultures have been strongly impacted by the new way of life.
# Row:  654 , translating:  这个问题并不在于技术本身
# translation:  The problem is not in the technology itself.
# Row:  659 , translating:  在那里 由于发现了金矿 人们蜂拥而至
# translation:  Because of the discovery of gold mines, people flocked there.
# Row:  664 , translating:  他立即被杀害了 他的叔叔和其他信徒
# translation:  He was immediately killed by his uncle and other believers.
# Row:  665 , translating:  一起逃亡到尼泊尔 他的母亲因为富农家庭成份
# translation:  His mother fled to Nepal because she was part of a wealthy farmer's family.
# Row:  667 , translating:  他的姐姐因为冒犯行为 而被送入学习班
# translation:  His sister was sent to the class for an offence.
# Row:  669 , translating:  西藏的痛楚让人难以承受 人类的救赎精神需要得到见证
# translation:  The pain in Tibet is unbearable, and the spirit of human redemption needs to be witnessed.
# Row:  674 , translating:  现代化的工业社会 只有将近三百年的历史
# translation:  现代化的工业社会 只有近300年的历史。
# Row:  680 , translating:  这位老人的祖父拒绝迁移
# translation:  The old man's grandfather refused to move.
# Row:  681 , translating:  他的家人担心他的安全 把他的所有武器和工具 都拿走了
# translation:  His family worried about his safety, taking all of his weapons and tools away.
# Row:  682 , translating:  你们都知道 因纽特人不怕冷 这是他们特天独厚的优势
# translation:  As you know, the Inuits are not afraid of cold. This is their unique advantage.
# Row:  683 , translating:  他们的雪橇的滑条最初是用 北美驯鹿皮包裹的冻鱼干做成的
# translation:  Their slippers were originally made of frozen fish wrapped in North American reindeer skin.
# Row:  690 , translating:  重新归还给因纽特人 我是我们的新家园 它的名字叫纽勒维特
# translation:  To the Inuit I am our new home. It's called Nyerwit.
# Row:  691 , translating:  这是一块独立的领土 他们控制那里所有的海洋资源
# translation:  It is an independent territory where they control all the marine resources.
# Row:  692 , translating:  这个例子很好地说明了 一个国家可以有所作为 想办法修复与它的人民之间的关系
# translation:  This example illustrates how a country can make a difference by trying to repair the relationship with its people.
# Row:  694 , translating:  因为那里是某个族类的家园
# translation:  Because it is the home of a certain ethnic group.
# Row:  698 , translating:  我们的电视频道在 156 个国家播放
# translation:  我们的电视频道在156个国家播放。
# Row:  699 , translating:  我们的杂志有上百万的读者
# translation:  Our magazine has millions of readers.
# Row:  701 , translating:  让所有种族的智慧 能够为全人类的福址做出贡献
# translation:  让所有种族的智慧 能够为整个人类做出贡献
# Row:  702 , translating:  谢谢
# translation:  谢谢
# Row:  704 , translating:  我想从一个公认的信条讲起。
# translation:  I want to start with an accepted creed.
# Row:  705 , translating:  什么样的公认的信条呢？
# translation:  What is the accepted creed?
# Row:  706 , translating:  就是整个西方工业社会所笃信不疑的 一个信条。
# translation:  That is the unquestionable precept of Western industrial society.
# Row:  708 , translating:  原因就是自由这东西在与本身就是美好的， 具有价值，为人们所必需。
# translation:  The reason is that freedom in itself is beautiful, valuable, and necessary.
# Row:  710 , translating:  使自由达到极大化的途径就是 最大限度的增加选择性。
# translation:  The way to maximise freedom is to maximize selectivity.
# Row:  713 , translating:  同样这个观念也深嵌于我们的日常生活之中。
# translation:  The same concept is embedded in our daily lives.
# Row:  714 , translating:  我来给你们举些例子看看当代社会的 进步发展让我们变得有可能做些什么事。
# translation:  Let me give you some examples of what the progressive development of modern society has made possible.
# Row:  715 , translating:  这是我家附近的一个超市。不算很大。
# translation:  This is a supermarket near my house. It's not very big.
# Row:  716 , translating:  我只想说说这里的色拉调料。
# translation:  I just want to talk about the coloring here.
# Row:  718 , translating:  你看，这就是超级市场的样子。
# translation:  看, that's what a supermarket looks like.
# Row:  721 , translating:  你没法不承认这可是不小的一堆选择吧。
# translation:  You can't deny that this is not a small set of choices.
# Row:  722 , translating:  换个行业，说说通讯。
# translation:  Change the industry, talk about communication.
# Row:  724 , translating:  你不用买，只需去租一架电话机回来。
# translation:  You don't have to buy, just rent a phone back.
# Row:  725 , translating:  通常情况是，那电话用到死都不会坏。
# translation:  通常情况下, the phone won't be bad to death.
# Row:  726 , translating:  那种日子早已一去不返了。
# translation:  Those days are long gone.
# Row:  727 , translating:  如今我们几乎有无穷无尽的电话品种， 尤其是手机。(显示漫画）
# translation:  Today we have almost endless phone varieties, especially mobile phones. (show comics)
# Row:  728 , translating:  这些都是未来的手机。
# translation:  These are the phones of the future.
# Row:  731 , translating:  这事的结果是， 人们跑到商店里问: 你们有没有一款不带这么多功能的?
# translation:  于是, people ran to the store and asked: "Are there any of these things that don't have so many functions?"
# Row:  732 , translating:  你想,回答会是什么？
# translation:  你们猜怎么回答?
# Row:  733 , translating:  回答是“没有”。
# translation:  The answer is no.
# Row:  734 , translating:  如今你已经不可能买到一款不干 那么多事的手机。
# translation:  现在 you can't buy a cell phone that doesn't do so much.
# Row:  735 , translating:  同样，在生活里的其它一些比购物更 对我们产生影响事情上， 这种选择的爆炸同样存在。
# translation:  Similarly, there are other things in life that affect us more than shopping, the explosion of choice is also present.
# Row:  738 , translating:  方案甲有如此这般疗效和风险。
# translation:  Programme A has such efficacy and risks.
# Row:  739 , translating:  方案乙有如此这般疗效和风险。 你想怎么治？
# translation:  Option B is so effective and risky. How do you treat it?
# Row:  740 , translating:  然后你说：“大夫，我该如何做？”
# translation:  Then you said, "Doctor, what should I do?"
# Row:  741 , translating:  医生又说一遍，甲有这些疗效和风险， 乙有那些疗效和风险。
# translation:  Physicians say again that A has these effects and risks, B has those effects and risks.
# Row:  742 , translating:  你想怎么治？
# translation:  What do you want to cure?
# Row:  743 , translating:  你再问医生：“大夫，你要是我，你选那种？”
# translation:  You ask the doctor, "If you were me, would you choose that?"
# Row:  744 , translating:  医生说：“但是我不是你。”
# translation:  The doctor said, "I'm not you."
# Row:  747 , translating:  他们为什么还要向我们做市场宣传？
# translation:  为什么他们还要向我们宣传市场?
# Row:  750 , translating:  现在我们的性别不是从父母那里继承下来， 而是由自己来发明。
# translation:  Our gender is not inherited from our parents, but invented by ourselves.
# Row:  751 , translating:  这样我们就可以随心所欲地的 重新塑造自己的性别身份。
# translation:  这样, we can re-create our gender identity as we please.
# Row:  754 , translating:  唯一你需要选择的就是和谁结婚， 而不是什么时候结，也不是结婚以后做什么。
# translation:  唯一的选择是和谁结婚,而不是什么时候结婚, 也不是做什么。
# Row:  755 , translating:  而如今呢，所有的事都可以拿来挑挑拣拣。
# translation:  现在, all things can be picked up.
# Row:  757 , translating:  这不是因为他们（比以前的学生）笨， 也不是因为他们不那么勤奋。
# translation:  Not because they're dumber than their former students, not because they're less diligent.
# Row:  759 , translating:  还是以后再说？我是该先要孩子， 还是先顾事业？
# translation:  还是以后再说?我需要孩子,还是先考虑事业?
# Row:  760 , translating:  这些都是费脑筋的问题。
# translation:  这些都是 brain-scrambling problems.
# Row:  762 , translating:  他们的确应该去想这些问题， 因为这都是些重要问题。
# translation:  They should really think about these issues, because they're all important ones.
# Row:  765 , translating:  不告诉你的理由是我也想用。
# translation:  不告诉你的理由是,我也想用它。
# Row:  769 , translating:  回还是不回这个Email？ 我该不该写这封信稿？
# translation:  回信还是不回信?我应该写这封信吗?
# Row:  771 , translating:  环顾四周， 不论大事还是小事， 物质的还是生活方式方面， 生活就是选择。
# translation:  环顾四周,不管 it's big or small, material or lifestyle, life is a choice.
# Row:  772 , translating:  我们过去生活的世界是这样的。
# translation:  我们过去的生活是这样的。
# Row:  773 , translating:  就是说，选择还是有的， 但不是事事都需要选择。
# translation:  就是说, there are choices, but not all things need to be chosen.
# Row:  774 , translating:  而今天我们生活的世界则是这样的。
# translation:  这就是我们今天所生活的世界。
# Row:  775 , translating:  问题是，这到底是好事还是坏事？
# translation:  问题是,这是好事还是坏事?
# Row:  776 , translating:  答案是肯定的。
# translation:  答案是肯定的。
# Row:  777 , translating:  我们都知道它的好处。 那么就让我来说说它的不好之处吧。
# translation:  我们都知道它的好处。那就让我来谈谈它的弊端吧。
# Row:  778 , translating:  所有这些选择对人们有两个影响， 而且是两个负面的影响。
# translation:  All these choices have two effects on people, and there are two negative ones.
# Row:  780 , translating:  面对这么许多的选择 人们发现要做出决定非常困难。
# translation:  Faced with so many choices, people find it very difficult to make a decision.
# Row:  783 , translating:  她的调查发现是 当这些客户 提供的互助基金种类每增加10个 参加的人数就减少2个百分点。
# translation:  Her survey found that when these clients provide mutual funds, the number of participants decreases by 2 percentage points.
# Row:  786 , translating:  明日复明日， 明日何其多， 当然，明天永远也不会到来。
# translation:  明天再也不会,当然。
# Row:  789 , translating:  所以，选择可能性过多的结果是麻痹僵化。
# translation:  So the result of over-selecting is paralysis.
# Row:  790 , translating:  它使得我们的世界变成这样样子
# translation:  It makes our world look like this.
# Row:  791 , translating:  当你进入极乐世界时， 你一定希望你做出的决定是正确的，是吗？
# translation:  When you enter the world of adoration, you must want your decision to be correct, right?
# Row:  792 , translating:  在那里你一定不想再选错互助基金， 或者是沙拉调料。
# translation:  You don't want to choose the wrong mutual fund, or salad dressing.
# Row:  794 , translating:  这里有几个原因。
# translation:  这里有几个原因。
# Row:  798 , translating:  其二，是经济学家称之为“机会成本”的东西。
# translation:  Second, economists call it "opportunity cost."
# Row:  802 , translating:  但这是你此时此刻应该想的事。
# translation:  但这是你现在应该想到的。
# Row:  803 , translating:  看看汉普顿的这两口子，
# translation:  Look at these two Hampton mouths,
# Row:  804 , translating:  昂贵的富人区，
# translation:  昂贵的富人区,
# Row:  805 , translating:  华丽的海滩，阳光明媚，他们拥有这一切。
# translation:  Beautiful beaches, sunny ones, they have it all.
# Row:  807 , translating:  “我要是回去就能把车停到我自己的门前了。”
# translation:  "I can stop the car in front of my own door."
# Row:  811 , translating:  这又是一个例子。 这幅漫画说明了好几个问题。
# translation:  Here's another example. This cartoon illustrates a number of issues.
# Row:  812 , translating:  它也说出了“活在当下”这个道理。 也许还包括做事情要一步一步来。
# translation:  It also says 'live in the present'. Perhaps it includes doing things step by step.
# Row:  814 , translating:  第三点，期望值增高。
# translation:  第三, expectations increase.
# Row:  815 , translating:  这点在有一次我去买一条 新牛仔裤时对我触动很大。
# translation:  It touched me a lot when I went to buy a new jeans.
# Row:  816 , translating:  我差不多总是穿牛仔裤。
# translation:  I almost always wear jeans.
# Row:  819 , translating:  店员说： 你要紧身型的，舒适型的，还是宽松型的？
# translation:  The clerk said: "You want to be tight, comfortable, or loose?"
# Row:  820 , translating:  前面要扣子的还是拉锁的？石磨的还是酸洗的？
# translation:  Should I pull the buttons in front of me? mellowed or acid washed?
# Row:  821 , translating:  要那种快磨破的么？
# translation:  Do you want to grind that fast?
# Row:  822 , translating:  直口的，还是缩口的？他喋喋不休地问着。
# translation:  Directly, or narrowly? he asked unceasingly.
# Row:  825 , translating:  我做得的确不错。这些选择 使得我有机会做的更好。
# translation:  I did really well. These choices gave me a chance to do better.
# Row:  826 , translating:  但是心里感觉却更糟。
# translation:  But my heart feels worse.
# Row:  827 , translating:  为什么？为这我还专门写了一本书 来为我自己找借口。
# translation:  Why? I also wrote a book for myself to justify it.
# Row:  829 , translating:  我以前期望值很低。 当牛仔裤就那么一种时，我没有过多指望。
# translation:  I had very low expectations. When jeans were like that, I didn't expect much.
# Row:  830 , translating:  当它们有一百种规格时，哼， 最好至少有一条是极致完美的。
# translation:  When they have a hundred specifications, at least one is perfect.
# Row:  831 , translating:  我那条的确不错，但是它还是不够完美。
# translation:  I did, but it wasn't perfect.
# Row:  834 , translating:  带来的只是使人们对结果不那么满意了， 即使那是好结果。
# translation:  It just makes people less happy with the results, even if it's a good result.
# Row:  835 , translating:  搞市场的人没有人懂得这个道理。
# translation:  No one in the market understands this.
# Row:  836 , translating:  因为如果他们里面有人懂的话， 你也就不会有机会知道这是什么意思了
# translation:  因为如果有人知道,你也不会有机会知道这是什么意思。
# Row:  839 , translating:  你再也不会被什么所惊喜， 因为你我的期望值比天还高。
# translation:  You won't be surprised anymore, because your expectations are higher than the sky.
# Row:  842 , translating:  这件事上我没有凑合，我尽力了。
# translation:  I didn't do anything about it, I did my best.
# Row:  843 , translating:  但是能凑合并不一定是坏事。
# translation:  But being able to merge isn't necessarily a bad thing.
# Row:  845 , translating:  这个世界该为此负责。 你有什么能做的么？
# translation:  这个世界应该对此负责。你能做些什么?
# Row:  847 , translating:  现在这个问题的答案显然就是：你。
# translation:  The answer to this question is: you.
# Row:  848 , translating:  你完全可以做得更好。
# translation:  You can do better.
# Row:  849 , translating:  那里摆着上百种牛仔裤， 你没有借口把事情搞砸。
# translation:  There are hundreds of jeans out there, and you have no excuse to mess around.
# Row:  851 , translating:  在我们过去的这一代人里， 工业化世界中临床压抑症爆炸性增长。
# translation:  In our past generation, clinical depression has exploded in the industrialized world.
# Row:  853 , translating:  最后的净效果就是，尽管客观上 我们做得比以往好了， 但是感觉上却不如从前。
# translation:  The net effect is that while we are doing better than ever, it doesn't feel the same.
# Row:  854 , translating:  我再提醒大家，
# translation:  再提醒大家,
# Row:  857 , translating:  这里有一个关键值，我不知道是多少。
# translation:  Here's a key value, I don't know how much.
# Row:  858 , translating:  但是我可以肯定我们早就远远超出了 ‘选择令我们富有’ 所需要的这个关键值了。
# translation:  但是, I can be sure that we have far exceeded the critical value of 'choice to make us rich'.
# Row:  861 , translating:  而是几乎没有。
# translation:  It's almost impossible.
# Row:  862 , translating:  所以我在这里谈的这个话题是现代富裕的西方社会的
# translation:  所以我今天要讲的这个话题 是关于富裕的西方社会。
# Row:  864 , translating:  而我今天要说的就是这些昂贵的，复杂的选择 不仅仅是于事无补，
# translation:  今天, I want to talk about these expensive, complex choices that aren't just inconvenient.
# Row:  865 , translating:  它们其实在给我们带来伤害。
# translation:  实际上, they're hurting us.
# Row:  866 , translating:  它们其实让我们变得不如从前。
# translation:  实际上,它们让我们变得不如以前。
# Row:  869 , translating:  告诉你，在这个鱼缸里一切都是不可能的。”
# translation:  To tell you, everything in this fish tank is impossible."
# Row:  870 , translating:  毫无想象力，目光短浅- 我第一次看到这幅画时是这么解读的。
# translation:  Unimagined, short-sighted - I read this picture for the first time.
# Row:  871 , translating:  可是，我越想越明显地感到 这鱼肯定知道些什么。
# translation:  But the more I wanted to feel that this fish must know something.
# Row:  873 , translating:  如果你想让一切都变得有可能而把鱼缸打破， 你反而降低了满意度。
# translation:  If you want to make everything possible and break the fish tank, you reduce satisfaction.
# Row:  874 , translating:  你增加了的是瘫痪，减少了的是满足。
# translation:  You increase paralysis, you decrease satisfaction.
# Row:  875 , translating:  每个人都需要这么个“鱼缸”。
# translation:  Everyone needs a fish tank.
# Row:  876 , translating:  至于这个（鱼缸）嘛，对这条鱼 可能是小了点，对于我们几乎肯定是太小了。
# translation:  As for this (fish tank), it might be a little bit small, almost certainly too small for us.
# Row:  877 , translating:  但是，没有这么个象征性的鱼缸那就 意味着苦难将至， 也许是，灾难。
# translation:  But the absence of such a symbolic tank means that suffering will come, perhaps, disaster.
# Row:  878 , translating:  非常感谢。
# translation:  非常感谢。

# %%
prefix = 'translate to zh: '

predictions = []

for index, pred in enumerate(first_predictions): # Translate back to zh
  print("Row: ", str(index), ", translating: ", pred)
  src_text = prefix + pred
  input_ids = tokenizer(src_text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids.to(device)
  generated_tokens = model.generate(input_ids)
  translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
  print("translation: ", translation)
  predictions.append(translation)
# Out:
# Row:  0 , translating:  But these do not fully explain the severity of the problem, because this does not indicate the thickness of the ice cap.
# translation:  但是这些并不能完全解释问题的严重性, 因为这并不能说明冰盖的厚度。
# Row:  1 , translating:  The Arctic ice cap feels like a beating heart in the global climate system.
# translation:  北极的冰盖感觉就像是全球气候系统中跳动的心脏。
# Row:  2 , translating:  The heart is swelled in winter and the heart contractes in summer.
# translation:  心脏在冬天膨胀,夏天收缩。
# Row:  3 , translating:  Below I want to show you the dramatic changes that have taken place over the past 25 years.
# translation:  下面我将向你们展示过去25年里发生的巨大变化。
# Row:  4 , translating:  The red is the permafrost ice.
# translation:  红色是永久冻冰。
# Row:  5 , translating:  25 years later, it came from here to here.
# translation:  25年后,它从这里来到这里。
# Row:  6 , translating:  If it breaks through, the GHG emissions will be the total global greenhouse gas pollutant in the existing atmosphere.
# translation:  如果它突破,全球温室气体排放量 将是现有大气中温室气体的总和。
# Row:  7 , translating:  In some shallow lakes in Alaska, biobubbles can already be seen inside the water probe.
# translation:  在阿拉斯加的一些浅湖里, 已经可以看到生物泡泡在水中。
# Row:  8 , translating:  Last winter, Professor Katey Walter of the University of Alaska teamed up to a shallow lake.
# translation:  去年冬天,阿拉斯加大学的凯蒂·沃尔特教授 来到了一个浅湖边。
# Row:  9 , translating:  Wow (quickly laughing) Gore: She's fine, what about us?
# translation:  (快笑) 戈尔:她没事儿,我们呢?
# Row:  10 , translating:  For one reason, the large amounts of thermal energy deposited in the north heated Greenland Island.
# translation:  原因之一是,北格陵兰岛储藏了大量的热能。
# Row:  11 , translating:  It is a river that melts every year.
# translation:  这条河每年融化。
# Row:  12 , translating:  But the flow is larger than in previous years.
# translation:  但是流量比前几年要大。
# Row:  13 , translating:  This is the south-west of Greenland's Kangerlussuaq River.
# translation:  这是格陵兰岛西南部的Kangerlussuaq河。
# Row:  14 , translating:  If you want to understand how the ice on land melts and raises sea levels, this is its entry into the sea.
# translation:  如果你想了解陆地上的冰融化和海平面上升, 这是它进入海洋的方式。
# Row:  15 , translating:  Traffic is rising rapidly here.
# translation:  交通量正在迅速增长。
# Row:  16 , translating:  Antarctica, the planet's largest ice block.
# translation:  南极洲,这个星球上最大的冰块。
# Row:  17 , translating:  Last month, scientists reported that the continent was in a phase of decreasing ice.
# translation:  上个月,科学家报告了这个大陆正处在冰层减少的阶段。
# Row:  18 , translating:  Suddenly several islands below sea level are being discovered in the western part of Antarctica, accelerating their melting.
# translation:  突然间在南极的西部发现了几个海平面以下的岛屿, 加速了它们的融化。
# Row:  19 , translating:  20英尺 above sea level, the same as Greenland.
# translation:  海拔20英尺,和格陵兰岛一样。
# Row:  20 , translating:  40% of the world gets half its drinking water from it.
# translation:  世界上有40%的人从中获得饮用水。
# Row:  21 , translating:  In the Andes, this ice river is the city's drinking water source.
# translation:  在安第斯山脉,这条冰河是城市的饮用水源泉。
# Row:  22 , translating:  Traffic is increasing.
# translation:  交通量在增加。
# Row:  23 , translating:  But when they disappear, we will also lose our drinking water.
# translation:  但是当它们消失时,我们也会失去饮用水。
# Row:  24 , translating:  In California, Sierra's snowfall is reduced by 40% per year.
# translation:  在加州,雪灾每年减少40%。
# Row:  25 , translating:  For water storage, this is a blow.
# translation:  对于储水来说,这是个打击。
# Row:  26 , translating:  And as you can see, it's expected to be very serious.
# translation:  如你所见,这是非常严肃的。
# Row:  27 , translating:  Global drying is causing a sharp increase in the number of fires.
# translation:  全球干燥导致火灾数量急剧增加。
# Row:  28 , translating:  The number of disasters around the world is also increasing at an unprecedented rate.
# translation:  全世界的灾难也在以前所未有的速度增加。
# Row:  29 , translating:  In the past 30 years, the total number of disasters has reached four times that of the previous 75 years.
# translation:  在过去的30年里,灾难的总数已经达到前75年的4倍。
# Row:  30 , translating:  This is a completely unsustainable model.
# translation:  这是一个完全不可持续的模式。
# Row:  31 , translating:  If you look at history, you can see what happened.
# translation:  看看历史,你可以看到发生了什么。
# Row:  32 , translating:  Oil is very important, coal is the most important.
# translation:  石油非常重要,煤炭也很重要。
# Row:  33 , translating:  The United States is becoming one of the world's two largest emitters, along with China.
# translation:  美国正在成为世界上最大的两个排放国之一, 还有中国。
# Row:  34 , translating:  The solution was to build a planet with more coal-carbons.
# translation:  解决的办法是建造一个拥有更多煤炭的星球。
# Row:  35 , translating:  但是, we are beginning to see the oceans change.
# translation:  但是,我们开始看到海洋的变化。
# Row:  36 , translating:  Here are some that have been canceled in recent years, as well as some new green alternatives.
# translation:  这些是近年来被取消的, 还有一些新的绿色替代品。
# Row:  37 , translating:  That picture reminded me of something.
# translation:  这张照片让我想起了一些事情。
# Row:  38 , translating:  Before and after Christmas, in my hometown of Tennessee, billions of litres of coal were mined.
# translation:  圣诞节之前和之后,田纳西州有数十亿公升的煤矿。
# Row:  39 , translating:  You may have seen it in the news.
# translation:  你可能在新闻里看过。
# Row:  40 , translating:  这是美国第二大 废水排放国。
# translation:  这是美国第二大的废水排放国。
# Row:  41 , translating:  This happened before and after Christmas.
# translation:  这发生在圣诞节前后。
# Row:  42 , translating:  There is one such coal-carbon industry advertisement.
# translation:  有这么一个煤炭行业广告。
# Row:  43 , translating:  Video: *** Mr. Coal is a joyful and happy incarnationist.
# translation:  视频:***煤先生是个快乐的化身主义者。
# Row:  44 , translating:  In the U.S., you can see that he's prolific and also helps us grow our economy.
# translation:  在美国,你可以看出他很有生产能力, 同时也帮助我们发展经济。
# Row:  45 , translating:  Mr. Coal is getting cleaner every day.
# translation:  煤炭每天都在清洁。
# Row:  46 , translating:  He's cute and affordable, bringing jobs to workers.
# translation:  他很可爱,能为工人带来工作。
# Row:  47 , translating:  GOL: West Virginia, the birthplace of many coals.
# translation:  西维吉尼亚州,许多煤的产地。
# Row:  48 , translating:  The largest mountaintop mining is the head of Massey Coal.
# translation:  最大的高山采矿业是马西煤矿。
# Row:  49 , translating:  Gore: So the Climate Protection Alliance launched two projects.
# translation:  戈尔:气候保护联盟启动了两个项目。
# Row:  50 , translating:  This is one of them, part of it.
# translation:  这是其中的一部分。
# Row:  51 , translating:  Actor: At COALergy, we take climate change very seriously as a threat to our cause.
# translation:  演员:在COALgy,我们非常严肃地看待气候变化 作为对我们事业的威胁。
# Row:  52 , translating:  In fact, coal is not dirty.
# translation:  事实上,煤并不脏。
# Row:  53 , translating:  我们认为,它是干净的, smelly.
# translation:  我们认为它是干净的,闻起来很香。
# Row:  54 , translating:  Therefore, there is no need to worry about global warming.
# translation:  因此,我们不需要担心全球变暖。
# Row:  55 , translating:  让我们来解决这个问题。
# translation:  让我们来解决这个问题。
# Row:  56 , translating:  Actor: Clean coal, you've heard a lot about it.
# translation:  演员:清洁煤,你听过很多。
# Row:  57 , translating:  那么, let's look at the art-like clean coal plant.
# translation:  那么,让我们看看像艺术一样的清洁煤电厂。
# Row:  58 , translating:  Magnificent! the machine is rumbling.
# translation:  太棒了!机器在颤抖。
# Row:  59 , translating:  But that's the sound of clean coal technology.
# translation:  这就是清洁煤技术的声音。
# Row:  60 , translating:  Although coal burning is one of the main causes of global warming, you can see that the complacent clean coal technology has changed everything.
# translation:  虽然煤炭燃烧是导致全球变暖的主要原因之一, 但你可以看到清洁煤技术已经改变了一切。
# Row:  61 , translating:  OK, that's clean coal technology right now.
# translation:  好吧,这就是清洁煤技术。
# Row:  62 , translating:  戈尔:最后, this positive program can address economic and national security challenges.
# translation:  戈尔:最后,这个积极的计划可以解决经济和国家安全问题。
# Row:  63 , translating:  Video: The United States is in a crisis of economics, national security, and climate.
# translation:  视频:美国正处在经济危机,国家安全危机和气候危机中。
# Row:  64 , translating:  But now there's a whole new solution to these problems, RePower America.
# translation:  但现在有一个全新的解决方案, 重新塑造美国。
# Row:  65 , translating:  100% clean electricity in a decade.
# translation:  十年内实现100%的清洁电力。
# Row:  66 , translating:  New jobs for Americans will make our lives safer, and the planet will not get warmer.
# translation:  美国人的就业机会会让我们的生活更安全,地球也不会变暖。
# Row:  67 , translating:  Ultimately, a plan large enough to solve our problems.
# translation:  最终,一个足够大的项目来解决我们的问题。
# Row:  68 , translating:  Repower America, learn more.
# translation:  重振美国,学习更多。
# Row:  69 , translating:  Gore: The last one.
# translation:  戈尔:最后一个。
# Row:  70 , translating:  Thread: This is about Repower America.
# translation:  Thread:这是关于美国的力量。
# Row:  71 , translating:  Old dirty oil is killing our planet, which is the fastest way to reduce our dependence on it.
# translation:  肮脏的石油正在扼杀我们的星球, 这是减少我们对它的依赖的最快方法。
# Row:  72 , translating:  MAN: The future is here.Wind, solar, new energy networks.
# translation:  未来就在这里。风能,太阳能,新能源网络。
# Row:  73 , translating:  男B: New investment creates better-paid jobs.
# translation:  男B:新的投资创造了更好的工作机会。
# Row:  74 , translating:  旁白:Repower America, it's time to come true!
# translation:  旁白:重振美国,是时候实现它了!
# Row:  75 , translating:  Gore: There's an old African proverb if you want to walk fast, go independent.
# translation:  戈尔:有句古老的非洲谚语,如果你想走得快,那就独立吧。
# Row:  76 , translating:  If you want to go far, partner with them.
# translation:  如果你想走得更远,和他们合作。
# Row:  77 , translating:  What we need is to go far, and fast.
# translation:  我们需要走得更远,更快。
# Row:  78 , translating:  非常感谢
# translation:  非常感谢。
# Row:  79 , translating:  Last year I introduced LHC to my TED talk.
# translation:  去年我向TED演讲介绍了LHC。
# Row:  80 , translating:  And I told you to come back with a factual update about how the machine works.
# translation:  我告诉过你们一个关于机器运作的最新情况。
# Row:  81 , translating:  Very ambitious.
# translation:  非常雄心勃勃。
# Row:  82 , translating:  This is the Geneva-based machinery.
# translation:  这是以日内瓦为基地的机器。
# Row:  83 , translating:  We use these detectors to take mini-explosion photos.
# translation:  我们用这些探测器来拍摄小型爆炸照片。
# Row:  84 , translating:  This is the spectacular sight of ATLAS's construction process. It can be seen on a large scale.
# translation:  这是ATLAS建造过程的壮观景象。可以大规模地看到。
# Row:  85 , translating:  On September 10th last year, we launched the machine for the first time.
# translation:  去年9月10日,我们首次推出了这个机器。
# Row:  86 , translating:  This is a picture taken by ATLAS.
# translation:  这是ATLAS拍摄的照片。
# Row:  87 , translating:  In the control room there was a rejoicing jump.
# translation:  在控制室里有个快乐的跳跃。
# Row:  88 , translating:  This shows that our work has caused a cultural shock, which is just as significant as its scientific impact.
# translation:  这表明我们的工作引起了文化上的冲击, 这和它的科学影响一样重要。
# Row:  89 , translating:  These wires conduct 13,000 amphibious currents when all the machines are started.
# translation:  这些电线可以导出13000个两栖电流。
# Row:  90 , translating:  Now some of your engineers might say, "It's impossible, these wires are too thin."
# translation:  你的工程师可能会说,“这些电线太薄了。”
# Row:  91 , translating:  They can do this because when the temperature is extremely low they become superconductive wires.
# translation:  因为当温度极低时,它们就会变成超导线。
# Row:  92 , translating:  At one of the more than 9000 connectors in the LHC, there is a technical installation error.
# translation:  在LHC的9000多个连接器中, 有一个技术安装错误。
# Row:  93 , translating:  这就是结果。
# translation:  这就是结果。
# Row:  94 , translating:  Extremely shocking because the magnets weighed up to 20 tons, they moved about a foot.
# translation:  因为磁铁重达20吨,它们移动了大约一英尺。
# Row:  95 , translating:  A total of 50 magnets were damaged.
# translation:  总共有50个磁铁受损。
# Row:  96 , translating:  They have to be removed, the work has been completed.
# translation:  它们必须被移除,工作已经完成。
# Row:  97 , translating:  Fixing them, fixing them.
# translation:  修复它们。
# Row:  98 , translating:  Now wait for them to come back underground.
# translation:  等他们回到地下。
# Row:  99 , translating:  LHC was re-connected around the end of March.
# translation:  3月底左右,LHC重新连接起来。
# Row:  100 , translating:  谢谢
# translation:  谢谢
# Row:  101 , translating:  首先, I would like to remind you of the building blocks that you used to play in your childhood.
# translation:  首先,我想提醒大家 你们在童年时玩的构件。
# Row:  102 , translating:  Knowing the spatial structure of an object helps us learn about a lot of things around it.
# translation:  了解一个物体的空间结构 可以帮助我们了解它周围的许多东西。
# Row:  103 , translating:  Combining information according to our thinking-- what would happen?
# translation:  根据我们的思考-- 会发生什么?
# Row:  104 , translating:  Simple to say, the Siftable is an interactive computer that's as big as a biscuit.
# translation:  简单来说,Siftable是一个互动电脑 它和饼干一样大。
# Row:  105 , translating:  The most important thing is that each Siftable is independent, like a building block, which can be matched at will.
# translation:  最重要的一点是每个Siftable都是独立的,就像一个可以随意匹配的构件。
# Row:  106 , translating:  Siftables represent a new ecosystem-- the operational tool for digitalizing information.
# translation:  Siftables代表了一种新的生态系统-- 一种将信息数字化的操作工具。
# Row:  107 , translating:  现在, let me show you some simple things.
# translation:  现在,让我给你们看一些简单的东西。
# Row:  108 , translating:  These siftables can sense each other.
# translation:  这些隐形体可以感知到彼此。
# Row:  109 , translating:  If you put them one by one, an interesting phenomenon will occur.
# translation:  如果你把它们一个接一个地放在一起, 就会有个有趣的现象发生。
# Row:  110 , translating:  If you put them all together, they'll notice a bit of confusion.
# translation:  如果你把它们放在一起,他们会注意到一些混乱。
# Row:  111 , translating:  They can also sense each other's movement and tilt.
# translation:  它们也能感知彼此的运动和倾斜。
# Row:  112 , translating:  If it's more, you can revert some.
# translation:  如果更多,你可以恢复一些。
# Row:  113 , translating:  Siftables can also play a spelling game-- a type of ccrabble and boggle that mixes.
# translation:  Siftables也可以玩拼写游戏-- 一种可以混搭的杂耍。
# Row:  114 , translating:  谢谢大家。
# translation:  谢谢大家。
# Row:  115 , translating:  The kids loved the siftables.
# translation:  孩子们喜欢隐形眼镜。
# Row:  116 , translating:  有趣的 is that we don't need to explain anything to them when playing the spelling game.
# translation:  有趣的是,当我们玩拼写游戏时,我们不需要向他们解释任何事情。
# Row:  117 , translating:  只要告诉 them it's a spelling game, they know what to do.
# translation:  只要告诉他们这是一个拼写游戏, 他们就知道该怎么做。
# Row:  118 , translating:  Now the screen shows someone else experiencing Siftables.
# translation:  现在屏幕显示其他人正在体验Siftables。
# Row:  119 , translating:  In the lower right corner is the youngest person to experience it.
# translation:  右下角是体验它最年轻的人。
# Row:  120 , translating:  He just wanted to stack the siftables together.
# translation:  他只是想把信封堆在一起。
# Row:  121 , translating:  In his view, the siftables are just building blocks.
# translation:  在他看来,隐形体只是构件。
# Row:  122 , translating:  The screen now shows an interactive attempt to animate.
# translation:  现在屏幕展示了一个互动的尝试。
# Row:  123 , translating:  We want Siftables to be a language assistant.
# translation:  我们希望Siftables成为语言助理。
# Row:  124 , translating:  The child in the picture is Felix.
# translation:  照片里的孩子是费利克斯。
# Row:  125 , translating:  He added the sun.
# translation:  他加了太阳。
# Row:  126 , translating:  Video: The sun rises.
# translation:  视频:太阳升起。
# Row:  127 , translating:  David Mayo: He added the tractor.
# translation:  大卫·梅奥:他加了拖拉机。
# Row:  128 , translating:  Video: The orange tractor.
# translation:  视频:橙色拖拉机
# Row:  129 , translating:  OK!
# translation:  好!
# Row:  130 , translating:  Mayo: He's writing his animated story.
# translation:  梅奥:他在写他的动画故事。
# Row:  131 , translating:  Video: Hello!
# translation:  视频:你好!
# Row:  132 , translating:  Mayo: This is an open-ended story about how he plans to start the story.
# translation:  梅奥:这是一个关于他计划如何开始的故事。
# Row:  133 , translating:  Video: The cat was seated in a hot air balloon.
# translation:  视频:猫坐在热气球里。
# Row:  134 , translating:  Each module has four patches to adjust for.
# translation:  每个模块有四个修补程序。
# Row:  135 , translating:  There are also Siftable modules that act like a mixer or filter.
# translation:  还有Siftable模块,就像一个混合器或过滤器。
# Row:  136 , translating:  Putting these modules close to the sound module can adjust the sound.
# translation:  把这些模块放在声音模块附近可以调节声音。
# Row:  137 , translating:  Next, you can control the overall rhythm and volume of the Siftable module.
# translation:  接下来,你可以控制Siftable模块的整体节奏和音量。
# Row:  138 , translating:  Siftable near the editing module to adjust the rhythm and volume. Let's look at it.
# translation:  在编辑模块附近调整节奏和音量。让我们看一下。
# Row:  139 , translating:  Now join the bass.
# translation:  现在加入贝斯。
# Row:  140 , translating:  Video: Mayo: Now add some punching instruments.
# translation:  视频:梅奥:现在加入一些弹奏乐器。
# Row:  141 , translating:  Video: Mayo: Put the filter module close to the drum module, so you can adjust the sound.
# translation:  视频:Mayo:把滤波器放在鼓模块附近,这样你就可以调整声音。
# Row:  142 , translating:  Video: Mayo: I'm going to speed it up a little bit. Just put the rhythm module near the edit module.
# translation:  视频:梅奥:我会加快速度的。只要把节奏模块放在编辑模块旁边就行了。
# Row:  143 , translating:  Video: Mayo: Now bring the filter module closer to the Bass module.
# translation:  视频:梅奥:现在把过滤模块拉近Bass模块。
# Row:  144 , translating:  Video: Mayo: It can also be reorganized during the musical process.
# translation:  视频:Mayo:在音乐过程中也可以重新组织。
# Row:  145 , translating:  Finally, I'm going to end the whole play with a volume module near the editing module, using this file on the left.
# translation:  最后,我将用编辑模块旁边的一个音量模块 来结束整个游戏。
# Row:  146 , translating:  谢谢大家。
# translation:  谢谢大家。
# Row:  147 , translating:  非常感谢大家。
# translation:  非常感谢大家。
# Row:  148 , translating:  I look forward to discussing it with you.
# translation:  我期待着与你们讨论。
# Row:  149 , translating:  I am a writer, not only my profession, but also the love and fascination of my life.
# translation:  我是一个作家, 不仅是我的职业,也是我生命中的爱和魅力。
# Row:  150 , translating:  I am a writer, not only my profession, but also the love and fascination of my life.
# translation:  我是一个作家, 不仅是我的职业,也是我生命中的爱和魅力。
# Row:  151 , translating:  I am a writer, not only my profession, but also the love and fascination of my life.
# translation:  我是一个作家, 不仅是我的职业,也是我生命中的爱和魅力。
# Row:  152 , translating:  我认为, this is something that will never change.
# translation:  我认为这是永不改变的。
# Row:  153 , translating:  真的, that's it, totally unsaved, overplayed!
# translation:  真的,完全没有被拯救过!
# Row:  154 , translating:  They can really comfort people.
# translation:  它们能真正地安慰人们。
# Row:  155 , translating:  I was faced with the same question, and people said: "Are you not afraid of never succeeding?"
# translation:  我也面临着同样的问题,人们会说:“你不怕成功吗?”
# Row:  156 , translating:  The simplest answer to these questions is 'fear'.
# translation:  这些问题最简单的答案是“恐惧”。
# Row:  157 , translating:  是的, everything is frightening to this day as well.
# translation:  是的,今天一切都很可怕。
# Row:  158 , translating:  是的, everything is frightening to this day as well.
# translation:  是的,今天一切都很可怕。
# Row:  159 , translating:  这是一个理性的想法吗?
# translation:  这是一个理性的想法吗?
# Row:  160 , translating:  Nobody said, "John, you've got a bottleneck?"
# translation:  没人说,“约翰,你有瓶颈吗?”
# Row:  161 , translating:  No such questioning has ever happened.
# translation:  从来没有发生过这样的质疑。
# Row:  162 , translating:  对于 your life's work, this is a radical statement.
# translation:  对你的生活来说,这是个激进的说法。
# Row:  163 , translating:  大家觉得这个观点没问题吗?
# translation:  大家觉得这个观点没问题吗?
# Row:  164 , translating:  This view is not only disgusting, but also horrifying, I don't want this idea to continue until the next century.
# translation:  这个观点不仅令人厌恶,而且让人恐惧。 我不想让这个想法持续到下一个世纪。
# Row:  165 , translating:  I think it would be better to encourage our great creative geniuses to continue living.
# translation:  我认为最好是鼓励我们伟大的天才继续生活。
# Row:  166 , translating:  I still have about 40 years of creative career to go through.
# translation:  我还有40年的创作生涯要经历。
# Row:  167 , translating:  天哪,这是什么主意!
# translation:  天哪,这是个主意!
# Row:  168 , translating:  I don't want to be that way, so the question becomes: What should I do?
# translation:  我不想这样,所以问题就变成了:我该怎么办?
# Row:  169 , translating:  我想继续 my love of writing, so the question becomes: What should I do?
# translation:  我想继续我对写作的热爱, 所以问题就变成了: 我该怎么办?
# Row:  170 , translating:  This search finally took me to ancient Greece and Rome.
# translation:  这次搜索终于把我带到了古希腊和罗马。
# Row:  171 , translating:  So please listen to me, because at the end of the day it will come back to our problem.
# translation:  所以请听我说, 因为最终会回到我们的问题。
# Row:  172 , translating:  The Greeks generally refer to this as the "guardian" of creativity.
# translation:  希腊人通常认为这是创造力的守护者。
# Row:  173 , translating:  我们可以理解它的运作模式,不是吗?
# translation:  我们可以理解它的运作模式,不是吗?
# Row:  174 , translating:  If your work is bad, it's not all your fault either.
# translation:  如果你的工作不好,那也不是你的错。
# Row:  175 , translating:  我要说的是,我认为那是个大错误。
# translation:  我想说的是,这是个大错误。
# Row:  176 , translating:  It's no different than asking him to swallow the sun, which is too much of a responsibility for vulnerable individuals.
# translation:  这和让他吞下太阳没什么区别, 这对脆弱的人来说太重要了。
# Row:  177 , translating:  如果这是真的,那么我们的问题是: 我们可以改变这种状况吗?
# translation:  如果这是真的,那么我们的问题是: 我们可以改变这种状况吗?
# Row:  178 , translating:  那么我们的问题是:我们能不能改变这种状况?
# translation:  那么我们的问题是:我们能不能改变这种状况?
# Row:  179 , translating:  Maybe not.
# translation:  也许不是。
# Row:  180 , translating:  也许我不能说服你们都同意我的观点。
# translation:  也许我不能说服你们都同意我的观点。
# Row:  181 , translating:  我想说的是:为什么不换个角度?
# translation:  我想说的是:为什么不换个角度?
# Row:  182 , translating:  In fact, the process of creation is sometimes just beyond common sense.
# translation:  事实上,创造的过程 有时是超出常识的。
# Row:  183 , translating:  It was like a thunderstorm, pouring down at her.
# translation:  就像一场暴风雨,向她倾泻。
# Row:  184 , translating:  She could feel it coming, because that force would shake the ground beneath her feet.
# translation:  她能感觉到它的到来,因为那股力量会震动她脚下的地面。
# Row:  185 , translating:  She could feel it coming, because that force would shake the ground beneath her feet.
# translation:  她能感觉到它的到来,因为那股力量会震动她脚下的地面。
# Row:  186 , translating:  Many people may have similar experiences sitting there.
# translation:  很多人可能有类似的经历。
# Row:  187 , translating:  到底是怎么回事?
# translation:  到底是怎么回事?
# Row:  188 , translating:  He desperately wanted to capture it, but he didn't have a pen or a recorder.
# translation:  他急切地想要捕捉它,但是他没有笔或录音机。
# Row:  189 , translating:  Suddenly, he stopped obsessive and anxious, and then did something unusual.
# translation:  突然,他停止了执迷和焦虑, 然后做了一些不寻常的事。
# Row:  190 , translating:  Suddenly, he stopped obsessive and anxious, and then did something unusual.
# translation:  突然,他停止了执迷和焦虑, 然后做了一些不寻常的事。
# Row:  191 , translating:  Do I look like I can remember the next song?
# translation:  我能记得下首歌吗?
# Row:  192 , translating:  Or you can harass someone today, go to Leonard Cohen.
# translation:  或者你可以骚扰某人,去找莱昂纳多·科恩。
# Row:  193 , translating:  Or you can harass someone today, go to Leonard Cohen.
# translation:  或者你可以骚扰某人,去找莱昂纳多·科恩。
# Row:  194 , translating:  Since then, Tom's entire creative process has changed.
# translation:  从那时起,汤姆的整个创作过程都发生了变化。
# Row:  195 , translating:  His work hasn't changed, his work is still as dark as ever.
# translation:  他的工作没有改变,他的工作还是一如既往的黑暗。
# Row:  196 , translating:  Not only was it bad, but I started to feel like I should give up writing this book.
# translation:  不仅如此,我开始觉得应该放弃写这本书。
# Row:  197 , translating:  Then I thought about Tom shouting at the sky, and then I tried to do it.
# translation:  然后我想到汤姆在天空中大喊,然后我试着去做。
# Row:  198 , translating:  Then I thought about Tom shouting at the sky, and then I tried to do it.
# translation:  然后我想到汤姆在天空中大喊,然后我试着去做。
# Row:  199 , translating:  "If you want a better book, it's your turn to come forward and do that part of your job."
# translation:  “如果你想要一本更好的书,轮到你来做你的工作。”
# Row:  200 , translating:  "If you don't want to help, go see your goddamn."
# translation:  “如果你不想帮忙,去看你妈的。”
# Row:  201 , translating:  At that moment he was no longer an ordinary human being, his life ignited from within, and lighted from the bottom of his heart.
# translation:  那一刻他不再是普通人了, 他的生命从心底被点燃。
# Row:  202 , translating:  每个人都知道: it's a miracle that manifests itself.
# translation:  每个人都知道:奇迹本身就显现出来。
# Row:  203 , translating:  That's a good way to do it, because that's exactly what we need.
# translation:  这是一个很好的方法,因为这正是我们需要的。
# Row:  204 , translating:  It's a tricky problem, and one of the most painful self-cognitions in your creative career.
# translation:  这是一个棘手的问题,也是你职业生涯中最痛苦的自我认知。
# Row:  205 , translating:  If we look at it this way, everything will change.
# translation:  如果我们这样看,一切都会改变。
# Row:  206 , translating:  "Don't be afraid, don't be discouraged, just do your part."
# translation:  “不要害怕,不要沮丧,只要尽你所能。”
# Row:  207 , translating:  Hold on to your position, whatever your position is: If you're a dancer, then dance.
# translation:  保持你的位置,无论你的立场是什么: 如果你是一个舞者,那就跳舞吧。
# Row:  208 , translating:  Hold on to your position, whatever your position is: If you're a dancer, then dance.
# translation:  保持你的位置,无论你的立场是什么: 如果你是一个舞者,那就跳舞吧。
# Row:  209 , translating:  如果没有, please continue to dance and hold on to your position. I still cheer for you: Oasis!
# translation:  如果没有,请继续跳舞。我仍然为你欢呼:绿洲!
# Row:  210 , translating:  如果没有, please continue to dance and hold on to your position. I still cheer for you: Oasis!
# translation:  如果没有,请继续跳舞。我仍然为你欢呼:绿洲!
# Row:  211 , translating:  我坚信 that we must teach this concept.
# translation:  我坚信我们必须传授这个概念。
# Row:  212 , translating:  谢谢
# translation:  谢谢
# Row:  213 , translating:  谢谢
# translation:  谢谢
# Row:  214 , translating:  谢谢!
# translation:  谢谢!
# Row:  215 , translating:  We often try to ask bigger questions.
# translation:  我们经常问更大的问题。
# Row:  216 , translating:  "What is life?" I think many biologists are constantly trying to understand the problem at different levels.
# translation:  “生命是什么?” 我认为许多生物学家在不同层面上不断尝试着去理解这个问题。
# Row:  217 , translating:  We tried many ways to break it down into the smallest part.
# translation:  我们尝试了很多方法把它分解成最小的部分。
# Row:  218 , translating:  于是我们开始沿着这条路走, "Can we artificially synthesize chromosomes?"
# translation:  我们开始沿着这条路走,“我们能不能人工合成染色体?”
# Row:  219 , translating:  Chemical principles really allow us to make these super-large molecules that we have never realized?
# translation:  化学原理真的允许我们制造这些超大分子, 我们从来没有意识到吗?
# Row:  220 , translating:  而且,即使我们能激活它?
# translation:  即使我们能激活它?
# Row:  221 , translating:  A pair of chromosomes, by the way, are just some non-active chemicals.
# translation:  一对染色体,顺便说一下,只是一些非活性化学物质。
# Row:  222 , translating:  Our digital life is accelerating exponentially.
# translation:  我们的数字生活正在指数化地加速。
# Row:  223 , translating:  We started this work 15 years ago.
# translation:  我们15年前就开始了这项工作。
# Row:  224 , translating:  It actually went through several stages. Before we did the initial experiment, a bioethics assessment was carried out.
# translation:  实际上,它经历了几个阶段。在我们做最初的实验之前, 我们进行了生物伦理学的评估。
# Row:  225 , translating:  But the result is that synthetic DNA is very difficult.
# translation:  但是合成DNA是非常困难的。
# Row:  226 , translating:  So we had to create a new way of ejected these small pieces together and correcting all the errors.
# translation:  所以我们必须创造一种新方法 把这些小部件放在一起,并纠正所有的错误。
# Row:  227 , translating:  This is our first attempt, starting with the digital information of the Phi X174 genome.
# translation:  这是我们第一次尝试,从Phi X174基因组的数字信息开始。
# Row:  228 , translating:  A small virus that kills bacteria.
# translation:  一种能杀死细菌的小病毒。
# Row:  229 , translating:  The cell then releases the virus particles and returns to kill E. coli.
# translation:  然后细胞释放病毒颗粒, 杀死大肠杆菌。
# Row:  230 , translating:  I've had some conversations with the oil industry recently, and I think they understand this pattern very well.
# translation:  我最近和石油行业谈过一些, 我认为他们非常了解这种模式。
# Row:  231 , translating:  设计 is very important, and if you start using digital information on a computer. These digital information must be accurate.
# translation:  设计是非常重要的,如果你开始在电脑上使用数字信息。这些数字信息必须是准确的。
# Row:  232 , translating:  These are the unique parts that we designed.
# translation:  这些是我们设计的独一无二的部分。
# Row:  233 , translating:  You may have heard that we added watermarks to it.
# translation:  你可能听说我们给它加了水印。
# Row:  234 , translating:  Think of the four characters that encode genes: A, C, G and T.
# translation:  想象一下编码基因的四个字符:A,C,G和T。
# Row:  235 , translating:  所以我们可以用 genetic code to write sentences, ideas.
# translation:  所以我们可以用基因编码来写句子,想法。
# Row:  236 , translating:  最初,我们用它来签名。
# translation:  最初,我们用它来签名。
# Row:  237 , translating:  Some people are disappointed that we didn't use it to make a poem.
# translation:  有些人失望的是,我们没有用它来创作一首诗。
# Row:  238 , translating:  We try to reach the level of automation.
# translation:  我们试着达到自动化的程度。
# Row:  239 , translating:  It looks like a basketball match.
# translation:  看起来像篮球赛。
# Row:  240 , translating:  We know that there is a method called co-source reorganisation, biologically used to repair DNA, it can combine fragments together.
# translation:  我们知道有一种叫做共源重组的方法, 在生物学上用来修复DNA, 它能把碎片组合在一起。
# Row:  241 , translating:  You can see in the top view, its chromosomes are scattered everywhere.
# translation:  你可以在上面看到,它的染色体散布到处都是。
# Row:  242 , translating:  12 to 24 hours later, it recombines itself back to its original form.
# translation:  12到24小时后,它重新组合成原来的形式。
# Row:  243 , translating:  数以千计的微生物 have this resilience.
# translation:  数以千计的微生物具有这种弹性。
# Row:  244 , translating:  These microbes are completely free from water. They can survive in a vacuum.
# translation:  这些微生物完全没有水。它们可以在真空中生存。
# Row:  245 , translating:  I am fully convinced that there is life in outer space, moving around and encountering a new watery environment.
# translation:  我完全相信在外太空有生命, 可以四处游动并遇到新的水生环境。
# Row:  246 , translating:  NASA has shown many such examples.
# translation:  NASA已经展示了很多这样的例子。
# Row:  247 , translating:  It's not an electronic micro-image; it's just a simple optical microscope.
# translation:  这不是电子的微图像; 它只是一个简单的光学显微镜。
# Row:  248 , translating:  这个分子 is so large that we can observe it with an optical microscope.
# translation:  这个分子太大了,我们可以用光学显微镜来观察它。
# Row:  249 , translating:  These are about six seconds long images.
# translation:  这大约是6秒长的照片。
# Row:  250 , translating:  These are the results of a recent trial that we have made public.
# translation:  这是我们最近公开的一个试验的结果。
# Row:  251 , translating:  It weighs more than 300 million molecules.
# translation:  它有3亿多个分子。
# Row:  252 , translating:  那么,我们如何激活 a chromosome?
# translation:  那么,我们如何激活染色体呢?
# Row:  253 , translating:  Clearly, dealing with a virus is very simple. Dealing with a bacterium is much more complicated.
# translation:  很显然,对付病毒非常简单。处理细菌要复杂得多。
# Row:  254 , translating:  新 chromosomes enter the cell.
# translation:  新的染色体进入细胞。
# Row:  255 , translating:  实际上,我们以为这个过程已经结束。但我们试着把它设计得更深入一些。
# translation:  实际上,我们认为这个过程已经结束。我们试着把它设计得更深入一些。
# Row:  256 , translating:  This is a major evolutionary mechanism.
# translation:  这是一个主要的进化机制。
# Row:  257 , translating:  The idea that only one gene can change in the course of evolution ignores many real-life situations.
# translation:  只有一种基因在进化过程中可以改变, 这个想法忽略了许多现实情况。
# Row:  258 , translating:  There is an enzyme called a limitase that can digest DNA.
# translation:  一种叫做极限酶的酶可以消化DNA。
# Row:  259 , translating:  The chromosomes in the original cells didn't have this enzyme, and when we put them into a section that had it, they weren't.
# translation:  原始细胞中没有这种酶, 我们把它们放到一个有它的区域里。
# Row:  260 , translating:  The genes we put in it turned blue.
# translation:  我们放进去的基因变蓝了。
# Row:  261 , translating:  Now, I would like to declare that this is not the Genesis century--it was built on three and a half billion years of evolution.
# translation:  现在,我想宣布这不是创世纪-- 它是建立在35亿年的进化之上的。
# Row:  262 , translating:  为什么新物种会这样呢?
# translation:  为什么新物种会这样?
# Row:  263 , translating:  I think some of the reasons why we do this are very obvious.
# translation:  我认为我们这样做的原因很明显。
# Row:  264 , translating:  未来40年,我们的人口将从6500万增长到900亿。
# translation:  未来40年,我们的人口将从65亿增长到90亿。
# Row:  265 , translating:  For my own example, I was born in 1946.
# translation:  举个例子,我出生于1946年。
# Row:  266 , translating:  We provide food, clean fresh water, medicine and fuel to 6500 million people.
# translation:  我们为65亿人提供食物,清洁水,药品和燃料。
# Row:  267 , translating:  换言之,900亿人 really do have elbows.
# translation:  换句话说,90亿人确实有肘。
# Row:  268 , translating:  当我们尝试 to think about this biological program, or anything that can replace it, would be a huge challenge.
# translation:  当我们试着去想这个生物程序,或者任何可以取代它的东西时, 会是一个巨大的挑战。
# Row:  269 , translating:  Next, of course, is the carbon dioxide emitted into the atmosphere.
# translation:  接下来,当然是二氧化碳排放到大气中。
# Row:  270 , translating:  There are only ten components in the electrical industry, look at the diversity that can be derived from it.
# translation:  电气行业只有10个组成部分,看看能从中得到的多样性。
# Row:  271 , translating:  Our main limitations come from the realities of biology and our imaginations.
# translation:  我们的主要局限来自于生物学的现实 和我们的想象力。
# Row:  272 , translating:  我们现在拥有 the ability to make a large robot that allows us to make one million chromosomes every day.
# translation:  我们现在有能力制造出一百万个染色体。
# Row:  273 , translating:  And that's just a standard choice. We can choose from the ability to survive, chemical or fuel production, vaccine production, etc.
# translation:  这只是一个标准选择。我们可以从生存能力, 化学或燃料生产,疫苗生产等中进行选择。
# Row:  274 , translating:  We don't necessarily know what it looks like.We know exactly what their genetic code is.
# translation:  我们不一定知道它们是什么样子的。我们确切地知道它们的基因密码。
# Row:  275 , translating:  We are now focusing on the fourth generation of fuels.
# translation:  我们现在关注的是第四代燃料。
# Row:  276 , translating:  You've seen the transformation of grains into ethanol is just a bad trial.
# translation:  你看过谷物变成乙醇 只是一个不好的试验。
# Row:  277 , translating:  And we think in 18 months we'll get the first fourth-generation fuel.
# translation:  18个月后,我们将得到第4代燃料。
# Row:  278 , translating:  Sunshine and carbon dioxide are one way--
# translation:  阳光和二氧化碳是一回事——
# Row:  279 , translating:  但我们从世界各地发现,我们还有很多其他方法。
# translation:  但是我们从世界各地发现,我们还有很多其他的方法。
# Row:  280 , translating:  This is a microbiome, recorded in 1996.
# translation:  这是1996年记录的微生物组。
# Row:  281 , translating:  It lives in the deep sea. About 1.5 miles deep, almost at boiling water temperature.
# translation:  它生活在深海。大约1.5英里深, 几乎在沸水温度下。
# Row:  282 , translating:  It converts carbon dioxide into methane using hydrogen molecules as its most important source of energy.
# translation:  它把二氧化碳转化为甲烷, 利用氢分子作为它最重要的能量来源。
# Row:  283 , translating:  我们也 use the same tools to make several groups of instant vaccines.
# translation:  我们用同样的工具 来制造几组即时疫苗。
# Row:  284 , translating:  I think this can be changed by pre-creating a hybrid vaccine.
# translation:  我认为这可以通过先制造混合疫苗来改变。
# Row:  285 , translating:  Seadragon is also a very flexible structure.
# translation:  海龙也是一个非常灵活的结构。
# Row:  286 , translating:  For example, this is a complete book, its data are non-images.
# translation:  比如说,这是一本完整的书,它的数据是非图像。
# Row:  287 , translating:  Dickens's "Desolate Mountains" is a chapter.
# translation:  狄更斯的“荒凉山”是一个章节。
# Row:  288 , translating:  Maybe it's a way to read e-books,
# translation:  也许这是一种阅读电子书的方法,
# Row:  289 , translating:  But I wouldn't recommend it.
# translation:  但我不会推荐它。
# Row:  290 , translating:  The following is a more practical example, the Guardian.
# translation:  下面是一个更实际的例子,卫报。
# Row:  291 , translating:  Each big picture is the opening page,
# translation:  每一张大图片都是开场白,
# Row:  292 , translating:  We made a small change in this issue of the Guardian.
# translation:  我们在《卫报》杂志上做了一个小改动。
# Row:  293 , translating:  如果你想要 to see the characteristics of this car, you can look here.
# translation:  如果你想看看这辆车的特点,你可以看这里。
# Row:  294 , translating:  You can also see other models, even technical specifications.
# translation:  你还可以看到其他的模型, 甚至是技术规格。
# Row:  295 , translating:  To a certain extent, this approach avoids the limitations of the screen's actual use area.
# translation:  在一定程度上,这种方法避免了屏幕的实际使用区域。
# Row:  296 , translating:  We want this technology to reduce unnecessary pop-up windows and similar trash information.
# translation:  我们希望这项技术能减少不必要的弹窗和类似的垃圾信息。
# Row:  297 , translating:  Clearly, digital maps are one of the obvious applications for this technology.
# translation:  很明显,数字地图是这项技术的明显应用之一。
# Row:  298 , translating:  These are based on NASA's geospatial images.
# translation:  这些都是基于NASA的地理空间图像。
# Row:  299 , translating:  A map of the U.S. road map is obtained by superimposed processing.
# translation:  美国的道路图是靠超负荷处理得到的。
# Row:  300 , translating:  让我们先放下这些,看看其他的。
# translation:  让我们先放下这些,看看其他的。
# Row:  301 , translating:  实际上, this technology has been put on the Internet, so everyone can experience it for themselves.
# translation:  实际上,这项技术已经被放到了互联网上,所以每个人都可以自己体验它。
# Row:  302 , translating:  This project is called Photosynth.
# translation:  这个项目叫做Photosynth。
# Row:  303 , translating:  The study was also conducted by Steve Seitz of the University of Washington.
# translation:  这项研究也是由华盛顿大学的Steve Seitz进行的。
# Row:  304 , translating:  Assisted by Microsoft Research Institute Rick Szeliski. This is a very beautiful collaboration.
# translation:  由微软研究院协助。这是个非常漂亮的合作项目。
# Row:  305 , translating:  The project has already been implemented on the Internet, and it is based on Seadragon technology.
# translation:  这个项目已经在互联网上实施, 它基于海龙技术。
# Row:  306 , translating:  However, the arrangement of these images in three-dimensional space is actually very meaningful.
# translation:  然而,这些图像在三维空间中的排列 实际上非常有意义。
# Row:  307 , translating:  So you can see that the elements here are stable slide projections or panoramic imaging, and these contents are spatially related.
# translation:  你可以看到这些元素是稳定的幻灯投影, 或全景成像, 这些内容与空间有关。
# Row:  308 , translating:  I'm not sure if we have time to show more panorama of the environment.
# translation:  我不确定我们是否有时间展示更多的环境全景。
# Row:  309 , translating:  There are many more examples than this sense of space.
# translation:  比这种空间感还多得多的例子。
# Row:  310 , translating:  Primarily because we make websites, we have to take into account a lot of legal issues.
# translation:  因为我们做网站,我们必须考虑很多法律问题。
# Row:  311 , translating:  Here's an image of the Notre Dame on Flickr.
# translation:  这是Flickr上的圣母院的照片。
# Row:  312 , translating:  All these orange-colored cone shapes represent a picture used to build models.
# translation:  所有这些橙色的圆锥形代表了用来构建模型的图片。
# Row:  313 , translating:  These are all images from Flickr, so they're chained up in space.
# translation:  这些都是Flickr的图片,所以它们被链接到太空中。
# Row:  314 , translating:  这样我们就可以自由地浏览了。
# translation:  这样我们就可以自由浏览了。
# Row:  315 , translating:  (Applause) To be honest, I never thought that I would end up working for Microsoft.
# translation:  (鼓掌) 说实话,我从没想过我会为微软工作。
# Row:  316 , translating:  It's a pleasure to be so welcome.
# translation:  很高兴被接纳。
# Row:  317 , translating:  I remember there should have been a series of photos-- 啊, here.
# translation:  我记得应该有一系列的照片-- 啊,在这里。
# Row:  318 , translating:  This is a poster of Notre Dame Paris.
# translation:  这是巴黎圣母院的海报。
# Row:  319 , translating:  我们可以钻到海报里去看看整个重建的环境。
# translation:  我们可以钻进海报,看看整个重建的环境。
# Row:  320 , translating:  重点是我们能有效地利用网络社区。我们可以从每个人那里获取数据。
# translation:  重点是我们能有效地利用网络社区。我们可以从每个人那里获取数据。
# Row:  321 , translating:  When all these pictures are intertwined, the result is much more than a single collection.
# translation:  当这些照片相互交织时, 结果远不止一个集合。
# Row:  322 , translating:  This model is derived from the entire Earth.
# translation:  这个模型来自整个地球。
# Row:  323 , translating:  It's like Stephen Lawler's "Virtual Earth" long tail market.
# translation:  就像史蒂芬·劳勒的“虚拟地球”长尾市场。
# Row:  324 , translating:  These models, as people use them, become more complex and valuable.
# translation:  这些模型,当人们使用它们时, 变得更加复杂和有价值。
# Row:  325 , translating:  The user's photos will be labeled.
# translation:  用户的照片会被贴上标签。
# Row:  326 , translating:  非常感谢!
# translation:  非常感谢!
# Row:  327 , translating:  完全 based on the content of the picture.
# translation:  完全基于图片的内容。
# Row:  328 , translating:  What's more exciting is the amount of semantic information contained in the pictures.
# translation:  更令人振奋的是图片中包含的语义信息。
# Row:  329 , translating:  假设 all of these pictures are connected to yours, what would happen?
# translation:  假设这些照片都与你的相联系,会发生什么?
# Row:  330 , translating:  At that time, the interlinkages of these semantic messages and the amount of content will be.
# translation:  那时候,这些语义信息的相互联系 和内容的数量是相同的。
# Row:  331 , translating:  Huge. This would be a very typical network effect.
# translation:  太大了。这是一个非常典型的网络效应。
# Row:  332 , translating:  CA: That's unbelievable.BAA: Thank you very much!
# translation:  CA:这太不可思议了。BAA:非常感谢!
# Row:  333 , translating:  It's just an adaptive choice that our ancestors made many generations ago.
# translation:  这只是我们祖先几代人 做出的适应性选择。
# Row:  334 , translating:  Of course, we all follow the same rules of adaptability.
# translation:  当然,我们都遵循同样的适应性规则。
# Row:  335 , translating:  We are all born in the womb, and we have children in this world.
# translation:  我们都出生在子宫里,在这个世界上我们有孩子。
# Row:  336 , translating:  We have to go through adult baptism.
# translation:  我们必须经历成人的洗礼。
# Row:  337 , translating:  但是, you will find that each culture's rhythm of song and dance has its own unique characteristics.
# translation:  但是,你会发现每一种文化的歌舞节奏 都有其独特的特点。
# Row:  338 , translating:  Mount Everest on the slopes.
# translation:  珠穆朗玛峰在斜坡上。
# Row:  339 , translating:  If you think seriously, this different mindset will give you hope.
# translation:  如果你认真地想,这种不同的心态会给你希望。
# Row:  340 , translating:  This racial circle is the great legacy of humanity.
# translation:  这个种族圈是人类的伟大遗产。
# Row:  341 , translating:  It is also a mark of our identity as a species with strong exploratory capabilities.
# translation:  它也标志着我们作为一个具有强大探索能力的物种。
# Row:  342 , translating:  One of the most important signs is language.
# translation:  语言是最重要的标志之一。
# Row:  343 , translating:  6:00的语言存在于我们生活的这个星球上。
# translation:  6:00的语言存在于我们生活的星球上。
# Row:  344 , translating:  Languages are not just about pronunciation and grammar rules.
# translation:  语言不仅仅是关于发音和语法规则。
# Row:  345 , translating:  语言 is the flash of human spirit.
# translation:  语言是人类精神的闪光。
# Row:  346 , translating:  It is the spiritual substance of every unique culture in this material world.
# translation:  它是物质世界中每一种独特文化的精神实质。
# Row:  347 , translating:  Every language is an idea, a consciousness and a mental ecosystem of long-term precipitation and accumulation.
# translation:  每一种语言都是一个想法,意识和精神生态系统。
# Row:  348 , translating:  These languages are no longer permeable, i.e. unless effective measures are taken, they will disappear completely.
# translation:  除非采取有效措施,否则这些语言将完全消失。
# Row:  349 , translating:  Or the coki language.
# translation:  或者说可口语。
# Row:  350 , translating:  你会发现你不会说你的母语。
# translation:  你会发现你不会说你的母语。
# Row:  351 , translating:  只要他们能听,他们就能说出一门语言。
# translation:  只要他们能听见,他们就能说出一门语言。
# Row:  352 , translating:  1957 Five missionaries tried to approach them, but they made a fatal mistake.
# translation:  1957年,五位传教士试图接近他们, 但是他们犯了一个致命的错误。
# Row:  353 , translating:  What's more terrifying is that Wallani doesn't just kill outsiders.
# translation:  更可怕的是瓦拉尼不仅仅杀死了局外人。
# Row:  354 , translating:  They also kill each other.
# translation:  它们也会互相残杀。
# Row:  355 , translating:  54% of the dead were killed by their own people.
# translation:  54%的死者是他们自己的人。
# Row:  356 , translating:  Conversely, this is a complex metaphysical worldview.
# translation:  相反,这是一个复杂的形而上学的世界观。
# Row:  357 , translating:  That's interesting.
# translation:  这很有趣。
# Row:  358 , translating:  IF YOU want to list some of the world's most important religions, what examples would you give?
# translation:  如果你想列举一些世界上最重要的宗教, 你愿意举些什么例子?
# Row:  359 , translating:  基督教 Islam Buddhism There are other religions.
# translation:  基督教佛教还有其他的宗教。
# Row:  360 , translating:  The living ones give birth to the soul.
# translation:  活生生的灵魂。
# Row:  361 , translating:  So the witchlikes like to say that you go to church for worship, it is necessary to call God.
# translation:  女巫们喜欢说,你去教堂敬拜是必须的。
# Row:  362 , translating:  We danced in the temple to become God.
# translation:  我们在寺庙里跳舞,成为上帝。
# Row:  363 , translating:  那么, how can you be harmed if you've been god-associated?
# translation:  那么,如果你与神有联系,你会受到怎样的伤害呢?
# Row:  364 , translating:  This bloody continent has never been conquered by the Spaniards.
# translation:  这个血腥的大陆从未被西班牙人征服过。
# Row:  365 , translating:  直到今天, they continue to rule the system of monks, but their teachings are very unique.
# translation:  直到今天,他们仍然统治着僧侣们的体系, 但是他们的教义非常独特。
# Row:  366 , translating:  多么美妙啊,你要保护它。
# translation:  多么美妙啊,你要保护它。
# Row:  367 , translating:  This intuitive comprehension is very important.
# translation:  直觉理解是非常重要的。
# Row:  368 , translating:  土著人 don't have much sadness, they don't suffer from the pain of thinking about their country.
# translation:  土著人没有太多的悲伤, 他们不会因为思考他们的国家而感到痛苦。
# Row:  369 , translating:  那么,这是什么意思呢?
# translation:  那是什么意思呢?
# Row:  370 , translating:  Whether the mountain is God's dwelling place, or just a pile of minerals, it doesn't matter.
# translation:  无论是山还是一堆矿物质,都无关紧要。
# Row:  371 , translating:  Importantly, this symbolizes the relationship between man and nature.
# translation:  重要的是,这象征着人与自然的关系。
# Row:  372 , translating:  I grew up in the jungles of British Columbia, influenced by local people's ideas. I think the jungle is to be cut down.
# translation:  我在不列颠哥伦比亚的丛林里长大,受当地人的想法影响。我认为森林是要被砍掉的。
# Row:  373 , translating:  This photo was taken in the Amazon Northwest region last August.
# translation:  这张照片是去年八月在亚马逊西北部拍摄的。
# Row:  374 , translating:  Mixed together.
# translation:  混合在一起。
# Row:  375 , translating:  Because they can be altered by an enzyme in a human organ called monoamine oxidase.
# translation:  因为它们可以被一种叫做一氧化胺的人体器官所改变。
# Row:  376 , translating:  To do this, there are other chemicals that must simultaneously alter the activity of monoamine oxidase.
# translation:  要做到这点,必须同时改变一氧化胺的活性。
# Row:  377 , translating:  我们普通人 do a variety of experiments, and make mistakes all the time, but we don't get any results.
# translation:  我们普通人做各种各样的实验,总是犯错误, 但我们没有任何结果。
# Row:  378 , translating:  但是如果你问印第安人,他们会说植物会说话。
# translation:  但是如果你问印第安人,他们会说植物会说话。
# Row:  379 , translating:  那是什么意思呢?
# translation:  那是什么意思呢?
# Row:  380 , translating:  If you ask them how to classify these plants, they say that you have some research on the plant.
# translation:  如果你问他们如何分类这些植物, 他们会说你对它们有一些研究。
# Row:  381 , translating:  Do you know anything about plants? I don't think so.
# translation:  你知道植物吗?我不这么认为。
# Row:  382 , translating:  All cultures have been strongly impacted by the new way of life.
# translation:  所有文化都受到新生活方式的强烈影响。
# Row:  383 , translating:  The problem is not in the technology itself.
# translation:  问题不在于技术本身。
# Row:  384 , translating:  Because of the discovery of gold mines, people flocked there.
# translation:  因为发现了金矿,人们蜂拥而至。
# Row:  385 , translating:  He was immediately killed by his uncle and other believers.
# translation:  他立即被他的叔叔和其他信徒杀害了。
# Row:  386 , translating:  His mother fled to Nepal because she was part of a wealthy farmer's family.
# translation:  他的母亲逃到了尼泊尔, 因为她是一个富有的农民家庭的一部分。
# Row:  387 , translating:  His sister was sent to the class for an offence.
# translation:  他的姐姐因为犯了罪而被送去上课。
# Row:  388 , translating:  The pain in Tibet is unbearable, and the spirit of human redemption needs to be witnessed.
# translation:  西藏的痛苦是无法忍受的,人类的救赎精神需要被见证。
# Row:  389 , translating:  现代化的工业社会 只有近300年的历史。
# translation:  现代工业社会只有近300年的历史。
# Row:  390 , translating:  The old man's grandfather refused to move.
# translation:  老人的爷爷拒绝搬家。
# Row:  391 , translating:  His family worried about his safety, taking all of his weapons and tools away.
# translation:  他家人担心他的安全, 把他所有的武器和工具拿走。
# Row:  392 , translating:  As you know, the Inuits are not afraid of cold. This is their unique advantage.
# translation:  如你所知,因纽特人并不害怕寒冷。这是他们独一无二的优势。
# Row:  393 , translating:  Their slippers were originally made of frozen fish wrapped in North American reindeer skin.
# translation:  它们的拖鞋最初是用北美的驯鹿皮制成的。
# Row:  394 , translating:  To the Inuit I am our new home. It's called Nyerwit.
# translation:  对因纽特人来说,我是我们的新家。它叫Nierwit。
# Row:  395 , translating:  It is an independent territory where they control all the marine resources.
# translation:  这是一个独立的领地,他们控制着所有的海洋资源。
# Row:  396 , translating:  This example illustrates how a country can make a difference by trying to repair the relationship with its people.
# translation:  这个例子说明了一个国家如何通过修复与人民的关系来做出改变。
# Row:  397 , translating:  Because it is the home of a certain ethnic group.
# translation:  因为它是某个民族的家园。
# Row:  398 , translating:  我们的电视频道在156个国家播放。
# translation:  我们的电视频道在156个国家播出。
# Row:  399 , translating:  Our magazine has millions of readers.
# translation:  我们的杂志有数以百万计的读者。
# Row:  400 , translating:  让所有种族的智慧 能够为整个人类做出贡献
# translation:  让所有的种族都能为全人类做出贡献。
# Row:  401 , translating:  谢谢
# translation:  谢谢
# Row:  402 , translating:  I want to start with an accepted creed.
# translation:  我想以一个被接受的信念开始。
# Row:  403 , translating:  What is the accepted creed?
# translation:  什么是被接受的信仰?
# Row:  404 , translating:  That is the unquestionable precept of Western industrial society.
# translation:  这是西方工业社会的不容置疑的戒律。
# Row:  405 , translating:  The reason is that freedom in itself is beautiful, valuable, and necessary.
# translation:  原因是自由本身是美丽的,宝贵的,也是必要的。
# Row:  406 , translating:  The way to maximise freedom is to maximize selectivity.
# translation:  最大限度的自由是选择性。
# Row:  407 , translating:  The same concept is embedded in our daily lives.
# translation:  同样的概念也存在于我们的日常生活中。
# Row:  408 , translating:  Let me give you some examples of what the progressive development of modern society has made possible.
# translation:  让我给你们举一些例子,说明现代社会的进步使这一切成为可能。
# Row:  409 , translating:  This is a supermarket near my house. It's not very big.
# translation:  这是我家附近的一个超市。它不是很大。
# Row:  410 , translating:  I just want to talk about the coloring here.
# translation:  我想谈谈颜色。
# Row:  411 , translating:  看, that's what a supermarket looks like.
# translation:  看,这就是超市的样子。
# Row:  412 , translating:  You can't deny that this is not a small set of choices.
# translation:  你不能否认这并不是一小撮选择。
# Row:  413 , translating:  Change the industry, talk about communication.
# translation:  改变行业,谈谈沟通。
# Row:  414 , translating:  You don't have to buy, just rent a phone back.
# translation:  你不需要买,只要租回一个电话。
# Row:  415 , translating:  通常情况下, the phone won't be bad to death.
# translation:  通常情况下,电话不会坏到死。
# Row:  416 , translating:  Those days are long gone.
# translation:  那些日子已经过去了。
# Row:  417 , translating:  Today we have almost endless phone varieties, especially mobile phones. (show comics)
# translation:  今天我们有几乎无尽的电话品种, 尤其是手机。(展示漫画)
# Row:  418 , translating:  These are the phones of the future.
# translation:  这些是未来的手机。
# Row:  419 , translating:  于是, people ran to the store and asked: "Are there any of these things that don't have so many functions?"
# translation:  于是人们跑到商店问道: “这些东西有没有那么多功能?”
# Row:  420 , translating:  你们猜怎么回答?
# translation:  你们猜怎么回答?
# Row:  421 , translating:  The answer is no.
# translation:  答案是否定的。
# Row:  422 , translating:  现在 you can't buy a cell phone that doesn't do so much.
# translation:  现在你买不起手机了。
# Row:  423 , translating:  Similarly, there are other things in life that affect us more than shopping, the explosion of choice is also present.
# translation:  同样,生活中还有其他的事情 比购物更能影响我们。
# Row:  424 , translating:  Programme A has such efficacy and risks.
# translation:  方案A有这样的效率和风险。
# Row:  425 , translating:  Option B is so effective and risky. How do you treat it?
# translation:  选择B是那么的有效和冒险。你怎么对待它?
# Row:  426 , translating:  Then you said, "Doctor, what should I do?"
# translation:  你说:“医生,我该怎么办?”
# Row:  427 , translating:  Physicians say again that A has these effects and risks, B has those effects and risks.
# translation:  医生又说A有这些影响和风险,B也有那些影响和风险。
# Row:  428 , translating:  What do you want to cure?
# translation:  你想治好什么?
# Row:  429 , translating:  You ask the doctor, "If you were me, would you choose that?"
# translation:  你问医生,“如果你是我,你会选择那个吗?”
# Row:  430 , translating:  The doctor said, "I'm not you."
# translation:  医生说:“我不是你。”
# Row:  431 , translating:  为什么他们还要向我们宣传市场?
# translation:  他们为什么要向我们宣传市场?
# Row:  432 , translating:  Our gender is not inherited from our parents, but invented by ourselves.
# translation:  我们的性别不是从父母那里继承来的, 而是我们自己发明的。
# Row:  433 , translating:  这样, we can re-create our gender identity as we please.
# translation:  这样,我们就可以重新创造出我们的性别认同。
# Row:  434 , translating:  唯一的选择是和谁结婚,而不是什么时候结婚, 也不是做什么。
# translation:  唯一的选择是和谁结婚,而不是什么时候结婚。
# Row:  435 , translating:  现在, all things can be picked up.
# translation:  现在,所有的东西都可以被捡起来。
# Row:  436 , translating:  Not because they're dumber than their former students, not because they're less diligent.
# translation:  不是因为他们比以前的学生更笨, 也不是因为他们没有那么勤奋。
# Row:  437 , translating:  还是以后再说?我需要孩子,还是先考虑事业?
# translation:  我需要孩子,还是先考虑事业?
# Row:  438 , translating:  这些都是 brain-scrambling problems.
# translation:  这些都是脑震荡的问题。
# Row:  439 , translating:  They should really think about these issues, because they're all important ones.
# translation:  他们应该认真思考这些问题, 因为它们都是很重要的。
# Row:  440 , translating:  不告诉你的理由是,我也想用它。
# translation:  不告诉你的理由是,我也想用它。
# Row:  441 , translating:  回信还是不回信?我应该写这封信吗?
# translation:  回信还是不回信?我该写这封信吗?
# Row:  442 , translating:  环顾四周,不管 it's big or small, material or lifestyle, life is a choice.
# translation:  环顾四周,无论大小,物质还是生活方式, 生活都是一个选择。
# Row:  443 , translating:  我们过去的生活是这样的。
# translation:  我们过去的生活是这样的。
# Row:  444 , translating:  就是说, there are choices, but not all things need to be chosen.
# translation:  也就是说,有选择,但不是所有事情都需要被选中。
# Row:  445 , translating:  这就是我们今天所生活的世界。
# translation:  这就是我们今天所生活的世界。
# Row:  446 , translating:  问题是,这是好事还是坏事?
# translation:  问题是,这是好事还是坏事?
# Row:  447 , translating:  答案是肯定的。
# translation:  答案是肯定的。
# Row:  448 , translating:  我们都知道它的好处。那就让我来谈谈它的弊端吧。
# translation:  我们都知道它的好处。那就让我们来谈谈它的弊端吧。
# Row:  449 , translating:  All these choices have two effects on people, and there are two negative ones.
# translation:  这些选择对人们有两种影响, 两个是负面的。
# Row:  450 , translating:  Faced with so many choices, people find it very difficult to make a decision.
# translation:  面对如此多的选择,人们很难做出决定。
# Row:  451 , translating:  Her survey found that when these clients provide mutual funds, the number of participants decreases by 2 percentage points.
# translation:  她的调查发现,当这些客户提供互助基金时, 参与者的数量会减少2个百分点。
# Row:  452 , translating:  明天再也不会,当然。
# translation:  明天再也不会了。
# Row:  453 , translating:  So the result of over-selecting is paralysis.
# translation:  所以过度选择的结果就是瘫痪。
# Row:  454 , translating:  It makes our world look like this.
# translation:  它让我们的世界看起来是这样的。
# Row:  455 , translating:  When you enter the world of adoration, you must want your decision to be correct, right?
# translation:  当你进入爱的世界时,你一定希望你的决定是正确的,对吧?
# Row:  456 , translating:  You don't want to choose the wrong mutual fund, or salad dressing.
# translation:  你不想选择错误的互助基金, 或者沙拉打扮。
# Row:  457 , translating:  这里有几个原因。
# translation:  原因有几个。
# Row:  458 , translating:  Second, economists call it "opportunity cost."
# translation:  第二,经济学家称其为“机会成本”。
# Row:  459 , translating:  但这是你现在应该想到的。
# translation:  但这是你现在应该想到的。
# Row:  460 , translating:  Look at these two Hampton mouths,
# translation:  看看这张汉普顿的嘴,
# Row:  461 , translating:  昂贵的富人区,
# translation:  昂贵的富人区,
# Row:  462 , translating:  Beautiful beaches, sunny ones, they have it all.
# translation:  美丽的沙滩,阳光明媚的海滩,他们拥有一切。
# Row:  463 , translating:  "I can stop the car in front of my own door."
# translation:  “我可以把车停在自己的门前。”
# Row:  464 , translating:  Here's another example. This cartoon illustrates a number of issues.
# translation:  这是另一个例子。这幅漫画说明了一些问题。
# Row:  465 , translating:  It also says 'live in the present'. Perhaps it includes doing things step by step.
# translation:  它还说“活在当下”。也许它包括一步一步地做事。
# Row:  466 , translating:  第三, expectations increase.
# translation:  第三,期望增加。
# Row:  467 , translating:  It touched me a lot when I went to buy a new jeans.
# translation:  当我去买新牛仔裤时,它触动了我很多。
# Row:  468 , translating:  I almost always wear jeans.
# translation:  我几乎总是穿牛仔裤。
# Row:  469 , translating:  The clerk said: "You want to be tight, comfortable, or loose?"
# translation:  店员说:“你要紧,舒服,还是松?”
# Row:  470 , translating:  Should I pull the buttons in front of me? mellowed or acid washed?
# translation:  我应该拉下我前面的按钮吗? 还是用酸洗呢?
# Row:  471 , translating:  Do you want to grind that fast?
# translation:  你想磨得这么快吗?
# Row:  472 , translating:  Directly, or narrowly? he asked unceasingly.
# translation:  直接的,还是狭窄的?他不停地问。
# Row:  473 , translating:  I did really well. These choices gave me a chance to do better.
# translation:  我做得很好。这些选择给了我一个更好的机会。
# Row:  474 , translating:  But my heart feels worse.
# translation:  但是我的心感觉更糟。
# Row:  475 , translating:  Why? I also wrote a book for myself to justify it.
# translation:  为什么?我自己也写了一本书来证明这一点。
# Row:  476 , translating:  I had very low expectations. When jeans were like that, I didn't expect much.
# translation:  当时我对牛仔裤的期望很低。
# Row:  477 , translating:  When they have a hundred specifications, at least one is perfect.
# translation:  当它们有一百个规格时, 至少有一个是完美的。
# Row:  478 , translating:  I did, but it wasn't perfect.
# translation:  我做到了,但并不完美。
# Row:  479 , translating:  It just makes people less happy with the results, even if it's a good result.
# translation:  它只会让人们对结果不那么满意, 即使这是一个好的结果。
# Row:  480 , translating:  No one in the market understands this.
# translation:  市场上没人知道。
# Row:  481 , translating:  因为如果有人知道,你也不会有机会知道这是什么意思。
# translation:  因为如果有人知道,你也不会有机会知道这是什么意思。
# Row:  482 , translating:  You won't be surprised anymore, because your expectations are higher than the sky.
# translation:  你不会再感到惊讶了, 因为你的期望高于天空。
# Row:  483 , translating:  I didn't do anything about it, I did my best.
# translation:  我什么都没做,我尽力了。
# Row:  484 , translating:  But being able to merge isn't necessarily a bad thing.
# translation:  但是合并并不一定是件坏事。
# Row:  485 , translating:  这个世界应该对此负责。你能做些什么?
# translation:  这个世界应该对此负责。你能做些什么?
# Row:  486 , translating:  The answer to this question is: you.
# translation:  这个问题的答案是:你。
# Row:  487 , translating:  You can do better.
# translation:  你可以做得更好。
# Row:  488 , translating:  There are hundreds of jeans out there, and you have no excuse to mess around.
# translation:  那里有成百上千的牛仔裤, 你没有理由乱搞。
# Row:  489 , translating:  In our past generation, clinical depression has exploded in the industrialized world.
# translation:  在过去的几代人中,临床抑郁症在工业化国家爆发了。
# Row:  490 , translating:  The net effect is that while we are doing better than ever, it doesn't feel the same.
# translation:  净效应是,虽然我们做得比以前好, 但感觉却不一样。
# Row:  491 , translating:  再提醒大家,
# translation:  再提醒大家,
# Row:  492 , translating:  Here's a key value, I don't know how much.
# translation:  这里有一个关键的价值,我不知道多少。
# Row:  493 , translating:  但是, I can be sure that we have far exceeded the critical value of 'choice to make us rich'.
# translation:  但我敢肯定,我们已经超越了“让自己变得富有”这一关键价值。
# Row:  494 , translating:  It's almost impossible.
# translation:  这几乎是不可能的。
# Row:  495 , translating:  所以我今天要讲的这个话题 是关于富裕的西方社会。
# translation:  所以我今天要讲的话题是关于富裕的西方社会。
# Row:  496 , translating:  今天, I want to talk about these expensive, complex choices that aren't just inconvenient.
# translation:  今天我想谈谈这些昂贵的、复杂的选择, 它们不仅仅是不方便的。
# Row:  497 , translating:  实际上, they're hurting us.
# translation:  实际上,它们伤害了我们。
# Row:  498 , translating:  实际上,它们让我们变得不如以前。
# translation:  实际上,它们让我们变得不如以前。
# Row:  499 , translating:  To tell you, everything in this fish tank is impossible."
# translation:  告诉你,这个鱼缸里的一切是不可能的。”
# Row:  500 , translating:  Unimagined, short-sighted - I read this picture for the first time.
# translation:  单视觉,短视——这是我第一次读到这张照片。
# Row:  501 , translating:  But the more I wanted to feel that this fish must know something.
# translation:  但是我越想让这条鱼知道些什么。
# Row:  502 , translating:  If you want to make everything possible and break the fish tank, you reduce satisfaction.
# translation:  如果你想让一切成为可能,打破鱼缸,你就会降低满意度。
# Row:  503 , translating:  You increase paralysis, you decrease satisfaction.
# translation:  增加麻痹,降低满意度。
# Row:  504 , translating:  Everyone needs a fish tank.
# translation:  每个人都需要一个鱼缸。
# Row:  505 , translating:  As for this (fish tank), it might be a little bit small, almost certainly too small for us.
# translation:  至于这个鱼缸,它可能有点小, 对我们来说肯定太小了。
# Row:  506 , translating:  But the absence of such a symbolic tank means that suffering will come, perhaps, disaster.
# translation:  但是没有这样一个象征性的坦克 就意味着痛苦会来临。
# Row:  507 , translating:  非常感谢。
# translation:  非常感谢。

# %%
processed_predictions_backward_2way = []
processed_references_backward_2way = []

def process_string(text):
    return replace_punctuation_with_zh(remove_spaces(text))

def remove_spaces(text):
    return ''.join(text.split())

# Replacing en punctuation with the zh counterparts
def replace_punctuation_with_zh(text):
    # Define a mapping of English punctuation to Chinese punctuation
    punctuation_mapping = {
        ',': '，',
        '.': '。',
        '?': '？',
        '!': '！',
        ':': '：',
        ';': '；',
        '"': '”',
        "'": '’',
        '(': '（',
        ')': '）',
        '[': '【',
        ']': '】',
        '{': '｛',
        '}': '｝'
    }

    # Replace each English punctuation with its Chinese counterpart
    for eng_punc, chi_punc in punctuation_mapping.items():
        text = text.replace(eng_punc, chi_punc)

    return text

processed_predictions_backward_2way = [process_string(sent) for sent in predictions]
processed_references_backward_2way = [process_string(sent[0]) for sent in references]

df = pd.DataFrame({'Prediction': processed_predictions_backward_2way, 'Reference': processed_references_backward_2way})
df.to_csv(f'zh_to_en_t5_{model_name}_bidirectional_translations_zh.csv', index=False)

processed_references_backward_2way = [[reference] for reference in processed_references_backward_2way]

bleu_score_no_smoothing = sacrebleu.corpus_bleu(processed_predictions_backward_2way, processed_references_backward_2way, tokenize='zh')
bleu_score_add_1 = sacrebleu.corpus_bleu(processed_predictions_backward_2way, processed_references_backward_2way, tokenize='zh', smooth_method="add-k", smooth_value=1)

print(f"BLEU Score without smoothing: BLEU = {bleu_score_no_smoothing}")
print(f"BLEU Score with smoothing: BLEU = {bleu_score_add_1}")
# Out:
# BLEU Score without smoothing: BLEU = BLEU = 44.76 93.8/67.7/36.7/17.2 (BP = 1.000 ratio = 1.000 hyp_len = 32 ref_len = 32)
# BLEU Score with smoothing: BLEU = BLEU = 47.26 93.8/68.8/38.7/20.0 (BP = 1.000 ratio = 1.000 hyp_len = 32 ref_len = 32)

# %% [markdown]
# 2 way evaluation from english to chinese back to english

# %%
prefix = 'translate to zh: '

first_predictions, references = [], []

for index, row in val_df.iterrows():
  print("Row: ", str(index), ", translating: ", row["en"])
  src_text = prefix + row['en']
  input_ids = tokenizer(src_text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids.to(device)
  generated_tokens = model.generate(input_ids)
  translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
  print("translation: ", translation)
  first_predictions.append(translation)
  references.append(row['en'])

references = [[reference] for reference in references]
# Out:
# Row:  1 , translating:  But this understates the seriousness of this particular problem  because it doesn't show the thickness of the ice.
# translation:  但是这低估了这个问题的严重性, 因为它没有显示冰的厚度。
# Row:  2 , translating:  The arctic ice cap is, in a sense,  the beating heart of the global climate system.
# translation:  从某种意义上说,北极冰盖是全球气候系统的跳动中心。
# Row:  3 , translating:  It expands in winter and contracts in summer.
# translation:  它在冬天扩张,在夏天收缩。
# Row:  4 , translating:  The next slide I show you will be  a rapid fast-forward of what's happened over the last 25 years.
# translation:  下一张幻灯片将展示过去25年里发生的事情。
# Row:  5 , translating:  The permanent ice is marked in red.
# translation:  永久性冰被标记为红色。
# Row:  8 , translating:  In 25 years it's gone from this, to this.
# translation:  25年过去了。
# Row:  10 , translating:  Compared to the total amount of global warming pollution in the atmosphere,  that amount could double if we cross this tipping point.
# translation:  与全球变暖的污染总量相比, 如果跨过这个转折点,这一数量可以翻一番。
# Row:  11 , translating:  Already in some shallow lakes in Alaska,  methane is actively bubbling up out of the water.
# translation:  在阿拉斯加的一些浅湖里, 甲烷正积极地从水中涌出。
# Row:  12 , translating:  Professor Katey Walter from the University of Alaska  went out with another team to another shallow lake last winter.
# translation:  阿拉斯加大学的凯蒂·沃尔特教授去年冬天去了另一个浅湖。
# Row:  13 , translating:  Video: Whoa!   Al Gore: She's okay. The question is whether we will be.
# translation:  视频:哇!戈尔:没问题。
# Row:  14 , translating:  And one reason is, this enormous heat sink  heats up Greenland from the north.
# translation:  其中一个原因是,这个巨大的热汇从北边向格陵兰岛升温。
# Row:  15 , translating:  This is an annual melting river.
# translation:  这是一年一度的河水融化。
# Row:  16 , translating:  But the volumes are much larger than ever.
# translation:  但它的数量比以往任何时候都要大。
# Row:  17 , translating:  This is the Kangerlussuaq River in southwest Greenland.
# translation:  这是格陵兰西南部的Kangerlussuaq河。
# Row:  18 , translating:  If you want to know how sea level rises  from land-base ice melting  this is where it reaches the sea.
# translation:  如果你想知道海平面是如何从陆地冰层融化而上升的, 那就是它到达海洋的地方。
# Row:  19 , translating:  These flows are increasing very rapidly.
# translation:  这些流动正在迅速增加。
# Row:  20 , translating:  At the other end of the planet, Antarctica  the largest mass of ice on the planet.
# translation:  在地球的另一端,南极是地球上最大的冰块。
# Row:  21 , translating:  Last month scientists reported the entire continent  is now in negative ice balance.
# translation:  上个月,科学家报告了整个大陆的负冰平衡。
# Row:  22 , translating:  And west Antarctica cropped up on top some under-sea islands,  is particularly rapid in its melting.
# translation:  西南极洲在一些海底岛屿上生长, 它的融化速度特别快。
# Row:  23 , translating:  That's equal to 20 feet of sea level, as is Greenland.
# translation:  相当于20英尺的海平面,就像格陵兰岛一样。
# Row:  25 , translating:  40 percent of all the people in the world  get half of their drinking water from that melting flow.
# translation:  世界上40%的人从这种融化中得到一半的饮用水。
# Row:  26 , translating:  In the Andes, this glacier is the  source of drinking water for this city.
# translation:  在安第斯山脉,冰川是这个城市饮用水的来源。
# Row:  27 , translating:  The flows have increased.
# translation:  流量增加。
# Row:  28 , translating:  But when they go away, so does much of the drinking water.
# translation:  但是当它们消失时,大部分的饮用水也随之消失。
# Row:  29 , translating:  In California there has been a 40 percent  decline in the Sierra snowpack.
# translation:  在加州,雪囊的数量下降了40%。
# Row:  30 , translating:  This is hitting the reservoirs.
# translation:  这会撞到水库。
# Row:  31 , translating:  And the predictions, as you've read, are serious.
# translation:  正如你所读到的,这些预测是严肃的。
# Row:  32 , translating:  This drying around the world has lead to  a dramatic increase in fires.
# translation:  全世界的干旱导致火灾急剧增加。
# Row:  33 , translating:  And the disasters around the world  have been increasing at an absolutely extraordinary  and unprecedented rate.
# translation:  全世界的灾难都在以前所未有的速度增加。
# Row:  34 , translating:  Four times as many in the last 30 years  as in the previous 75.
# translation:  在过去的30年里,这个数字是前75年的4倍。
# Row:  35 , translating:  This is a completely unsustainable pattern.
# translation:  这是一种完全不可持续的模式。
# Row:  36 , translating:  If you look at in the context of history  you can see what this is doing.
# translation:  如果你从历史的角度来看,你可以看到这是怎么回事。
# Row:  40 , translating:  Oil is a problem, and coal is the most serious problem.
# translation:  石油是个问题,而煤炭则是最严重的问题。
# Row:  41 , translating:  The United States is one of the two  largest emitters, along with China.
# translation:  美国是最大的两个排放国之一。
# Row:  42 , translating:  And the proposal has been to build a lot more coal plants.
# translation:  建议建造更多的燃煤电厂。
# Row:  43 , translating:  But we're beginning to see a sea change.
# translation:  但我们开始看到大海的变化。
# Row:  44 , translating:  Here are the ones that have been cancelled in the last few years  with some green alternatives proposed.
# translation:  这些是在过去几年里被取消的, 有一些绿色的替代品。
# Row:  46 , translating:  That image reminded me of something.
# translation:  这张照片让我想起了一些事情。
# Row:  47 , translating:  Around Christmas, in my home in Tennessee,  a billion gallons of coal sludge was spilled.
# translation:  在田纳西州的圣诞节前夕, 10亿加仑的煤污被泄漏了。
# Row:  48 , translating:  You probably saw it on the news.
# translation:  你可能在新闻上看到过。
# Row:  49 , translating:  This, all over the country, is the second largest waste stream in America.
# translation:  在美国,这是第二大的废物流。
# Row:  50 , translating:  This happened around Christmas.
# translation:  那是在圣诞节的时候。
# Row:  51 , translating:  One of the coal industry's ads around Christmas was this one.
# translation:  一个关于圣诞节的广告是这个。
# Row:  52 , translating:  Video: ♪♫ Frosty the coal man is a jolly, happy soul.
# translation:  视频:♪冻煤人是一个快乐的灵魂。
# Row:  53 , translating:  He's abundant here in America,  and he helps our economy grow.
# translation:  他在美国很丰富,他帮助我们的经济成长。
# Row:  54 , translating:  Frosty the coal man is getting cleaner everyday.
# translation:  煤矿工人每天都在变的更清洁。
# Row:  55 , translating:  He's affordable and adorable, and workers keep their pay.
# translation:  他负担得起,很可爱,而且工人可以拿到工资。
# Row:  56 , translating:  Al Gore: This is the source of much of the coal in West Virginia.
# translation:  戈尔:这是西弗吉尼亚州大部分煤炭的来源。
# Row:  57 , translating:  The largest mountaintop miner is the head of Massey Coal.
# translation:  最大的矿工是马西煤矿。
# Row:  59 , translating:  Al Gore: So the Alliance for Climate Protection  has launched two campaigns.
# translation:  戈尔:气候保护联盟发起了两项运动。
# Row:  60 , translating:  This is one of them, part of one of them.
# translation:  这是其中之一,也是其中的一部分。
# Row:  61 , translating:  Video: Actor: At COALergy we view climate change as a very serious  threat to our business.
# translation:  视频:在COALgy,我们把气候变化看作是对我们业务的一个非常严重的威胁。
# Row:  63 , translating:  The fact is, coal isn't dirty.
# translation:  事实是,煤并不脏。
# Row:  64 , translating:  We think it's clean --  smells good, too.
# translation:  我们认为它很干净,味道也很好。
# Row:  65 , translating:  So don't worry about climate change.
# translation:  所以不要担心气候变化。
# Row:  66 , translating:  Leave that up to us.
# translation:  留给我们吧。
# Row:  67 , translating:  Video: Actor: Clean coal -- you've heard a lot about it.
# translation:  视频:清洁煤——你听过很多。
# Row:  68 , translating:  So let's take a tour of this state-of-the-art clean coal facility.
# translation:  让我们来看看这个最先进的清洁煤矿设施。
# Row:  69 , translating:  Amazing! The machinery is kind of loud.
# translation:  太棒了!机器有点响。
# Row:  70 , translating:  But that's the sound of clean coal technology.
# translation:  这就是清洁煤技术的声音。
# Row:  71 , translating:  And while burning coal is one of the leading causes of global warming,  the remarkable clean coal technology you see here  changes everything.
# translation:  虽然燃烧煤炭是导致全球变暖的主要原因之一, 但清洁煤技术可以改变一切。
# Row:  72 , translating:  Take a good long look: this is today's clean coal technology.
# translation:  长话短说:这是今天的清洁煤技术。
# Row:  73 , translating:  Al Gore: Finally, the positive alternative  meshes with our economic challenge  and our national security challenge.
# translation:  Al Gore:最后,积极的选择 与我们的经济挑战和国家安全挑战交汇在一起。
# Row:  74 , translating:  Video: Narrator: America is in crisis -- the economy,  national security, the climate crisis.
# translation:  视频:美国正处在危机中--经济,国家安全,气候危机。
# Row:  76 , translating:  But now there is a bold new solution to get us out of this mess.
# translation:  但是现在有一个大胆的新方案 来让我们摆脱这种混乱。
# Row:  77 , translating:  Repower America with 100 percent clean electricity  within 10 years.
# translation:  用100%的清洁电力来重振美国。
# Row:  78 , translating:  A plan to put America back to work,  make us more secure, and help stop global warming.
# translation:  让美国恢复工作,让我们更加安全, 并帮助阻止全球变暖。
# Row:  79 , translating:  Finally, a solution that's big enough to solve our problems.
# translation:  最后,一个足够大的解决方案 来解决我们的问题。
# Row:  80 , translating:  Repower America. Find out more.
# translation:  重振美国。了解更多
# Row:  81 , translating:  Al Gore: This is the last one.
# translation:  戈尔:这是最后一个。
# Row:  82 , translating:  Video: Narrator: It's about repowering America.
# translation:  视频:是关于重振美国。
# Row:  83 , translating:  One of the fastest ways to cut our dependence  on old dirty fuels that are killing our planet.
# translation:  减少我们对旧燃料的依赖的最快方法之一, 它正在扼杀我们的星球。
# Row:  84 , translating:  Man: Future's over here. Wind, sun, a new energy grid.
# translation:  男人:未来来了。风,太阳,新能源网。
# Row:  85 , translating:  Man #2: New investments to create high-paying jobs.
# translation:  男人2:创造高薪工作的新投资。
# Row:  86 , translating:  Narrator: Repower America. It's time to get real.
# translation:  讲述者:重振美国。是时候让它变成现实了。
# Row:  87 , translating:  Al Gore: There is an old African proverb that says,  "If you want to go quickly, go alone.
# translation:  阿尔·戈尔:有句古老的非洲谚语说, “如果你想快点去,就一个人去。”
# Row:  88 , translating:  If you want to go far, go together."
# translation:  如果你想走得更远,一起去。”
# Row:  89 , translating:  We need to go far, quickly.
# translation:  我们需要走得更远,更快。
# Row:  90 , translating:  Thank you very much.
# translation:  非常感谢。
# Row:  91 , translating:  Last year at TED I gave an introduction to the LHC.
# translation:  去年我在TED做了一个LHC的介绍。
# Row:  92 , translating:  And I promised to come back and give you an update  on how that machine worked.
# translation:  我答应再给你一个关于那台机器如何工作的更新。
# Row:  95 , translating:  It's nothing if not ambitious.
# translation:  如果不是雄心勃勃的话,那就什么都没有了。
# Row:  96 , translating:  This is the machine below Geneva.
# translation:  这是日内瓦下方的机器。
# Row:  97 , translating:  We take the pictures of those mini-Big Bangs inside detectors.
# translation:  我们拍下这些小爆炸探测器里面的照片。
# Row:  99 , translating:  Spectacular picture here of ATLAS under construction  so you can see the scale.
# translation:  这里是正在建设中的ATLAS的壮观图片,所以你可以看到它的规模。
# Row:  100 , translating:  On the 10th of September last year we turned the machine on for the first time.
# translation:  去年9月10日,我们第一次打开机器。
# Row:  101 , translating:  And this picture was taken by ATLAS.
# translation:  这张照片是ATLAS拍摄的。
# Row:  102 , translating:  It caused immense celebration in the control room.
# translation:  它在控制室里引起了极大的欢庆。
# Row:  106 , translating:  It means we made cultural impact  as well as scientific impact.
# translation:  这意味着我们不仅对文化产生了影响, 也对科学产生了影响。
# Row:  108 , translating:  Those wires carry 13 thousand amps  when the machine is working in full power.
# translation:  这些电线携带13000个安培器 当机器全功率工作时。
# Row:  109 , translating:  Now the engineers amongst you will look at them and say,  "No they don't. They're small wires."
# translation:  你们中的工程师会看着他们,说:“不是。它们是小电线。”
# Row:  110 , translating:  They can do that because  when they are very cold they are what's called superconducting wire.
# translation:  因为当它们很冷的时候,就被称为超导线。
# Row:  112 , translating:  In one of the joints between over 9,000 magnets in LHC,  there was a manufacturing defect.
# translation:  在LHC中超过9000个磁体之间的一个关节里, 有一个制造缺陷。
# Row:  114 , translating:  This was the result.
# translation:  这就是结果。
# Row:  115 , translating:  Now that's more impressive  when you consider those magnets weigh over 20 tons,  and they moved about a foot.
# translation:  更让人印象深刻的是,这些磁铁重达20吨, 然后它们移动了大约一英尺。
# Row:  116 , translating:  So we damaged about 50 of the magnets.
# translation:  所以我们损坏了大约50个磁铁。
# Row:  117 , translating:  We had to take them out, which we did.
# translation:  我们必须把它们拿出来,我们做到了。
# Row:  118 , translating:  We reconditioned them all, fixed them.
# translation:  我们重新调整了它们,修复了它们。
# Row:  119 , translating:  They're all on their way back underground now.
# translation:  他们正准备回到地下。
# Row:  120 , translating:  By the end of March the LHC will be intact again.
# translation:  到3月底,LHC将再次完好无损。
# Row:  125 , translating:  Thank you.
# translation:  谢谢。
# Row:  126 , translating:  I want to start out by asking you to think back to when you were a kid,  playing with blocks.
# translation:  我想先让大家回想一下 你还是个孩子的时候,玩砖块。
# Row:  128 , translating:  Spatial reasoning is deeply connected  to how we understand a lot of the world around us.
# translation:  空间推理与我们如何理解周围世界息息相关。
# Row:  130 , translating:  arranging it the way we wanted?
# translation:  按照我们想要的方式来安排?
# Row:  132 , translating:  In a nutshell, a Siftable is an interactive computer  the size of a cookie.
# translation:  简而言之,Siftable是一个像饼干一样的交互式计算机。
# Row:  134 , translating:  Most importantly, they're physical,  so like the blocks, you can move them just by reaching out and grasping.
# translation:  最重要的是,它们是有形的,你可以通过伸展和抓取来移动它们。
# Row:  135 , translating:  And Siftables are an example of a new ecosystem  of tools for manipulating digital information.
# translation:  Siftables是一种新的生态系统, 用来操纵数字信息。
# Row:  137 , translating:  So, I'm going to start with some simple examples.
# translation:  那么,我将以一些简单的例子开始。
# Row:  139 , translating:  And these interactive portraits are aware of each other.
# translation:  这些互动的肖像是相互了解的。
# Row:  140 , translating:  So if I put them next to each other, they get interested.
# translation:  如果我把它们放在一起,它们就会变得很感兴趣。
# Row:  141 , translating:  If they get surrounded, they notice that too,  they might get a little flustered.
# translation:  如果他们被包围了,他们也可能会有点晕眩。
# Row:  142 , translating:  And they can also sense their motion and tilt.
# translation:  它们也能感知它们的运动和倾斜。
# Row:  145 , translating:  If we overshoot, we can pour a little bit back.
# translation:  如果我们超额,我们可以倒退一点。
# Row:  148 , translating:  Here we have a word game that's kind of like a mash-up between Scrabble and Boggle.
# translation:  这里有个单词游戏,有点像在Scrabble和Boggle之间。
# Row:  151 , translating:  Thank you.
# translation:  谢谢。
# Row:  153 , translating:  They really loved it.
# translation:  他们真的很喜欢它。
# Row:  154 , translating:  And, one of the interesting things about this kind of application  is that you don't have to give people many instructions.
# translation:  而且,这种应用的有趣之处在于 你不需要给人们很多指令。
# Row:  155 , translating:  All you have to say is, "Make words,"  and they know exactly what to do.
# translation:  你要说的就是“写字”,他们知道该怎么做。
# Row:  156 , translating:  So here's another few people trying it out.
# translation:  还有几个人试着去做。
# Row:  157 , translating:  That's our youngest beta tester, down there on the right.
# translation:  这是我们最年轻的测试者,在右边。
# Row:  158 , translating:  Turns out, all he wanted to do was to stack the Siftables up.
# translation:  结果是,他想做的就是把Siftables堆起来。
# Row:  159 , translating:  So to him, they were just blocks.
# translation:  对他来说,他们只是个街区。
# Row:  160 , translating:  Now, this is an interactive cartoon application.
# translation:  现在,这是一个交互式卡通应用程序。
# Row:  161 , translating:  And we wanted to build a learning tool for language learners.
# translation:  我们想为语言学习者建立一个学习工具。
# Row:  162 , translating:  And this is Felix, actually.
# translation:  这是费利克斯,事实上。
# Row:  164 , translating:  Here, he's bringing the sun out.
# translation:  在这里,他把太阳拿出来。
# Row:  165 , translating:  Video: The sun is rising.
# translation:  视频:太阳在升起。
# Row:  166 , translating:  David Merrill: Now he's brought a tractor into the scene.
# translation:  大卫·梅里尔:他把拖拉机带到了现场。
# Row:  167 , translating:  Video: The orange tractor.
# translation:  视频:橙色拖拉机
# Row:  168 , translating:  Good job! Yeah!
# translation:  干得好!
# Row:  170 , translating:  DM: inventing his own narrative.
# translation:  DM:发明他自己的叙事。
# Row:  171 , translating:  Video: Hello!
# translation:  视频:你好!
# Row:  172 , translating:  DM: It's an open-ended story,  and he gets to decide how it unfolds.
# translation:  DM:这是一个开放的故事,他可以决定如何展开。
# Row:  173 , translating:  Video: Fly away, cat.
# translation:  视频:飞开,猫。
# Row:  175 , translating:  Each of these has four different variations,  you get to choose which one you want to use.
# translation:  每一个都有四个不同的变化,你可以选择你想要用哪一个。
# Row:  177 , translating:  And you inject it by just bumping up the sound Siftable against a sequence Siftable.
# translation:  只需将声波与音波对撞即可注射。
# Row:  178 , translating:  There are effects that you can control live, like reverb and filter.
# translation:  你可以实时控制这些影响,比如说声波和滤波器。
# Row:  179 , translating:  You attach it to a particular sound and then tilt to adjust it.
# translation:  你把它附在一个特定的声音上 然后倾斜来调节它。
# Row:  180 , translating:  And then, overall effects like tempo and volume  So let's have a look.
# translation:  总的来说,比如速度和音量。
# Row:  182 , translating:  Now I put a bass line in.
# translation:  现在我把一条低音线放进去。
# Row:  183 , translating:  Video:   DM: Now I'll put some percussion in.
# translation:  视频:DM:现在我要放一些冲击。
# Row:  184 , translating:  Video:   DM: And now I'll attach the filter to the drums, so I can control the effect live.
# translation:  视频:DM:现在我把过滤器附在鼓上,这样我可以实时控制效果。
# Row:  185 , translating:  Video:   DM: I can speed up the whole sequence  by tilting the tempo one way or the other.
# translation:  视频:DM:我可以通过倾斜速度来加快整个过程。
# Row:  186 , translating:  Video:   DM: And now I'll attach the filter to the bass for some more expression.
# translation:  视频:DM:现在我将过滤器附加到低音上,以获得更多的表情。
# Row:  187 , translating:  Video:   DM: I can rearrange the sequence while it plays.
# translation:  视频:DM:我可以重新排列顺序。
# Row:  189 , translating:  And now, finally, I can fade the whole sequence out  using the volume Siftable, tilted to the left.
# translation:  现在,我可以用左边的音量 将整个序列褪色。
# Row:  190 , translating:  Thank you.
# translation:  谢谢。
# Row:  194 , translating:  Thank you very much.
# translation:  非常感谢。
# Row:  195 , translating:  I look forward to talking with all of you.
# translation:  我很期待与大家交流。
# Row:  196 , translating:  I am a writer.
# translation:  我是作家。
# Row:  197 , translating:  Writing books is my profession but it's more than that, of course.
# translation:  写书是我的职业,当然不止如此。
# Row:  198 , translating:  It is also my great lifelong love and fascination.
# translation:  这也是我一生的爱和魅力。
# Row:  199 , translating:  And I don't expect that that's ever going to change.
# translation:  我不认为这会改变。
# Row:  203 , translating:  Seriously -- doomed, doomed!
# translation:  真的——注定,注定!
# Row:  206 , translating:  So that's reassuring, you know.
# translation:  那令人放心,你知道的。
# Row:  208 , translating:  And people would say, "Aren't you afraid you're never going to have any success?
# translation:  人们会说:“你不怕什么成功吗?”
# Row:  211 , translating:  The answer -- the short answer to all those questions is, "Yes."
# translation:  答案--对所有这些问题的简短回答是, “是的。”
# Row:  212 , translating:  Yes, I'm afraid of all those things.
# translation:  是的,我害怕所有这些事情。
# Row:  213 , translating:  And I always have been.
# translation:  我一直都是。
# Row:  216 , translating:  You know, is it rational?
# translation:  你知道吗?
# Row:  220 , translating:  "That chemical-engineering block, John, how's it going?"
# translation:  “化学工程学块,约翰,怎么回事?”
# Row:  221 , translating:  It just didn't come up like that, you know?
# translation:  它不是这样出现的,你知道吗?
# Row:  226 , translating:  An extraordinary statement to make about your life's work.
# translation:  一个关于你一生工作的非凡声明。
# Row:  229 , translating:  Are you comfortable with that?
# translation:  你觉得舒服吗?
# Row:  231 , translating:  I think it's odious.
# translation:  我觉得很可怕。
# Row:  233 , translating:  I think it's better if we encourage our great creative minds to live.
# translation:  我认为如果我们鼓励我们伟大的创造力,那就更好了。
# Row:  236 , translating:  I still have maybe another four decades of work left in me.
# translation:  也许我还有四十年的工作。
# Row:  239 , translating:  So Jesus, what a thought!
# translation:  天啊,真是个想法!
# Row:  241 , translating:  I would prefer to keep doing this work that I love.
# translation:  我宁愿继续做我热爱的工作。
# Row:  242 , translating:  And so, the question becomes, how?
# translation:  那么问题就变成了,如何?
# Row:  246 , translating:  And that search has led me to ancient Greece and ancient Rome.
# translation:  那次搜索带我到了古希腊和古罗马。
# Row:  247 , translating:  So stay with me, because it does circle around and back.
# translation:  那就跟我一起吧,因为它会四处游荡。
# Row:  250 , translating:  The Greeks famously called these divine attendant spirits of creativity "daemons."
# translation:  古希腊人称这些神灵为“达蒙”。
# Row:  256 , translating:  And everyone knew that this is how it functioned, right?
# translation:  每个人都知道这是怎么运作的,对吧?
# Row:  259 , translating:  If your work bombed, not entirely your fault, you know?
# translation:  如果你的工作被轰炸了,不是完全是你的错。
# Row:  263 , translating:  And I got to tell you, I think that was a huge error.
# translation:  我想说,这是一个很大的错误。
# Row:  265 , translating:  It's like asking somebody to swallow the sun.
# translation:  就像要人吞下太阳一样。
# Row:  268 , translating:  And, if this is true,  and I think it is true,  the question becomes, what now?
# translation:  如果这是真的,那么问题就变成了,现在呢?
# Row:  269 , translating:  Can we do this differently?
# translation:  我们能做点别的吗?
# Row:  271 , translating:  Maybe not.
# translation:  也许不是。
# Row:  274 , translating:  I'm not, probably, going to bring you all along with me on this.
# translation:  我可能不会把你们都带到这里来。
# Row:  276 , translating:  Why not think about it this way?
# translation:  为什么不这样想呢?
# Row:  279 , translating:  And, in fact, can sometimes feel downright paranormal.
# translation:  事实上,有时会感觉很不正常。
# Row:  281 , translating:  And she said it was like a thunderous train of air.
# translation:  她说那就像一列巨大的空中列车。
# Row:  282 , translating:  And it would come barreling down at her over the landscape.
# translation:  它会向她伸出手来。
# Row:  283 , translating:  And she felt it coming, because it would shake the earth under her feet.
# translation:  她感觉到它来了,因为它会震动她脚下的地球。
# Row:  294 , translating:  And I would imagine that a lot of you have too.
# translation:  我想你们很多人也一样。
# Row:  296 , translating:  And what is that thing?
# translation:  那是什么呢?
# Row:  302 , translating:  He doesn't have a piece of paper, or a pencil, or a tape recorder.
# translation:  他没有一张纸,或者铅笔,或录音机。
# Row:  305 , translating:  And instead of panicking, he just stopped.
# translation:  而不是惊慌失措,他停了下来。
# Row:  306 , translating:  He just stopped that whole mental process and he did something completely novel.
# translation:  他停止了整个心理过程, 做了一些完全新颖的事情。
# Row:  308 , translating:  "Do I look like I can write down a song right now?
# translation:  “我现在能写一首歌吗?”
# Row:  310 , translating:  Otherwise, go bother somebody else today.
# translation:  否则,今天就去麻烦别人了。
# Row:  311 , translating:  Go bother Leonard Cohen."
# translation:  麻烦伦纳德·科恩。”
# Row:  312 , translating:  And his whole work process changed after that.
# translation:  之后他的整个工作流程都发生了变化。
# Row:  313 , translating:  Not the work, the work was still oftentimes as dark as ever.
# translation:  不是工作,还是像以前一样黑暗。
# Row:  318 , translating:  Not just bad, but the worst book ever written.
# translation:  不光是坏书,更是有史以来最差的书。
# Row:  319 , translating:  And I started to think I should just dump this project.
# translation:  我开始想,我应该把这个项目扔掉。
# Row:  320 , translating:  But then I remembered Tom talking to the open air and I tried it.
# translation:  但我记得汤姆在开阔的空气中说话,然后我试了一下。
# Row:  324 , translating:  If you want it to be better, you've got to show up and do your part of the deal.
# translation:  如果你想做得更好,你就必须参与其中。
# Row:  325 , translating:  But if you don't do that, you know what, the hell with it.
# translation:  但是如果你不这样做,你知道吗?
# Row:  333 , translating:  And all of a sudden, he would no longer appear to be merely human.
# translation:  突然间,他不再是人类了。
# Row:  337 , translating:  That's God, you know.
# translation:  那是上帝,你知道的。
# Row:  340 , translating:  Which is great, because we need that.
# translation:  那太棒了,因为我们需要它。
# Row:  344 , translating:  This is hard.
# translation:  这是很难的。
# Row:  348 , translating:  And, you know, if we think about it this way, it starts to change everything.
# translation:  如果我们这样想,它就会改变一切。
# Row:  351 , translating:  Don't be daunted. Just do your job.
# translation:  不要害怕。做你的工作。
# Row:  352 , translating:  Continue to show up for your piece of it, whatever that might be.
# translation:  继续展示你的作品,不管它是什么。
# Row:  353 , translating:  If your job is to dance, do your dance.
# translation:  如果你的工作是跳舞,那就跳吧。
# Row:  355 , translating:  And if not, do your dance anyhow.
# translation:  如果不是,那就跳舞吧。
# Row:  356 , translating:  And "Olé!" to you, nonetheless.
# translation:  还有“Olé”
# Row:  357 , translating:  I believe this and I feel that we must teach it.
# translation:  我相信这一点,我觉得我们必须教它。
# Row:  359 , translating:  Thank you.
# translation:  谢谢。
# Row:  360 , translating:  Thank you.
# translation:  谢谢。
# Row:  361 , translating:  June Cohen: Olé!
# translation:  朱恩·科恩:奥莱!
# Row:  364 , translating:  So, we've always been trying to ask big questions.
# translation:  所以,我们一直试图问一些大问题。
# Row:  365 , translating:  "What is life?" is something that I think many biologists  have been trying to understand  at various levels.
# translation:  “生命是什么?” 是许多生物学家在不同层面上试图理解的。
# Row:  366 , translating:  We've tried various approaches,  paring it down to minimal components.
# translation:  我们尝试了各种方法, 把它归结为最小的组件。
# Row:  373 , translating:  And so we started down the road of:  can we synthesize a chromosome?
# translation:  于是我们开始了: 我们能不能合成一个染色体?
# Row:  374 , translating:  Can chemistry permit making  these really large molecules  where we've never been before?
# translation:  化学能不能创造出我们从未有过的巨大分子呢?
# Row:  375 , translating:  And if we do, can we boot up a chromosome?
# translation:  如果我们这样做,我们能启动染色体吗?
# Row:  376 , translating:  A chromosome, by the way, is just a piece of inert chemical material.
# translation:  顺便说一下,染色体只是一小块惰性化学材料。
# Row:  377 , translating:  So, our pace of digitizing life has been increasing  at an exponential pace.
# translation:  因此,我们把生命数字化的速度 以指数速度增长。
# Row:  379 , translating:  We started this over 15 years ago.
# translation:  我们是在15年前开始的。
# Row:  380 , translating:  It took several stages, in fact,  starting with a bioethical review before we did the first experiments.
# translation:  实际上,在进行第一次实验之前,它经历了几个阶段。
# Row:  381 , translating:  But it turns out synthesizing DNA  is very difficult.
# translation:  但是合成DNA是非常困难的。
# Row:  383 , translating:  So we had to create a new method  for putting these little pieces together and correct all the errors.
# translation:  所以我们必须创造一种新的方法 把这些小片段放在一起,并纠正所有的错误。
# Row:  384 , translating:  And this was our first attempt, starting with the digital information  of the genome of phi X174.
# translation:  这是我们第一次尝试,从数码信息开始。
# Row:  385 , translating:  It's a small virus that kills bacteria.
# translation:  一种能杀死细菌的小病毒。
# Row:  388 , translating:  The viral particles then were released from the cells  and came back and killed the E. coli.
# translation:  病毒颗粒从细胞中释放出来,杀死了大肠杆菌。
# Row:  389 , translating:  I was talking to the oil industry recently  and I said they clearly understood that model.
# translation:  我最近和石油行业谈过,他们说他们很清楚这个模型。
# Row:  392 , translating:  Design is critical,  and if you're starting with digital information in the computer,  that digital information has to be really accurate.
# translation:  设计是至关重要的,如果你从计算机里的数字信息开始, 这个数字信息必须非常准确。
# Row:  396 , translating:  We design unique elements into this.
# translation:  我们设计了独特的元素。
# Row:  397 , translating:  You may have read that we put watermarks in.
# translation:  你可能读过我们把水印进去。
# Row:  398 , translating:  Think of this:  we have a four-letter genetic code -- A, C, G and T.
# translation:  想一想:我们有四字母的基因密码--A,C,G和T。
# Row:  400 , translating:  So we can use the genetic code to write out words,  sentences, thoughts.
# translation:  我们可以用基因编码来写出单词,句子,想法。
# Row:  401 , translating:  Initially, all we did was autograph it.
# translation:  最初,我们所做的只是自画像。
# Row:  402 , translating:  Some people were disappointed there was not poetry.
# translation:  有些人失望的是,那不是诗。
# Row:  406 , translating:  We're trying to get to the point of automation.
# translation:  我们正在努力实现自动化。
# Row:  407 , translating:  So, this looks like a basketball playoff.
# translation:  看起来就像一个篮球季后赛。
# Row:  409 , translating:  We knew there's a mechanism called homologous recombination  that biology uses to repair DNA  that can put pieces together.
# translation:  我们知道有一种叫做同质重组的机制, 生物学用它来修复DNA。
# Row:  411 , translating:  You can see in the top panel, its chromosome just gets blown apart.
# translation:  你可以在上面看到,它的染色体被撕裂了。
# Row:  412 , translating:  Twelve to 24 hours later, it put it  back together exactly as it was before.
# translation:  12到24小时后,它又回到了原来的样子。
# Row:  413 , translating:  We have thousands of organisms that can do this.
# translation:  我们有数以千计的生物可以做到这点。
# Row:  414 , translating:  These organisms can be totally desiccated;  they can live in a vacuum.
# translation:  这些生物可以完全枯竭; 它们可以在真空中生存。
# Row:  415 , translating:  I am absolutely certain that life can exist in outer space,  move around, find a new aqueous environment.
# translation:  我绝对确信生命可以在外太空存在, 可以四处移动,找到新的水生环境。
# Row:  416 , translating:  In fact, NASA has shown a lot of this is out there.
# translation:  事实上,美国宇航局已经展示了很多这样的例子。
# Row:  418 , translating:  This is not an electron micrograph;  this is just a regular photomicrograph.
# translation:  这不是电子图;这只是一个普通的微图像。
# Row:  419 , translating:  It's such a large molecule  we can see it with a light microscope.
# translation:  这是一个很大的分子,我们可以用光显微镜来观察它。
# Row:  420 , translating:  These are pictures over about a six-second period.
# translation:  这些照片大约是六秒钟。
# Row:  421 , translating:  So, this is the publication we had just a short while ago.
# translation:  这就是我们不久前发表的文章。
# Row:  423 , translating:  It's over 300 million molecular weight.
# translation:  超过3亿分子重。
# Row:  425 , translating:  Well, how do we boot up a chromosome? How do we activate this?
# translation:  那么,我们如何启动一个染色体? 我们如何激活它呢?
# Row:  426 , translating:  Obviously, with a virus it's pretty simple;  it's much more complicated dealing with bacteria.
# translation:  很显然,对付病毒要简单得多。
# Row:  430 , translating:  The new chromosome went into the cell.
# translation:  新的染色体进入细胞。
# Row:  431 , translating:  In fact, we thought this might be as far as it went,  but we tried to design the process a little bit further.
# translation:  实际上,我们认为这个过程可能更远一些。
# Row:  432 , translating:  This is a major mechanism of evolution right here.
# translation:  这是进化的一个主要机制。
# Row:  434 , translating:  So, people who think of evolution  as just one gene changing at a time  have missed much of biology.
# translation:  所以,那些认为进化只是一个基因一次的改变的人 忽略了很多生物学。
# Row:  435 , translating:  There are enzymes called restriction enzymes  that actually digest DNA.
# translation:  有限制性酶,它们能消化DNA。
# Row:  436 , translating:  The chromosome that was in the cell  doesn't have one;  the chromosome we put in does.
# translation:  细胞里没有染色体;我们放的染色体有。
# Row:  438 , translating:  It turned blue because of the genes we put in it.
# translation:  它变成了蓝色,因为我们放进去的基因。
# Row:  442 , translating:  Now I've argued, this is not genesis;  this is building on three and a half billion years of evolution.
# translation:  我一直认为,这不是创世纪; 而是建立在35亿年的进化之上。
# Row:  444 , translating:  Why do this?
# translation:  为什么要这么做?
# Row:  445 , translating:  I think this is pretty obvious in terms of some of the needs.
# translation:  我认为这在一定程度上是显而易见的。
# Row:  446 , translating:  We're about to go from six and a half  to nine billion people over the next 40 years.
# translation:  未来40年,我们将会从65亿人发展到90亿人。
# Row:  447 , translating:  To put it in context for myself:  I was born in 1946.
# translation:  用我自己的话来说: 我生于1946年。
# Row:  449 , translating:  We have trouble feeding, providing fresh, clean water,  medicines, fuel  for the six and a half billion.
# translation:  我们很难为这65亿人提供新鲜、清洁的水,药品和燃料。
# Row:  450 , translating:  It's going to be a stretch to do it for nine.
# translation:  这将是一个9小时的拉伸。
# Row:  452 , translating:  When we try to think of biological processes  or any process to replace that,  it's going to be a huge challenge.
# translation:  当我们试着去思考生物过程,或者任何可以取代它的过程时, 这将会是一个巨大的挑战。
# Row:  453 , translating:  Then of course, there's all that  CO2 from this material  that ends up in the atmosphere.
# translation:  当然,所有来自这种物质的二氧化碳 最终都会进入大气层。
# Row:  455 , translating:  The electronics industry only had a dozen or so components,  and look at the diversity that came out of that.
# translation:  电子工业只有几十个部件,看看其中的多样性。
# Row:  456 , translating:  We're limited here primarily  by a biological reality  and our imagination.
# translation:  我们主要受到生物现实和想象力的限制。
# Row:  458 , translating:  We have the ability now to build a large robot  that can make a million chromosomes a day.
# translation:  现在我们有能力制造一个大型的机器人, 每天可以产生100万个染色体。
# Row:  460 , translating:  And it's just standard selection:  we can select for viability,  chemical or fuel production,  vaccine production, etc.
# translation:  这只是标准的选择:我们可以选择可行性, 化学或燃料生产,疫苗生产等等。
# Row:  462 , translating:  You know, we don't know necessarily what it'll look like:  we know exactly what their genetic code looks like.
# translation:  我们不一定知道它们会是什么样子: 我们知道它们的基因密码是什么样的。
# Row:  463 , translating:  We're focusing on now fourth-generation fuels.
# translation:  我们现在关注的是第四代燃料。
# Row:  464 , translating:  You've seen recently, corn to ethanol  is just a bad experiment.
# translation:  你最近看到的,玉米到乙醇只是个坏实验。
# Row:  467 , translating:  And we think we'll have the first fourth-generation fuels  in about 18 months.
# translation:  我们将有第四代燃料在18个月左右。
# Row:  468 , translating:  Sunlight and CO2 is one method ...
# translation:  阳光和二氧化碳是一种方法。
# Row:  469 , translating:  but in our discovery around the world,  we have all kinds of other methods.
# translation:  但在全世界的发现中,我们还有其他各种方法。
# Row:  470 , translating:  This is an organism we described in 1996.
# translation:  这是我们在1996年描述的有机体。
# Row:  471 , translating:  It lives in the deep ocean,  about a mile and a half deep,  almost at boiling-water temperatures.
# translation:  它生活在深海中,大约有1.5英里深, 几乎处于沸腾的温度下。
# Row:  472 , translating:  It takes CO2 to methane  using molecular hydrogen as its energy source.
# translation:  它使用分子氢气作为其能源。
# Row:  476 , translating:  But also, we're now working on using these same tools  to come up with instant sets of vaccines.
# translation:  但是,我们也在用同样的工具 来设计一整套疫苗。
# Row:  478 , translating:  I think that can be changed  by building combinatorial vaccines in advance.
# translation:  我认为这可以通过预先建立组合疫苗来改变。
# Row:  487 , translating:  It's also very flexible architecture.
# translation:  它也是一个非常灵活的建筑。
# Row:  488 , translating:  This is an entire book, so this is an example of non-image data.
# translation:  这是整本书,这是一个非图像数据的例子。
# Row:  489 , translating:  This is "Bleak House" by Dickens. Every column is a chapter.
# translation:  这是狄更斯的《白屋》。每一列都是一章。
# Row:  491 , translating:  Maybe this is an artificial way to read an e-book.
# translation:  也许这是一种人工阅读电子书的方法。
# Row:  492 , translating:  I wouldn't recommend it.
# translation:  我不会推荐它。
# Row:  493 , translating:  This is a more realistic case, an issue of The Guardian.
# translation:  这是一个更现实的例子,《卫报》的问题。
# Row:  494 , translating:  Every large image is the beginning of a section.
# translation:  每个大图像都是一个部分的开始。
# Row:  496 , translating:  We've done something  with the corner of this particular issue of The Guardian.
# translation:  我们在“卫报”这个特别的议题上做了些什么。
# Row:  498 , translating:  If you want to see the features of this car, you can see it here.
# translation:  如果你想看看这辆车的特点,你可以在这里看到。
# Row:  499 , translating:  Or other models, or even technical specifications.
# translation:  或者其他模型,甚至技术规格。
# Row:  500 , translating:  And this really gets at some of these ideas  about really doing away with those limits on screen real estate.
# translation:  这些想法真的可以消除 屏幕房地产的限制。
# Row:  501 , translating:  We hope that this means no more pop-ups  and other rubbish like that -- shouldn't be necessary.
# translation:  我们希望这不会再有弹出和其他的垃圾了-- 这不应该是必要的。
# Row:  502 , translating:  Of course, mapping is one of those obvious applications  for a technology like this.
# translation:  当然,地图是这类技术的明显应用之一。
# Row:  504 , translating:  But those are all the roads in the U.S.
# translation:  但在美国,这些都是道路。
# Row:  505 , translating:  superimposed on top of a NASA geospatial image.
# translation:  置于NASA的地理空间图像之上。
# Row:  506 , translating:  So let's pull up, now, something else.
# translation:  那么,让我们拉上去,别的什么东西。
# Row:  507 , translating:  This is actually live on the Web now; you can go check it out.
# translation:  实际上这是在网络上,你可以去看看。
# Row:  508 , translating:  This is a project called Photosynth, which marries two different technologies.
# translation:  这是一个叫做Photosynth的项目, 它结合了两种不同的技术。
# Row:  510 , translating:  and Rick Szeliski at Microsoft Research.
# translation:  还有微软的Rick Szeliski。
# Row:  511 , translating:  A very nice collaboration.
# translation:  非常好的合作。
# Row:  512 , translating:  And so this is live on the Web. It's powered by Seadragon.
# translation:  这是在网络上直播的,由Seadragon提供动力。
# Row:  514 , translating:  But the spatial arrangement of the images here is actually meaningful.
# translation:  但是这些图像的空间排列其实是有意义的。
# Row:  516 , translating:  So you see elements here of stabilized slide-show or panoramic imaging,  and these things have all been related spatially.
# translation:  这里你可以看到稳定的幻灯片或全景成像, 这些东西都和空间有关。
# Row:  517 , translating:  I'm not sure if I have time to show you any other environments.
# translation:  我不确定我是否有时间给你们展示其他环境。
# Row:  518 , translating:  Some are much more spatial.
# translation:  有些更具有空间性。
# Row:  520 , translating:  We had to worry about the lawyers and so on.
# translation:  我们不得不担心律师,等等。
# Row:  521 , translating:  This is a reconstruction of Notre Dame Cathedral  that was done entirely computationally from images scraped from Flickr.
# translation:  这是圣母大教堂的重建, 完全是用Flickr上的图像完成的。
# Row:  523 , translating:  And each of these orange cones represents an image  that was discovered to belong to this model.
# translation:  这些橙色的圆柱代表了 一个被发现属于这个模型的图像。
# Row:  524 , translating:  And so these are all Flickr images,  and they've all been related spatially in this way.
# translation:  这些都是Flickr的图片, 它们都以这种方式在空间上相关联。
# Row:  525 , translating:  We can just navigate in this very simple way.
# translation:  我们可以用这种简单的方式导航。
# Row:  526 , translating:  You know, I never thought that I'd end up working at Microsoft.
# translation:  我从没想过我会在微软工作。
# Row:  527 , translating:  It's very gratifying to have this kind of reception here.
# translation:  很高兴能有这样的接待。
# Row:  530 , translating:  Somewhere in here there is actually a series of photographs -- here we go.
# translation:  这里有一系列的照片。
# Row:  531 , translating:  This is actually a poster of Notre Dame that registered correctly.
# translation:  这是一张圣母院的海报,注册正确。
# Row:  532 , translating:  We can dive in from the poster  to a physical view of this environment.
# translation:  我们可以从海报到这个环境的物理视图。
# Row:  533 , translating:  What the point here really is  is that we can do things with the social environment.
# translation:  这里的重点是,我们能用社会环境做些什么。
# Row:  535 , translating:  Those photos become linked, and they make something emergent  that's greater than the sum of the parts.
# translation:  这些照片变得关联起来, 它们产生的比部分的总和还要大。
# Row:  536 , translating:  You have a model that emerges of the entire Earth.
# translation:  整个地球都有一个模型。
# Row:  537 , translating:  Think of this as the long tail to Stephen Lawler's Virtual Earth work.
# translation:  把这看作是史蒂芬·劳勒的虚拟地球作品。
# Row:  538 , translating:  And this is something that grows in complexity as people use it,  and whose benefits become greater to the users as they use it.
# translation:  当人们使用它时,它的好处会越来越大。
# Row:  539 , translating:  Their own photos are getting tagged with meta-data that somebody else entered.
# translation:  他们自己的照片被别人输入的元数据标记。
# Row:  542 , translating:  Thank you so much.
# translation:  非常感谢。
# Row:  545 , translating:  It's doing that based on the content inside the images.
# translation:  它基于图像中的内容。
# Row:  546 , translating:  And that gets really exciting when you think about the richness  of the semantic information a lot of images have.
# translation:  当你想到语义信息的丰富性时,你会感到非常兴奋。
# Row:  548 , translating:  What if that picture links to all of your pictures?
# translation:  如果这张照片链接到你所有的图片呢?
# Row:  549 , translating:  The amount of semantic interconnection and richness  that comes out of that is really huge.
# translation:  语义上的联系和丰富性是巨大的。
# Row:  550 , translating:  It's a classic network effect.
# translation:  这是一个经典的网络效应。
# Row:  551 , translating:  CA: Truly incredible. Congratulations.
# translation:  克里斯·安德森:真是太不可思议了。
# Row:  554 , translating:  the consequence of one particular set of adaptive choices  that our lineage made, albeit successfully, many generations ago.
# translation:  一个特定的适应性选择的后果, 虽然是成功的,许多代以前。
# Row:  555 , translating:  And of course, we all share the same adaptive imperatives.
# translation:  当然,我们都有同样的适应性。
# Row:  556 , translating:  We're all born. We all bring our children into the world.
# translation:  我们都是天生的。我们把孩子带进了这个世界。
# Row:  557 , translating:  We go through initiation rites.
# translation:  我们通过启蒙仪式。
# Row:  559 , translating:  But what's interesting is the unique cadence of the song,  the rhythm of the dance in every culture.
# translation:  但有趣的是这首歌的独特节奏, 每一种文化中舞蹈的节奏。
# Row:  561 , translating:  Everest, the goddess mother of the world.
# translation:  珠穆朗玛,世界之母。
# Row:  563 , translating:  And this is an idea, if you think about it,  can only fill you with hope.
# translation:  如果你仔细想想,这个想法只能充满希望。
# Row:  566 , translating:  The ethnosphere is humanity's great legacy.
# translation:  种族是人类的伟大遗产。
# Row:  567 , translating:  It's the symbol of all that we are  and all that we can be as an astonishingly inquisitive species.
# translation:  它象征着我们, 也象征着我们作为一个令人惊叹的物种。
# Row:  570 , translating:  And the great indicator of that, of course, is language loss.
# translation:  当然,最大的指标是语言流失。
# Row:  571 , translating:  When each of you in this room were born,  there were 6,000 languages spoken on the planet.
# translation:  当你们每一个人出生时,地球上有6000种语言。
# Row:  572 , translating:  Now, a language is not just a body of vocabulary  or a set of grammatical rules.
# translation:  现在,语言不仅仅是一个词汇体 或者一套语法规则。
# Row:  573 , translating:  A language is a flash of the human spirit.
# translation:  语言是人类精神的闪光。
# Row:  574 , translating:  It's a vehicle through which the soul of each particular culture  comes into the material world.
# translation:  它是每个特定文化的灵魂进入物质世界的载体。
# Row:  575 , translating:  Every language is an old-growth forest of the mind,  a watershed, a thought, an ecosystem of spiritual possibilities.
# translation:  每一种语言都是心灵的古老森林, 一个分水岭,一个充满灵性可能性的生态系统。
# Row:  577 , translating:  They're no longer being taught to babies,  which means, effectively, unless something changes,  they're already dead.
# translation:  他们不再被教导, 也就是说,除非有什么改变,他们已经死了。
# Row:  581 , translating:  Let's make it Kogi."
# translation:  让它Kogi。”
# Row:  582 , translating:  And you'll suddenly discover what it would be like  to be unable to speak your own language.
# translation:  你就会突然发现 不能说你自己的语言。
# Row:  588 , translating:  They simply listen and then begin to speak.
# translation:  他们只是听着然后开始说话。
# Row:  590 , translating:  In 1957, five missionaries attempted contact  and made a critical mistake.
# translation:  1957年,五位传教士试图联系并犯了一个重大错误。
# Row:  593 , translating:  But the Waorani didn't just spear outsiders.
# translation:  但瓦拉尼人不仅仅只是局外人。
# Row:  594 , translating:  They speared each other.
# translation:  他们互相推搡。
# Row:  595 , translating:  54 percent of their mortality was due to them spearing each other.
# translation:  54%的死亡是因为他们互相鞭打。
# Row:  600 , translating:  On the contrary, it's a complex metaphysical worldview.
# translation:  相反,这是一个复杂的形而上学的世界观。
# Row:  601 , translating:  It's interesting.
# translation:  很有趣。
# Row:  602 , translating:  If I asked you to name the great religions of the world,  what would you say?
# translation:  如果我请你给世界各大宗教起名字,你会怎么说?
# Row:  603 , translating:  Christianity, Islam, Buddhism, Judaism, whatever.
# translation:  基督教,伊斯兰教,犹太教,等等。
# Row:  606 , translating:  So, the living give birth to the spirits.
# translation:  于是,活人就生了灵魂。
# Row:  608 , translating:  That's why the Voodooists like to say  that "You white people go to church and speak about God.
# translation:  这就是为什么伏地魔喜欢说 “你们白人去教堂谈论上帝。
# Row:  609 , translating:  We dance in the temple and become God."
# translation:  我们在寺庙里跳舞,成为上帝。”
# Row:  610 , translating:  And because you are possessed, you are taken by the spirit --  how can you be harmed?
# translation:  因为你被精神所占据, 你怎么会受到伤害呢?
# Row:  614 , translating:  In a bloodstained continent,  these people alone were never conquered by the Spanish.
# translation:  在一片鲜血的大陆上, 只有这些人从未被西班牙人征服过。
# Row:  615 , translating:  To this day, they remain ruled by a ritual priesthood  but the training for the priesthood is rather extraordinary.
# translation:  直到今天,他们仍然被一个仪式的祭司统治着 但牧师的训练是相当了不起的。
# Row:  619 , translating:  It is that beautiful. It is yours to protect."
# translation:  太美了,是你们的保护。”
# Row:  621 , translating:  Now, this level of intuition becomes very important.
# translation:  现在,直觉变得非常重要。
# Row:  623 , translating:  Well, indigenous people are neither sentimental  nor weakened by nostalgia.
# translation:  土著人既没有感情,也没有怀旧。
# Row:  625 , translating:  Now, what does that mean?
# translation:  这意味着什么?
# Row:  627 , translating:  Whether it's the abode of a spirit or a pile of ore is irrelevant.
# translation:  不管是精神还是一堆矿石,都无关紧要。
# Row:  628 , translating:  What's interesting is the metaphor that defines the relationship  between the individual and the natural world.
# translation:  有趣的是,这个比喻定义了个人和自然界之间的关系。
# Row:  629 , translating:  I was raised in the forests of British Columbia  to believe those forests existed to be cut.
# translation:  我是在不列颠哥伦比亚省的森林里长大的, 相信这些森林是可以被砍伐的。
# Row:  632 , translating:  It's a photograph I took in the Northwest Amazon just last April.
# translation:  这是我去年四月在亚马逊西北部拍摄的照片。
# Row:  635 , translating:  called Psychotria viridis.
# translation:  叫做Psychotria viridis。
# Row:  640 , translating:  because they're denatured by an enzyme  found naturally in the human gut called monoamine oxidase.
# translation:  因为它们被一种叫做一氧化二氮的酶破坏了。
# Row:  641 , translating:  They can only be taken orally if taken in conjunction  with some other chemical that denatures the MAO.
# translation:  它们只能被口服, 如果与一些其他化学物质结合使用的话。
# Row:  644 , translating:  Well, we use that great euphemism, "trial and error,"  which is exposed to be meaningless.
# translation:  嗯,我们用“试错”这句话来形容它毫无意义。
# Row:  645 , translating:  But you ask the Indians, and they say, "The plants talk to us."
# translation:  但是你问印第安人,他们说,“植物会跟我们说话。”
# Row:  646 , translating:  Well, what does that mean?
# translation:  那是什么意思呢?
# Row:  648 , translating:  And then you ask them how they establish their taxonomy  and they say, "I thought you knew something about plants.
# translation:  然后你问他们如何建立他们的分类法,他们说,“我以为你知道一些关于植物的东西。
# Row:  649 , translating:  I mean, don't you know anything?" And I said, "No."
# translation:  你知道吗?”我说,“不。”
# Row:  653 , translating:  All cultures through all time  have constantly been engaged in a dance  with new possibilities of life.
# translation:  所有的文化都不断地参与到舞蹈中, 带着新的生命可能性。
# Row:  654 , translating:  And the problem is not technology itself.
# translation:  问题不在于技术本身。
# Row:  659 , translating:  it's the disease entities that have come in,  in the wake of the discovery of gold.
# translation:  是那些在发现黄金之后出现的病菌。
# Row:  664 , translating:  That meant he was instantly killed  at the time of the Chinese invasion.
# translation:  这意味着他在中国入侵时被立即杀死。
# Row:  665 , translating:  His uncle fled with His Holiness in the Diaspora  that took the people to Nepal.
# translation:  他的叔叔逃到了尼泊尔的散居地。
# Row:  667 , translating:  The sister who had done that brave deed  was put into an education camp.
# translation:  做了那件勇敢的事的姐姐被送进了教育营。
# Row:  669 , translating:  The pain of Tibet can be impossible to bear,  but the redemptive spirit of the people is something to behold.
# translation:  西藏的痛苦是无法忍受的, 但人民的救赎精神却是值得注意的。
# Row:  674 , translating:  The modern industrial world as we know it  is barely 300 years old.
# translation:  我们所知的现代工业世界 只有300年的历史。
# Row:  680 , translating:  This old man's grandfather refused to go.
# translation:  这位老人的爷爷拒绝了。
# Row:  681 , translating:  The family, fearful for his life, took away all of his weapons,  all of his tools.
# translation:  他的家人,害怕他的生活,拿走了所有的武器,所有的工具。
# Row:  682 , translating:  Now, you must understand that the Inuit did not fear the cold;  they took advantage of it.
# translation:  现在,你必须明白因纽特人并不害怕寒冷;他们利用了它。
# Row:  683 , translating:  The runners of their sleds were originally made of fish  wrapped in caribou hide.
# translation:  他们的雪橇最初是用鱼包装成的。
# Row:  690 , translating:  It's our new homeland. It's called Nunavut.
# translation:  这就是我们的新家园。它叫做Nunavut。
# Row:  691 , translating:  It's an independent territory. They control all mineral resources.
# translation:  这是一个独立的领土。他们控制着所有的矿产资源。
# Row:  692 , translating:  An amazing example of how a nation-state  can seek restitution with its people.
# translation:  一个民族国家如何与人民一起寻求恢复。
# Row:  694 , translating:  They're homelands of somebody.
# translation:  他们是某人的故乡。
# Row:  698 , translating:  156 nations carry our television channel.
# translation:  156个国家拥有我们的电视频道。
# Row:  699 , translating:  Our magazines are read by millions.
# translation:  我们的杂志被数以百万计的人阅读。
# Row:  701 , translating:  where all of the wisdom of all peoples  can contribute to our collective well-being.
# translation:  所有人民的智慧 都能为我们的集体幸福做出贡献。
# Row:  702 , translating:  Thank you very much.
# translation:  非常感谢。
# Row:  704 , translating:  But I want to start with what I call the "official dogma."
# translation:  我想从“官方的教条”开始。
# Row:  705 , translating:  The official dogma of what?
# translation:  官方的教条是什么?
# Row:  706 , translating:  The official dogma of all Western industrial societies.
# translation:  西方工业社会的官方教条。
# Row:  708 , translating:  The reason for this is both that freedom is in and of itself good,  valuable, worthwhile, essential to being human.
# translation:  因为自由本身就是好的,有价值的,对人类来说是必不可少的。
# Row:  710 , translating:  The way to maximize freedom is to maximize choice.
# translation:  最大化自由的方法就是最大限度地选择。
# Row:  713 , translating:  And it's also deeply embedded in our lives.
# translation:  它也深深地植根于我们的生活中。
# Row:  714 , translating:  I'll give you some examples of what modern progress has made possible for us.
# translation:  我给你们举几个例子, 说明现代进步给我们带来了什么。
# Row:  715 , translating:  This is my supermarket. Not such a big one.
# translation:  这是我的超市。不是那么大。
# Row:  716 , translating:  I want to say just a word about salad dressing.
# translation:  我想说一个关于沙拉打扮的词。
# Row:  718 , translating:  So this is what the supermarket is like.
# translation:  这就是超市的样子。
# Row:  721 , translating:  You've got to admit that's a lot of choice.
# translation:  你必须承认这有很多选择。
# Row:  722 , translating:  In other domains -- the world of communications.
# translation:  在其他领域——通讯的世界。
# Row:  724 , translating:  You rented your phone. You didn't buy it.
# translation:  你租了你的手机,你没有买。
# Row:  725 , translating:  One consequence of that, by the way, is that the phone never broke.
# translation:  顺便说一下,其中一个后果是电话从未断过。
# Row:  726 , translating:  And those days are gone.
# translation:  那些日子过去了。
# Row:  727 , translating:  We now have an almost unlimited variety of phones,  especially in the world of cell phones.
# translation:  现在我们有几乎无限的手机, 尤其是在手机的世界里。
# Row:  728 , translating:  These are cell phones of the future.
# translation:  这些是未来的手机。
# Row:  731 , translating:  And what this does  is it leads people to walk into their stores asking this question.
# translation:  这会让人们走进商店 问这个问题。
# Row:  732 , translating:  And do you know what the answer to this question now is?
# translation:  你知道这个问题的答案是什么吗?
# Row:  733 , translating:  The answer is "no."
# translation:  答案是“不”。
# Row:  734 , translating:  It is not possible to buy a cell phone that doesn't do too much.
# translation:  买一个没有太多功效的手机是不可能的。
# Row:  735 , translating:  So, in other aspects of life that are much more significant than buying things,  the same explosion of choice is true.
# translation:  所以,在生活中的其他方面 比购买东西更重要,同样的选择爆炸性是真的。
# Row:  738 , translating:  A has these benefits, and these risks.
# translation:  A有这些好处,还有这些风险。
# Row:  739 , translating:  B has these benefits, and these risks. What do you want to do?"
# translation:  B有这些好处和风险。你想做什么?”
# Row:  740 , translating:  And you say, "Doc, what should I do?"
# translation:  你说:“医生,我该怎么办?”
# Row:  741 , translating:  And the doc says, "A has these benefits and risks, and B has these benefits and risks.
# translation:  医生说,“A有这些好处和风险,B也有这些好处和风险。”
# Row:  742 , translating:  What do you want to do?"
# translation:  你想怎么做?”
# Row:  743 , translating:  And you say, "If you were me, Doc, what would you do?"
# translation:  你会说,“如果你是我,博士,你会怎么做?”
# Row:  744 , translating:  And the doc says, "But I'm not you."
# translation:  医生说:“我不是你。”
# Row:  747 , translating:  Why do they market to us if we can't buy them?
# translation:  如果我们买不到它们,为什么要向我们推销呢?
# Row:  750 , translating:  We don't inherit an identity; we get to invent it.
# translation:  我们不能继承一个身份,我们可以发明它。
# Row:  751 , translating:  And we get to re-invent ourselves as often as we like.
# translation:  我们会尽可能的重塑自己。
# Row:  754 , translating:  The only real choice was who,  not when, and not what you did after.
# translation:  唯一的选择是谁,而不是你之后做了什么。
# Row:  755 , translating:  Nowadays, everything is very much up for grabs.
# translation:  如今,一切都是可以抓取的。
# Row:  757 , translating:  And it's not because they're less smart,  and it's not because they're less diligent.
# translation:  不是因为他们不够聪明,也不是因为他们不那么勤奋。
# Row:  759 , translating:  Should I get married later? Should I have kids first, or a career first?"
# translation:  我应该结婚吗?我应该先生孩子,还是先有事业?”
# Row:  760 , translating:  All of these are consuming questions.
# translation:  这些都是消耗性的问题。
# Row:  762 , translating:  And indeed they should. These are important questions to answer.
# translation:  的确,他们应该回答这些重要的问题。
# Row:  765 , translating:  I'm not telling you about it because I want to use it.
# translation:  我不是在跟你们说这个,因为我想用它。
# Row:  769 , translating:  Should I respond to this email? Should I draft this letter?"
# translation:  我应该回复这封邮件吗?我应该起草这封信吗?”
# Row:  771 , translating:  So everywhere we look,  big things and small things, material things and lifestyle things,  life is a matter of choice.
# translation:  无论我们看到什么,大事小事,物质和生活方式的事物, 生活都是一个选择。
# Row:  772 , translating:  And the world we used to live in looked like this.
# translation:  我们曾经生活的世界是这样的。
# Row:  773 , translating:  That is to say, there were some choices,  but not everything was a matter of choice.
# translation:  也就是说,有一些选择, 但不是所有事情都是有选择的。
# Row:  774 , translating:  And the world we now live in looks like this.
# translation:  我们现在生活的世界是这样的。
# Row:  775 , translating:  And the question is, is this good news, or bad news?
# translation:  问题是,这是好消息还是坏消息?
# Row:  776 , translating:  And the answer is, "yes."
# translation:  答案是肯定的。
# Row:  777 , translating:  We all know what's good about it,  so I'm going to talk about what's bad about it.
# translation:  我们都知道什么是好的,所以我将要谈论什么是坏的。
# Row:  778 , translating:  All of this choice has two effects,  two negative effects on people.
# translation:  所有这些选择都对人们有两种负面影响。
# Row:  780 , translating:  With so many options to choose from,  people find it very difficult to choose at all.
# translation:  有如此多的选择,人们觉得很难去选择。
# Row:  783 , translating:  And what she found  is that for every 10 mutual funds the employer offered,  rate of participation went down two percent.
# translation:  她发现每提供10个共同基金, 参与率就下降了2%。
# Row:  786 , translating:  And then tomorrow,  and tomorrow, and tomorrow,  and of course tomorrow never comes.
# translation:  明天,明天,当然也永远不会到来。
# Row:  789 , translating:  So paralysis is a consequence of having too many choices.
# translation:  所以瘫痪是有太多选择的后果。
# Row:  790 , translating:  And I think it makes the world look like this.
# translation:  我认为这个世界是这样的。
# Row:  791 , translating:  You really want to get the decision right if it's for all eternity, right?
# translation:  你真的想做出正确的决定,如果它是永恒的,对吧?
# Row:  792 , translating:  You don't want to pick the wrong mutual fund, or the wrong salad dressing.
# translation:  你不会选择错误的互助基金, 或者不正确的沙拉打扮。
# Row:  794 , translating:  And there are several reasons for this.
# translation:  原因有几个。
# Row:  798 , translating:  Second, what economists call "opportunity costs."
# translation:  第二,经济学家称之为“机会成本”。
# Row:  802 , translating:  Here's what you're supposed to be thinking.
# translation:  这就是你要想的。
# Row:  803 , translating:  Here's this couple on the Hamptons.
# translation:  这是一对汉普顿夫妇。
# Row:  804 , translating:  Very expensive real estate.
# translation:  非常昂贵的房地产。
# Row:  805 , translating:  Gorgeous beach. Beautiful day. They have it all to themselves.
# translation:  美妙的海滩,美好的一天。他们自己拥有这一切。
# Row:  807 , translating:  I could be parking right in front of my building."
# translation:  我可以停在我大楼前面。”
# Row:  811 , translating:  Here's another example.   Now this cartoon makes a lot of points.
# translation:  这里是另一个例子。这幅漫画有很多要点。
# Row:  812 , translating:  It makes points about living in the moment as well,  and probably about doing things slowly.
# translation:  它也意味着活在当下,并且可能慢慢地做一些事情。
# Row:  814 , translating:  Third: escalation of expectations.
# translation:  第三,期望的升级。
# Row:  815 , translating:  This hit me when I went to replace my jeans.
# translation:  当我去换牛仔裤的时候,我被吓坏了。
# Row:  816 , translating:  I wear jeans almost all the time.
# translation:  我几乎总是穿牛仔裤。
# Row:  819 , translating:  And the shopkeeper said,  "Do you want slim fit, easy fit, relaxed fit?
# translation:  店主说:“你想要柔软的,容易的,放松的吗?”
# Row:  820 , translating:  You want button fly or zipper fly? You want stonewashed or acid-washed?
# translation:  你要按钮飞,还是起重机飞?要洗石头或酸奶吗?
# Row:  821 , translating:  Do you want them distressed?
# translation:  你想让他们痛苦吗?
# Row:  822 , translating:  You want boot cut, tapered, blah blah." On and on he went.
# translation:  你要剪靴子,带上磁带。”他继续说道。
# Row:  825 , translating:  I did better. All this choice made it possible for me to do better.
# translation:  我做得更好。这些选择使我能做得更好。
# Row:  826 , translating:  But -- I felt worse.
# translation:  但我感觉更糟。
# Row:  827 , translating:  Why? I wrote a whole book to try to explain this to myself.
# translation:  为什么?我写了整本书来向自己解释。
# Row:  829 , translating:  I had very low, no particular expectations when they only came in one flavor.
# translation:  我的期望值很低,只有一种味道。
# Row:  830 , translating:  When they came in 100 flavors, damn it, one of them should've been perfect.
# translation:  当它们有100种味道,该死的,其中一个应该是完美的。
# Row:  831 , translating:  And what I got was good, but it wasn't perfect.
# translation:  我得到的很好,但并不完美。
# Row:  834 , translating:  And what that's going to produce is less satisfaction with results,  even when they're good results.
# translation:  结果的满意度会降低, 即使效果好。
# Row:  835 , translating:  Nobody in the world of marketing knows this.
# translation:  营销界没有人知道这个。
# Row:  836 , translating:  Because if they did, you wouldn't all know what this was about.
# translation:  因为如果他们这么做了,你们可能不知道这是什么。
# Row:  839 , translating:  You will never be pleasantly surprised  because your expectations, my expectations, have gone through the roof.
# translation:  你永远不会感到惊讶, 因为你的期望,我的期待,已经过时了。
# Row:  842 , translating:  I couldn't have done better. I didn't settle.
# translation:  我不能做得更好。我没有安定下来。
# Row:  843 , translating:  But settling isn't always such a bad thing.
# translation:  但安定并不总是一件坏事。
# Row:  845 , translating:  What could you do?
# translation:  你能做什么?
# Row:  847 , translating:  It is equally clear that the answer to the question is "you."
# translation:  很明显,这个问题的答案是“你”。
# Row:  848 , translating:  You could have done better.
# translation:  你可以做得更好。
# Row:  849 , translating:  With a hundred different kinds of jeans on display,  there is no excuse for failure.
# translation:  有上百种不同的牛仔裤,没有理由失败。
# Row:  851 , translating:  Clinical depression has exploded in the industrial world in the last generation.
# translation:  临床抑郁症在上一代人中爆发了。
# Row:  853 , translating:  And so the net result is that we do better in general, objectively,  and we feel worse.
# translation:  总的来说,我们做得更好, 我们感觉更糟。
# Row:  854 , translating:  So let me remind you.
# translation:  让我提醒你们。
# Row:  857 , translating:  There's some magical amount. I don't know what it is.
# translation:  有些神奇的量。我不知道它是什么。
# Row:  858 , translating:  I'm pretty confident that we have long since passed the point  where options improve our welfare.
# translation:  我非常有信心,我们早就通过 选择来改善我们的福利。
# Row:  861 , translating:  Their problem is that they have too little.
# translation:  问题是他们太少了。
# Row:  862 , translating:  So the stuff I'm talking about is the peculiar problem of modern, affluent, Western societies.
# translation:  我所谈论的是 现代的,富裕的,西方社会的特殊问题。
# Row:  864 , translating:  What I'm telling you is that these expensive, complicated choices --  it's not simply that they don't help.
# translation:  我要告诉你们的是,这些昂贵而复杂的选择-- 不仅仅是它们无济于事。
# Row:  865 , translating:  They actually hurt.
# translation:  他们真的很伤人。
# Row:  866 , translating:  They actually make us worse off.
# translation:  实际上,他们让我们更糟。
# Row:  869 , translating:  You know, nothing is possible in this fishbowl."
# translation:  你知道,在这个鱼碗里什么都不可能。”
# Row:  870 , translating:  Impoverished imagination, a myopic view of the world --  and that's the way I read it at first.
# translation:  贫穷的想象力,我最初读的方式。
# Row:  871 , translating:  The more I thought about it, however,  the more I came to the view that this fish knows something.
# translation:  然而,我越是想到 这条鱼就知道些什么。
# Row:  873 , translating:  If you shatter this fishbowl so that everything is possible,  you decrease satisfaction.
# translation:  如果你打破了这个鱼碗,所有事情都有可能发生, 你就会降低满意度。
# Row:  874 , translating:  You increase paralysis, and you decrease satisfaction.
# translation:  会增加麻痹,降低满意度。
# Row:  875 , translating:  Everybody needs a fishbowl.
# translation:  每个人都需要一碗鱼。
# Row:  876 , translating:  This one is almost certainly too limited --  perhaps even for the fish, certainly for us.
# translation:  这几乎肯定是太有限了-- 甚至鱼,对我们来说也是。
# Row:  877 , translating:  But the absence of some metaphorical fishbowl is a recipe for misery,  and, I suspect, disaster.
# translation:  但是缺乏一些隐喻的鱼碗 是痛苦的秘诀,我怀疑,灾难。
# Row:  878 , translating:  Thank you very much.
# translation:  非常感谢。

# %%
prefix = 'translate to en: '

predictions = []

for index, pred in enumerate(first_predictions): # Translate back to zh
  print("Row: ", str(index), ", translating: ", pred)
  src_text = prefix + pred
  input_ids = tokenizer(src_text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids.to(device)
  generated_tokens = model.generate(input_ids)
  translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
  print("translation: ", translation)
  predictions.append(translation)
# Out:
# Row:  0 , translating:  但是这低估了这个问题的严重性, 因为它没有显示冰的厚度。
# translation:  But this underestimates the severity of the problem, because it doesn't show the thickness of the ice.
# Row:  1 , translating:  从某种意义上说,北极冰盖是全球气候系统的跳动中心。
# translation:  In a sense, the Arctic ice sheet is the beating center of the global climate system.
# Row:  2 , translating:  它在冬天扩张,在夏天收缩。
# translation:  It expands in winter, contracting in summer.
# Row:  3 , translating:  下一张幻灯片将展示过去25年里发生的事情。
# translation:  The next slide will show what has happened over the past 25 years.
# Row:  4 , translating:  永久性冰被标记为红色。
# translation:  The permanent ice is marked with red.
# Row:  5 , translating:  25年过去了。
# translation:  25年过去了。
# Row:  6 , translating:  与全球变暖的污染总量相比, 如果跨过这个转折点,这一数量可以翻一番。
# translation:  Compared to the total amount of global warming pollution, this number could be doubled.
# Row:  7 , translating:  在阿拉斯加的一些浅湖里, 甲烷正积极地从水中涌出。
# translation:  In some shallow lakes in Alaska, methane is actively pouring out of the water.
# Row:  8 , translating:  阿拉斯加大学的凯蒂·沃尔特教授去年冬天去了另一个浅湖。
# translation:  Katie Walter of the University of Alaska went to another shallow lake last winter.
# Row:  9 , translating:  视频:哇!戈尔:没问题。
# translation:  Video: Wow! Gore: OK.
# Row:  10 , translating:  其中一个原因是,这个巨大的热汇从北边向格陵兰岛升温。
# translation:  One of the reasons for this is that huge heat sinks are warming up from the north to Greenland.
# Row:  11 , translating:  这是一年一度的河水融化。
# translation:  The river melts every year.
# Row:  12 , translating:  但它的数量比以往任何时候都要大。
# translation:  But it's bigger than ever.
# Row:  13 , translating:  这是格陵兰西南部的Kangerlussuaq河。
# translation:  This is the Kangerlussuaq River in south-west Greenland.
# Row:  14 , translating:  如果你想知道海平面是如何从陆地冰层融化而上升的, 那就是它到达海洋的地方。
# translation:  If you want to know how sea level rises from the melting of land ice, that's where it reaches the ocean.
# Row:  15 , translating:  这些流动正在迅速增加。
# translation:  These flows are increasing rapidly.
# Row:  16 , translating:  在地球的另一端,南极是地球上最大的冰块。
# translation:  At the other end of the planet, Antarctica is the largest ice block on Earth.
# Row:  17 , translating:  上个月,科学家报告了整个大陆的负冰平衡。
# translation:  Last month, scientists reported negative ice balances across the continent.
# Row:  18 , translating:  西南极洲在一些海底岛屿上生长, 它的融化速度特别快。
# translation:  West Antarctica grows on some of the seabed islands, and it melts particularly fast.
# Row:  19 , translating:  相当于20英尺的海平面,就像格陵兰岛一样。
# translation:  20英尺 above sea level, like Greenland.
# Row:  20 , translating:  世界上40%的人从这种融化中得到一半的饮用水。
# translation:  40% of the world's people get half their drinking water from this melting.
# Row:  21 , translating:  在安第斯山脉,冰川是这个城市饮用水的来源。
# translation:  In the Andes Mountains, glaciers are a source of drinking water for this city.
# Row:  22 , translating:  流量增加。
# translation:  Increased flow.
# Row:  23 , translating:  但是当它们消失时,大部分的饮用水也随之消失。
# translation:  But when they disappear, most of the drinking water also disappears.
# Row:  24 , translating:  在加州,雪囊的数量下降了40%。
# translation:  In California, the number of snowbags dropped by 40%.
# Row:  25 , translating:  这会撞到水库。
# translation:  It would hit the reservoir.
# Row:  26 , translating:  正如你所读到的,这些预测是严肃的。
# translation:  As you read, these predictions are serious.
# Row:  27 , translating:  全世界的干旱导致火灾急剧增加。
# translation:  Droughts around the world have led to a sharp increase in fires.
# Row:  28 , translating:  全世界的灾难都在以前所未有的速度增加。
# translation:  世界范围内 disasters are increasing at an unprecedented rate.
# Row:  29 , translating:  在过去的30年里,这个数字是前75年的4倍。
# translation:  In the past 30 years, this figure is four times that of the previous 75 years.
# Row:  30 , translating:  这是一种完全不可持续的模式。
# translation:  这是一个完全不可持续的模式。
# Row:  31 , translating:  如果你从历史的角度来看,你可以看到这是怎么回事。
# translation:  If you look at history, you can see what's going on.
# Row:  32 , translating:  石油是个问题,而煤炭则是最严重的问题。
# translation:  Oil is a problem, and coal is the most serious one.
# Row:  33 , translating:  美国是最大的两个排放国之一。
# translation:  The United States is one of the two largest emitters.
# Row:  34 , translating:  建议建造更多的燃煤电厂。
# translation:  It is recommended to build more coal-fired power plants.
# Row:  35 , translating:  但我们开始看到大海的变化。
# translation:  但我们开始看到海洋的变化。
# Row:  36 , translating:  这些是在过去几年里被取消的, 有一些绿色的替代品。
# translation:  These have been canceled in the past few years, and there are some green alternatives.
# Row:  37 , translating:  这张照片让我想起了一些事情。
# translation:  This photo reminded me of something.
# Row:  38 , translating:  在田纳西州的圣诞节前夕, 10亿加仑的煤污被泄漏了。
# translation:  On the eve of Christmas in Tennessee, 1 billion gallons of coal were leaked.
# Row:  39 , translating:  你可能在新闻上看到过。
# translation:  You may have seen it in the news.
# Row:  40 , translating:  在美国,这是第二大的废物流。
# translation:  In the United States, this is the second largest waste stream.
# Row:  41 , translating:  那是在圣诞节的时候。
# translation:  那是在圣诞节的时候。
# Row:  42 , translating:  一个关于圣诞节的广告是这个。
# translation:  A Christmas Advertisement is this.
# Row:  43 , translating:  视频:♪冻煤人是一个快乐的灵魂。
# translation:  ♪ Frozen Coal Man is a happy soul.
# Row:  44 , translating:  他在美国很丰富,他帮助我们的经济成长。
# translation:  He is very rich in the United States, and he has helped our economy grow.
# Row:  45 , translating:  煤矿工人每天都在变的更清洁。
# translation:  Coal miners are becoming cleaner every day.
# Row:  46 , translating:  他负担得起,很可爱,而且工人可以拿到工资。
# translation:  He's affordable, cute, and the workers get paid.
# Row:  47 , translating:  戈尔:这是西弗吉尼亚州大部分煤炭的来源。
# translation:  Gore: This is the source of much of West Virginia's coal.
# Row:  48 , translating:  最大的矿工是马西煤矿。
# translation:  The largest miner is the Marseille mine.
# Row:  49 , translating:  戈尔:气候保护联盟发起了两项运动。
# translation:  Gore: The Climate Protection Alliance has launched two campaigns.
# Row:  50 , translating:  这是其中之一,也是其中的一部分。
# translation:  That's one of them, and part of it.
# Row:  51 , translating:  视频:在COALgy,我们把气候变化看作是对我们业务的一个非常严重的威胁。
# translation:  Video: At COALgy, we see climate change as a very serious threat to our business.
# Row:  52 , translating:  事实是,煤并不脏。
# translation:  The truth is, coal isn't dirty.
# Row:  53 , translating:  我们认为它很干净,味道也很好。
# translation:  We think it's clean and tasteful.
# Row:  54 , translating:  所以不要担心气候变化。
# translation:  So don't worry about climate change.
# Row:  55 , translating:  留给我们吧。
# translation:  留给我们。
# Row:  56 , translating:  视频:清洁煤——你听过很多。
# translation:  Video: Clean coal - you've heard a lot.
# Row:  57 , translating:  让我们来看看这个最先进的清洁煤矿设施。
# translation:  Let's take a look at this state-of-the-art clean coal mine.
# Row:  58 , translating:  太棒了!机器有点响。
# translation:  GREAT! the machine is a little loud.
# Row:  59 , translating:  这就是清洁煤技术的声音。
# translation:  That's the sound of clean coal technology.
# Row:  60 , translating:  虽然燃烧煤炭是导致全球变暖的主要原因之一, 但清洁煤技术可以改变一切。
# translation:  While burning coal is one of the main causes of global warming, clean coal technology can change everything.
# Row:  61 , translating:  长话短说:这是今天的清洁煤技术。
# translation:  Long story short: this is today's clean coal technology.
# Row:  62 , translating:  Al Gore:最后,积极的选择 与我们的经济挑战和国家安全挑战交汇在一起。
# translation:  Al Gore: Finally, the positive choices come together with our economic and national security challenges.
# Row:  63 , translating:  视频:美国正处在危机中--经济,国家安全,气候危机。
# translation:  Video: The United States is in a crisis-- economic, national security, climate crisis.
# Row:  64 , translating:  但是现在有一个大胆的新方案 来让我们摆脱这种混乱。
# translation:  But now there's a bold new plan to get us out of this mess.
# Row:  65 , translating:  用100%的清洁电力来重振美国。
# translation:  100% clean electricity to revive the United States.
# Row:  66 , translating:  让美国恢复工作,让我们更加安全, 并帮助阻止全球变暖。
# translation:  Let's get the U.S. back to work, make it safer and help stop global warming.
# Row:  67 , translating:  最后,一个足够大的解决方案 来解决我们的问题。
# translation:  最终, a big enough solution to solve our problem.
# Row:  68 , translating:  重振美国。了解更多
# translation:  Revitalize America. Learn more.
# Row:  69 , translating:  戈尔:这是最后一个。
# translation:  GOL: That's the last one.
# Row:  70 , translating:  视频:是关于重振美国。
# translation:  Video: It's about reinvigorating the United States.
# Row:  71 , translating:  减少我们对旧燃料的依赖的最快方法之一, 它正在扼杀我们的星球。
# translation:  One of the quickest ways to reduce our reliance on old fuel, it is stifling our planet.
# Row:  72 , translating:  男人:未来来了。风,太阳,新能源网。
# translation:  MAN: The future is here. Wind, sun, new energy grid.
# Row:  73 , translating:  男人2:创造高薪工作的新投资。
# translation:  Men 2: New investment in high-paying jobs.
# Row:  74 , translating:  讲述者:重振美国。是时候让它变成现实了。
# translation:  Revitalize America.It's time to make it a reality.
# Row:  75 , translating:  阿尔·戈尔:有句古老的非洲谚语说, “如果你想快点去,就一个人去。”
# translation:  Al Gore: There is an old African proverb that says, "If you want to go fast, go alone."
# Row:  76 , translating:  如果你想走得更远,一起去。”
# translation:  If you want to go further, go together."
# Row:  77 , translating:  我们需要走得更远,更快。
# translation:  We need to go further, faster.
# Row:  78 , translating:  非常感谢。
# translation:  非常感谢。
# Row:  79 , translating:  去年我在TED做了一个LHC的介绍。
# translation:  Last year I gave a presentation to LHC.
# Row:  80 , translating:  我答应再给你一个关于那台机器如何工作的更新。
# translation:  I promise to give you another update on how the machine works.
# Row:  81 , translating:  如果不是雄心勃勃的话,那就什么都没有了。
# translation:  如果没有雄心壮志,那就什么都没有了。
# Row:  82 , translating:  这是日内瓦下方的机器。
# translation:  This is the machine below Geneva.
# Row:  83 , translating:  我们拍下这些小爆炸探测器里面的照片。
# translation:  We took pictures of these small explosive detectors.
# Row:  84 , translating:  这里是正在建设中的ATLAS的壮观图片,所以你可以看到它的规模。
# translation:  Here's a spectacular picture of ATLAS being built, so you can see its size.
# Row:  85 , translating:  去年9月10日,我们第一次打开机器。
# translation:  On September 10th, we opened the machine for the first time.
# Row:  86 , translating:  这张照片是ATLAS拍摄的。
# translation:  This photo was taken by ATLAS.
# Row:  87 , translating:  它在控制室里引起了极大的欢庆。
# translation:  It was a great celebration in the control room.
# Row:  88 , translating:  这意味着我们不仅对文化产生了影响, 也对科学产生了影响。
# translation:  This means that we have an impact not only on culture, but also on science.
# Row:  89 , translating:  这些电线携带13000个安培器 当机器全功率工作时。
# translation:  These wires carry 13000 amplifiers when the machine is fully powered.
# Row:  90 , translating:  你们中的工程师会看着他们,说:“不是。它们是小电线。”
# translation:  One of your engineers will look at them and say, "No. They're small wires."
# Row:  91 , translating:  因为当它们很冷的时候,就被称为超导线。
# translation:  Because when they're cold, they're called superconductors.
# Row:  92 , translating:  在LHC中超过9000个磁体之间的一个关节里, 有一个制造缺陷。
# translation:  In one joint between more than 9000 magnets in the LHC, there is a manufacturing defect.
# Row:  93 , translating:  这就是结果。
# translation:  这就是结果。
# Row:  94 , translating:  更让人印象深刻的是,这些磁铁重达20吨, 然后它们移动了大约一英尺。
# translation:  Even more impressive is the fact that these magnets weigh 20 tons, and then they move about one foot.
# Row:  95 , translating:  所以我们损坏了大约50个磁铁。
# translation:  So we damaged about 50 magnets.
# Row:  96 , translating:  我们必须把它们拿出来,我们做到了。
# translation:  我们必须把它们拿出来,我们做到了。
# Row:  97 , translating:  我们重新调整了它们,修复了它们。
# translation:  我们重新调整了它们,修复了它们。
# Row:  98 , translating:  他们正准备回到地下。
# translation:  They're getting ready to go underground.
# Row:  99 , translating:  到3月底,LHC将再次完好无损。
# translation:  By the end of March, LHC will be intact again.
# Row:  100 , translating:  谢谢。
# translation:  谢谢。
# Row:  101 , translating:  我想先让大家回想一下 你还是个孩子的时候,玩砖块。
# translation:  我想让大家回想一下,当你还是个孩子的时候,玩砖块。
# Row:  102 , translating:  空间推理与我们如何理解周围世界息息相关。
# translation:  Space reasoning is closely related to how we understand the world around us.
# Row:  103 , translating:  按照我们想要的方式来安排?
# translation:  按照我们想要的方式来安排?
# Row:  104 , translating:  简而言之,Siftable是一个像饼干一样的交互式计算机。
# translation:  In short, Siftable is a cookie-like interactive computer.
# Row:  105 , translating:  最重要的是,它们是有形的,你可以通过伸展和抓取来移动它们。
# translation:  Most importantly, they are tangible and you can move them by stretching and grabbing them.
# Row:  106 , translating:  Siftables是一种新的生态系统, 用来操纵数字信息。
# translation:  Siftables are a new ecosystem used to manipulate digital information.
# Row:  107 , translating:  那么,我将以一些简单的例子开始。
# translation:  那么, I'll start with a few simple examples.
# Row:  108 , translating:  这些互动的肖像是相互了解的。
# translation:  Portraits of these interactions are mutually familiar.
# Row:  109 , translating:  如果我把它们放在一起,它们就会变得很感兴趣。
# translation:  If I put them together, they will become very interesting.
# Row:  110 , translating:  如果他们被包围了,他们也可能会有点晕眩。
# translation:  If they're surrounded, they might be a little dizzy.
# Row:  111 , translating:  它们也能感知它们的运动和倾斜。
# translation:  They can also sense their movement and tilt.
# Row:  112 , translating:  如果我们超额,我们可以倒退一点。
# translation:  If we overrun, we can go back a little.
# Row:  113 , translating:  这里有个单词游戏,有点像在Scrabble和Boggle之间。
# translation:  There's a word game here, sort of between Scrabble and Boggle.
# Row:  114 , translating:  谢谢。
# translation:  谢谢。
# Row:  115 , translating:  他们真的很喜欢它。
# translation:  他们真的很喜欢它。
# Row:  116 , translating:  而且,这种应用的有趣之处在于 你不需要给人们很多指令。
# translation:  而且, the interesting thing about this application is that you don't need to give people a lot of instructions.
# Row:  117 , translating:  你要说的就是“写字”,他们知道该怎么做。
# translation:  What you want to say is 'write', they know what to do.
# Row:  118 , translating:  还有几个人试着去做。
# translation:  A few others are trying to do it.
# Row:  119 , translating:  这是我们最年轻的测试者,在右边。
# translation:  This is our youngest tester, on the right.
# Row:  120 , translating:  结果是,他想做的就是把Siftables堆起来。
# translation:  All he wanted to do was build up the siftables.
# Row:  121 , translating:  对他来说,他们只是个街区。
# translation:  For him, they're just a block.
# Row:  122 , translating:  现在,这是一个交互式卡通应用程序。
# translation:  Now, it's an interactive cartoon app.
# Row:  123 , translating:  我们想为语言学习者建立一个学习工具。
# translation:  We want to build a learning tool for language learners.
# Row:  124 , translating:  这是费利克斯,事实上。
# translation:  It's Felix, actually.
# Row:  125 , translating:  在这里,他把太阳拿出来。
# translation:  Here, he took out the sun.
# Row:  126 , translating:  视频:太阳在升起。
# translation:  Video: The sun is rising.
# Row:  127 , translating:  大卫·梅里尔:他把拖拉机带到了现场。
# translation:  David Merrill: He brought the tractor to the scene.
# Row:  128 , translating:  视频:橙色拖拉机
# translation:  Video: Orange tractor
# Row:  129 , translating:  干得好!
# translation:  OK!
# Row:  130 , translating:  DM:发明他自己的叙事。
# translation:  DM: He invented his own narrative.
# Row:  131 , translating:  视频:你好!
# translation:  Video: Hello!
# Row:  132 , translating:  DM:这是一个开放的故事,他可以决定如何展开。
# translation:  DM: It's an open story, he can decide how to go about it.
# Row:  133 , translating:  视频:飞开,猫。
# translation:  Video: Fly away, cat.
# Row:  134 , translating:  每一个都有四个不同的变化,你可以选择你想要用哪一个。
# translation:  每一个都有四个不同的变化,你可以选择哪一个。
# Row:  135 , translating:  只需将声波与音波对撞即可注射。
# translation:  It is enough to inject sound waves into a collision.
# Row:  136 , translating:  你可以实时控制这些影响,比如说声波和滤波器。
# translation:  You can control these effects in real time, like soundwaves and filters.
# Row:  137 , translating:  你把它附在一个特定的声音上 然后倾斜来调节它。
# translation:  You attach it to a specific sound and then tilt it.
# Row:  138 , translating:  总的来说,比如速度和音量。
# translation:  总而言之, speed and volume.
# Row:  139 , translating:  现在我把一条低音线放进去。
# translation:  Now I put a low-sonic line in it.
# Row:  140 , translating:  视频:DM:现在我要放一些冲击。
# translation:  Video: DM: Now I'm going to put some shocks on.
# Row:  141 , translating:  视频:DM:现在我把过滤器附在鼓上,这样我可以实时控制效果。
# translation:  DM: Now I attach the filter to the drum so that I can control the effect in real time.
# Row:  142 , translating:  视频:DM:我可以通过倾斜速度来加快整个过程。
# translation:  DM: I can speed up the whole process by tilting.
# Row:  143 , translating:  视频:DM:现在我将过滤器附加到低音上,以获得更多的表情。
# translation:  Video: DM: Now I'm attaching the filter to the low voice for more expression.
# Row:  144 , translating:  视频:DM:我可以重新排列顺序。
# translation:  DM: I can re-order.
# Row:  145 , translating:  现在,我可以用左边的音量 将整个序列褪色。
# translation:  Now, I can erase the whole sequence with the volume on the left.
# Row:  146 , translating:  谢谢。
# translation:  谢谢。
# Row:  147 , translating:  非常感谢。
# translation:  非常感谢。
# Row:  148 , translating:  我很期待与大家交流。
# translation:  我很期待与大家交流。
# Row:  149 , translating:  我是作家。
# translation:  我是作家。
# Row:  150 , translating:  写书是我的职业,当然不止如此。
# translation:  写书是我的职业,当然不止如此。
# Row:  151 , translating:  这也是我一生的爱和魅力。
# translation:  It is also the love and charm of my life.
# Row:  152 , translating:  我不认为这会改变。
# translation:  我不认为这会改变。
# Row:  153 , translating:  真的——注定,注定!
# translation:  Really-destined, destined!
# Row:  154 , translating:  那令人放心,你知道的。
# translation:  That's reassuring, you know.
# Row:  155 , translating:  人们会说:“你不怕什么成功吗?”
# translation:  人们会说:“你不怕成功吗?”
# Row:  156 , translating:  答案--对所有这些问题的简短回答是, “是的。”
# translation:  Answer--to all these questions a short answer is, "Yes."
# Row:  157 , translating:  是的,我害怕所有这些事情。
# translation:  是的,I'm afraid of all these things.
# Row:  158 , translating:  我一直都是。
# translation:  我一直都是。
# Row:  159 , translating:  你知道吗?
# translation:  你知道吗?
# Row:  160 , translating:  “化学工程学块,约翰,怎么回事?”
# translation:  "Chemical Engineering, John, what's going on?"
# Row:  161 , translating:  它不是这样出现的,你知道吗?
# translation:  It didn't appear like that, did you know?
# Row:  162 , translating:  一个关于你一生工作的非凡声明。
# translation:  A remarkable statement about your life's work.
# Row:  163 , translating:  你觉得舒服吗?
# translation:  Do you feel comfortable?
# Row:  164 , translating:  我觉得很可怕。
# translation:  I think it's terrifying.
# Row:  165 , translating:  我认为如果我们鼓励我们伟大的创造力,那就更好了。
# translation:  I think it would be better if we encouraged our great creativity.
# Row:  166 , translating:  也许我还有四十年的工作。
# translation:  也许我还有40年的工作。
# Row:  167 , translating:  天啊,真是个想法!
# translation:  天啊,真是个主意!
# Row:  168 , translating:  我宁愿继续做我热爱的工作。
# translation:  I'd rather keep doing what I love.
# Row:  169 , translating:  那么问题就变成了,如何?
# translation:  那么问题就变成了,怎么样?
# Row:  170 , translating:  那次搜索带我到了古希腊和古罗马。
# translation:  The search took me to ancient Greece and Rome.
# Row:  171 , translating:  那就跟我一起吧,因为它会四处游荡。
# translation:  Follow me, because it's all around.
# Row:  172 , translating:  古希腊人称这些神灵为“达蒙”。
# translation:  Ancient Greeks called these gods "Damon."
# Row:  173 , translating:  每个人都知道这是怎么运作的,对吧?
# translation:  每个人都知道这是怎么回事,对吧?
# Row:  174 , translating:  如果你的工作被轰炸了,不是完全是你的错。
# translation:  If your job gets bombed, it's not entirely your fault.
# Row:  175 , translating:  我想说,这是一个很大的错误。
# translation:  我想说,这是个大错误。
# Row:  176 , translating:  就像要人吞下太阳一样。
# translation:  It's like asking people to swallow the sun.
# Row:  177 , translating:  如果这是真的,那么问题就变成了,现在呢?
# translation:  If that's true, then the question becomes, now?
# Row:  178 , translating:  我们能做点别的吗?
# translation:  我们可以做点别的吗?
# Row:  179 , translating:  也许不是。
# translation:  也许不是。
# Row:  180 , translating:  我可能不会把你们都带到这里来。
# translation:  我可能不会把你们都带到这里来。
# Row:  181 , translating:  为什么不这样想呢?
# translation:  为什么不这么想?
# Row:  182 , translating:  事实上,有时会感觉很不正常。
# translation:  In fact, sometimes it feels uncommon.
# Row:  183 , translating:  她说那就像一列巨大的空中列车。
# translation:  She said it was like a huge air train.
# Row:  184 , translating:  它会向她伸出手来。
# translation:  It will reach out to her.
# Row:  185 , translating:  她感觉到它来了,因为它会震动她脚下的地球。
# translation:  She felt it coming because it would shake the earth under her feet.
# Row:  186 , translating:  我想你们很多人也一样。
# translation:  我想你们很多人也是。
# Row:  187 , translating:  那是什么呢?
# translation:  那又怎样呢?
# Row:  188 , translating:  他没有一张纸,或者铅笔,或录音机。
# translation:  He didn't have a paper, or a pencil, or a recorder.
# Row:  189 , translating:  而不是惊慌失措,他停了下来。
# translation:  Instead of panicking, he stopped.
# Row:  190 , translating:  他停止了整个心理过程, 做了一些完全新颖的事情。
# translation:  He stopped the whole psychological process and did something completely new.
# Row:  191 , translating:  “我现在能写一首歌吗?”
# translation:  "Can I write a song now?"
# Row:  192 , translating:  否则,今天就去麻烦别人了。
# translation:  不然, let's bother others today.
# Row:  193 , translating:  麻烦伦纳德·科恩。”
# translation:  Leonard Cohen."
# Row:  194 , translating:  之后他的整个工作流程都发生了变化。
# translation:  After that, his entire workflow changed.
# Row:  195 , translating:  不是工作,还是像以前一样黑暗。
# translation:  Not working, or as dark as before.
# Row:  196 , translating:  不光是坏书,更是有史以来最差的书。
# translation:  It's not just bad books, it's the worst book ever.
# Row:  197 , translating:  我开始想,我应该把这个项目扔掉。
# translation:  我开始想, I should throw this project away.
# Row:  198 , translating:  但我记得汤姆在开阔的空气中说话,然后我试了一下。
# translation:  But I remember Tom talking in the open air, and then I tried it.
# Row:  199 , translating:  如果你想做得更好,你就必须参与其中。
# translation:  If you want to do better, you have to be involved.
# Row:  200 , translating:  但是如果你不这样做,你知道吗?
# translation:  但是如果你不这样做,你知道吗?
# Row:  201 , translating:  突然间,他不再是人类了。
# translation:  突然间,他不再是人类了。
# Row:  202 , translating:  那是上帝,你知道的。
# translation:  那是上帝,你知道的。
# Row:  203 , translating:  那太棒了,因为我们需要它。
# translation:  那太棒了,因为我们需要它。
# Row:  204 , translating:  这是很难的。
# translation:  这很难。
# Row:  205 , translating:  如果我们这样想,它就会改变一切。
# translation:  如果我们这样想,它会改变一切。
# Row:  206 , translating:  不要害怕。做你的工作。
# translation:  Don't be afraid, do your job.
# Row:  207 , translating:  继续展示你的作品,不管它是什么。
# translation:  Continuing to show off your work, whatever it is.
# Row:  208 , translating:  如果你的工作是跳舞,那就跳吧。
# translation:  如果你的工作是跳舞,那就跳吧。
# Row:  209 , translating:  如果不是,那就跳舞吧。
# translation:  如果不是,那就跳舞吧。
# Row:  210 , translating:  还有“Olé”
# translation:  There's also "Ole."
# Row:  211 , translating:  我相信这一点,我觉得我们必须教它。
# translation:  我相信, I think we have to teach it.
# Row:  212 , translating:  谢谢。
# translation:  谢谢。
# Row:  213 , translating:  谢谢。
# translation:  谢谢。
# Row:  214 , translating:  朱恩·科恩:奥莱!
# translation:  June Cohen: O'Lee!
# Row:  215 , translating:  所以,我们一直试图问一些大问题。
# translation:  So, we've been trying to ask some big questions.
# Row:  216 , translating:  “生命是什么?” 是许多生物学家在不同层面上试图理解的。
# translation:  "What is life?" many biologists try to understand at different levels.
# Row:  217 , translating:  我们尝试了各种方法, 把它归结为最小的组件。
# translation:  We tried a variety of ways to reduce it to the smallest component.
# Row:  218 , translating:  于是我们开始了: 我们能不能合成一个染色体?
# translation:  于是我们开始:我们能不能合成一个染色体?
# Row:  219 , translating:  化学能不能创造出我们从未有过的巨大分子呢?
# translation:  化学能不能创造出我们从未有过的巨大分子?
# Row:  220 , translating:  如果我们这样做,我们能启动染色体吗?
# translation:  如果我们这样做,我们能启动染色体吗?
# Row:  221 , translating:  顺便说一下,染色体只是一小块惰性化学材料。
# translation:  顺便说一下, chromosomes are just a small piece of inert chemistry.
# Row:  222 , translating:  因此,我们把生命数字化的速度 以指数速度增长。
# translation:  So we digitalize life at an exponential rate.
# Row:  223 , translating:  我们是在15年前开始的。
# translation:  我们是15年前开始的。
# Row:  224 , translating:  实际上,在进行第一次实验之前,它经历了几个阶段。
# translation:  In fact, before the first experiment, it went through several stages.
# Row:  225 , translating:  但是合成DNA是非常困难的。
# translation:  Synthesizing DNA is very difficult.
# Row:  226 , translating:  所以我们必须创造一种新的方法 把这些小片段放在一起,并纠正所有的错误。
# translation:  So we have to create a new way to put these small pieces together and correct all the mistakes.
# Row:  227 , translating:  这是我们第一次尝试,从数码信息开始。
# translation:  This is our first attempt, starting with digital information.
# Row:  228 , translating:  一种能杀死细菌的小病毒。
# translation:  A small virus that can kill bacteria.
# Row:  229 , translating:  病毒颗粒从细胞中释放出来,杀死了大肠杆菌。
# translation:  Viral particles are released from the cells, killing large intestines.
# Row:  230 , translating:  我最近和石油行业谈过,他们说他们很清楚这个模型。
# translation:  I talked to the oil industry recently, and they said they knew this model well.
# Row:  231 , translating:  设计是至关重要的,如果你从计算机里的数字信息开始, 这个数字信息必须非常准确。
# translation:  设计是至关重要的,如果要从计算机的数字信息开始, 这个数字信息必须非常准确。
# Row:  232 , translating:  我们设计了独特的元素。
# translation:  我们设计了独特的元素。
# Row:  233 , translating:  你可能读过我们把水印进去。
# translation:  You may have read that we put watermarks in.
# Row:  234 , translating:  想一想:我们有四字母的基因密码--A,C,G和T。
# translation:  Think about it: we have a four-letter genetic code -- A, C, G and T.
# Row:  235 , translating:  我们可以用基因编码来写出单词,句子,想法。
# translation:  We can code words, sentences, ideas.
# Row:  236 , translating:  最初,我们所做的只是自画像。
# translation:  最初,我们只做了 self-images.
# Row:  237 , translating:  有些人失望的是,那不是诗。
# translation:  Some people are disappointed, it's not poetry.
# Row:  238 , translating:  我们正在努力实现自动化。
# translation:  We're trying to automate it.
# Row:  239 , translating:  看起来就像一个篮球季后赛。
# translation:  It looks like a post-season basketball game.
# Row:  240 , translating:  我们知道有一种叫做同质重组的机制, 生物学用它来修复DNA。
# translation:  We know a mechanism called homogenous reorganisation, which biology uses to repair DNA.
# Row:  241 , translating:  你可以在上面看到,它的染色体被撕裂了。
# translation:  As you can see, its chromosomes have been torn.
# Row:  242 , translating:  12到24小时后,它又回到了原来的样子。
# translation:  12-24 hours later, it was back to its original form.
# Row:  243 , translating:  我们有数以千计的生物可以做到这点。
# translation:  数以千计的生物可以做到。
# Row:  244 , translating:  这些生物可以完全枯竭; 它们可以在真空中生存。
# translation:  These organisms can be completely depleted; they can survive in a vacuum.
# Row:  245 , translating:  我绝对确信生命可以在外太空存在, 可以四处移动,找到新的水生环境。
# translation:  I am absolutely convinced that life can exist in outer space, move around and find a new aquatic environment.
# Row:  246 , translating:  事实上,美国宇航局已经展示了很多这样的例子。
# translation:  In fact, NASA has shown many such examples.
# Row:  247 , translating:  这不是电子图;这只是一个普通的微图像。
# translation:  It's not an electronic picture; it's just a simple micro-image.
# Row:  248 , translating:  这是一个很大的分子,我们可以用光显微镜来观察它。
# translation:  这是一个很大的分子,我们可以用光显微镜来观察它。
# Row:  249 , translating:  这些照片大约是六秒钟。
# translation:  These pictures are about six seconds.
# Row:  250 , translating:  这就是我们不久前发表的文章。
# translation:  This is an article we published a short time ago.
# Row:  251 , translating:  超过3亿分子重。
# translation:  超过300万分子重。
# Row:  252 , translating:  那么,我们如何启动一个染色体? 我们如何激活它呢?
# translation:  那么,我们如何激活一个染色体?
# Row:  253 , translating:  很显然,对付病毒要简单得多。
# translation:  Clearly, dealing with viruses is much simpler.
# Row:  254 , translating:  新的染色体进入细胞。
# translation:  新 chromosomes enter the cell.
# Row:  255 , translating:  实际上,我们认为这个过程可能更远一些。
# translation:  实际上, we think the process may be a bit further.
# Row:  256 , translating:  这是进化的一个主要机制。
# translation:  This is a major mechanism of evolution.
# Row:  257 , translating:  所以,那些认为进化只是一个基因一次的改变的人 忽略了很多生物学。
# translation:  所以, those who think that evolution is just a one-time change in a gene ignore many biology.
# Row:  258 , translating:  有限制性酶,它们能消化DNA。
# translation:  Limited enzymes, they can digest DNA.
# Row:  259 , translating:  细胞里没有染色体;我们放的染色体有。
# translation:  细胞里没有 chromosomes;我们放置 chromosomes.
# Row:  260 , translating:  它变成了蓝色,因为我们放进去的基因。
# translation:  It turns blue because of the genes we put in it.
# Row:  261 , translating:  我一直认为,这不是创世纪; 而是建立在35亿年的进化之上。
# translation:  I always thought it wasn't the Genesis century; it was built on three-and-a-half billion years of evolution.
# Row:  262 , translating:  为什么要这么做?
# translation:  为什么要这么做?
# Row:  263 , translating:  我认为这在一定程度上是显而易见的。
# translation:  I think it's obvious to some extent.
# Row:  264 , translating:  未来40年,我们将会从65亿人发展到90亿人。
# translation:  未来40年,我们将会从650亿人发展到900万。
# Row:  265 , translating:  用我自己的话来说: 我生于1946年。
# translation:  In my own words: I was born in 1946.
# Row:  266 , translating:  我们很难为这65亿人提供新鲜、清洁的水,药品和燃料。
# translation:  我们很难为这650亿人提供新鲜清洁的水, 药品和燃料。
# Row:  267 , translating:  这将是一个9小时的拉伸。
# translation:  It will be a nine-hour stretch.
# Row:  268 , translating:  当我们试着去思考生物过程,或者任何可以取代它的过程时, 这将会是一个巨大的挑战。
# translation:  When we try to think about biological processes, or any process that can replace them, it will be a huge challenge.
# Row:  269 , translating:  当然,所有来自这种物质的二氧化碳 最终都会进入大气层。
# translation:  当然, all the CO2 from this substance eventually enters the atmosphere.
# Row:  270 , translating:  电子工业只有几十个部件,看看其中的多样性。
# translation:  The electronics industry has only a few dozen components, look at the diversity of them.
# Row:  271 , translating:  我们主要受到生物现实和想象力的限制。
# translation:  We are mainly limited by biological reality and imagination.
# Row:  272 , translating:  现在我们有能力制造一个大型的机器人, 每天可以产生100万个染色体。
# translation:  Now we have the ability to make a large robot that can produce 1 million chromosomes every day.
# Row:  273 , translating:  这只是标准的选择:我们可以选择可行性, 化学或燃料生产,疫苗生产等等。
# translation:  It's just a standard choice: we can choose feasibility, chemical or fuel production, vaccine production, etc.
# Row:  274 , translating:  我们不一定知道它们会是什么样子: 我们知道它们的基因密码是什么样的。
# translation:  We don't necessarily know what they will look like: we know what their genetic code is.
# Row:  275 , translating:  我们现在关注的是第四代燃料。
# translation:  We are now focusing on fourth-generation fuels.
# Row:  276 , translating:  你最近看到的,玉米到乙醇只是个坏实验。
# translation:  As you've seen recently, corn to ethanol is just a bad experiment.
# Row:  277 , translating:  我们将有第四代燃料在18个月左右。
# translation:  We will have a fourth-generation fuel in about 18 months.
# Row:  278 , translating:  阳光和二氧化碳是一种方法。
# translation:  Sunshine and carbon dioxide is one way.
# Row:  279 , translating:  但在全世界的发现中,我们还有其他各种方法。
# translation:  但在世界范围内,我们还有很多其他的方法。
# Row:  280 , translating:  这是我们在1996年描述的有机体。
# translation:  This is the organism we described in 1996.
# Row:  281 , translating:  它生活在深海中,大约有1.5英里深, 几乎处于沸腾的温度下。
# translation:  It lives in the deep sea, about 1.5 miles deep, almost at boiling temperatures.
# Row:  282 , translating:  它使用分子氢气作为其能源。
# translation:  It uses molecular hydrogen as its source of energy.
# Row:  283 , translating:  但是,我们也在用同样的工具 来设计一整套疫苗。
# translation:  但是,我们也用同样的工具 来设计一整套疫苗。
# Row:  284 , translating:  我认为这可以通过预先建立组合疫苗来改变。
# translation:  I think this can be changed by pre-establishing combination vaccines.
# Row:  285 , translating:  它也是一个非常灵活的建筑。
# translation:  It's also a very flexible building.
# Row:  286 , translating:  这是整本书,这是一个非图像数据的例子。
# translation:  This is the whole book, an example of non-image data.
# Row:  287 , translating:  这是狄更斯的《白屋》。每一列都是一章。
# translation:  This is Dickens' White House. Each column is a chapter.
# Row:  288 , translating:  也许这是一种人工阅读电子书的方法。
# translation:  Maybe it's a way to artificially read e-books.
# Row:  289 , translating:  我不会推荐它。
# translation:  I wouldn't recommend it.
# Row:  290 , translating:  这是一个更现实的例子,《卫报》的问题。
# translation:  This is a more realistic example, the Guardian problem.
# Row:  291 , translating:  每个大图像都是一个部分的开始。
# translation:  Each large image is the beginning of a part.
# Row:  292 , translating:  我们在“卫报”这个特别的议题上做了些什么。
# translation:  What did we do on this particular issue of the Guardian?
# Row:  293 , translating:  如果你想看看这辆车的特点,你可以在这里看到。
# translation:  If you want to see the characteristics of this car, you can see it here.
# Row:  294 , translating:  或者其他模型,甚至技术规格。
# translation:  Or other models, or even technical specifications.
# Row:  295 , translating:  这些想法真的可以消除 屏幕房地产的限制。
# translation:  These ideas can really remove the limitations of screen real estate.
# Row:  296 , translating:  我们希望这不会再有弹出和其他的垃圾了-- 这不应该是必要的。
# translation:  我们希望 there won't be any more outbursts and other trash--it shouldn't be necessary.
# Row:  297 , translating:  当然,地图是这类技术的明显应用之一。
# translation:  Of course, maps are one of the obvious applications of this kind of technology.
# Row:  298 , translating:  但在美国,这些都是道路。
# translation:  But in America, these are the paths.
# Row:  299 , translating:  置于NASA的地理空间图像之上。
# translation:  It is placed above NASA's geospatial imagery.
# Row:  300 , translating:  那么,让我们拉上去,别的什么东西。
# translation:  那么,让我们拉上去,别的什么。
# Row:  301 , translating:  实际上这是在网络上,你可以去看看。
# translation:  实际上,这是在网络上,你可以去看看。
# Row:  302 , translating:  这是一个叫做Photosynth的项目, 它结合了两种不同的技术。
# translation:  This is a project called Photosynth, which combines two different technologies.
# Row:  303 , translating:  还有微软的Rick Szeliski。
# translation:  And Microsoft's Rick Szeliski.
# Row:  304 , translating:  非常好的合作。
# translation:  非常好的合作.
# Row:  305 , translating:  这是在网络上直播的,由Seadragon提供动力。
# translation:  It's live on the web, powered by Seadragon.
# Row:  306 , translating:  但是这些图像的空间排列其实是有意义的。
# translation:  But the spatial arrangement of these images is actually meaningful.
# Row:  307 , translating:  这里你可以看到稳定的幻灯片或全景成像, 这些东西都和空间有关。
# translation:  Here you can see stable slides or panorama images, all of which are space-related.
# Row:  308 , translating:  我不确定我是否有时间给你们展示其他环境。
# translation:  I'm not sure if I have time to show you other environments.
# Row:  309 , translating:  有些更具有空间性。
# translation:  Some are more spatial.
# Row:  310 , translating:  我们不得不担心律师,等等。
# translation:  We have to worry about lawyers, etc.
# Row:  311 , translating:  这是圣母大教堂的重建, 完全是用Flickr上的图像完成的。
# translation:  This reconstruction of the Cathedral was done entirely with images on Flickr.
# Row:  312 , translating:  这些橙色的圆柱代表了 一个被发现属于这个模型的图像。
# translation:  These orange pillars represent an image that was found to belong to this model.
# Row:  313 , translating:  这些都是Flickr的图片, 它们都以这种方式在空间上相关联。
# translation:  These are Flickr images, they're all spatially related in this way.
# Row:  314 , translating:  我们可以用这种简单的方式导航。
# translation:  We can navigate in this simple way.
# Row:  315 , translating:  我从没想过我会在微软工作。
# translation:  我从没想过我会在微软工作。
# Row:  316 , translating:  很高兴能有这样的接待。
# translation:  很高兴 to have such a reception.
# Row:  317 , translating:  这里有一系列的照片。
# translation:  Here's a series of photos.
# Row:  318 , translating:  这是一张圣母院的海报,注册正确。
# translation:  This is a poster from the Notre Dame, registered correctly.
# Row:  319 , translating:  我们可以从海报到这个环境的物理视图。
# translation:  We can go from posters to physical views of this environment.
# Row:  320 , translating:  这里的重点是,我们能用社会环境做些什么。
# translation:  重点是我们能用社会环境做些什么。
# Row:  321 , translating:  这些照片变得关联起来, 它们产生的比部分的总和还要大。
# translation:  These photos become associated, and they produce more than the sum of parts.
# Row:  322 , translating:  整个地球都有一个模型。
# translation:  整个地球都有一个模型.
# Row:  323 , translating:  把这看作是史蒂芬·劳勒的虚拟地球作品。
# translation:  Think of it as a virtual earth work by Stephen Lawler.
# Row:  324 , translating:  当人们使用它时,它的好处会越来越大。
# translation:  When people use it, its benefits are increasing.
# Row:  325 , translating:  他们自己的照片被别人输入的元数据标记。
# translation:  Their own photos are tagged with the metadata entered by others.
# Row:  326 , translating:  非常感谢。
# translation:  非常感谢。
# Row:  327 , translating:  它基于图像中的内容。
# translation:  It's based on the content in the image.
# Row:  328 , translating:  当你想到语义信息的丰富性时,你会感到非常兴奋。
# translation:  When you think about the richness of semantic information, you are very excited.
# Row:  329 , translating:  如果这张照片链接到你所有的图片呢?
# translation:  如果 this photo is linked to all your pictures?
# Row:  330 , translating:  语义上的联系和丰富性是巨大的。
# translation:  The semantic connection and richness is enormous.
# Row:  331 , translating:  这是一个经典的网络效应。
# translation:  这是一个经典的网络效应。
# Row:  332 , translating:  克里斯·安德森:真是太不可思议了。
# translation:  Chris Anderson: That's unbelievable.
# Row:  333 , translating:  一个特定的适应性选择的后果, 虽然是成功的,许多代以前。
# translation:  The consequences of a particular adaptive choice, though successful, were many generations ago.
# Row:  334 , translating:  当然,我们都有同样的适应性。
# translation:  当然, we all have the same adaptability.
# Row:  335 , translating:  我们都是天生的。我们把孩子带进了这个世界。
# translation:  我们都是天生的。我们把孩子带进了这个世界。
# Row:  336 , translating:  我们通过启蒙仪式。
# translation:  We passed the enlightenment ceremony.
# Row:  337 , translating:  但有趣的是这首歌的独特节奏, 每一种文化中舞蹈的节奏。
# translation:  But what's interesting is the unique rhythm of this song, the rhythm of dance in every culture.
# Row:  338 , translating:  珠穆朗玛,世界之母。
# translation:  珠穆朗玛,世界之母。
# Row:  339 , translating:  如果你仔细想想,这个想法只能充满希望。
# translation:  仔细想想,这个想法只能充满希望。
# Row:  340 , translating:  种族是人类的伟大遗产。
# translation:  种族是人类的伟大遗产。
# Row:  341 , translating:  它象征着我们, 也象征着我们作为一个令人惊叹的物种。
# translation:  It symbolizes us, and we are an amazing species.
# Row:  342 , translating:  当然,最大的指标是语言流失。
# translation:  The biggest indicator, of course, is the loss of language.
# Row:  343 , translating:  当你们每一个人出生时,地球上有6000种语言。
# translation:  当你们每一个人出生时, 地球上有6000种语言。
# Row:  344 , translating:  现在,语言不仅仅是一个词汇体 或者一套语法规则。
# translation:  语言 isn't just a vocabulary, or a set of grammar rules.
# Row:  345 , translating:  语言是人类精神的闪光。
# translation:  语言 is the spark of human spirit.
# Row:  346 , translating:  它是每个特定文化的灵魂进入物质世界的载体。
# translation:  It is the vehicle by which each particular culture's soul enters the material world.
# Row:  347 , translating:  每一种语言都是心灵的古老森林, 一个分水岭,一个充满灵性可能性的生态系统。
# translation:  每一种语言都是 a forest of mind, a watershed, an ecosystem full of spiritual possibilities.
# Row:  348 , translating:  他们不再被教导, 也就是说,除非有什么改变,他们已经死了。
# translation:  They are no longer taught, that is, unless something changes, they have died.
# Row:  349 , translating:  让它Kogi。”
# translation:  Let it Kogi."
# Row:  350 , translating:  你就会突然发现 不能说你自己的语言。
# translation:  你会突然发现你不能说你自己的语言。
# Row:  351 , translating:  他们只是听着然后开始说话。
# translation:  They just listen and start talking.
# Row:  352 , translating:  1957年,五位传教士试图联系并犯了一个重大错误。
# translation:  In 1957, five missionaries tried to contact and made a major mistake.
# Row:  353 , translating:  但瓦拉尼人不仅仅只是局外人。
# translation:  But the Varanis are not just outsiders.
# Row:  354 , translating:  他们互相推搡。
# translation:  They push each other.
# Row:  355 , translating:  54%的死亡是因为他们互相鞭打。
# translation:  54% of deaths were due to their whipping each other.
# Row:  356 , translating:  相反,这是一个复杂的形而上学的世界观。
# translation:  相反, it's a complex metaphysical worldview.
# Row:  357 , translating:  很有趣。
# translation:  It's funny.
# Row:  358 , translating:  如果我请你给世界各大宗教起名字,你会怎么说?
# translation:  如果我请你给世界各大宗教起个名字,你会怎么说?
# Row:  359 , translating:  基督教,伊斯兰教,犹太教,等等。
# translation:  Christianity, Islam, Judaism, etc.
# Row:  360 , translating:  于是,活人就生了灵魂。
# translation:  于是, the living man gave birth to a soul.
# Row:  361 , translating:  这就是为什么伏地魔喜欢说 “你们白人去教堂谈论上帝。
# translation:  That's why Voldemort likes to say, "You white people go to church and talk about God."
# Row:  362 , translating:  我们在寺庙里跳舞,成为上帝。”
# translation:  We danced in the temple and became God."
# Row:  363 , translating:  因为你被精神所占据, 你怎么会受到伤害呢?
# translation:  因为 you are occupied by the spirit, how can you be hurt?
# Row:  364 , translating:  在一片鲜血的大陆上, 只有这些人从未被西班牙人征服过。
# translation:  On a bloody continent, only these people have never been conquered by the Spaniards.
# Row:  365 , translating:  直到今天,他们仍然被一个仪式的祭司统治着 但牧师的训练是相当了不起的。
# translation:  To this day they are still ruled by a ritual priest, but the training of priests is quite remarkable.
# Row:  366 , translating:  太美了,是你们的保护。”
# translation:  Beautiful, it's your protection."
# Row:  367 , translating:  现在,直觉变得非常重要。
# translation:  Intuition has become very important.
# Row:  368 , translating:  土著人既没有感情,也没有怀旧。
# translation:  Indigenous people have no feelings, nor are they old-fashioned.
# Row:  369 , translating:  这意味着什么?
# translation:  这意味着什么?
# Row:  370 , translating:  不管是精神还是一堆矿石,都无关紧要。
# translation:  Whether it's spirit or a pile of minerals, it doesn't matter.
# Row:  371 , translating:  有趣的是,这个比喻定义了个人和自然界之间的关系。
# translation:  Interestingly, this metaphor defines the relationship between individuals and nature.
# Row:  372 , translating:  我是在不列颠哥伦比亚省的森林里长大的, 相信这些森林是可以被砍伐的。
# translation:  I grew up in the forests of British Columbia, believing that these forests could be deforested.
# Row:  373 , translating:  这是我去年四月在亚马逊西北部拍摄的照片。
# translation:  This is a photograph I took in the north-west of Amazon last April.
# Row:  374 , translating:  叫做Psychotria viridis。
# translation:  It's called psychic viridis.
# Row:  375 , translating:  因为它们被一种叫做一氧化二氮的酶破坏了。
# translation:  Because they are damaged by an enzyme called nitrous oxide.
# Row:  376 , translating:  它们只能被口服, 如果与一些其他化学物质结合使用的话。
# translation:  They can only be used orally if combined with other chemicals.
# Row:  377 , translating:  嗯,我们用“试错”这句话来形容它毫无意义。
# translation:  Well, we don't use the phrase "trying wrong" to describe it.
# Row:  378 , translating:  但是你问印第安人,他们说,“植物会跟我们说话。”
# translation:  But you ask the Indians, they say, "Plants will talk to us."
# Row:  379 , translating:  那是什么意思呢?
# translation:  那是什么意思呢?
# Row:  380 , translating:  然后你问他们如何建立他们的分类法,他们说,“我以为你知道一些关于植物的东西。
# translation:  Then you ask them how to establish their classification, they say, "I thought you knew something about plants."
# Row:  381 , translating:  你知道吗?”我说,“不。”
# translation:  你知道吗?" I said, "No."
# Row:  382 , translating:  所有的文化都不断地参与到舞蹈中, 带着新的生命可能性。
# translation:  All cultures are constantly involved in dance, with new possibilities for life.
# Row:  383 , translating:  问题不在于技术本身。
# translation:  The problem is not the technology itself.
# Row:  384 , translating:  是那些在发现黄金之后出现的病菌。
# translation:  These are the bacteria that emerged after the discovery of gold.
# Row:  385 , translating:  这意味着他在中国入侵时被立即杀死。
# translation:  That means he was killed immediately in China's invasion.
# Row:  386 , translating:  他的叔叔逃到了尼泊尔的散居地。
# translation:  His uncle fled to the scattered areas of Nepal.
# Row:  387 , translating:  做了那件勇敢的事的姐姐被送进了教育营。
# translation:  My sister, who did the brave thing, was sent to an educational camp.
# Row:  388 , translating:  西藏的痛苦是无法忍受的, 但人民的救赎精神却是值得注意的。
# translation:  The pain in Tibet is unbearable, but the people's spirit of redemption is worth noting.
# Row:  389 , translating:  我们所知的现代工业世界 只有300年的历史。
# translation:  我们所知的现代工业世界 只有300年的历史。
# Row:  390 , translating:  这位老人的爷爷拒绝了。
# translation:  这位老人拒绝了。
# Row:  391 , translating:  他的家人,害怕他的生活,拿走了所有的武器,所有的工具。
# translation:  His family, fearful of his life, took all the weapons, all the tools.
# Row:  392 , translating:  现在,你必须明白因纽特人并不害怕寒冷;他们利用了它。
# translation:  Now, you have to understand that the Inuit are not afraid of cold; they take advantage of it.
# Row:  393 , translating:  他们的雪橇最初是用鱼包装成的。
# translation:  Their sled was originally packed with fish.
# Row:  394 , translating:  这就是我们的新家园。它叫做Nunavut。
# translation:  This is our new home. It's called Nunavut.
# Row:  395 , translating:  这是一个独立的领土。他们控制着所有的矿产资源。
# translation:  It's an independent territory. They control all the mineral resources.
# Row:  396 , translating:  一个民族国家如何与人民一起寻求恢复。
# translation:  How a nation-state seeks to recover with its people.
# Row:  397 , translating:  他们是某人的故乡。
# translation:  They are someone's home.
# Row:  398 , translating:  156个国家拥有我们的电视频道。
# translation:  156 countries have our TV channels.
# Row:  399 , translating:  我们的杂志被数以百万计的人阅读。
# translation:  Our magazines are read by millions of people.
# Row:  400 , translating:  所有人民的智慧 都能为我们的集体幸福做出贡献。
# translation:  所有的智慧都能为我们的集体幸福做出贡献.
# Row:  401 , translating:  非常感谢。
# translation:  非常感谢。
# Row:  402 , translating:  我想从“官方的教条”开始。
# translation:  I want to start with the official dogma.
# Row:  403 , translating:  官方的教条是什么?
# translation:  官方的教条是什么?
# Row:  404 , translating:  西方工业社会的官方教条。
# translation:  The official dogma of Western industrial society.
# Row:  405 , translating:  因为自由本身就是好的,有价值的,对人类来说是必不可少的。
# translation:  Because freedom itself is good, valuable, and essential to humanity.
# Row:  406 , translating:  最大化自由的方法就是最大限度地选择。
# translation:  The way to maximise freedom is to maximize choice.
# Row:  407 , translating:  它也深深地植根于我们的生活中。
# translation:  It is also deeply rooted in our lives.
# Row:  408 , translating:  我给你们举几个例子, 说明现代进步给我们带来了什么。
# translation:  Let me give you a few examples of what modern progress has brought us.
# Row:  409 , translating:  这是我的超市。不是那么大。
# translation:  This is my supermarket. It's not that big.
# Row:  410 , translating:  我想说一个关于沙拉打扮的词。
# translation:  I want to say a word about salad dressing.
# Row:  411 , translating:  这就是超市的样子。
# translation:  This is what a supermarket looks like.
# Row:  412 , translating:  你必须承认这有很多选择。
# translation:  You have to admit that there are many options.
# Row:  413 , translating:  在其他领域——通讯的世界。
# translation:  In other areas-the world of communication.
# Row:  414 , translating:  你租了你的手机,你没有买。
# translation:  You rented your phone, you didn't buy it.
# Row:  415 , translating:  顺便说一下,其中一个后果是电话从未断过。
# translation:  顺便说一下, one consequence is that the phone has never been broken.
# Row:  416 , translating:  那些日子过去了。
# translation:  那些日子过去了。
# Row:  417 , translating:  现在我们有几乎无限的手机, 尤其是在手机的世界里。
# translation:  现在 we have almost unlimited phones, especially in the mobile world.
# Row:  418 , translating:  这些是未来的手机。
# translation:  These are the phones of the future.
# Row:  419 , translating:  这会让人们走进商店 问这个问题。
# translation:  这会让人们走进商店问这个问题。
# Row:  420 , translating:  你知道这个问题的答案是什么吗?
# translation:  你知道答案吗?
# Row:  421 , translating:  答案是“不”。
# translation:  The answer is no.
# Row:  422 , translating:  买一个没有太多功效的手机是不可能的。
# translation:  It's impossible to buy a cell phone that doesn't have much power.
# Row:  423 , translating:  所以,在生活中的其他方面 比购买东西更重要,同样的选择爆炸性是真的。
# translation:  So other aspects of life are more important than buying things, the same explosiveity is true.
# Row:  424 , translating:  A有这些好处,还有这些风险。
# translation:  A has these benefits, and those risks.
# Row:  425 , translating:  B有这些好处和风险。你想做什么?”
# translation:  B has these benefits and risks. What do you want to do?"
# Row:  426 , translating:  你说:“医生,我该怎么办?”
# translation:  "Doctor, what should I do?"
# Row:  427 , translating:  医生说,“A有这些好处和风险,B也有这些好处和风险。”
# translation:  The doctor said, "A has these benefits and risks, B also has them."
# Row:  428 , translating:  你想怎么做?”
# translation:  "What do you want to do?"
# Row:  429 , translating:  你会说,“如果你是我,博士,你会怎么做?”
# translation:  "If you were me, doctor, what would you do?"
# Row:  430 , translating:  医生说:“我不是你。”
# translation:  The doctor said, "I'm not you."
# Row:  431 , translating:  如果我们买不到它们,为什么要向我们推销呢?
# translation:  如果我们买不到它们,为什么要向我们推销呢?
# Row:  432 , translating:  我们不能继承一个身份,我们可以发明它。
# translation:  We can't inherit an identity, we can invent it.
# Row:  433 , translating:  我们会尽可能的重塑自己。
# translation:  我们会尽可能的重塑自己。
# Row:  434 , translating:  唯一的选择是谁,而不是你之后做了什么。
# translation:  唯一的选择是谁,而不是你后来做了什么。
# Row:  435 , translating:  如今,一切都是可以抓取的。
# translation:  现在,一切都可以抓到。
# Row:  436 , translating:  不是因为他们不够聪明,也不是因为他们不那么勤奋。
# translation:  Not because they weren't smart enough, or because they didn't work so hard.
# Row:  437 , translating:  我应该结婚吗?我应该先生孩子,还是先有事业?”
# translation:  我应该结婚吗?先生,还是先有事业?”
# Row:  438 , translating:  这些都是消耗性的问题。
# translation:  这些都是消耗性的问题。
# Row:  439 , translating:  的确,他们应该回答这些重要的问题。
# translation:  的确, they should answer these important questions.
# Row:  440 , translating:  我不是在跟你们说这个,因为我想用它。
# translation:  我不是在跟你们说这个,因为我想用它。
# Row:  441 , translating:  我应该回复这封邮件吗?我应该起草这封信吗?”
# translation:  我应该回复这封邮件吗?我应该起草它?”
# Row:  442 , translating:  无论我们看到什么,大事小事,物质和生活方式的事物, 生活都是一个选择。
# translation:  Whatever we see, big and small, material and lifestyle things, life is a choice.
# Row:  443 , translating:  我们曾经生活的世界是这样的。
# translation:  我们曾经生活的世界是这样的。
# Row:  444 , translating:  也就是说,有一些选择, 但不是所有事情都是有选择的。
# translation:  That is to say, there are some choices, but not all things have been chosen.
# Row:  445 , translating:  我们现在生活的世界是这样的。
# translation:  我们生活的世界是这样的。
# Row:  446 , translating:  问题是,这是好消息还是坏消息?
# translation:  问题是,这是好消息还是坏消息?
# Row:  447 , translating:  答案是肯定的。
# translation:  答案是肯定的。
# Row:  448 , translating:  我们都知道什么是好的,所以我将要谈论什么是坏的。
# translation:  我们知道什么是好的,所以我将要谈什么是坏的。
# Row:  449 , translating:  所有这些选择都对人们有两种负面影响。
# translation:  All these choices have two negative effects on people.
# Row:  450 , translating:  有如此多的选择,人们觉得很难去选择。
# translation:  There are so many choices that people find difficult to make.
# Row:  451 , translating:  她发现每提供10个共同基金, 参与率就下降了2%。
# translation:  She found that for every 10 mutual funds provided, the participation rate dropped by 2%.
# Row:  452 , translating:  明天,明天,当然也永远不会到来。
# translation:  明天,当然也永远不会到来。
# Row:  453 , translating:  所以瘫痪是有太多选择的后果。
# translation:  So paralysis is the consequence of too many choices.
# Row:  454 , translating:  我认为这个世界是这样的。
# translation:  我认为世界是这样的。
# Row:  455 , translating:  你真的想做出正确的决定,如果它是永恒的,对吧?
# translation:  You really want to make the right decision, if it's everlasting, right?
# Row:  456 , translating:  你不会选择错误的互助基金, 或者不正确的沙拉打扮。
# translation:  You don't choose the wrong mutual fund, or the wrong salad dress.
# Row:  457 , translating:  原因有几个。
# translation:  There are several reasons.
# Row:  458 , translating:  第二,经济学家称之为“机会成本”。
# translation:  Second, economists call it "opportunity cost."
# Row:  459 , translating:  这就是你要想的。
# translation:  这就是你要想的。
# Row:  460 , translating:  这是一对汉普顿夫妇。
# translation:  This is a Hampton couple.
# Row:  461 , translating:  非常昂贵的房地产。
# translation:  Real estate is very expensive.
# Row:  462 , translating:  美妙的海滩,美好的一天。他们自己拥有这一切。
# translation:  Beautiful beach, a beautiful day. They own it all.
# Row:  463 , translating:  我可以停在我大楼前面。”
# translation:  I can stop in front of my building."
# Row:  464 , translating:  这里是另一个例子。这幅漫画有很多要点。
# translation:  Here's another example. This comic has a lot of points.
# Row:  465 , translating:  它也意味着活在当下,并且可能慢慢地做一些事情。
# translation:  It also means living in the moment, and maybe doing something slowly.
# Row:  466 , translating:  第三,期望的升级。
# translation:  第三, the expected upgrade.
# Row:  467 , translating:  当我去换牛仔裤的时候,我被吓坏了。
# translation:  When I changed my jeans, I was frightened.
# Row:  468 , translating:  我几乎总是穿牛仔裤。
# translation:  I almost always wear jeans.
# Row:  469 , translating:  店主说:“你想要柔软的,容易的,放松的吗?”
# translation:  The shopkeeper said, "You want to be soft, easy, relaxed?"
# Row:  470 , translating:  你要按钮飞,还是起重机飞?要洗石头或酸奶吗?
# translation:  Do you want a button to fly, or a crane to fly? do you want to wash stones or yogurt?
# Row:  471 , translating:  你想让他们痛苦吗?
# translation:  你想让他们痛苦吗?
# Row:  472 , translating:  你要剪靴子,带上磁带。”他继续说道。
# translation:  You have to cut your boots and bring the tape." he continued.
# Row:  473 , translating:  我做得更好。这些选择使我能做得更好。
# translation:  I did better. These choices made me do better.
# Row:  474 , translating:  但我感觉更糟。
# translation:  But I feel worse.
# Row:  475 , translating:  为什么?我写了整本书来向自己解释。
# translation:  Why? I wrote a whole book to explain it to myself.
# Row:  476 , translating:  我的期望值很低,只有一种味道。
# translation:  My expectations are low, there is only one taste.
# Row:  477 , translating:  当它们有100种味道,该死的,其中一个应该是完美的。
# translation:  When they have 100 different flavors, one of them should be perfect.
# Row:  478 , translating:  我得到的很好,但并不完美。
# translation:  I got it good, but not perfect.
# Row:  479 , translating:  结果的满意度会降低, 即使效果好。
# translation:  Satisfaction will be reduced, even if it works well.
# Row:  480 , translating:  营销界没有人知道这个。
# translation:  Nobody in the marketing community knows this.
# Row:  481 , translating:  因为如果他们这么做了,你们可能不知道这是什么。
# translation:  因为如果他们这么做了,你可能不知道这是什么。
# Row:  482 , translating:  你永远不会感到惊讶, 因为你的期望,我的期待,已经过时了。
# translation:  You'll never be surprised, because your expectations, my expectations, are outdated.
# Row:  483 , translating:  我不能做得更好。我没有安定下来。
# translation:  I couldn't do better. I didn't settle down.
# Row:  484 , translating:  但安定并不总是一件坏事。
# translation:  But peace is not always a bad thing.
# Row:  485 , translating:  你能做什么?
# translation:  你能做什么?
# Row:  486 , translating:  很明显,这个问题的答案是“你”。
# translation:  很明显, the answer to this question is 'you'.
# Row:  487 , translating:  你可以做得更好。
# translation:  You can do better.
# Row:  488 , translating:  有上百种不同的牛仔裤,没有理由失败。
# translation:  There are hundreds of different jeans, no reason to fail.
# Row:  489 , translating:  临床抑郁症在上一代人中爆发了。
# translation:  Clinical depression erupted in the last generation.
# Row:  490 , translating:  总的来说,我们做得更好, 我们感觉更糟。
# translation:  总的来说, we do better, we feel worse.
# Row:  491 , translating:  让我提醒你们。
# translation:  让我提醒你们。
# Row:  492 , translating:  有些神奇的量。我不知道它是什么。
# translation:  There's some amazing amount. I don't know what it is.
# Row:  493 , translating:  我非常有信心,我们早就通过 选择来改善我们的福利。
# translation:  I am very confident that we have long been able to improve our well-being by choosing.
# Row:  494 , translating:  问题是他们太少了。
# translation:  问题是, they're too few.
# Row:  495 , translating:  我所谈论的是 现代的,富裕的,西方社会的特殊问题。
# translation:  I'm talking about the special problems of modern, affluent, Western societies.
# Row:  496 , translating:  我要告诉你们的是,这些昂贵而复杂的选择-- 不仅仅是它们无济于事。
# translation:  我要告诉你们的是,这些昂贵而又复杂的选择--不仅仅是它们无济于事。
# Row:  497 , translating:  他们真的很伤人。
# translation:  They're really hurtful.
# Row:  498 , translating:  实际上,他们让我们更糟。
# translation:  实际上, they make us worse.
# Row:  499 , translating:  你知道,在这个鱼碗里什么都不可能。”
# translation:  你知道, nothing is possible in this fish bowl."
# Row:  500 , translating:  贫穷的想象力,我最初读的方式。
# translation:  Poor imagination, the way I first read it.
# Row:  501 , translating:  然而,我越是想到 这条鱼就知道些什么。
# translation:  However, the more I think about this fish, the more I know what it is.
# Row:  502 , translating:  如果你打破了这个鱼碗,所有事情都有可能发生, 你就会降低满意度。
# translation:  If you break the fish bowl, all things will happen, and you'll be less satisfied.
# Row:  503 , translating:  会增加麻痹,降低满意度。
# translation:  It increases paralysis and decreases satisfaction.
# Row:  504 , translating:  每个人都需要一碗鱼。
# translation:  每个人都需要 a bowl of fish.
# Row:  505 , translating:  这几乎肯定是太有限了-- 甚至鱼,对我们来说也是。
# translation:  It's almost certainly too limited-- even fish, for us.
# Row:  506 , translating:  但是缺乏一些隐喻的鱼碗 是痛苦的秘诀,我怀疑,灾难。
# translation:  But the lack of metaphoric fish bowls is a recipe for pain, I suspect, disaster.
# Row:  507 , translating:  非常感谢。
# translation:  非常感谢。

# %%
def process_string(text):
    return replace_punctuation_with_en(text)

'''def remove_spaces(text):
    return ''.join(text.split())'''

# Replacing en punctuation with the zh counterparts
def replace_punctuation_with_en(text):
    # Define a mapping of English punctuation to Chinese punctuation
    punctuation_mapping = {
        '，': ',',
        '。': '.',
        '？': '?',
        '！': '!',
        '：': ':',
        '；': ';',
        '”': '"',
        '’': "'",
        '（': '(',
        '）': ')',
        '【': '[',
        '】': ']',
        '｛': '{',
        '｝': '}'
    }

    # Replace each English punctuation with its Chinese counterpart
    for chi_punc, eng_punc in punctuation_mapping.items():
        text = text.replace(chi_punc, eng_punc)

    return text

processed_predictions_forward_2way = [process_string(sent) for sent in predictions]
processed_references_forward_2way = [process_string(sent[0]) for sent in references]

df = pd.DataFrame({'Prediction': processed_predictions_forward_2way, 'Reference': processed_references_forward_2way})
df.to_csv(f'zh_to_en_t5_{model_name}_bidirectional_translations_en.csv', index=False)

processed_references_forward_2way = [[reference] for reference in processed_references_forward_2way]

bleu_score_no_smoothing = sacrebleu.corpus_bleu(processed_predictions_forward_2way, processed_references_forward_2way)
bleu_score_add_1 = sacrebleu.corpus_bleu(processed_predictions_forward_2way, processed_references_forward_2way, smooth_method="add-k", smooth_value=1)

print(f"BLEU Score without smoothing: BLEU = {bleu_score_no_smoothing}")
print(f"BLEU Score with smoothing: BLEU = {bleu_score_add_1}")
# Out:
# BLEU Score without smoothing: BLEU = BLEU = 63.36 89.5/77.8/52.9/43.8 (BP = 1.000 ratio = 1.000 hyp_len = 19 ref_len = 19)
# BLEU Score with smoothing: BLEU = BLEU = 65.55 89.5/78.9/55.6/47.1 (BP = 1.000 ratio = 1.000 hyp_len = 19 ref_len = 19)
